# %% [markdown]
# #### Imports & Downloads

# %%
# !pip install emoji
# !pip install pyspellchecker
# !pip install textblob
# Out:
# Requirement already satisfied: emoji in c:\users\nasiba\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.14.0)
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: C:\Users\Nasiba\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Requirement already satisfied: pyspellchecker in c:\users\nasiba\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.8.1)
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: C:\Users\Nasiba\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: C:\Users\Nasiba\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Requirement already satisfied: textblob in c:\users\nasiba\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.18.0.post0)
# Requirement already satisfied: nltk>=3.8 in c:\users\nasiba\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from textblob) (3.9.1)
# Requirement already satisfied: click in c:\users\nasiba\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from nltk>=3.8->textblob) (8.1.7)
# Requirement already satisfied: joblib in c:\users\nasiba\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from nltk>=3.8->textblob) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\nasiba\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from nltk>=3.8->textblob) (2024.9.11)
# Requirement already satisfied: tqdm in c:\users\nasiba\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from nltk>=3.8->textblob) (4.66.5)
# Requirement already satisfied: colorama in c:\users\nasiba\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from click->nltk>=3.8->textblob) (0.4.6)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
from textblob import TextBlob
import nltk
import re
import string
import emoji
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

from collections import Counter
from spellchecker import SpellChecker

from sklearn.feature_extraction.text import CountVectorizer
from nltk.tokenize import RegexpTokenizer
from sklearn.model_selection import train_test_split

from sklearn.naive_bayes import BernoulliNB, MultinomialNB, ComplementNB
from sklearn.metrics import classification_report, confusion_matrix
from sklearn import metrics
from sklearn.metrics import precision_score, recall_score, f1_score
import os
from wordcloud import WordCloud
from nltk.stem.porter import PorterStemmer
from textblob import Word, TextBlob
pd.set_option('display.max_colwidth', None)

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Nasiba\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Nasiba\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Nasiba\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Nasiba\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %% [markdown]
# ### Beladung der Daten

# %%
current_dir = os.getcwd()
csv_path  = os.path.abspath(os.path.join(current_dir, '../../../data/twitter_hate-speech/train.csv'))
df_origin = pd.read_csv(csv_path, encoding='utf-8')

df_origin.head()
# Out:
#    id  label  \
# 0   1      0
# 1   2      0
# 2   3      0
# 3   4      0
# 4   5      0
#
#                                                                                                                         tweet
# 0                       @user when a father is dysfunctional and is so selfish he drags his kids into his dysfunction.   #run
# 1  @user @user thanks for #lyft credit i can't use cause they don't offer wheelchair vans in pdx.    #disapointed #getthanked
# 2                                                                                                         bihday your majesty
# 3                                      #model   i love u take with u all the time in urð±!!! ðððð
# ð¦ð¦ð¦
# 4                                                                                      factsguide: society now    #motivation

# %% [markdown]
# ## 1. Datenexploration

# %% [markdown]
# ### 1.1 Datenqualitätsüberprüfung generell

# %%
# Check for null values
df_origin.info()

# no null's
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31962 entries, 0 to 31961
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      31962 non-null  int64
#  1   label   31962 non-null  int64
#  2   tweet   31962 non-null  object
# dtypes: int64(2), object(1)
# memory usage: 749.2+ KB

# %%
# check for duplicates
print(df_origin.duplicated().sum())

# no duplicates
# Out:
# 0

# %% [markdown]
# ### 1.2 Text Qualität Checks

# %% [markdown]
# ##### 1.2.1 Überprüfung von stopwords

# %%
# which words are actually stop words?
stop_words = set(stopwords.words('english'))

stop_words_list = list(stop_words)
print(stop_words_list)
# Out:
# ['those', 'wouldn', 'you', "it's", 'hasn', 'needn', 'doesn', 'y', 'his', 'mightn', 'some', 'o', "haven't", "weren't", 'who', 'mustn', 'been', 'no', 'be', 'doing', 'are', 'herself', 'by', 'had', 'theirs', 'here', 'can', 'after', 'from', 'my', 'where', "doesn't", 're', 'why', 'down', 'through', 'other', 'am', 'off', 'their', 'both', "you've", 'until', 'on', 'our', "needn't", 'it', 'hers', 'again', "you'd", 'such', 'does', 'a', 'as', "isn't", "should've", 'into', 'and', 'for', 'between', 'm', 'don', 'so', 'the', 'to', 'yourself', 'me', 'now', "shouldn't", 'weren', 'with', 'above', 'or', "don't", "aren't", 'was', 'he', 'just', 'couldn', 'aren', 'up', 'more', 'of', 'over', 'very', 'than', 'against', 'all', 'then', 'that', 'did', 'ourselves', 'before', 'should', 't', 'we', "she's", 'wasn', 'but', 'what', 'if', "won't", 'ours', 'in', 'himself', "that'll", 'an', 'ain', 'too', 'ma', 'will', 'when', 'isn', 'there', "hadn't", 'under', 'at', 'further', 'own', 'have', "didn't", 'about', "mustn't", 'shan', "shan't", 'same', 'her', "couldn't", 'its', 'shouldn', 'hadn', 'not', 'd', 'll', 'itself', "wouldn't", 'is', 'only', 'has', 'were', 'each', 've', 'how', 'your', 'him', 'most', 'didn', 'being', 'few', 'once', "you'll", 'because', 'won', 'yours', 'having', "mightn't", 'any', 'i', 'nor', 's', 'below', "hasn't", "wasn't", 'whom', "you're", 'these', 'them', 'do', 'myself', 'yourselves', 'this', 'she', 'haven', 'themselves', 'which', 'during', 'while', 'they', 'out']

# %%
# find stop words in tweet column
def find_stop_words(df):
    df['stopwords'] = df['tweet'].apply(lambda x: len([x for x in x.split() if x in stop_words]))
    return df
df_raw= find_stop_words(df_origin)
df_raw[df_raw['stopwords'].notna()].head()
# Out:
#    id  label  \
# 0   1      0
# 1   2      0
# 2   3      0
# 3   4      0
# 4   5      0
#
#                                                                                                                         tweet  \
# 0                       @user when a father is dysfunctional and is so selfish he drags his kids into his dysfunction.   #run
# 1  @user @user thanks for #lyft credit i can't use cause they don't offer wheelchair vans in pdx.    #disapointed #getthanked
# 2                                                                                                         bihday your majesty
# 3                                      #model   i love u take with u all the time in urð±!!! ðððð
# ð¦ð¦ð¦
# 4                                                                                      factsguide: society now    #motivation
#
#    stopwords
# 0         10
# 1          5
# 2          1
# 3          5
# 4          1

# %% [markdown]
# ##### 1.2.2 Überprüfung von HTML tags/ special characters

# %%
def find_hash_tags(df):
    df['hashtags'] = df['tweet'].apply(lambda x: len([x for x in x.split() if x.startswith('#')]))
    return df
    
df_raw=find_hash_tags(df_raw)
df_raw[df_raw['hashtags']>0].head()
# Out:
#    id  label  \
# 0   1      0
# 1   2      0
# 3   4      0
# 4   5      0
# 5   6      0
#
#                                                                                                                         tweet  \
# 0                       @user when a father is dysfunctional and is so selfish he drags his kids into his dysfunction.   #run
# 1  @user @user thanks for #lyft credit i can't use cause they don't offer wheelchair vans in pdx.    #disapointed #getthanked
# 3                                      #model   i love u take with u all the time in urð±!!! ðððð
# ð¦ð¦ð¦
# 4                                                                                      factsguide: society now    #motivation
# 5        [2/2] huge fan fare and big talking before they leave. chaos and pay disputes when they get there. #allshowandnogo
#
#    stopwords  hashtags
# 0         10         1
# 1          5         3
# 3          5         1
# 4          1         1
# 5          6         1

# %% [markdown]
# ##### 1.2.3 Überprüfung von Wörtern mit Großbuchstaben

# %%
def find_num_uppercase(df):
    df['upper_case'] = df['tweet'].apply(lambda x: len([x for x in x.split() if x.isupper()]))
    return df

df_raw=find_num_uppercase(df_raw)
df_raw[df_raw['upper_case']>0].head()
# Out:
#         id  label  \
# 160    161      0
# 554    555      0
# 1108  1109      1
# 1714  1715      0
# 2501  2502      0
#
#                                                                                                                                         tweet  \
# 160                                                                                               new selfie \Â¤.Â¤/  #guy   #mato #chapones
# 554   come on #ee piss poor reception today Â£20 a month and struggle to get a signal in #buxton put more masts up or i'm switching   #grumpy
# 1108                 @user all happy for Ã¨ #lbgt family,but what i don't get is the incessant but thin veiled  against other gay minorities?
# 1714   over a year after leaving @user i received a demand for Â£12. should have told me when i left! #paidnow #fuckoffnevercomingbacktosky
# 2501                    #bahrain   #youth #protesters #clash with #riot #police and  #armoured #vehicles #Ø§ÙØ¨Ø­Ø±ÙÙ #Ø§ÙÙÙÙØ¯Ø±Ø§Øª
#
#       stopwords  hashtags  upper_case
# 160           0         3           1
# 554           9         3           1
# 1108         10         1           1
# 1714         11         2           1
# 2501          2        10           1

# %% [markdown]
# ##### 1.2.4 Überprüfung von HTML Tags im Text

# %%
def identify_html_tags(text):
    pattern = re.compile('<.*?>')
    tags = pattern.findall(text)
    tag_count = len(tags)
    return tag_count    

df_raw['html_tag_count'] = df_raw['tweet'].apply(identify_html_tags)
df_raw[df_raw['html_tag_count']>0]

# Conclusion: no html tags
# Out:
# Empty DataFrame
# Columns: [id, label, tweet, stopwords, hashtags, upper_case, html_tag_count]
# Index: []

# %% [markdown]
# ##### 1.2.5 Überprüfung von URL's im Text

# %%
def identify_urls(text):
    pattern = re.compile(r'https?://\S+|www\.\S+')
    urls = pattern.findall(text)
    tag_count = len(urls)
    return tag_count    

df_raw['url_count'] = df_raw['tweet'].apply(identify_urls)
df_raw[df_raw['url_count']>0]
# Out:
#           id  label  \
# 1111    1112      0
# 6375    6376      0
# 8084    8085      0
# 8484    8485      0
# 8660    8661      0
# 25745  25746      0
#
#                                                                                                                                          tweet  \
# 1111                                               #fly   #and #better #with #us #buranus  #www.flybcc.com #call #7/24  #airbroker #flightâ¦
# 6375                                                                             #isitthursdayyet? it's not? awwww... #criticalrole   #critter
# 8084                                                                                    couple having sex www.drunk singapore girl get fuck
# 8484   so glad my #workout includes smoke breaks...www.smokeweedeatbacon.com #weed #bacon #fitness #sex #health #marijuana   #strength #living
# 8660                                           @user just run 10kms for @user @user   #loveisall  pour donner: www.alvarum/heloiseetlespremas
# 25745                 @user  sirrr getting new one wowwww...  to see this plss take care of urself...love youððâ¤ï¸â¤ï¸â¤ï¸â¤ï¸
#
#        stopwords  hashtags  upper_case  html_tag_count  url_count
# 1111           0        11           0               0          1
# 6375           1         3           0               0          1
# 8084           1         0           0               0          1
# 8484           2         9           0               0          1
# 8660           2         1           0               0          1
# 25745          3         0           0               0          1

# %% [markdown]
# ##### 1.2.6 Überprüfung von oft auftretenden Wörter im Text

# %%
freq_words = pd.Series(' '.join(df_raw['tweet']).split()).value_counts()[:10]

words = freq_words.index
counts = freq_words.values
plt.figure(figsize=(8, 2)) 
plt.bar(words, counts, color='skyblue') 

plt.xticks(rotation=20)
plt.tight_layout()  
plt.show()

# %% [markdown]
# ##### 1.2.7 Überprüfung von shortcuts/slangs im Text

# %%
shortcuts = {
    'ROFL': 'Rolling On The Floor Laughing',
    'STFU': 'Shut the f*** up',
    'ICYMI': 'In case you missed it',
    'TL;DR': 'Too long, didn’t read',
    'TMI': 'Too much information',
    'AFAIK': 'As Far As I Know',
    'LMK': 'Let me know',
    'NVM': 'Nevermind',
    'FTW': 'For the win',
    'BYOB': 'Bring your own beer',
    'BOGO': 'Buy one get one',
    'JK': 'Just kidding',
    'JW': 'Just wondering',
    'TGIF': 'Thank goodness it’s Friday',
    'TBH': 'To be honest',
    'TBF': 'To be frank',
    'RN': 'Right now',
    'FUBAR': 'F***** up beyond all recognition',
    'BRB': 'Be Right Back',
    'ISO': 'In search of',
    'BRT': 'Be Right There',
    'BTW': 'By The Way',
    'FTFY': 'Fixed that for you',
    'GG': 'Good Game',
    'BFD': 'Big freaking deal',
    'IRL': 'In Real Life',
    'DAE': 'Does anyone else?',
    'LOL': 'Laughing Out Loud',
    'SMH': 'Shaking My Head',
    'NGL': 'Not gonna lie',
    'BTS': 'Behind the scenes',
    'IKR': 'I Know Right',
    'TTYL': 'Talk to you later',
    'HMU': 'Hit me up',
    'FWIW': 'For what it’s worth',
    'IMO': 'In my opinion',
    'WYD': 'What are you doing?',
    'IMHO': 'In my humble opinion',
    'IDK': 'I Don’t Know',
    'IDC': 'I Don’t Care',
    'IDGAF': 'I don’t give a f***',
    'NBD': 'No big deal',
    'TBA': 'To be announced',
    'TBD': 'To be decided',
    'AFK': 'Away From Keyboard',
    'ABT': 'About',
    'IYKYK': 'If You Know You Know',
    'B4': 'Before',
    'BC': 'Because',
    'JIC': 'Just In Case',
    'FOMO': 'Fear Of Missing Out',
    'SNAFU': 'Situation Normal, All F***** Up',
    'GTG/G2G': 'Got To Go',
    'H8': 'Hate',
    'LMAO': 'Laughing My A** Off',
    'IYKWIM': 'If You Know What I Mean',
    'MYOB': 'Mind Your Own Business',
    'POV': 'Point Of View',
    'TLC': 'Tender Loving Care',
    'HBD': 'Happy Birthday',
    'W/E': 'Whatever',
    'WTF': 'What The F***',
    'WYSIWYG': 'What You See Is What You Get',
    'FWIF': 'For What It’s Worth',
    'TW': 'Trigger Warning',
    'EOD': 'End Of Day',
    'FAQ': 'Frequently Asked Question',
    'AKA': 'Also Known As',
    'ASAP': 'As Soon As Possible',
    'DIY': 'Do It Yourself',
    'LMGTFY': 'Let Me Google That For You',
    'NP': 'No Problem',
    'N/A': 'Not Applicable Or Not Available',
    'OOO': 'Out Of Office',
    'TIA': 'Thanks In Advance',
    'COB': 'Close Of Business',
    'FYI': 'For Your Information',
    'NSFW': 'Not Safe For Work',
    'WFH': 'Work From Home',
    'OMW': 'On My Way',
    'WDYT': 'What Do You Think?',
    'WYGAM': 'When You Get A Minute',
    'SMP': 'Social Media Platform',
    'DM': 'Direct Message',
    'FB': 'Facebook',
    'IG': 'Instagram',
    'LI': 'LinkedIn',
    'YT': 'YouTube',
    'SC': 'Snapchat',
    'BR': 'BeReal',
    'X': 'Previously Named Twitter',
    'WA': 'WhatsApp',
    'TT': 'TikTok',
    'FF': 'Follow Friday',
    'IM': 'Instant Message',
    'PM': 'Private Message',
    'OP': 'Original Post',
    'QOTD': 'Quote Of The Day',
    'OOTD': 'Outfit Of The Day',
    'RT': 'Retweet',
    'TBT': 'Throwback Thursday',
    'TIL': 'Today I Learned',
    'AMA': 'Ask Me Anything',
    'ELI5': 'Explain Like I’m 5',
    'FBF': 'Flashback Friday',
    'MFW': 'My Feeling When',
    'HMU': 'Hit Me Up',
    'GRWM': 'Get Ready With Me',
    'ILY': 'I Love You',
    'MCM': 'Man Crush Monday',
    'WCW': 'Woman Crush Wednesday',
    'BF': 'Boyfriend',
    'GF': 'Girlfriend',
    'LYSM': 'Love You So Much',
    'PDA': 'Public Display Of Affection',
    'LTR': 'Longterm Relationship',
    'DTR': 'Define The Relationship',
    'LDR': 'Long Distance Relationship',
    'XOXO': 'Hugs And Kisses',
    'OTP': 'One True Pairing',
    'LOML': 'Love Of My Life',
    'ATK': 'At The Keyboard',
    'ATM': 'At The Moment',
    'A3': 'Anytime, Anywhere, Anyplace',
    'BAK': 'Back At Keyboard',
    'BBL': 'Be Back Later',
    'BBS': 'Be Back Soon',
    'BFN': 'Bye For Now',
    'B4N': 'Bye For Now',
    'CU': 'See You',
    'CUL8R': 'See You Later',
    'CYA': 'See You',
    'FC': 'Fingers Crossed',
    'GAL': 'Get A Life',
    'GN': 'Good Night',
    'GMTA': 'Great Minds Think Alike',
    'GR8': 'Great!',
    'G9': 'Genius',
    'IC': 'I See',
    'ICQ': 'I Seek You (Also A Chat Program)',
    'ILU': 'I Love You',
    'IOW': 'In Other Words',
    'KISS': 'Keep It Simple, Stupid',
    'LTNS': 'Long Time No See',
    'L8R': 'Later',
    'MTE': 'My Thoughts Exactly',
    'M8': 'Mate',
    'NRN': 'No Reply Necessary',
    'OIC': 'Oh I See',
    'PITA': 'Pain In The A..',
    'PRT': 'Party',
    'PRW': 'Parents Are Watching',
    'QPSA?': 'Que Pasa?',
    'ROFLOL': 'Rolling On The Floor Laughing Out Loud',
    'ROTFLMAO': 'Rolling On The Floor Laughing My A** Off',
    'SK8': 'Skate',
    'STATS': 'Your Sex And Age',
    'ASL': 'Age, Sex, Location',
    'THX': 'Thank You',
    'TTFN': 'Ta-Ta For Now!',
    'U': 'You',
    'U2': 'You Too',
    'U4E': 'Yours For Ever',
    'WB': 'Welcome Back',
    'WTF': 'What The F***',
    'WTG': 'Way To Go!',
    'WUF': 'Where Are You From?',
    'W8': 'Wait...',
    '7K': 'Sick:-D Laugher',
    'TFW': 'That Feeling When',
    'MFW': 'My Face When',
    'MRW': 'My Reaction When',
    'IFYP': 'I Feel Your Pain',
    'TNTL': 'Trying Not To Laugh',
    'IMU': 'I Miss You',
    'ADIH': 'Another Day In Hell',
    'ZZZ': 'Sleeping, Bored, Tired',
    'WYWH': 'Wish You Were Here',
    'FIMH': 'Forever In My Heart',
    'BSAAW': 'Big Smile And A Wink',
    'BWL': 'Bursting With Laughter',
    'BFF': 'Best Friends Forever',
    'CSL': "Can't Stop Laughing",
    'OMG':"Oh my Good",
    "isn't": "is not",
    "he's": "he is",
    "wasn't": "was not",
    "there's": "there is",
    "couldn't": "could not",
    "won't": "will not",
    "they're": "they are",
    "she's": "she is",
    "There's": "there is",
    "wouldn't": "would not",
    "haven't": "have not",
    "That's": "That is",
    "you've": "you have",
    "He's": "He is",
    "what's": "what is",
    "weren't": "were not",
    "we're": "we are",
    "hasn't": "has not",
    "you'd": "you would",
    "shouldn't": "should not",
    "let's": "let us",
    "they've": "they have",
    "You'll": "You will",
    "i'm": "I am",
    "i´m": "I am",
    "we've": "we have",
    "it's": "it is",
    "don't": "do not",
    "that´s": "that is",
    "I´m": "I am",
    "it’s": "it is",
    "she´s": "she is",
    "he’s'": "he is",
    "I’m": "I am",
    "I’d": "I did",
    "he’s'": "he is",
    "there’s": "there is",
    "can't": "can not"
    }

# %%
def expand_shortcuts(text):
    new_text = []
    for w in text.split():
        if w.upper() in shortcuts:
            new_text.append(shortcuts[w.upper()])
            return new_text
        else:
            None

df_raw['expanded_shortcut'] = df_raw['tweet'].apply(expand_shortcuts)
df_result = df_raw[df_raw['expanded_shortcut'].notna()]
df_result = df_result[['tweet', 'expanded_shortcut']]
df_result
# Out:
#                                                                                                                                 tweet  \
# 3                                              #model   i love u take with u all the time in urð±!!! ðððð
# ð¦ð¦ð¦
# 18                                                     its #friday! ð smiles all around via ig user: @user #cookies make people
# 46                                             #model   i love u take with u all the time in urð±!!! ðððð
# ð¦ð¦ð¦
# 47                                                                                     #whenever im   and #something goes #wrong  |
# 96                                             #model   i love u take with u all the time in urð±!!! ðððð
# ð¦ð¦ð¦
# ...                                                                                                                               ...
# 31631                          fake fb accounts =&gt;  seems it's common, but how nasty to accuse people without proof !! #paranoia
# 31672                                                  @user idk why women think they can have a mans hea when his hea is elsewhere
# 31785  @user doesn't care abt u. let's be honest. he cares about himself &amp; his money!! all of you are getting played.   #neverump
# 31904                                          #model   i love u take with u all the time in urð±!!! ðððð
# ð¦ð¦ð¦
# 31923  #hea is the easiest thing which can be #fooled,  i am  , i am #sad and it just takes a thought to be anywhere in btw them ð
#
#        expanded_shortcut
# 3                  [You]
# 18           [Instagram]
# 46                 [You]
# 47     [Instant Message]
# 96                 [You]
# ...                  ...
# 31631         [Facebook]
# 31672     [I Don’t Know]
# 31785            [About]
# 31904              [You]
# 31923       [By The Way]
#
# [1462 rows x 2 columns]

# %% [markdown]
# ##### 1.2.7 Überprüfung von emojis im Text

# %%
def fix_mojibake(text):
    try:

        return text.encode('latin1').decode('utf-8')
    except (UnicodeEncodeError, UnicodeDecodeError):
        return text


df_raw['tweet'] = df_raw['tweet'].apply(fix_mojibake)
df_raw.head(3)
# Out:
#    id  label  \
# 0   1      0
# 1   2      0
# 2   3      0
#
#                                                                                                                         tweet  \
# 0                       @user when a father is dysfunctional and is so selfish he drags his kids into his dysfunction.   #run
# 1  @user @user thanks for #lyft credit i can't use cause they don't offer wheelchair vans in pdx.    #disapointed #getthanked
# 2                                                                                                         bihday your majesty
#
#    stopwords  hashtags  upper_case  html_tag_count  url_count  \
# 0         10         1           0               0          0
# 1          5         3           0               0          0
# 2          1         0           0               0          0
#
#   expanded_shortcut
# 0              None
# 1              None
# 2              None

# %% [markdown]
# ##### 1.2.8 Überprüfung von falsch geschriebenen Wörtern im Text

# %%
spell = SpellChecker()
def identify_misspelled_words(text):
    words = text.split()

    misspelled = [
        word for word in words 
        if not any(emoji.is_emoji(char) for char in word)  # Ignoriere Emojis
        and not word.startswith('@')  # Ignoriere Wörter, die mit @ beginnen
        and not word.startswith('#')  # Ignoriere Wörter, die mit # beginnen
        and word in spell.unknown([word])  # Führe Rechtschreibprüfung auf verbleibende Wörter durch
        and not word.endswith('!')
        and not word.endswith(']')
        and not word.startswith('[')
    ]
    return misspelled

df_raw['misspelled_words'] = df_raw['tweet'].apply(identify_misspelled_words)
df_raw[['tweet', 'misspelled_words']]
# Out:
#                                                                                                                                      tweet  \
# 0                                    @user when a father is dysfunctional and is so selfish he drags his kids into his dysfunction.   #run
# 1               @user @user thanks for #lyft credit i can't use cause they don't offer wheelchair vans in pdx.    #disapointed #getthanked
# 2                                                                                                                      bihday your majesty
# 3                                                                           #model   i love u take with u all the time in ur📱!!! 😙😎👄👅💦💦💦
# 4                                                                                                   factsguide: society now    #motivation
# ...                                                                                                                                    ...
# 31957                                                                                                ate @user isz that youuu?😍😍😍😍😍😍😍😍😍❤️
# 31958    to see nina turner on the airwaves trying to wrap herself in the mantle of a genuine hero like shirley chisolm. #shame #imwithher
# 31959                                                                      listening to sad songs on a monday morning otw to work is sad
# 31960                                                                  @user #sikh #temple vandalised in in #calgary, #wso condemns  act
# 31961                                                                                                     thank you @user for you follow
#
#                 misspelled_words
# 0                 [dysfunction.]
# 1                         [pdx.]
# 2                       [bihday]
# 3                             []
# 4                  [factsguide:]
# ...                          ...
# 31957                      [isz]
# 31958  [nina, shirley, chisolm.]
# 31959              [monday, otw]
# 31960               [vandalised]
# 31961                         []
#
# [31962 rows x 2 columns]

# %% [markdown]
# ##### 1.2.9 Überprüfung Anzahl der Wörtern in Tweets

# %%
df_raw['count_of_words'] = df_raw['tweet'].apply(lambda x : len(str(x).split(" ")))

sns.histplot(df_raw['count_of_words'])

plt.title('Word Count of all Tweets')

plt.xlabel('Word Count')
plt.ylabel('Number of Tweets')
plt.figure(figsize=(4, 2)) 
plt.show()

# %% [markdown]
# ## 2. Daten Vorbereitung

# %% [markdown]
# ### 2.1 Datenbereinigung

# %% [markdown]
# ##### 2.1.1 Entfernung von special characters, @user

# %%
def remove_special_characters(df):
    pattern = re.compile(r'<.*?>|@\w+|[\/§&]')
    
    df['tweet'] = df['tweet'].apply(lambda x: pattern.sub('', x))
    
    return df
df_cleaned=remove_special_characters(df_raw)
df_cleaned.head(2)
# Out:
#    id  label  \
# 0   1      0
# 1   2      0
#
#                                                                                                               tweet  \
# 0                   when a father is dysfunctional and is so selfish he drags his kids into his dysfunction.   #run
# 1    thanks for #lyft credit i can't use cause they don't offer wheelchair vans in pdx.    #disapointed #getthanked
#
#    stopwords  hashtags  upper_case  html_tag_count  url_count  \
# 0         10         1           0               0          0
# 1          5         3           0               0          0
#
#   expanded_shortcut misspelled_words  count_of_words
# 0              None   [dysfunction.]              21
# 1              None           [pdx.]              22

# %% [markdown]
# ##### 2.1.2 Entfernung von URL's im Text

# %%
def remove_url_from_tweet(df):
    pattern=re.compile(r'https?://\S+|www\.\S+')
    df['tweet']=df['tweet'].apply(lambda x: pattern.sub('', x))
    return df  
df_cleaned=remove_url_from_tweet(df_cleaned)
df_cleaned.head(1)
# Out:
#    id  label  \
# 0   1      0
#
#                                                                                                tweet  \
# 0    when a father is dysfunctional and is so selfish he drags his kids into his dysfunction.   #run
#
#    stopwords  hashtags  upper_case  html_tag_count  url_count  \
# 0         10         1           0               0          0
#
#   expanded_shortcut misspelled_words  count_of_words
# 0              None   [dysfunction.]              21

# %% [markdown]
# ##### 2.1.3 Entfernung von Punkten, Kommas

# %%
def remove_punctuation(df):
    pattern = re.compile(r'[.:,\[\]/%&§{}]')
    df['tweet'] = df['tweet'].apply(lambda x: pattern.sub('', x))
    return df
df_cleaned=remove_punctuation(df_cleaned)
df_cleaned.head(1)
# Out:
#    id  label  \
# 0   1      0
#
#                                                                                               tweet  \
# 0    when a father is dysfunctional and is so selfish he drags his kids into his dysfunction   #run
#
#    stopwords  hashtags  upper_case  html_tag_count  url_count  \
# 0         10         1           0               0          0
#
#   expanded_shortcut misspelled_words  count_of_words
# 0              None   [dysfunction.]              21

# %% [markdown]
# ##### 2.1.4 Entfernung von Nummern:

# %%
def remove_digis(df):
    pattern = re.compile(r'\d')
    df['tweet'] = df['tweet'].apply(lambda x: pattern.sub('', x))
    return df
df_cleaned=remove_digis(df_cleaned)
df_cleaned.head(1)
# Out:
#    id  label  \
# 0   1      0
#
#                                                                                               tweet  \
# 0    when a father is dysfunctional and is so selfish he drags his kids into his dysfunction   #run
#
#    stopwords  hashtags  upper_case  html_tag_count  url_count  \
# 0         10         1           0               0          0
#
#   expanded_shortcut misspelled_words  count_of_words
# 0              None   [dysfunction.]              21

# %% [markdown]
# ##### 2.1.5 Extraktion/Korrektur von shortcuts/slangs im Text

# %%
def expand_shortcuts_result(text):
    new_text = []
    for w in text.split():
        
        if w.upper() in shortcuts:
            new_text.append(shortcuts[w.upper()])  # Ersetzen, wenn es ein Shortcut ist
        if w in shortcuts:
            new_text.append(shortcuts[w])
        else:
            new_text.append(w)  # sonst original beibehalten
    
    return ' '.join(new_text)

df_cleaned['tweet'] = df_cleaned['tweet'].apply(expand_shortcuts_result)
result=df_cleaned[df_cleaned['expanded_shortcut'].notna()].head(2)
result
# Out:
#     id  label  \
# 3    4      0
# 18  19      0
#
#                                                                           tweet  \
# 3            #model i love You u take with You u all the time in ur📱!!! 😙😎👄👅💦💦💦
# 18  its #friday! 😀 smiles all around via Instagram ig user #cookies make people
#
#     stopwords  hashtags  upper_case  html_tag_count  url_count  \
# 3           5         1           0               0          0
# 18          2         2           0               0          0
#
#    expanded_shortcut misspelled_words  count_of_words
# 3              [You]               []              17
# 18       [Instagram]      [ig, user:]              16

# %% [markdown]
# ##### 2.1.6 Entfernung von Stopwords

# %%
stop_words = set(stopwords.words('english'))
def remove_stop_words(df):
  
    df['tweet'] = df['tweet'].apply(lambda x: " ".join(w for w in x.split() if w.lower() not in stop_words))
    return df

clenead_df = remove_stop_words(df_cleaned)
clenead_df.head(5)
# Out:
#    id  label  \
# 0   1      0
# 1   2      0
# 2   3      0
# 3   4      0
# 4   5      0
#
#                                                                               tweet  \
# 0                          father dysfunctional selfish drags kids dysfunction #run
# 1  thanks #lyft credit use cause offer wheelchair vans pdx #disapointed #getthanked
# 2                                                                    bihday majesty
# 3                                          #model love u take u time ur📱!!! 😙😎👄👅💦💦💦
# 4                                                    factsguide society #motivation
#
#    stopwords  hashtags  upper_case  html_tag_count  url_count  \
# 0         10         1           0               0          0
# 1          5         3           0               0          0
# 2          1         0           0               0          0
# 3          5         1           0               0          0
# 4          1         1           0               0          0
#
#   expanded_shortcut misspelled_words  count_of_words
# 0              None   [dysfunction.]              21
# 1              None           [pdx.]              22
# 2              None         [bihday]               5
# 3             [You]               []              17
# 4              None    [factsguide:]               8

# %% [markdown]
# ##### 2.1.6  Korrektur von Großbuchstaben in Wörtern

# %%
def to_lowercase_if_string(text):
    if isinstance(text, str):  
        return text.lower()     
    return text                

df_cleaned['tweet'] = df_cleaned['tweet'].fillna('').apply(to_lowercase_if_string)
result = df_cleaned[df_cleaned['upper_case'] > 0].head(2)
result
# Out:
#       id  label  \
# 160  161      0
# 554  555      0
#
#                                                                                                   tweet  \
# 160                                                                 new selfie \¤¤ #guy #mato #chapones
# 554  come #ee piss poor reception today £ month struggle get signal #buxton put masts switching #grumpy
#
#      stopwords  hashtags  upper_case  html_tag_count  url_count  \
# 160          0         3           1               0          0
# 554          9         3           1               0          0
#
#     expanded_shortcut misspelled_words  count_of_words
# 160              None  [selfie, \¤.¤/]              10
# 554              None       [£20, i'm]              28

# %% [markdown]
# ##### 2.1.7  Korrektur von falsch geschriebenen Wörtern im Text

# %%
df_cleaned['tweet'] = df_cleaned['tweet'].str.replace('user', ' ', case=False)

def identify_misspelled_words(text):
    words = text.split()

    misspelled = [
        word for word in words 
        if not any(emoji.is_emoji(char) for char in word)  # Ignoriere Emojis
        and not word.startswith('@')  # Ignoriere Wörter, die mit @ beginnen
        and not word.startswith('#')  # Ignoriere Wörter, die mit # beginnen
        and not word.endswith('!')
        and not word.startswith("'")
        and not word.endswith("'")
        and word in spell.unknown([word]) 
    ]
    
    if len(misspelled)==0:
        return None 
    else:
        return misspelled

df_cleaned['misspelled_words_new'] = df_cleaned['tweet'].apply(identify_misspelled_words)

df_cleaned.head(5)
# Out:
#    id  label  \
# 0   1      0
# 1   2      0
# 2   3      0
# 3   4      0
# 4   5      0
#
#                                                                               tweet  \
# 0                          father dysfunctional selfish drags kids dysfunction #run
# 1  thanks #lyft credit use cause offer wheelchair vans pdx #disapointed #getthanked
# 2                                                                    bihday majesty
# 3                                          #model love u take u time ur📱!!! 😙😎👄👅💦💦💦
# 4                                                    factsguide society #motivation
#
#    stopwords  hashtags  upper_case  html_tag_count  url_count  \
# 0         10         1           0               0          0
# 1          5         3           0               0          0
# 2          1         0           0               0          0
# 3          5         1           0               0          0
# 4          1         1           0               0          0
#
#   expanded_shortcut misspelled_words  count_of_words misspelled_words_new
# 0              None   [dysfunction.]              21                 None
# 1              None           [pdx.]              22                [pdx]
# 2              None         [bihday]               5             [bihday]
# 3             [You]               []              17                 None
# 4              None    [factsguide:]               8         [factsguide]

# %%
# Dataframe in kleinere Subsets verteilen, damit die Funktion schneller ist

df_cleaned_1 = df_cleaned.iloc[0:2001]
df_cleaned_2 = df_cleaned.iloc[2001:4001]
df_cleaned_3 = df_cleaned.iloc[4001:6001]
df_cleaned_4 = df_cleaned.iloc[6001:8001]
df_cleaned_5 = df_cleaned.iloc[8001:10001]
# df_cleaned_7 = df_cleaned.iloc[10001:12001]
# df_cleaned_8 = df_cleaned.iloc[12001:14001]
# df_cleaned_9 = df_cleaned.iloc[6001:8001]
# df_cleaned_10 = df_cleaned.iloc[6001:8001]
# df_cleaned_11 = df_cleaned.iloc[6001:8001]
# df_cleaned_12 = df_cleaned.iloc[6001:8001]
# df_cleaned_13 = df_cleaned.iloc[6001:8001]
# df_cleaned_14 = df_cleaned.iloc[6001:8001]
# df_cleaned_15 = df_cleaned.iloc[6001:8001]
df_cleaned_1.head(5)
# Out:
#    id  label  \
# 0   1      0
# 1   2      0
# 2   3      0
# 3   4      0
# 4   5      0
#
#                                                                               tweet  \
# 0                          father dysfunctional selfish drags kids dysfunction #run
# 1  thanks #lyft credit use cause offer wheelchair vans pdx #disapointed #getthanked
# 2                                                                    bihday majesty
# 3                                          #model love u take u time ur📱!!! 😙😎👄👅💦💦💦
# 4                                                    factsguide society #motivation
#
#    stopwords  hashtags  upper_case  html_tag_count  url_count  \
# 0         10         1           0               0          0
# 1          5         3           0               0          0
# 2          1         0           0               0          0
# 3          5         1           0               0          0
# 4          1         1           0               0          0
#
#   expanded_shortcut misspelled_words  count_of_words misspelled_words_new
# 0              None   [dysfunction.]              21                 None
# 1              None           [pdx.]              22                [pdx]
# 2              None         [bihday]               5             [bihday]
# 3             [You]               []              17                 None
# 4              None    [factsguide:]               8         [factsguide]

# %%
def correct_misspelled_words(text):
    
    def is_emoji(s):
        return emoji.is_emoji(s)

    words = text.split()
    corrected_text = []
    
    for word in words:
       
        if is_emoji(word) or word.startswith('@') or word.startswith('#') or word.endswith('!') or word.startswith("'") or word.endswith("'"):
            corrected_text.append(word)
        else:
            
            text_blob = TextBlob(word)
            corrected_text.append(str(text_blob.correct()))  # Korrigierter Text
    
    return ' '.join(corrected_text)

# %%
df_cleaned_1['cleaned_tweet'] = df_cleaned_1['tweet'].apply(correct_misspelled_words)
# Out:
# C:\Users\Nasiba\AppData\Local\Temp\ipykernel_22000\546645986.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned_1['cleaned_tweet'] = df_cleaned_1['tweet'].apply(correct_misspelled_words)

# %%
df_cleaned_1.head(5)
# Out:
#    id  label  \
# 0   1      0
# 1   2      0
# 2   3      0
# 3   4      0
# 4   5      0
#
#                                                                               tweet  \
# 0                          father dysfunctional selfish drags kids dysfunction #run
# 1  thanks #lyft credit use cause offer wheelchair vans pdx #disapointed #getthanked
# 2                                                                    bihday majesty
# 3                                          #model love u take u time ur📱!!! 😙😎👄👅💦💦💦
# 4                                                    factsguide society #motivation
#
#    stopwords  hashtags  upper_case  html_tag_count  url_count  \
# 0         10         1           0               0          0
# 1          5         3           0               0          0
# 2          1         0           0               0          0
# 3          5         1           0               0          0
# 4          1         1           0               0          0
#
#   expanded_shortcut misspelled_words  count_of_words misspelled_words_new  \
# 0              None   [dysfunction.]              21                 None
# 1              None           [pdx.]              22                [pdx]
# 2              None         [bihday]               5             [bihday]
# 3             [You]               []              17                 None
# 4              None    [factsguide:]               8         [factsguide]
#
#                                                                      cleaned_tweet
# 0                         father dysfunctional selfish drags kiss dysfunction #run
# 1  thanks #lyft credit use cause offer wheelchair van pox #disapointed #getthanked
# 2                                                                   midday majesty
# 3                                         #model love u take u time ur📱!!! 😙😎👄👅💦💦💦
# 4                                                   factsguide society #motivation

# %%
df_cleaned_2['cleaned_tweet'] = df_cleaned_2['tweet'].apply(correct_misspelled_words)
# Out:
# C:\Users\Nasiba\AppData\Local\Temp\ipykernel_22000\3928433484.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned_2['cleaned_tweet'] = df_cleaned_2['tweet'].apply(correct_misspelled_words)

# %%
df_cleaned_2.head(5)
# Out:
#         id  label  \
# 2001  2002      0
# 2002  2003      0
# 2003  2004      0
# 2004  2005      0
# 2005  2006      1
#
#                                                                                         tweet  \
# 2001                               makes ?? stick post-it put mirror 😊 📍spotted #sanfrancisco
# 2002                                                                      always tears #anime
# 2003  resurrected twitter dead back guys! conveniently time euros! #euro #europaleaguefinal !
# 2004                             unfounate today aids control hate kills gays yearly #orlando
# 2005                   #electoralcollege elects presidents #trump #notmypresident #newswithed
#
#       stopwords  hashtags  upper_case  html_tag_count  url_count  \
# 2001         10         1           0               0          0
# 2002          3         1           0               0          0
# 2003         10         2           0               0          0
# 2004          8         1           0               0          0
# 2005          2         4           0               0          0
#
#      expanded_shortcut   misspelled_words  count_of_words  \
# 2001              None     [??, post-it,]              22
# 2002              None                 []               9
# 2003              None            [dead.]              22
# 2004              None  [unfounate, not,]              20
# 2005              None                 []              11
#
#      misspelled_words_new  \
# 2001        [??, post-it]
# 2002                 None
# 2003                 None
# 2004          [unfounate]
# 2005                 None
#
#                                                                                 cleaned_tweet
# 2001                               makes ?? stick post-it put mirror 😊 📍spotted #sanfrancisco
# 2002                                                                      always tears #anime
# 2003  resurrected twitter dead back guys! conveniently time euros! #euro #europaleaguefinal !
# 2004                           unfortunate today aids control hate kills days yearly #orlando
# 2005                   #electoralcollege elects presidents #trump #notmypresident #newswithed

# %%
df_cleaned_3['cleaned_tweet'] = df_cleaned_3['tweet'].apply(correct_misspelled_words)
# Out:
# C:\Users\Nasiba\AppData\Local\Temp\ipykernel_22000\1334202654.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned_3['cleaned_tweet'] = df_cleaned_3['tweet'].apply(correct_misspelled_words)

# %%
df_cleaned_4['cleaned_tweet'] = df_cleaned_4['tweet'].apply(correct_misspelled_words)
# Out:
# C:\Users\Nasiba\AppData\Local\Temp\ipykernel_22000\1403794492.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned_4['cleaned_tweet'] = df_cleaned_4['tweet'].apply(correct_misspelled_words)

# %%
df_cleaned_5['cleaned_tweet'] = df_cleaned_5['tweet'].apply(correct_misspelled_words)
# Out:
# C:\Users\Nasiba\AppData\Local\Temp\ipykernel_22000\1376076252.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned_5['cleaned_tweet'] = df_cleaned_5['tweet'].apply(correct_misspelled_words)

# %%
df_cleaned_union = pd.concat([df_cleaned_1, df_cleaned_2], axis=0)
df_cleaned=df_cleaned_union.drop(['misspelled_words','count_of_words'],axis=1)
df_cleaned.head(5)
# Out:
#    id  label  \
# 0   1      0
# 1   2      0
# 2   3      0
# 3   4      0
# 4   5      0
#
#                                                                               tweet  \
# 0                          father dysfunctional selfish drags kids dysfunction #run
# 1  thanks #lyft credit use cause offer wheelchair vans pdx #disapointed #getthanked
# 2                                                                    bihday majesty
# 3                                          #model love u take u time ur📱!!! 😙😎👄👅💦💦💦
# 4                                                    factsguide society #motivation
#
#    stopwords  hashtags  upper_case  html_tag_count  url_count  \
# 0         10         1           0               0          0
# 1          5         3           0               0          0
# 2          1         0           0               0          0
# 3          5         1           0               0          0
# 4          1         1           0               0          0
#
#   expanded_shortcut misspelled_words_new  \
# 0              None                 None
# 1              None                [pdx]
# 2              None             [bihday]
# 3             [You]                 None
# 4              None         [factsguide]
#
#                                                                      cleaned_tweet
# 0                         father dysfunctional selfish drags kiss dysfunction #run
# 1  thanks #lyft credit use cause offer wheelchair van pox #disapointed #getthanked
# 2                                                                   midday majesty
# 3                                         #model love u take u time ur📱!!! 😙😎👄👅💦💦💦
# 4                                                   factsguide society #motivation

# %% [markdown]
# ##### 2.1.8  Ersetzen von Emojis

# %%
def replace_emojis(text):
    if isinstance(text, str):  
        return emoji.demojize(text)
    else:
        return text 

df_cleaned['tweet_with_replaced_emoji'] = df_cleaned['cleaned_tweet'].apply(replace_emojis)
df_cleaned.head(5)
# Out:
#    id  label  \
# 0   1      0
# 1   2      0
# 2   3      0
# 3   4      0
# 4   5      0
#
#                                                                               tweet  \
# 0                          father dysfunctional selfish drags kids dysfunction #run
# 1  thanks #lyft credit use cause offer wheelchair vans pdx #disapointed #getthanked
# 2                                                                    bihday majesty
# 3                                          #model love u take u time ur📱!!! 😙😎👄👅💦💦💦
# 4                                                    factsguide society #motivation
#
#    stopwords  hashtags  upper_case  html_tag_count  url_count  \
# 0         10         1           0               0          0
# 1          5         3           0               0          0
# 2          1         0           0               0          0
# 3          5         1           0               0          0
# 4          1         1           0               0          0
#
#   expanded_shortcut misspelled_words_new  \
# 0              None                 None
# 1              None                [pdx]
# 2              None             [bihday]
# 3             [You]                 None
# 4              None         [factsguide]
#
#                                                                      cleaned_tweet  \
# 0                         father dysfunctional selfish drags kiss dysfunction #run
# 1  thanks #lyft credit use cause offer wheelchair van pox #disapointed #getthanked
# 2                                                                   midday majesty
# 3                                         #model love u take u time ur📱!!! 😙😎👄👅💦💦💦
# 4                                                   factsguide society #motivation
#
#                                                                                                                                                      tweet_with_replaced_emoji
# 0                                                                                                                     father dysfunctional selfish drags kiss dysfunction #run
# 1                                                                                              thanks #lyft credit use cause offer wheelchair van pox #disapointed #getthanked
# 2                                                                                                                                                               midday majesty
# 3  #model love u take u time ur:mobile_phone:!!! :kissing_face_with_smiling_eyes::smiling_face_with_sunglasses::mouth::tongue::sweat_droplets::sweat_droplets::sweat_droplets:
# 4                                                                                                                                               factsguide society #motivation

# %% [markdown]
# ##### 2.1.9  Entfernung von Emojis

# %%
def remove_emoji(text):
    emoji_pattern = re.compile("["                             
                             u"\U0001F600-\U0001F64F"  # emoticons
                             u"\U0001F300-\U0001F5FF"  # symbols, pictographs
                             u"\U0001F680-\U0001F6FF"  # transport & map symbols
                             u"\U0001F1E0-\U0001F1FF"  # flags
                             u"\U00002702-\U000027B0"  # other symbols
                             u"\U00002FC2-\U0001F251"  # more symbols
                             "]+", flags=re.UNICODE)
    
    if isinstance(text, str):
        return emoji_pattern.sub(r'', text)
    return text

df_cleaned['tweet_with_removed_emoji']=df_cleaned['cleaned_tweet'].apply(remove_emoji)

# %%
df_cleaned = df_cleaned[['id','label','cleaned_tweet','tweet_with_replaced_emoji','tweet_with_removed_emoji']]
df_cleaned.head(5)
# Out:
#    id  label  \
# 0   1      0
# 1   2      0
# 2   3      0
# 3   4      0
# 4   5      0
#
#                                                                      cleaned_tweet  \
# 0                         father dysfunctional selfish drags kiss dysfunction #run
# 1  thanks #lyft credit use cause offer wheelchair van pox #disapointed #getthanked
# 2                                                                   midday majesty
# 3                                         #model love u take u time ur📱!!! 😙😎👄👅💦💦💦
# 4                                                   factsguide society #motivation
#
#                                                                                                                                                      tweet_with_replaced_emoji  \
# 0                                                                                                                     father dysfunctional selfish drags kiss dysfunction #run
# 1                                                                                              thanks #lyft credit use cause offer wheelchair van pox #disapointed #getthanked
# 2                                                                                                                                                               midday majesty
# 3  #model love u take u time ur:mobile_phone:!!! :kissing_face_with_smiling_eyes::smiling_face_with_sunglasses::mouth::tongue::sweat_droplets::sweat_droplets::sweat_droplets:
# 4                                                                                                                                               factsguide society #motivation
#
#                                                           tweet_with_removed_emoji
# 0                         father dysfunctional selfish drags kiss dysfunction #run
# 1  thanks #lyft credit use cause offer wheelchair van pox #disapointed #getthanked
# 2                                                                   midday majesty
# 3                                                 #model love u take u time ur!!!
# 4                                                   factsguide society #motivation

# %% [markdown]
# ##### 2.1.10  Erstellung neue Spalte Hashtag

# %%
df_cleaned['hashtags'] = df_cleaned['cleaned_tweet'].apply(lambda x: ' '.join([word for word in x.split() if '#' in word]))
df_cleaned.head(5)
# Out:
#    id  label  \
# 0   1      0
# 1   2      0
# 2   3      0
# 3   4      0
# 4   5      0
#
#                                                                      cleaned_tweet  \
# 0                         father dysfunctional selfish drags kiss dysfunction #run
# 1  thanks #lyft credit use cause offer wheelchair van pox #disapointed #getthanked
# 2                                                                   midday majesty
# 3                                         #model love u take u time ur📱!!! 😙😎👄👅💦💦💦
# 4                                                   factsguide society #motivation
#
#                                                                                                                                                      tweet_with_replaced_emoji  \
# 0                                                                                                                     father dysfunctional selfish drags kiss dysfunction #run
# 1                                                                                              thanks #lyft credit use cause offer wheelchair van pox #disapointed #getthanked
# 2                                                                                                                                                               midday majesty
# 3  #model love u take u time ur:mobile_phone:!!! :kissing_face_with_smiling_eyes::smiling_face_with_sunglasses::mouth::tongue::sweat_droplets::sweat_droplets::sweat_droplets:
# 4                                                                                                                                               factsguide society #motivation
#
#                                                           tweet_with_removed_emoji  \
# 0                         father dysfunctional selfish drags kiss dysfunction #run
# 1  thanks #lyft credit use cause offer wheelchair van pox #disapointed #getthanked
# 2                                                                   midday majesty
# 3                                                 #model love u take u time ur!!!
# 4                                                   factsguide society #motivation
#
#                          hashtags
# 0                            #run
# 1  #lyft #disapointed #getthanked
# 2
# 3                          #model
# 4                     #motivation

# %% [markdown]
# #### Vergleich

# %%
df_cleaned.head(5)
# Out:
#    id  label  \
# 0   1      0
# 1   2      0
# 2   3      0
# 3   4      0
# 4   5      0
#
#                                                                      cleaned_tweet  \
# 0                         father dysfunctional selfish drags kiss dysfunction #run
# 1  thanks #lyft credit use cause offer wheelchair van pox #disapointed #getthanked
# 2                                                                   midday majesty
# 3                                         #model love u take u time ur📱!!! 😙😎👄👅💦💦💦
# 4                                                   factsguide society #motivation
#
#                                                                                                                                                      tweet_with_replaced_emoji  \
# 0                                                                                                                     father dysfunctional selfish drags kiss dysfunction #run
# 1                                                                                              thanks #lyft credit use cause offer wheelchair van pox #disapointed #getthanked
# 2                                                                                                                                                               midday majesty
# 3  #model love u take u time ur:mobile_phone:!!! :kissing_face_with_smiling_eyes::smiling_face_with_sunglasses::mouth::tongue::sweat_droplets::sweat_droplets::sweat_droplets:
# 4                                                                                                                                               factsguide society #motivation
#
#                                                           tweet_with_removed_emoji  \
# 0                         father dysfunctional selfish drags kiss dysfunction #run
# 1  thanks #lyft credit use cause offer wheelchair van pox #disapointed #getthanked
# 2                                                                   midday majesty
# 3                                                 #model love u take u time ur!!!
# 4                                                   factsguide society #motivation
#
#                          hashtags
# 0                            #run
# 1  #lyft #disapointed #getthanked
# 2
# 3                          #model
# 4                     #motivation

# %%
csv_path  = os.path.abspath(os.path.join(current_dir, '../../../data/twitter_hate-speech/train.csv'))
df_origin = pd.read_csv(csv_path, encoding='utf-8')
df_origin.head(5)
# Out:
#    id  label  \
# 0   1      0
# 1   2      0
# 2   3      0
# 3   4      0
# 4   5      0
#
#                                                                                                                         tweet
# 0                       @user when a father is dysfunctional and is so selfish he drags his kids into his dysfunction.   #run
# 1  @user @user thanks for #lyft credit i can't use cause they don't offer wheelchair vans in pdx.    #disapointed #getthanked
# 2                                                                                                         bihday your majesty
# 3                                      #model   i love u take with u all the time in urð±!!! ðððð
# ð¦ð¦ð¦
# 4                                                                                      factsguide: society now    #motivation

# %% [markdown]
# ##### Die Ergebnisse speichern

# %%
filepath_name = os.path.abspath(os.path.join(current_dir, 'data/train_cleaned.csv'))
# directory_path = Path(filepath_name).parent  
# directory_path.mkdir(parents=True, exist_ok=True)
df_cleaned.to_csv(filepath_name)

# %% [markdown]
# # 3 Dateneanalyse nach Cleaning

# %% [markdown]
# ##### WordCloud Analyse

# %%
filepath_name = os.path.abspath(os.path.join(current_dir, 'data/train_cleaned.csv'))
df_analyse = pd.read_csv(filepath_name)

# %% [markdown]
# #### Verteilung der Labels

# %%
label_counts = df_analyse['label'].value_counts()

plt.figure(figsize=(6,2))
label_counts.plot(kind='bar', color='blue')
plt.title('Label Verteilung')
plt.xlabel('Label')
plt.ylabel('Anzahl')
plt.xticks(rotation=0)
plt.show()

# %%
df_analyse_label_0= df_analyse[df_analyse['label']==0]
df_analyse_label_1= df_analyse[df_analyse['label']==1]

# %%
df_analyse_label_0['tweet_with_removed_emoji'] = df_analyse_label_0['tweet_with_removed_emoji'].apply(lambda x: x if isinstance(x, str) else '')
text = " ".join(tweet for tweet in df_analyse_label_0['tweet_with_removed_emoji'])

wc = WordCloud(background_color="white",
               width=200, 
               height=200,
               contour_width=0,
               contour_color="red",
               max_words=1000,
               scale=1,
               collocations=False,
               repeat=False,
               min_font_size=1)

wc.generate(text)


plt.figure(figsize=[6, 6])
plt.imshow(wc, interpolation="bilinear")
plt.axis("off")  # Hide the axes
plt.title("Häufigkeiten der Label 0 Wörter")
plt.show()
# Out:
# C:\Users\Nasiba\AppData\Local\Temp\ipykernel_22000\1079308708.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_analyse_label_0['tweet_with_removed_emoji'] = df_analyse_label_0['tweet_with_removed_emoji'].apply(lambda x: x if isinstance(x, str) else '')

# %%
df_analyse_label_1['tweet_with_removed_emoji'] = df_analyse_label_1['tweet_with_removed_emoji'].apply(lambda x: x if isinstance(x, str) else '')
text = " ".join(tweet for tweet in df_analyse_label_1['tweet_with_removed_emoji'])

wc = WordCloud(background_color="white",
               width=200, 
               height=200,
               contour_width=0,
               contour_color="red",
               max_words=1000,
               scale=1,
               collocations=False,
               repeat=False,
               min_font_size=1)

wc.generate(text)


plt.figure(figsize=[6, 6])
plt.imshow(wc, interpolation="bilinear")
plt.axis("off")  # Hide the axes
plt.title("Häufigkeiten der Label 1 Wörter")
plt.show()
# Out:
# C:\Users\Nasiba\AppData\Local\Temp\ipykernel_22000\4168645348.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_analyse_label_1['tweet_with_removed_emoji'] = df_analyse_label_1['tweet_with_removed_emoji'].apply(lambda x: x if isinstance(x, str) else '')

# %%
df_analyse_label_0['hashtags'] = df_analyse_label_0['hashtags'].apply(lambda x: x if isinstance(x, str) else '')
text = " ".join(tweet for tweet in df_analyse_label_0['hashtags'])

wc = WordCloud(background_color="white",
               width=200, 
               height=200,
               contour_width=0,
               contour_color="red",
               max_words=1000,
               scale=1,
               collocations=False,
               repeat=False,
               min_font_size=1)

wc.generate(text)


plt.figure(figsize=[6, 6])
plt.imshow(wc, interpolation="bilinear")
plt.axis("off")  # Hide the axes
plt.title("Häufigkeiten der Label 0 Hashtags")
plt.show()
# Out:
# C:\Users\Nasiba\AppData\Local\Temp\ipykernel_22000\1601303686.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_analyse_label_0['hashtags'] = df_analyse_label_0['hashtags'].apply(lambda x: x if isinstance(x, str) else '')

# %%
df_analyse_label_1['hashtags'] = df_analyse_label_1['hashtags'].apply(lambda x: x if isinstance(x, str) else '')
text = " ".join(tweet for tweet in df_analyse_label_1['hashtags'])

wc = WordCloud(background_color="white",
               width=200, 
               height=200,
               contour_width=0,
               contour_color="red",
               max_words=1000,
               scale=1,
               collocations=False,
               repeat=False,
               min_font_size=1)

wc.generate(text)


plt.figure(figsize=[6, 6])
plt.imshow(wc, interpolation="bilinear")
plt.axis("off")  # Hide the axes
plt.title("Häufigkeiten der Label 1 Hashtags")
plt.show()
# Out:
# C:\Users\Nasiba\AppData\Local\Temp\ipykernel_22000\2497192674.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_analyse_label_1['hashtags'] = df_analyse_label_1['hashtags'].apply(lambda x: x if isinstance(x, str) else '')

# %% [markdown]
# # 4 Datenvorbereitung nach Cleaning

# %%
current_dir = os.getcwd()
filepath_name = os.path.abspath(os.path.join(current_dir, 'data/train_cleaned.csv'))
df_prepare = pd.read_csv(filepath_name)
df_prepare.head(2)
# Out:
#    Unnamed: 0  id  label  \
# 0           0   1      0
# 1           1   2      0
#
#                                                                      cleaned_tweet  \
# 0                         father dysfunctional selfish drags kiss dysfunction #run
# 1  thanks #lyft credit use cause offer wheelchair van pox #disapointed #getthanked
#
#                                                          tweet_with_replaced_emoji  \
# 0                         father dysfunctional selfish drags kiss dysfunction #run
# 1  thanks #lyft credit use cause offer wheelchair van pox #disapointed #getthanked
#
#                                                           tweet_with_removed_emoji  \
# 0                         father dysfunctional selfish drags kiss dysfunction #run
# 1  thanks #lyft credit use cause offer wheelchair van pox #disapointed #getthanked
#
#                          hashtags
# 0                            #run
# 1  #lyft #disapointed #getthanked

# %%
df_prepare.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4001 entries, 0 to 4000
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Unnamed: 0                 4001 non-null   int64
#  1   id                         4001 non-null   int64
#  2   label                      4001 non-null   int64
#  3   cleaned_tweet              4000 non-null   object
#  4   tweet_with_replaced_emoji  4000 non-null   object
#  5   tweet_with_removed_emoji   4001 non-null   object
#  6   hashtags                   2965 non-null   object
#  7   tweet_tokenized            4001 non-null   object
#  8   tweet_stemmed              4001 non-null   object
# dtypes: int64(3), object(6)
# memory usage: 281.4+ KB

# %% [markdown]
# #### 4.1 Datentyp Cast

# %%
df_prepare['tweet_with_removed_emoji']= df_prepare['tweet_with_removed_emoji'].apply(lambda x: x if isinstance(x, str) else '')

# %% [markdown]
# #### 4.1 Tokenizierung

# %%
df_prepare['tweet_tokenized']=df_prepare['tweet_with_removed_emoji'].apply(lambda x: x.split())
df_prepare.head(2)
# Out:
#    Unnamed: 0  id  label  \
# 0           0   1      0
# 1           1   2      0
#
#                                                                      cleaned_tweet  \
# 0                         father dysfunctional selfish drags kiss dysfunction #run
# 1  thanks #lyft credit use cause offer wheelchair van pox #disapointed #getthanked
#
#                                                          tweet_with_replaced_emoji  \
# 0                         father dysfunctional selfish drags kiss dysfunction #run
# 1  thanks #lyft credit use cause offer wheelchair van pox #disapointed #getthanked
#
#                                                           tweet_with_removed_emoji  \
# 0                         father dysfunctional selfish drags kiss dysfunction #run
# 1  thanks #lyft credit use cause offer wheelchair van pox #disapointed #getthanked
#
#                          hashtags  \
# 0                            #run
# 1  #lyft #disapointed #getthanked
#
#                                                                                tweet_tokenized
# 0                             [father, dysfunctional, selfish, drags, kiss, dysfunction, #run]
# 1  [thanks, #lyft, credit, use, cause, offer, wheelchair, van, pox, #disapointed, #getthanked]

# %% [markdown]
# #### 4.2 Stemming

# %%
ps=PorterStemmer()
def stem_words(text):
    return " ".join([ps.stem(word) for word in text.split()])
sample="Walk walking walked walks"
stem_words(sample)
# Out:
# 'walk walk walk walk'

# %%
df_prepare['tweet_stemmed']=df_prepare['tweet_with_removed_emoji'].apply(lambda x: " ".join([ps.stem(word) for word in x.split()]))
df_prepare.head(2)
# Out:
#    Unnamed: 0  id  label  \
# 0           0   1      0
# 1           1   2      0
#
#                                                                      cleaned_tweet  \
# 0                         father dysfunctional selfish drags kiss dysfunction #run
# 1  thanks #lyft credit use cause offer wheelchair van pox #disapointed #getthanked
#
#                                                          tweet_with_replaced_emoji  \
# 0                         father dysfunctional selfish drags kiss dysfunction #run
# 1  thanks #lyft credit use cause offer wheelchair van pox #disapointed #getthanked
#
#                                                           tweet_with_removed_emoji  \
# 0                         father dysfunctional selfish drags kiss dysfunction #run
# 1  thanks #lyft credit use cause offer wheelchair van pox #disapointed #getthanked
#
#                          hashtags  \
# 0                            #run
# 1  #lyft #disapointed #getthanked
#
#                                                                                tweet_tokenized  \
# 0                             [father, dysfunctional, selfish, drags, kiss, dysfunction, #run]
# 1  [thanks, #lyft, credit, use, cause, offer, wheelchair, van, pox, #disapointed, #getthanked]
#
#                                                                tweet_stemmed
# 0                            father dysfunct selfish drag kiss dysfunct #run
# 1  thank #lyft credit use caus offer wheelchair van pox #disapoint #getthank

# %% [markdown]
# #### 4.3 Lemmatization

# %%
def lemmatization(df):
    df['tweet_lemmatized'] = df['tweet_tokenized'].apply(lambda x: " ".join([Word(word).lemmatize() for word in x]))


lemmatization(df_prepare)
df_prepare.head(2)
# Out:
#    Unnamed: 0  id  label  \
# 0           0   1      0
# 1           1   2      0
#
#                                                                      cleaned_tweet  \
# 0                         father dysfunctional selfish drags kiss dysfunction #run
# 1  thanks #lyft credit use cause offer wheelchair van pox #disapointed #getthanked
#
#                                                          tweet_with_replaced_emoji  \
# 0                         father dysfunctional selfish drags kiss dysfunction #run
# 1  thanks #lyft credit use cause offer wheelchair van pox #disapointed #getthanked
#
#                                                           tweet_with_removed_emoji  \
# 0                         father dysfunctional selfish drags kiss dysfunction #run
# 1  thanks #lyft credit use cause offer wheelchair van pox #disapointed #getthanked
#
#                          hashtags  \
# 0                            #run
# 1  #lyft #disapointed #getthanked
#
#                                                                                tweet_tokenized  \
# 0                             [father, dysfunctional, selfish, drags, kiss, dysfunction, #run]
# 1  [thanks, #lyft, credit, use, cause, offer, wheelchair, van, pox, #disapointed, #getthanked]
#
#                                                                tweet_stemmed  \
# 0                            father dysfunct selfish drag kiss dysfunct #run
# 1  thank #lyft credit use caus offer wheelchair van pox #disapoint #getthank
#
#                                                                   tweet_lemmatized
# 0                          father dysfunctional selfish drag kiss dysfunction #run
# 1  thanks #lyft credit use cause offer wheelchair van pox #disapointed #getthanked

# %% [markdown]
# #### Ergebnisse speichern

# %%
filepath_name = os.path.abspath(os.path.join(current_dir, 'data/train_prepared.csv'))
# directory_path = Path(filepath_name).parent  
# directory_path.mkdir(parents=True, exist_ok=True)
df_prepare.to_csv(filepath_name)
