# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import GridSearchCV, train_test_split, cross_val_score
from sklearn.datasets import make_classification

# %% [markdown]
# Einladen der vektorisierten Daten

# %%
# %run ../../functions/vectorize_functions.py

# %%
filepath_name = ("..\\..\\..\\data\\new_datasets\\train_cleaned.csv")
df_cleaned = pd.read_csv(filepath_name, encoding='utf-8')

# %%
X_train, X_test, y_train, y_test = vectorize_w2v(df=df_cleaned, text_column='tweet_cleaned', 
                                                                                 label_column="label")

# %%
positive = np.count_nonzero(y_train == 1)
negative = np.count_nonzero(y_train == 0)
print("Train")
print("- Positive:", positive)
print("- Negative:", negative)
print("- Verhältnis:", negative / positive)

positive = np.count_nonzero(y_test == 1)
negative = np.count_nonzero(y_test == 0)
print("Test")
print("- Positive:", positive)
print("- Negative:", negative)
print("- Verhältnis:", negative / positive)
# Out:
# Train
# - Positive: 9184
# - Negative: 33695
# - Verhältnis: 3.668880662020906
# Test
# - Positive: 3919
# - Negative: 14459
# - Verhältnis: 3.689461597346262

# %%
print("X_train shape", X_train.shape)
print("y_train shape", y_train.shape)

print("X_test shape", X_test.shape)
print("y_test shape", y_test.shape)
# Out:
# X_train shape (42879, 300)
# y_train shape (42879,)
# X_test shape (18378, 300)
# y_test shape (18378,)

# %% [markdown]
# # Evaluation

# %% [markdown]
# # SVM

# %%
results_list = []

param_grid = {
    'kernel': ['sigmoid'],
    #'degree': [3, 4, 5],
    'C': [0.1, 1],
    'gamma': [0.1, 1],
    'random_state': [42],
    'class_weight': [{0: 1, 1: 1}, {0: 1, 1: 3}, {0: 1, 1: 5}]
}

svm = SVC()

grid_search = GridSearchCV(estimator=svm, param_grid=param_grid, scoring='f1', cv=3, verbose=2, n_jobs=-1)

grid_search.fit(X_train, y_train)

for params in grid_search.cv_results_['params']:
    model = SVC(**params)  
    model.fit(X_train, y_train)  

    y_train_pred = model.predict(X_train)

    y_test_pred = model.predict(X_test)

    train_report = classification_report(y_train, y_train_pred, output_dict=True)
    test_report = classification_report(y_test, y_test_pred, output_dict=True)

    train_accuracy = accuracy_score(y_train, y_train_pred)
    train_recall = recall_score(y_train, y_train_pred)
    train_precision = precision_score(y_train, y_train_pred)
    train_f1 = f1_score(y_train, y_train_pred)

    test_accuracy = accuracy_score(y_test, y_test_pred)
    test_recall = recall_score(y_test, y_test_pred)
    test_precision = precision_score(y_test, y_test_pred)
    test_f1 = f1_score(y_test, y_test_pred)

    result_dict = {
        'vectorization': 'tfidf',
        'kernel': params['kernel'],
        'degree': 'X',
        'C': params['C'],
        'gamma': params['gamma'],
        'random_state': params['random_state'],
        'class_weight': params['class_weight'],

        # Train metrics
        'train_precision_0': train_report['0']['precision'],
        'train_recall_0': train_report['0']['recall'],
        'train_f1_0': train_report['0']['f1-score'],
        'train_support_0': train_report['0']['support'],
        'train_precision_1': train_report['1']['precision'],
        'train_recall_1': train_report['1']['recall'],
        'train_f1_1': train_report['1']['f1-score'],
        'train_support_1': train_report['1']['support'],
        'train_accuracy': train_accuracy,
        'train_recall': train_recall,
        'train_precision': train_precision,
        'train_f1': train_f1,

        # Test metrics
        'test_precision_0': test_report['0']['precision'],
        'test_recall_0': test_report['0']['recall'],
        'test_f1_0': test_report['0']['f1-score'],
        'test_support_0': test_report['0']['support'],
        'test_precision_1': test_report['1']['precision'],
        'test_recall_1': test_report['1']['recall'],
        'test_f1_1': test_report['1']['f1-score'],
        'test_support_1': test_report['1']['support'],
        'test_accuracy': test_accuracy,
        'test_recall': test_recall,
        'test_precision': test_precision,
        'test_f1': test_f1
    } 

    results_list.append(result_dict)

results_df = pd.DataFrame(results_list)

results_df.to_csv('svm_grid_w2v_sigmoid_new_data.csv', index=False)

print(results_df)
# Out:
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
#    vectorization   kernel degree    C  gamma  random_state  class_weight  \
# 0          tfidf  sigmoid      X  0.1    0.1            42  {0: 1, 1: 1}
# 1          tfidf  sigmoid      X  0.1    1.0            42  {0: 1, 1: 1}
# 2          tfidf  sigmoid      X  0.1    0.1            42  {0: 1, 1: 3}
# 3          tfidf  sigmoid      X  0.1    1.0            42  {0: 1, 1: 3}
# 4          tfidf  sigmoid      X  0.1    0.1            42  {0: 1, 1: 5}
# 5          tfidf  sigmoid      X  0.1    1.0            42  {0: 1, 1: 5}
# 6          tfidf  sigmoid      X  1.0    0.1            42  {0: 1, 1: 1}
# 7          tfidf  sigmoid      X  1.0    1.0            42  {0: 1, 1: 1}
# 8          tfidf  sigmoid      X  1.0    0.1            42  {0: 1, 1: 3}
# 9          tfidf  sigmoid      X  1.0    1.0            42  {0: 1, 1: 3}
# 10         tfidf  sigmoid      X  1.0    0.1            42  {0: 1, 1: 5}
# 11         tfidf  sigmoid      X  1.0    1.0            42  {0: 1, 1: 5}
#
#     train_precision_0  train_recall_0  train_f1_0  ...  test_f1_0  \
# 0            0.798867        0.803443    0.801148  ...   0.807434
# 1            0.779379        0.780234    0.779806  ...   0.780491
# 2            0.807476        0.584033    0.677815  ...   0.688294
# 3            0.780001        0.541475    0.639211  ...   0.635071
# 4            0.809357        0.458495    0.585378  ...   0.596602
# 5            0.783930        0.420151    0.547088  ...   0.542813
# 6            0.799003        0.799406    0.799205  ...   0.804584
# 7            0.779552        0.779552    0.779552  ...   0.779881
# 8            0.807297        0.582490    0.676711  ...   0.686678
# 9            0.780369        0.542217    0.639852  ...   0.635153
# 10           0.809462        0.459564    0.586275  ...   0.597184
# 11           0.784095        0.420775    0.547656  ...   0.543125
#
#     test_support_0  test_precision_1  test_recall_1  test_f1_1  \
# 0            14459          0.268990       0.252105   0.260274
# 1            14459          0.195312       0.197755   0.196526
# 2            14459          0.246435       0.485073   0.326829
# 3            14459          0.203822       0.438122   0.278214
# 4            14459          0.238019       0.610870   0.342563
# 5            14459          0.208790       0.568512   0.305415
# 6            14459          0.267390       0.257974   0.262597
# 7            14459          0.195287       0.198775   0.197016
# 8            14459          0.245775       0.486093   0.326478
# 9            14459          0.203941       0.438377   0.278376
# 10           14459          0.237849       0.609339   0.342145
# 11           14459          0.209017       0.569023   0.305731
#
#     test_support_1  test_accuracy  test_recall  test_precision   test_f1
# 0             3919       0.694417     0.252105        0.268990  0.260274
# 1             3919       0.655186     0.197755        0.195312  0.196526
# 2             3919       0.573893     0.485073        0.246435  0.326829
# 3             3919       0.515236     0.438122        0.203822  0.278214
# 4             3919       0.500000     0.610870        0.238019  0.342563
# 5             3919       0.448580     0.568512        0.208790  0.305415
# 6             3919       0.691044     0.257974        0.267390  0.262597
# 7             3919       0.654478     0.198775        0.195287  0.197016
# 8             3919       0.572315     0.486093        0.245775  0.326478
# 9             3919       0.515344     0.438377        0.203941  0.278376
# 10            3919       0.500326     0.609339        0.237849  0.342145
# 11            3919       0.448906     0.569023        0.209017  0.305731
#
# [12 rows x 31 columns]

# %%
results_list = []

param_grid = {
    'kernel': ['linear'],
    #'degree': [3, 4, 5],
    'C': [0.1, 1.0],
    'gamma': [0.01, 0.1, 1],
    'random_state': [42],
    'class_weight': [{0: 1, 1: 1}, {0: 1, 1: 3}, {0: 1, 1: 5}]
}

svm = SVC()

grid_search = GridSearchCV(estimator=svm, param_grid=param_grid, scoring='f1', cv=3, verbose=2, n_jobs=-1)

grid_search.fit(X_train, y_train)

for params in grid_search.cv_results_['params']:
    model = SVC(**params)  
    model.fit(X_train, y_train)  

    y_train_pred = model.predict(X_train)

    y_test_pred = model.predict(X_test)

    train_report = classification_report(y_train, y_train_pred, output_dict=True)
    test_report = classification_report(y_test, y_test_pred, output_dict=True)

    train_accuracy = accuracy_score(y_train, y_train_pred)
    train_recall = recall_score(y_train, y_train_pred)
    train_precision = precision_score(y_train, y_train_pred)
    train_f1 = f1_score(y_train, y_train_pred)

    test_accuracy = accuracy_score(y_test, y_test_pred)
    test_recall = recall_score(y_test, y_test_pred)
    test_precision = precision_score(y_test, y_test_pred)
    test_f1 = f1_score(y_test, y_test_pred)

    result_dict = {
        'vectorization': 'tfidf',
        'kernel': params['kernel'],
        'degree': 'X',
        'C': params['C'],
        'gamma': params['gamma'],
        'random_state': params['random_state'],
        'class_weight': params['class_weight'],

        # Train metrics
        'train_precision_0': train_report['0']['precision'],
        'train_recall_0': train_report['0']['recall'],
        'train_f1_0': train_report['0']['f1-score'],
        'train_support_0': train_report['0']['support'],
        'train_precision_1': train_report['1']['precision'],
        'train_recall_1': train_report['1']['recall'],
        'train_f1_1': train_report['1']['f1-score'],
        'train_support_1': train_report['1']['support'],
        'train_accuracy': train_accuracy,
        'train_recall': train_recall,
        'train_precision': train_precision,
        'train_f1': train_f1,

        # Test metrics
        'test_precision_0': test_report['0']['precision'],
        'test_recall_0': test_report['0']['recall'],
        'test_f1_0': test_report['0']['f1-score'],
        'test_support_0': test_report['0']['support'],
        'test_precision_1': test_report['1']['precision'],
        'test_recall_1': test_report['1']['recall'],
        'test_f1_1': test_report['1']['f1-score'],
        'test_support_1': test_report['1']['support'],
        'test_accuracy': test_accuracy,
        'test_recall': test_recall,
        'test_precision': test_precision,
        'test_f1': test_f1
    }

    results_list.append(result_dict)

results_df = pd.DataFrame(results_list)

results_df.to_csv('svm_grid_w2v_linear_new_data.csv', index=False)

print(results_df)
# Out:
# Fitting 3 folds for each of 18 candidates, totalling 54 fits

# %%
results_list = []

param_grid = {
    'kernel': ['poly'],
    'degree': [3, 4],
    'C': [0.1, 1],
    'gamma': [0.1, 1],
    'random_state': [42],
    'class_weight': [{0: 1, 1: 1}, {0: 1, 1: 3}, {0: 1, 1: 5}]
}

svm = SVC()

grid_search = GridSearchCV(estimator=svm, param_grid=param_grid, scoring='f1', cv=3, verbose=2, n_jobs=-1)

grid_search.fit(X_train, y_train)

for params in grid_search.cv_results_['params']:
    model = SVC(**params)  
    model.fit(X_train, y_train)  

    y_train_pred = model.predict(X_train)

    y_test_pred = model.predict(X_test)

    train_report = classification_report(y_train, y_train_pred, output_dict=True)
    test_report = classification_report(y_test, y_test_pred, output_dict=True)

    train_accuracy = accuracy_score(y_train, y_train_pred)
    train_recall = recall_score(y_train, y_train_pred)
    train_precision = precision_score(y_train, y_train_pred)
    train_f1 = f1_score(y_train, y_train_pred)

    test_accuracy = accuracy_score(y_test, y_test_pred)
    test_recall = recall_score(y_test, y_test_pred)
    test_precision = precision_score(y_test, y_test_pred)
    test_f1 = f1_score(y_test, y_test_pred)

    result_dict = {
        'vectorization': 'tfidf',
        'kernel': params['kernel'],
        'degree': params['degree'],
        'C': params['C'],
        'gamma': params['gamma'],
        'random_state': params['random_state'],
        'class_weight': params['class_weight'],

        # Train metrics
        'train_precision_0': train_report['0']['precision'],
        'train_recall_0': train_report['0']['recall'],
        'train_f1_0': train_report['0']['f1-score'],
        'train_support_0': train_report['0']['support'],
        'train_precision_1': train_report['1']['precision'],
        'train_recall_1': train_report['1']['recall'],
        'train_f1_1': train_report['1']['f1-score'],
        'train_support_1': train_report['1']['support'],
        'train_accuracy': train_accuracy,
        'train_recall': train_recall,
        'train_precision': train_precision,
        'train_f1': train_f1,

        # Test metrics
        'test_precision_0': test_report['0']['precision'],
        'test_recall_0': test_report['0']['recall'],
        'test_f1_0': test_report['0']['f1-score'],
        'test_support_0': test_report['0']['support'],
        'test_precision_1': test_report['1']['precision'],
        'test_recall_1': test_report['1']['recall'],
        'test_f1_1': test_report['1']['f1-score'],
        'test_support_1': test_report['1']['support'],
        'test_accuracy': test_accuracy,
        'test_recall': test_recall,
        'test_precision': test_precision,
        'test_f1': test_f1
    }

    results_list.append(result_dict)

results_df = pd.DataFrame(results_list)

results_df.to_csv('svm_w2v_poly_new_data.csv', index=False)


print(results_df)
# Out:
# Fitting 3 folds for each of 24 candidates, totalling 72 fits
#    vectorization kernel  degree    C  gamma  random_state  class_weight  \
# 0          tfidf   poly       3  0.9    0.9            42  {0: 1, 1: 1}
# 1          tfidf   poly       3  0.9    1.0            42  {0: 1, 1: 1}
# 2          tfidf   poly       4  0.9    0.9            42  {0: 1, 1: 1}
# 3          tfidf   poly       4  0.9    1.0            42  {0: 1, 1: 1}
# 4          tfidf   poly       3  0.9    0.9            42  {0: 1, 1: 3}
# 5          tfidf   poly       3  0.9    1.0            42  {0: 1, 1: 3}
# 6          tfidf   poly       4  0.9    0.9            42  {0: 1, 1: 3}
# 7          tfidf   poly       4  0.9    1.0            42  {0: 1, 1: 3}
# 8          tfidf   poly       3  0.9    0.9            42  {0: 1, 1: 5}
# 9          tfidf   poly       3  0.9    1.0            42  {0: 1, 1: 5}
# 10         tfidf   poly       4  0.9    0.9            42  {0: 1, 1: 5}
# 11         tfidf   poly       4  0.9    1.0            42  {0: 1, 1: 5}
# 12         tfidf   poly       3  1.0    0.9            42  {0: 1, 1: 1}
# 13         tfidf   poly       3  1.0    1.0            42  {0: 1, 1: 1}
# 14         tfidf   poly       4  1.0    0.9            42  {0: 1, 1: 1}
# 15         tfidf   poly       4  1.0    1.0            42  {0: 1, 1: 1}
# 16         tfidf   poly       3  1.0    0.9            42  {0: 1, 1: 3}
# 17         tfidf   poly       3  1.0    1.0            42  {0: 1, 1: 3}
# 18         tfidf   poly       4  1.0    0.9            42  {0: 1, 1: 3}
# 19         tfidf   poly       4  1.0    1.0            42  {0: 1, 1: 3}
# 20         tfidf   poly       3  1.0    0.9            42  {0: 1, 1: 5}
# 21         tfidf   poly       3  1.0    1.0            42  {0: 1, 1: 5}
# 22         tfidf   poly       4  1.0    0.9            42  {0: 1, 1: 5}
# 23         tfidf   poly       4  1.0    1.0            42  {0: 1, 1: 5}
#
#     train_precision_0  train_recall_0  train_f1_0  ...  test_f1_0  \
# 
],
    'random_state': [42],
    'class_weight': [{0: 1, 1: 1}, {0: 1, 1: 3}, {0: 1, 1: 5}]
}


svm = SVC()

grid_search = GridSearchCV(estimator=svm, param_grid=param_grid, scoring='f1', cv=3, verbose=2, n_jobs=-1)

grid_search.fit(X_train, y_train)

for params in grid_search.cv_results_['params']:
    model = SVC(**params)  
    model.fit(X_train, y_train)  

    y_train_pred = model.predict(X_train)

    y_test_pred = model.predict(X_test)

    train_report = classification_report(y_train, y_train_pred, output_dict=True)
    test_report = classification_report(y_test, y_test_pred, output_dict=True)

    train_accuracy = accuracy_score(y_train, y_train_pred)
    train_recall = recall_score(y_train, y_train_pred)
    train_precision = precision_score(y_train, y_train_pred)
    train_f1 = f1_score(y_train, y_train_pred)

    test_accuracy = accuracy_score(y_test, y_test_pred)
    test_recall = recall_score(y_test, y_test_pred)
    test_precision = precision_score(y_test, y_test_pred)
    test_f1 = f1_score(y_test, y_test_pred)
    
    result_dict = {
        'vectorization': 'tfidf',
        'kernel': params['kernel'],
        'degree': 'X',
        'C': params['C'],
        'gamma': params['gamma'],
        'random_state': params['random_state'],
        'class_weight': params['class_weight'],

        # Train metrics
        'train_precision_0': train_report['0']['precision'],
        'train_recall_0': train_report['0']['recall'],
        'train_f1_0': train_report['0']['f1-score'],
        'train_support_0': train_report['0']['support'],
        'train_precision_1': train_report['1']['precision'],
        'train_recall_1': train_report['1']['recall'],
        'train_f1_1': train_report['1']['f1-score'],
        'train_support_1': train_report['1']['support'],
        'train_accuracy': train_accuracy,
        'train_recall': train_recall,
        'train_precision': train_precision,
        'train_f1': train_f1,

        # Test metrics
        'test_precision_0': test_report['0']['precision'],
        'test_recall_0': test_report['0']['recall'],
        'test_f1_0': test_report['0']['f1-score'],
        'test_support_0': test_report['0']['support'],
        'test_precision_1': test_report['1']['precision'],
        'test_recall_1': test_report['1']['recall'],
        'test_f1_1': test_report['1']['f1-score'],
        'test_support_1': test_report['1']['support'],
        'test_accuracy': test_accuracy,
        'test_recall': test_recall,
        'test_precision': test_precision,
        'test_f1': test_f1
    }

    results_list.append(result_dict)

results_df = pd.DataFrame(results_list)

results_df.to_csv('svm_w2v_rbf_new_data.csv', index=False)

print(results_df)
# Out:
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
#    vectorization kernel degree    C  gamma  random_state  class_weight  \
# 0          tfidf    rbf      X  0.1   0.01            42  {0: 1, 1: 1}
# 1          tfidf    rbf      X  0.1   0.10            42  {0: 1, 1: 1}
# 2          tfidf    rbf      X  0.1   0.01            42  {0: 1, 1: 3}
# 3          tfidf    rbf      X  0.1   0.10            42  {0: 1, 1: 3}
# 4          tfidf    rbf      X  0.1   0.01            42  {0: 1, 1: 5}
# 5          tfidf    rbf      X  0.1   0.10            42  {0: 1, 1: 5}
# 6          tfidf    rbf      X  1.0   0.01            42  {0: 1, 1: 1}
# 7          tfidf    rbf      X  1.0   0.10            42  {0: 1, 1: 1}
# 8          tfidf    rbf      X  1.0   0.01            42  {0: 1, 1: 3}
# 9          tfidf    rbf      X  1.0   0.10            42  {0: 1, 1: 3}
# 10         tfidf    rbf      X  1.0   0.01            42  {0: 1, 1: 5}
# 11         tfidf    rbf      X  1.0   0.10            42  {0: 1, 1: 5}
#
#     train_precision_0  train_recall_0  train_f1_0  ...  test_f1_0  \
# 0            0.793240        0.997418    0.883689  ...   0.884385
# 1            0.796586        0.998694    0.886264  ...   0.884999
# 2            0.887491        0.810001    0.846977  ...   0.844292
# 3            0.886097        0.899035    0.892519  ...   0.867329
# 4            0.928302        0.605579    0.732991  ...   0.720520
# 5            0.967896        0.569966    0.717448  ...   0.664028
# 6            0.812976        0.991423    0.893376  ...   0.890564
# 7            0.913844        0.993797    0.952145  ...   0.894079
# 8            0.907536        0.826681    0.865223  ...   0.850051
# 9            0.993816        0.968274    0.980879  ...   0.875759
# 10           0.946845        0.660810    0.778382  ...   0.748682
# 11           0.999195        0.958273    0.978306  ...   0.866722
#
#     test_support_0  test_precision_1  test_recall_1  test_f1_1  \
# 0            14459          0.836364       0.046951   0.088910
# 1            14459          0.819853       0.056902   0.106419
# 2            14459          0.463091       0.614698   0.528232
# 3            14459          0.506186       0.469763   0.487295
# 4            14459          0.352182       0.821638   0.493033
# 5            14459          0.324447       0.857106   0.470712
# 6            14459          0.775815       0.145700   0.245328
# 7            14459          0.709517       0.254912   0.375070
# 8            14459          0.479107       0.640725   0.548253
# 9            14459          0.538047       0.458280   0.494970
# 10           14459          0.372207       0.811942   0.510427
# 11           14459          0.505235       0.480225   0.492412
#
#     test_support_1  test_accuracy  test_recall  test_precision   test_f1
# 0             3919       0.794809     0.046951        0.836364  0.088910
# 1             3919       0.796224     0.056902        0.819853  0.106419
# 2             3919       0.765861     0.614698        0.463091  0.528232
# 3             3919       0.789204     0.469763        0.506186  0.487295
# 4             3919       0.639678     0.821638        0.352182  0.493033
# 5             3919       0.588965     0.857106        0.324447  0.470712
# 6             3919       0.808848     0.145700        0.775815  0.245328
# 7             3919       0.818860     0.254912        0.709517  0.375070
# 8             3919       0.774839     0.640725        0.479107  0.548253
# 9             3919       0.800577     0.458280        0.538047  0.494970
# 10            3919       0.667864     0.811942        0.372207  0.510427
# 11            3919       0.788878     0.480225        0.505235  0.492412
#
# [12 rows x 31 columns]
