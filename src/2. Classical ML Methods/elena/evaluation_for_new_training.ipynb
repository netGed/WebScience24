# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## tfidf

# %%
tfidf_sig = pd.read_csv('./eval_data/original_data/svm_grid_tfidf_sigmoid.csv', index_col=0)

filtered_df = tfidf_sig[(tfidf_sig['kernel'] == 'sigmoid')]

filtered_df.sort_values(by=["test_recall"], ascending=False).head(15)
# Out:
#                 kernel degree    C  gamma  random_state  class_weight  \
# vectorization
# tfidf          sigmoid      X  1.0    1.0            44  {0: 1, 1: 5}
# tfidf          sigmoid      X  1.0    1.0            42  {0: 1, 1: 5}
# tfidf          sigmoid      X  1.0    1.0            40  {0: 1, 1: 5}
# tfidf          sigmoid      X  1.0    1.0            44  {0: 1, 1: 3}
# tfidf          sigmoid      X  1.0    1.0            42  {0: 1, 1: 3}
# tfidf          sigmoid      X  1.0    1.0            40  {0: 1, 1: 3}
# tfidf          sigmoid      X  0.1    1.0            40  {0: 1, 1: 5}
# tfidf          sigmoid      X  0.1    1.0            42  {0: 1, 1: 5}
# tfidf          sigmoid      X  0.1    1.0            44  {0: 1, 1: 5}
# tfidf          sigmoid      X  1.0    0.1            44  {0: 1, 1: 5}
# tfidf          sigmoid      X  1.0    0.1            42  {0: 1, 1: 5}
# tfidf          sigmoid      X  1.0    0.1            40  {0: 1, 1: 5}
# ...

# %%
tfidf_sig = pd.read_csv('./eval_data/original_data/svm_grid_tfidf_linear.csv', index_col=0)

filtered_df = tfidf_sig[(tfidf_sig['kernel'] == 'linear')]

filtered_df.sort_values(by=["test_recall"], ascending=False).head(15)
# Out:
#                kernel degree    C  gamma  random_state  class_weight  \
# vectorization
# tfidf          linear      X  1.0   1.00            44  {0: 1, 1: 5}
# tfidf          linear      X  1.0   1.00            42  {0: 1, 1: 5}
# tfidf          linear      X  1.0   1.00            40  {0: 1, 1: 5}
# tfidf          linear      X  1.0   0.10            44  {0: 1, 1: 5}
# tfidf          linear      X  1.0   0.10            42  {0: 1, 1: 5}
# tfidf          linear      X  1.0   0.10            40  {0: 1, 1: 5}
# tfidf          linear      X  1.0   0.01            44  {0: 1, 1: 5}
# tfidf          linear      X  1.0   0.01            42  {0: 1, 1: 5}
# tfidf          linear      X  1.0   0.01            40  {0: 1, 1: 5}
# tfidf          linear      X  1.0   0.10            42  {0: 1, 1: 3}
# tfidf          linear      X  1.0   0.01            40  {0: 1, 1: 3}
# tfidf          linear      X  1.0   0.01            42  {0: 1, 1: 3}
# ...

# %%
tfidf_sig = pd.read_csv('./eval_data/original_data/svm_grid_tfidf_poly.csv', index_col=0)

filtered_df = tfidf_sig[(tfidf_sig['kernel'] == 'poly')]

filtered_df.sort_values(by=["test_recall"], ascending=False).head(15)
# Out:
#               kernel  degree    C  gamma  random_state  class_weight  \
# vectorization
# tfidf           poly       3  1.0    1.0            42  {0: 1, 1: 5}
# tfidf           poly       3  1.0    1.0            40  {0: 1, 1: 5}
# tfidf           poly       3  1.0    1.0            40  {0: 1, 1: 3}
# tfidf           poly       3  1.0    1.0            42  {0: 1, 1: 3}
# tfidf           poly       3  1.0    1.0            44  {0: 1, 1: 3}
# tfidf           poly       3  1.0    1.0            44  {0: 1, 1: 5}
# tfidf           poly       4  1.0    1.0            40  {0: 1, 1: 3}
# tfidf           poly       4  1.0    1.0            42  {0: 1, 1: 3}
# tfidf           poly       4  1.0    1.0            44  {0: 1, 1: 3}
# tfidf           poly       4  1.0    1.0            44  {0: 1, 1: 5}
# tfidf           poly       4  1.0    1.0            42  {0: 1, 1: 5}
# tfidf           poly       4  1.0    1.0            40  {0: 1, 1: 5}
# ...

# %%
tfidf_sig = pd.read_csv('./eval_data/original_data/svm_grid_tfidf_rbf.csv', index_col=0)

filtered_df = tfidf_sig[(tfidf_sig['kernel'] == 'rbf')]

filtered_df.sort_values(by=["test_recall"], ascending=False).head(15)
# Out:
#               kernel degree    C  gamma  random_state  class_weight  \
# vectorization
# tfidf            rbf      X  1.0    0.1            44  {0: 1, 1: 5}
# tfidf            rbf      X  1.0    0.1            42  {0: 1, 1: 5}
# tfidf            rbf      X  1.0    0.1            40  {0: 1, 1: 5}
# tfidf            rbf      X  1.0    0.1            42  {0: 1, 1: 3}
# tfidf            rbf      X  1.0    0.1            40  {0: 1, 1: 3}
# tfidf            rbf      X  1.0    0.1            44  {0: 1, 1: 3}
# tfidf            rbf      X  1.0    1.0            44  {0: 1, 1: 5}
# tfidf            rbf      X  1.0    1.0            42  {0: 1, 1: 5}
# tfidf            rbf      X  1.0    1.0            40  {0: 1, 1: 5}
# tfidf            rbf      X  1.0    1.0            44  {0: 1, 1: 3}
# tfidf            rbf      X  1.0    1.0            42  {0: 1, 1: 3}
# tfidf            rbf      X  1.0    1.0            40  {0: 1, 1: 3}
# tfidf            rbf      X  1.0    1.0            40  {0: 1, 1: 1}
# ...

# %% [markdown]
# ## w2v

# %%
tfidf_sig = pd.read_csv('./eval_data/original_data/svm_grid_w2v_sigmoid.csv', index_col=0)

filtered_df = tfidf_sig[(tfidf_sig['kernel'] == 'sigmoid')]

filtered_df.sort_values(by=["test_recall"], ascending=False).head(15)
# Out:
#                 kernel degree     C  gamma  random_state  class_weight  \
# vectorization
# w2v            sigmoid      X  1.00   0.01            44  {0: 1, 1: 5}
# w2v            sigmoid      X  1.00   0.01            42  {0: 1, 1: 5}
# w2v            sigmoid      X  1.00   0.01            40  {0: 1, 1: 5}
# w2v            sigmoid      X  0.10   0.01            42  {0: 1, 1: 5}
# w2v            sigmoid      X  0.10   0.01            40  {0: 1, 1: 5}
# w2v            sigmoid      X  0.10   0.01            44  {0: 1, 1: 5}
# w2v            sigmoid      X  0.10   0.10            44  {0: 1, 1: 5}
# w2v            sigmoid      X  0.10   0.10            40  {0: 1, 1: 5}
# w2v            sigmoid      X  0.10   0.10            42  {0: 1, 1: 5}
# w2v            sigmoid      X  0.01   0.10            44  {0: 1, 1: 5}
# w2v            sigmoid      X  0.01   0.10            40  {0: 1, 1: 5}
# w2v            sigmoid      X  0.01   0.10            42  {0: 1, 1: 5}
# ...

# %%
tfidf_sig = pd.read_csv('./eval_data/original_data/svm_grid_w2v_linear.csv', index_col=0)

filtered_df = tfidf_sig[(tfidf_sig['kernel'] == 'linear')]

filtered_df.sort_values(by=["test_recall"], ascending=False).head(15)
# Out:
#                kernel degree    C  gamma  random_state  class_weight  \
# vectorization
# w2v            linear      X  0.1   0.01            42  {0: 1, 1: 5}
# w2v            linear      X  0.1   0.01            40  {0: 1, 1: 5}
# w2v            linear      X  0.1   1.00            44  {0: 1, 1: 5}
# w2v            linear      X  0.1   1.00            42  {0: 1, 1: 5}
# w2v            linear      X  0.1   1.00            40  {0: 1, 1: 5}
# w2v            linear      X  0.1   0.10            44  {0: 1, 1: 5}
# w2v            linear      X  0.1   0.10            42  {0: 1, 1: 5}
# w2v            linear      X  0.1   0.10            40  {0: 1, 1: 5}
# w2v            linear      X  0.1   0.01            44  {0: 1, 1: 5}
# w2v            linear      X  1.0   1.00            44  {0: 1, 1: 5}
# w2v            linear      X  1.0   0.01            40  {0: 1, 1: 5}
# w2v            linear      X  1.0   0.01            42  {0: 1, 1: 5}
# ...

# %%
tfidf_sig = pd.read_csv('./eval_data/original_data/svm_grid_w2v_poly.csv', index_col=0)

filtered_df = tfidf_sig[(tfidf_sig['kernel'] == 'poly')]

filtered_df.sort_values(by=["test_recall"], ascending=False).head(15)
# Out:
#               kernel  degree     C  gamma  random_state  class_weight  \
# vectorization
# w2v             poly       3  1.00    0.1            40  {0: 1, 1: 5}
# w2v             poly       3  1.00    0.1            42  {0: 1, 1: 5}
# w2v             poly       3  1.00    0.1            44  {0: 1, 1: 5}
# w2v             poly       3  0.10    0.1            42  {0: 1, 1: 5}
# w2v             poly       3  0.10    0.1            44  {0: 1, 1: 5}
# w2v             poly       3  0.10    0.1            40  {0: 1, 1: 5}
# w2v             poly       4  1.00    0.1            44  {0: 1, 1: 5}
# w2v             poly       4  1.00    0.1            40  {0: 1, 1: 5}
# w2v             poly       4  1.00    0.1            42  {0: 1, 1: 5}
# w2v             poly       3  0.01    1.0            40  {0: 1, 1: 5}
# w2v             poly       3  0.01    1.0            42  {0: 1, 1: 5}
# w2v             poly       3  0.01    1.0            44  {0: 1, 1: 5}
# ...

# %%
tfidf_sig = pd.read_csv('./eval_data/original_data/svm_grid_w2v_rbf.csv', index_col=0)

filtered_df = tfidf_sig[(tfidf_sig['kernel'] == 'rbf')]

filtered_df.sort_values(by=["test_recall"], ascending=False).head(15)
# Out:
#               kernel degree    C  gamma  random_state  class_weight  \
# vectorization
# w2v              rbf      X  1.0   0.10            44  {0: 1, 1: 5}
# w2v              rbf      X  1.0   0.10            42  {0: 1, 1: 5}
# w2v              rbf      X  1.0   0.10            40  {0: 1, 1: 5}
# w2v              rbf      X  1.0   0.01            44  {0: 1, 1: 5}
# w2v              rbf      X  1.0   0.01            42  {0: 1, 1: 5}
# w2v              rbf      X  1.0   0.01            40  {0: 1, 1: 5}
# w2v              rbf      X  0.1   0.10            42  {0: 1, 1: 5}
# w2v              rbf      X  0.1   0.10            40  {0: 1, 1: 5}
# w2v              rbf      X  0.1   0.10            44  {0: 1, 1: 5}
# w2v              rbf      X  0.1   0.01            40  {0: 1, 1: 5}
# w2v              rbf      X  0.1   0.01            44  {0: 1, 1: 5}
# w2v              rbf      X  0.1   0.01            42  {0: 1, 1: 5}
# w2v              rbf      X  1.0   0.10            40  {0: 1, 1: 3}
# ...
