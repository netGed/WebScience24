# %%
import pandas as pd

# %%
tfidf = pd.read_csv('./eval_data/evaluation_tfidf.csv', index_col=0)
bow = pd.read_csv('./eval_data/evaluation_bow.csv', index_col=0)
w2v = pd.read_csv('./eval_data/evaluation_w2v.csv', index_col=0)
ft = pd.read_csv('./eval_data/evaluation_ft.csv', index_col=0)

# %%
evaluation = pd.concat([tfidf,
                        bow,
                        w2v,
                        ft,
                        ])

# %%
evaluation
# Out:
#                                    model variant vectorize_variant  train_acc  \
# 0                     StackingClassifier   clean             tfidf   0.995040
# 1                 RandomForestClassifier   clean             tfidf   0.999897
# 2              RandomForest-tuned-optuna   clean             tfidf   0.972305
# 3         BalancedRandomForestClassifier   clean             tfidf   0.905549
# 4   BalancedRandomForestClassifier-tuned   clean             tfidf   0.885398
# 5                          XGBClassifier   clean             tfidf   0.959750
# 6               XGBClassifier-tuned-grid   clean             tfidf   0.962333
# 7               XGBClassifier-tuned-rand   clean             tfidf   0.951276
# 8             XGBClassifier-tuned-optuna   clean             tfidf   0.978919
# 9                     CatBoostClassifier   clean             tfidf   0.946058
# 10                        LGBMClassifier   clean             tfidf   0.961713
# 0                 RandomForestClassifier   clean               bow   0.999948
# 1      RandomForestClassifier-tuned-rand   clean               bow   0.939857
# 2              RandomForest-tuned-optuna   clean               bow   0.978196
# 3         BalancedRandomForestClassifier   clean               bow   0.897541
# 4   BalancedRandomForestClassifier-tuned   clean               bow   0.856670
# 5                          XGBClassifier   clean               bow   0.956805
# 6               XGBClassifier-tuned-grid   clean               bow   0.958200
# 7               XGBClassifier-tuned-rand   clean               bow   0.941149
# 8             XGBClassifier-tuned-optuna   clean               bow   0.990648
# 9                     CatBoostClassifier   clean               bow   0.947039
# 10                    StackingClassifier   clean               bow   0.998708
# 0                 RandomForestClassifier   clean               w2v   0.999948
# 1      RandomForestClassifier-tuned-rand   clean               w2v   0.943991
# 2              RandomForest-tuned-optuna   clean               w2v   0.999897
# 3               XGBClassifier-tuned-grid   clean               w2v   0.999948
# 4               XGBClassifier-tuned-rand   clean               w2v   0.999173
# 5                     CatBoostClassifier   clean               w2v   0.954170
# 6                         LGBMClassifier   clean               w2v   0.995763
# 7                     StackingClassifier   clean               w2v   0.969722
# 8                          XGBClassifier   clean               w2v   0.999948
# 9         BalancedRandomForestClassifier   clean               w2v   0.868916
# 10  BalancedRandomForestClassifier-tuned   clean               w2v   0.826961
# 0                 RandomForestClassifier   clean                ft   0.999948
# 1      RandomForestClassifier-tuned-rand   clean                ft   0.943526
# 2         BalancedRandomForestClassifier   clean                ft   0.860184
# 3   BalancedRandomForestClassifier-tuned   clean                ft   0.817195
# 4                          XGBClassifier   clean                ft   0.999948
# 5               XGBClassifier-tuned-grid   clean                ft   0.999948
# 6               XGBClassifier-tuned-rand   clean                ft   0.998192
# 7             XGBClassifier-tuned-optuna   clean                ft   0.939651
# 8                     CatBoostClassifier   clean                ft   0.952361
# 9                         LGBMClassifier   clean                ft   0.995298
# 10                    StackingClassifier   clean                ft   0.971065
# 11             RandomForest-tuned-optuna   clean                ft   0.999948
#
#     train_prec  train_rec  train_f1  test_acc  test_prec  test_rec   test_f1
# 0     0.988353   0.935433  0.961165  0.960699   0.799443  0.530499  0.637778
# 1     1.000000   0.998425  0.999212  0.957806   0.832753  0.441774  0.577295
# 2     0.990642   0.583465  0.734390  0.954430   0.865471  0.356747  0.505236
# 3     0.409942   1.000000  0.581502  0.883785   0.322716  0.711645  0.444060
# 4     0.334266   0.752756  0.462954  0.885473   0.322328  0.685767  0.438534
# 5     0.922547   0.422047  0.579146  0.950332   0.808612  0.312384  0.450667
# 6     0.921997   0.465354  0.618524  0.950693   0.775000  0.343808  0.476312
# 7     0.931398   0.277953  0.428138  0.948162   0.844720  0.251386  0.387464
# 8     0.985360   0.688976  0.810936  0.953707   0.783394  0.401109  0.530562
# 9     0.915441   0.196063  0.322957  0.945750   0.902655  0.188540  0.311927
# 10    0.927302   0.451969  0.607729  0.948162   0.753425  0.304991  0.434211
# 0     1.000000   0.999213  0.999606  0.955274   0.759146  0.460259  0.573072
# 1     0.778947   0.116535  0.202740  0.940205   0.764706  0.120148  0.207668
# 2     1.000000   0.667717  0.800755  0.956239   0.844961  0.402957  0.545682
# 3     0.390409   1.000000  0.561574  0.875949   0.309672  0.733826  0.435546
# 4     0.289709   0.815748  0.427569  0.853406   0.273338  0.752311  0.400985
# 5     0.894545   0.387402  0.540659  0.951537   0.808889  0.336414  0.475196
# 6     0.876020   0.422835  0.570366  0.952381   0.792000  0.365989  0.500632
# 7     0.695522   0.183465  0.290343  0.940928   0.675862  0.181146  0.285714
# 8     0.989218   0.866929  0.924045  0.953225   0.690773  0.512015  0.588110
# 9     0.893891   0.218898  0.351676  0.946594   0.876923  0.210721  0.339791
# 10    1.000000   0.980315  0.990060  0.958770   0.781870  0.510166  0.617450
# 0     1.000000   0.999213  0.999606  0.943701   0.793651  0.184843  0.299850
# 1     0.839416   0.181102  0.297927  0.941893   0.792079  0.147874  0.249221
# 2     1.000000   0.998425  0.999212  0.943701   0.772059  0.194085  0.310192
# 3     1.000000   0.999213  0.999606  0.948523   0.733607  0.330869  0.456051
# 4     0.999204   0.988189  0.993666  0.948885   0.725869  0.347505  0.470000
# 5     0.830743   0.378740  0.520281  0.944304   0.683721  0.271719  0.388889
# 6     0.995826   0.939370  0.966775  0.948764   0.732000  0.338262  0.462705
# 7     0.907143   0.600000  0.722275  0.946715   0.702041  0.317930  0.437659
# 8     1.000000   0.999213  0.999606  0.947438   0.690909  0.351201  0.465686
# 9     0.333596   1.000000  0.500295  0.840506   0.259828  0.781885  0.390041
# 10    0.253615   0.842520  0.389871  0.822905   0.239033  0.785582  0.366537
# 0     0.999213   1.000000  0.999606  0.944304   0.796992  0.195933  0.314540
# 1     0.784566   0.192126  0.308665  0.940928   0.700787  0.164510  0.266467
# 2     0.319416   1.000000  0.484178  0.837734   0.259988  0.805915  0.393147
# 3     0.240741   0.829134  0.373140  0.816998   0.232035  0.781885  0.357868
# 4     1.000000   0.999213  0.999606  0.946835   0.695312  0.329020  0.446675
# 5     1.000000   0.999213  0.999606  0.947800   0.728814  0.317930  0.442728
# 6     1.000000   0.972441  0.986028  0.949005   0.750000  0.327172  0.455598
# 7     0.618605   0.209449  0.312941  0.939120   0.613924  0.179298  0.277539
# 8     0.828302   0.345669  0.487778  0.943219   0.669903  0.255083  0.369478
# 9     0.993305   0.934646  0.963083  0.946112   0.689516  0.316081  0.433460
# 10    0.914720   0.616535  0.736595  0.945992   0.706667  0.293900  0.415144
# 11    1.000000   0.999213  0.999606  0.943339   0.779528  0.182994  0.296407

# %%
evaluation.sort_values(by=["test_prec"], ascending=False)
# Out:
#                                    model variant vectorize_variant  train_acc  \
# 9                     CatBoostClassifier   clean             tfidf   0.946058
# 9                     CatBoostClassifier   clean               bow   0.947039
# 2              RandomForest-tuned-optuna   clean             tfidf   0.972305
# 2              RandomForest-tuned-optuna   clean               bow   0.978196
# 7               XGBClassifier-tuned-rand   clean             tfidf   0.951276
# 1                 RandomForestClassifier   clean             tfidf   0.999897
# 5                          XGBClassifier   clean               bow   0.956805
# 5                          XGBClassifier   clean             tfidf   0.959750
# 0                     StackingClassifier   clean             tfidf   0.995040
# 0                 RandomForestClassifier   clean                ft   0.999948
# 0                 RandomForestClassifier   clean               w2v   0.999948
# 1      RandomForestClassifier-tuned-rand   clean               w2v   0.943991
# 6               XGBClassifier-tuned-grid   clean               bow   0.958200
# 8             XGBClassifier-tuned-optuna   clean             tfidf   0.978919
# 10                    StackingClassifier   clean               bow   0.998708
# 11             RandomForest-tuned-optuna   clean                ft   0.999948
# 6               XGBClassifier-tuned-grid   clean             tfidf   0.962333
# 2              RandomForest-tuned-optuna   clean               w2v   0.999897
# 1      RandomForestClassifier-tuned-rand   clean               bow   0.939857
# 0                 RandomForestClassifier   clean               bow   0.999948
# 10                        LGBMClassifier   clean             tfidf   0.961713
# 6               XGBClassifier-tuned-rand   clean                ft   0.998192
# 3               XGBClassifier-tuned-grid   clean               w2v   0.999948
# 6                         LGBMClassifier   clean               w2v   0.995763
# 5               XGBClassifier-tuned-grid   clean                ft   0.999948
# 4               XGBClassifier-tuned-rand   clean               w2v   0.999173
# 10                    StackingClassifier   clean                ft   0.971065
# 7                     StackingClassifier   clean               w2v   0.969722
# 1      RandomForestClassifier-tuned-rand   clean                ft   0.943526
# 4                          XGBClassifier   clean                ft   0.999948
# 8                          XGBClassifier   clean               w2v   0.999948
# 8             XGBClassifier-tuned-optuna   clean               bow   0.990648
# 9                         LGBMClassifier   clean                ft   0.995298
# 5                     CatBoostClassifier   clean               w2v   0.954170
# 7               XGBClassifier-tuned-rand   clean               bow   0.941149
# 8                     CatBoostClassifier   clean                ft   0.952361
# 7             XGBClassifier-tuned-optuna   clean                ft   0.939651
# 3         BalancedRandomForestClassifier   clean             tfidf   0.905549
# 4   BalancedRandomForestClassifier-tuned   clean             tfidf   0.885398
# 3         BalancedRandomForestClassifier   clean               bow   0.897541
# 4   BalancedRandomForestClassifier-tuned   clean               bow   0.856670
# 2         BalancedRandomForestClassifier   clean                ft   0.860184
# 9         BalancedRandomForestClassifier   clean               w2v   0.868916
# 10  BalancedRandomForestClassifier-tuned   clean               w2v   0.826961
# 3   BalancedRandomForestClassifier-tuned   clean                ft   0.817195
#
#     train_prec  train_rec  train_f1  test_acc  test_prec  test_rec   test_f1
# 9     0.915441   0.196063  0.322957  0.945750   0.902655  0.188540  0.311927
# 9     0.893891   0.218898  0.351676  0.946594   0.876923  0.210721  0.339791
# 2     0.990642   0.583465  0.734390  0.954430   0.865471  0.356747  0.505236
# 2     1.000000   0.667717  0.800755  0.956239   0.844961  0.402957  0.545682
# 7     0.931398   0.277953  0.428138  0.948162   0.844720  0.251386  0.387464
# 1     1.000000   0.998425  0.999212  0.957806   0.832753  0.441774  0.577295
# 5     0.894545   0.387402  0.540659  0.951537   0.808889  0.336414  0.475196
# 5     0.922547   0.422047  0.579146  0.950332   0.808612  0.312384  0.450667
# 0     0.988353   0.935433  0.961165  0.960699   0.799443  0.530499  0.637778
# 0     0.999213   1.000000  0.999606  0.944304   0.796992  0.195933  0.314540
# 0     1.000000   0.999213  0.999606  0.943701   0.793651  0.184843  0.299850
# 1     0.839416   0.181102  0.297927  0.941893   0.792079  0.147874  0.249221
# 6     0.876020   0.422835  0.570366  0.952381   0.792000  0.365989  0.500632
# 8     0.985360   0.688976  0.810936  0.953707   0.783394  0.401109  0.530562
# 10    1.000000   0.980315  0.990060  0.958770   0.781870  0.510166  0.617450
# 11    1.000000   0.999213  0.999606  0.943339   0.779528  0.182994  0.296407
# 6     0.921997   0.465354  0.618524  0.950693   0.775000  0.343808  0.476312
# 2     1.000000   0.998425  0.999212  0.943701   0.772059  0.194085  0.310192
# 1     0.778947   0.116535  0.202740  0.940205   0.764706  0.120148  0.207668
# 0     1.000000   0.999213  0.999606  0.955274   0.759146  0.460259  0.573072
# 10    0.927302   0.451969  0.607729  0.948162   0.753425  0.304991  0.434211
# 6     1.000000   0.972441  0.986028  0.949005   0.750000  0.327172  0.455598
# 3     1.000000   0.999213  0.999606  0.948523   0.733607  0.330869  0.456051
# 6     0.995826   0.939370  0.966775  0.948764   0.732000  0.338262  0.462705
# 5     1.000000   0.999213  0.999606  0.947800   0.728814  0.317930  0.442728
# 4     0.999204   0.988189  0.993666  0.948885   0.725869  0.347505  0.470000
# 10    0.914720   0.616535  0.736595  0.945992   0.706667  0.293900  0.415144
# 7     0.907143   0.600000  0.722275  0.946715   0.702041  0.317930  0.437659
# 1     0.784566   0.192126  0.308665  0.940928   0.700787  0.164510  0.266467
# 4     1.000000   0.999213  0.999606  0.946835   0.695312  0.329020  0.446675
# 8     1.000000   0.999213  0.999606  0.947438   0.690909  0.351201  0.465686
# 8     0.989218   0.866929  0.924045  0.953225   0.690773  0.512015  0.588110
# 9     0.993305   0.934646  0.963083  0.946112   0.689516  0.316081  0.433460
# 5     0.830743   0.378740  0.520281  0.944304   0.683721  0.271719  0.388889
# 7     0.695522   0.183465  0.290343  0.940928   0.675862  0.181146  0.285714
# 8     0.828302   0.345669  0.487778  0.943219   0.669903  0.255083  0.369478
# 7     0.618605   0.209449  0.312941  0.939120   0.613924  0.179298  0.277539
# 3     0.409942   1.000000  0.581502  0.883785   0.322716  0.711645  0.444060
# 4     0.334266   0.752756  0.462954  0.885473   0.322328  0.685767  0.438534
# 3     0.390409   1.000000  0.561574  0.875949   0.309672  0.733826  0.435546
# 4     0.289709   0.815748  0.427569  0.853406   0.273338  0.752311  0.400985
# 2     0.319416   1.000000  0.484178  0.837734   0.259988  0.805915  0.393147
# 9     0.333596   1.000000  0.500295  0.840506   0.259828  0.781885  0.390041
# 10    0.253615   0.842520  0.389871  0.822905   0.239033  0.785582  0.366537
# 3     0.240741   0.829134  0.373140  0.816998   0.232035  0.781885  0.357868

# %%
evaluation.sort_values(by=["test_rec"], ascending=False)
# Out:
#                                    model variant vectorize_variant  train_acc  \
# 2         BalancedRandomForestClassifier   clean                ft   0.860184
# 10  BalancedRandomForestClassifier-tuned   clean               w2v   0.826961
# 3   BalancedRandomForestClassifier-tuned   clean                ft   0.817195
# 9         BalancedRandomForestClassifier   clean               w2v   0.868916
# 4   BalancedRandomForestClassifier-tuned   clean               bow   0.856670
# 3         BalancedRandomForestClassifier   clean               bow   0.897541
# 3         BalancedRandomForestClassifier   clean             tfidf   0.905549
# 4   BalancedRandomForestClassifier-tuned   clean             tfidf   0.885398
# 0                     StackingClassifier   clean             tfidf   0.995040
# 8             XGBClassifier-tuned-optuna   clean               bow   0.990648
# 10                    StackingClassifier   clean               bow   0.998708
# 0                 RandomForestClassifier   clean               bow   0.999948
# 1                 RandomForestClassifier   clean             tfidf   0.999897
# 2              RandomForest-tuned-optuna   clean               bow   0.978196
# 8             XGBClassifier-tuned-optuna   clean             tfidf   0.978919
# 6               XGBClassifier-tuned-grid   clean               bow   0.958200
# 2              RandomForest-tuned-optuna   clean             tfidf   0.972305
# 8                          XGBClassifier   clean               w2v   0.999948
# 4               XGBClassifier-tuned-rand   clean               w2v   0.999173
# 6               XGBClassifier-tuned-grid   clean             tfidf   0.962333
# 6                         LGBMClassifier   clean               w2v   0.995763
# 5                          XGBClassifier   clean               bow   0.956805
# 3               XGBClassifier-tuned-grid   clean               w2v   0.999948
# 4                          XGBClassifier   clean                ft   0.999948
# 6               XGBClassifier-tuned-rand   clean                ft   0.998192
# 7                     StackingClassifier   clean               w2v   0.969722
# 5               XGBClassifier-tuned-grid   clean                ft   0.999948
# 9                         LGBMClassifier   clean                ft   0.995298
# 5                          XGBClassifier   clean             tfidf   0.959750
# 10                        LGBMClassifier   clean             tfidf   0.961713
# 10                    StackingClassifier   clean                ft   0.971065
# 5                     CatBoostClassifier   clean               w2v   0.954170
# 8                     CatBoostClassifier   clean                ft   0.952361
# 7               XGBClassifier-tuned-rand   clean             tfidf   0.951276
# 9                     CatBoostClassifier   clean               bow   0.947039
# 0                 RandomForestClassifier   clean                ft   0.999948
# 2              RandomForest-tuned-optuna   clean               w2v   0.999897
# 9                     CatBoostClassifier   clean             tfidf   0.946058
# 0                 RandomForestClassifier   clean               w2v   0.999948
# 11             RandomForest-tuned-optuna   clean                ft   0.999948
# 7               XGBClassifier-tuned-rand   clean               bow   0.941149
# 7             XGBClassifier-tuned-optuna   clean                ft   0.939651
# 1      RandomForestClassifier-tuned-rand   clean                ft   0.943526
# 1      RandomForestClassifier-tuned-rand   clean               w2v   0.943991
# 1      RandomForestClassifier-tuned-rand   clean               bow   0.939857
#
#     train_prec  train_rec  train_f1  test_acc  test_prec  test_rec   test_f1
# 2     0.319416   1.000000  0.484178  0.837734   0.259988  0.805915  0.393147
# 10    0.253615   0.842520  0.389871  0.822905   0.239033  0.785582  0.366537
# 3     0.240741   0.829134  0.373140  0.816998   0.232035  0.781885  0.357868
# 9     0.333596   1.000000  0.500295  0.840506   0.259828  0.781885  0.390041
# 4     0.289709   0.815748  0.427569  0.853406   0.273338  0.752311  0.400985
# 3     0.390409   1.000000  0.561574  0.875949   0.309672  0.733826  0.435546
# 3     0.409942   1.000000  0.581502  0.883785   0.322716  0.711645  0.444060
# 4     0.334266   0.752756  0.462954  0.885473   0.322328  0.685767  0.438534
# 0     0.988353   0.935433  0.961165  0.960699   0.799443  0.530499  0.637778
# 8     0.989218   0.866929  0.924045  0.953225   0.690773  0.512015  0.588110
# 10    1.000000   0.980315  0.990060  0.958770   0.781870  0.510166  0.617450
# 0     1.000000   0.999213  0.999606  0.955274   0.759146  0.460259  0.573072
# 1     1.000000   0.998425  0.999212  0.957806   0.832753  0.441774  0.577295
# 2     1.000000   0.667717  0.800755  0.956239   0.844961  0.402957  0.545682
# 8     0.985360   0.688976  0.810936  0.953707   0.783394  0.401109  0.530562
# 6     0.876020   0.422835  0.570366  0.952381   0.792000  0.365989  0.500632
# 2     0.990642   0.583465  0.734390  0.954430   0.865471  0.356747  0.505236
# 8     1.000000   0.999213  0.999606  0.947438   0.690909  0.351201  0.465686
# 4     0.999204   0.988189  0.993666  0.948885   0.725869  0.347505  0.470000
# 6     0.921997   0.465354  0.618524  0.950693   0.775000  0.343808  0.476312
# 6     0.995826   0.939370  0.966775  0.948764   0.732000  0.338262  0.462705
# 5     0.894545   0.387402  0.540659  0.951537   0.808889  0.336414  0.475196
# 3     1.000000   0.999213  0.999606  0.948523   0.733607  0.330869  0.456051
# 4     1.000000   0.999213  0.999606  0.946835   0.695312  0.329020  0.446675
# 6     1.000000   0.972441  0.986028  0.949005   0.750000  0.327172  0.455598
# 7     0.907143   0.600000  0.722275  0.946715   0.702041  0.317930  0.437659
# 5     1.000000   0.999213  0.999606  0.947800   0.728814  0.317930  0.442728
# 9     0.993305   0.934646  0.963083  0.946112   0.689516  0.316081  0.433460
# 5     0.922547   0.422047  0.579146  0.950332   0.808612  0.312384  0.450667
# 10    0.927302   0.451969  0.607729  0.948162   0.753425  0.304991  0.434211
# 10    0.914720   0.616535  0.736595  0.945992   0.706667  0.293900  0.415144
# 5     0.830743   0.378740  0.520281  0.944304   0.683721  0.271719  0.388889
# 8     0.828302   0.345669  0.487778  0.943219   0.669903  0.255083  0.369478
# 7     0.931398   0.277953  0.428138  0.948162   0.844720  0.251386  0.387464
# 9     0.893891   0.218898  0.351676  0.946594   0.876923  0.210721  0.339791
# 0     0.999213   1.000000  0.999606  0.944304   0.796992  0.195933  0.314540
# 2     1.000000   0.998425  0.999212  0.943701   0.772059  0.194085  0.310192
# 9     0.915441   0.196063  0.322957  0.945750   0.902655  0.188540  0.311927
# 0     1.000000   0.999213  0.999606  0.943701   0.793651  0.184843  0.299850
# 11    1.000000   0.999213  0.999606  0.943339   0.779528  0.182994  0.296407
# 7     0.695522   0.183465  0.290343  0.940928   0.675862  0.181146  0.285714
# 7     0.618605   0.209449  0.312941  0.939120   0.613924  0.179298  0.277539
# 1     0.784566   0.192126  0.308665  0.940928   0.700787  0.164510  0.266467
# 1     0.839416   0.181102  0.297927  0.941893   0.792079  0.147874  0.249221
# 1     0.778947   0.116535  0.202740  0.940205   0.764706  0.120148  0.207668

# %%
evaluation.sort_values(by=["test_f1"], ascending=False)
# Out:
#                                    model variant vectorize_variant  train_acc  \
# 0                     StackingClassifier   clean             tfidf   0.995040
# 10                    StackingClassifier   clean               bow   0.998708
# 8             XGBClassifier-tuned-optuna   clean               bow   0.990648
# 1                 RandomForestClassifier   clean             tfidf   0.999897
# 0                 RandomForestClassifier   clean               bow   0.999948
# 2              RandomForest-tuned-optuna   clean               bow   0.978196
# 8             XGBClassifier-tuned-optuna   clean             tfidf   0.978919
# 2              RandomForest-tuned-optuna   clean             tfidf   0.972305
# 6               XGBClassifier-tuned-grid   clean               bow   0.958200
# 6               XGBClassifier-tuned-grid   clean             tfidf   0.962333
# 5                          XGBClassifier   clean               bow   0.956805
# 4               XGBClassifier-tuned-rand   clean               w2v   0.999173
# 8                          XGBClassifier   clean               w2v   0.999948
# 6                         LGBMClassifier   clean               w2v   0.995763
# 3               XGBClassifier-tuned-grid   clean               w2v   0.999948
# 6               XGBClassifier-tuned-rand   clean                ft   0.998192
# 5                          XGBClassifier   clean             tfidf   0.959750
# 4                          XGBClassifier   clean                ft   0.999948
# 3         BalancedRandomForestClassifier   clean             tfidf   0.905549
# 5               XGBClassifier-tuned-grid   clean                ft   0.999948
# 4   BalancedRandomForestClassifier-tuned   clean             tfidf   0.885398
# 7                     StackingClassifier   clean               w2v   0.969722
# 3         BalancedRandomForestClassifier   clean               bow   0.897541
# 10                        LGBMClassifier   clean             tfidf   0.961713
# 9                         LGBMClassifier   clean                ft   0.995298
# 10                    StackingClassifier   clean                ft   0.971065
# 4   BalancedRandomForestClassifier-tuned   clean               bow   0.856670
# 2         BalancedRandomForestClassifier   clean                ft   0.860184
# 9         BalancedRandomForestClassifier   clean               w2v   0.868916
# 5                     CatBoostClassifier   clean               w2v   0.954170
# 7               XGBClassifier-tuned-rand   clean             tfidf   0.951276
# 8                     CatBoostClassifier   clean                ft   0.952361
# 10  BalancedRandomForestClassifier-tuned   clean               w2v   0.826961
# 3   BalancedRandomForestClassifier-tuned   clean                ft   0.817195
# 9                     CatBoostClassifier   clean               bow   0.947039
# 0                 RandomForestClassifier   clean                ft   0.999948
# 9                     CatBoostClassifier   clean             tfidf   0.946058
# 2              RandomForest-tuned-optuna   clean               w2v   0.999897
# 0                 RandomForestClassifier   clean               w2v   0.999948
# 11             RandomForest-tuned-optuna   clean                ft   0.999948
# 7               XGBClassifier-tuned-rand   clean               bow   0.941149
# 7             XGBClassifier-tuned-optuna   clean                ft   0.939651
# 1      RandomForestClassifier-tuned-rand   clean                ft   0.943526
# 1      RandomForestClassifier-tuned-rand   clean               w2v   0.943991
# 1      RandomForestClassifier-tuned-rand   clean               bow   0.939857
#
#     train_prec  train_rec  train_f1  test_acc  test_prec  test_rec   test_f1
# 0     0.988353   0.935433  0.961165  0.960699   0.799443  0.530499  0.637778
# 10    1.000000   0.980315  0.990060  0.958770   0.781870  0.510166  0.617450
# 8     0.989218   0.866929  0.924045  0.953225   0.690773  0.512015  0.588110
# 1     1.000000   0.998425  0.999212  0.957806   0.832753  0.441774  0.577295
# 0     1.000000   0.999213  0.999606  0.955274   0.759146  0.460259  0.573072
# 2     1.000000   0.667717  0.800755  0.956239   0.844961  0.402957  0.545682
# 8     0.985360   0.688976  0.810936  0.953707   0.783394  0.401109  0.530562
# 2     0.990642   0.583465  0.734390  0.954430   0.865471  0.356747  0.505236
# 6     0.876020   0.422835  0.570366  0.952381   0.792000  0.365989  0.500632
# 6     0.921997   0.465354  0.618524  0.950693   0.775000  0.343808  0.476312
# 5     0.894545   0.387402  0.540659  0.951537   0.808889  0.336414  0.475196
# 4     0.999204   0.988189  0.993666  0.948885   0.725869  0.347505  0.470000
# 8     1.000000   0.999213  0.999606  0.947438   0.690909  0.351201  0.465686
# 6     0.995826   0.939370  0.966775  0.948764   0.732000  0.338262  0.462705
# 3     1.000000   0.999213  0.999606  0.948523   0.733607  0.330869  0.456051
# 6     1.000000   0.972441  0.986028  0.949005   0.750000  0.327172  0.455598
# 5     0.922547   0.422047  0.579146  0.950332   0.808612  0.312384  0.450667
# 4     1.000000   0.999213  0.999606  0.946835   0.695312  0.329020  0.446675
# 3     0.409942   1.000000  0.581502  0.883785   0.322716  0.711645  0.444060
# 5     1.000000   0.999213  0.999606  0.947800   0.728814  0.317930  0.442728
# 4     0.334266   0.752756  0.462954  0.885473   0.322328  0.685767  0.438534
# 7     0.907143   0.600000  0.722275  0.946715   0.702041  0.317930  0.437659
# 3     0.390409   1.000000  0.561574  0.875949   0.309672  0.733826  0.435546
# 10    0.927302   0.451969  0.607729  0.948162   0.753425  0.304991  0.434211
# 9     0.993305   0.934646  0.963083  0.946112   0.689516  0.316081  0.433460
# 10    0.914720   0.616535  0.736595  0.945992   0.706667  0.293900  0.415144
# 4     0.289709   0.815748  0.427569  0.853406   0.273338  0.752311  0.400985
# 2     0.319416   1.000000  0.484178  0.837734   0.259988  0.805915  0.393147
# 9     0.333596   1.000000  0.500295  0.840506   0.259828  0.781885  0.390041
# 5     0.830743   0.378740  0.520281  0.944304   0.683721  0.271719  0.388889
# 7     0.931398   0.277953  0.428138  0.948162   0.844720  0.251386  0.387464
# 8     0.828302   0.345669  0.487778  0.943219   0.669903  0.255083  0.369478
# 10    0.253615   0.842520  0.389871  0.822905   0.239033  0.785582  0.366537
# 3     0.240741   0.829134  0.373140  0.816998   0.232035  0.781885  0.357868
# 9     0.893891   0.218898  0.351676  0.946594   0.876923  0.210721  0.339791
# 0     0.999213   1.000000  0.999606  0.944304   0.796992  0.195933  0.314540
# 9     0.915441   0.196063  0.322957  0.945750   0.902655  0.188540  0.311927
# 2     1.000000   0.998425  0.999212  0.943701   0.772059  0.194085  0.310192
# 0     1.000000   0.999213  0.999606  0.943701   0.793651  0.184843  0.299850
# 11    1.000000   0.999213  0.999606  0.943339   0.779528  0.182994  0.296407
# 7     0.695522   0.183465  0.290343  0.940928   0.675862  0.181146  0.285714
# 7     0.618605   0.209449  0.312941  0.939120   0.613924  0.179298  0.277539
# 1     0.784566   0.192126  0.308665  0.940928   0.700787  0.164510  0.266467
# 1     0.839416   0.181102  0.297927  0.941893   0.792079  0.147874  0.249221
# 1     0.778947   0.116535  0.202740  0.940205   0.764706  0.120148  0.207668

# %% [markdown]
# #### Auswertung

# %% [markdown]
# - Modelle, die eine gute Precision erzielen, haben einen schlechten Recall => die getroffenen Vorhersagen sind gut, allerdings werden nicht viele korrekt vorhergesagt (wenige true positives)
# - Modelle, die einen guten Recall erzielen, haben einen schlechten Recall => es werden mehr korrekt vorhergesagt, allerdings bei allgemein schlechteren Vorhersagen (mehr false positives)
# - deutlich erkennbar am f1 score => Modelle mit bester Precision/Recall mit schlechtem f1 score
# - o.g. Punkte sowohl in Train als auch Test zu sehen
# - bestes Modell: RandomForest ohne Tuning => ca. 81% Precision und 43% Recall bei Test, bei Train ~99%; cross validation (10) führt zu f1 von ~52%
# - Performance RF deutet auf Overfitting hin, mittels RandomizedSearchCV jedoch kein Modell mit geringerer Train aber besserer Test Performance erreichbar (gilt auch für BalancedRandomForestClassifier)

# %% [markdown]
# Zielmetrik: F1-Score
#
# XGBClassifier: GridSearch vs. RandomizedSearch
# - Grid deutlich besser
#
# StackingClassifier
# - erzielt leicht bessere Ergebnisse als das beste Einzelmodell (SVC mit 61%, gestackt mit RandomForest 64%)
