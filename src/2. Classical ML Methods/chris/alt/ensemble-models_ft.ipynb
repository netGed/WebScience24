# %% [markdown]
# #### Imports & Downloads

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix, classification_report
from sklearn import metrics

from sklearn.ensemble import RandomForestClassifier, StackingClassifier
from imblearn.ensemble import BalancedRandomForestClassifier
from xgboost import XGBClassifier
import xgboost as xgboost
from sklearn.svm import LinearSVC

from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier

from sklearn.model_selection import cross_val_score
import vectorize_functions

from sklearn.metrics import mean_squared_error
import time
import optuna

from optuna.visualization.matplotlib import plot_optimization_history
from optuna.visualization.matplotlib import plot_param_importances
from typing import Tuple
from sklearn.metrics import log_loss
from optuna.samplers import TPESampler

# %% [markdown]
# ### Einladen der vektorisierten Daten - FastText

# %%
X_train, X_test, y_train, y_test = vectorize_functions.vectorize_ft()

# %%
positive = np.count_nonzero(y_train == 1)
negative = np.count_nonzero(y_train == 0)
print("Train")
print("- Positive:", positive)
print("- Negative:", negative)
print("- Verhältnis:", negative / positive)

positive = np.count_nonzero(y_test == 1)
negative = np.count_nonzero(y_test == 0)
print("Test")
print("- Positive:", positive)
print("- Negative:", negative)
print("- Verhältnis:", negative / positive)
# Out:
# Train
# - Positive: 1270
# - Negative: 18084
# - Verhältnis: 14.239370078740157
# Test
# - Positive: 541
# - Negative: 7754
# - Verhältnis: 14.33271719038817

# %%
print("X_train shape", X_train.shape)
print("y_train shape", y_train.shape)

print("X_test shape", X_test.shape)
print("y_test shape", y_test.shape)
# Out:
# X_train shape (19354, 300)
# y_train shape (19354,)
# X_test shape (8295, 300)
# y_test shape (8295,)

# %% [markdown]
# ### 2. Ensemble Models

# %%
evaluation = pd.DataFrame(
    columns=["model", "variant", "train_acc", "train_prec", "train_rec", "train_f1", "test_acc", "test_prec",
             "test_rec", "test_f1"])

# %%
def add_to_eval_df(model, model_name, variant, x_data_train, y_data_train, x_data_test, y_data_test):
    train_acc = model.score(x_data_train, y_data_train)
    train_precision = precision_score(y_data_train, model.predict(x_data_train))
    train_recall = recall_score(y_data_train, model.predict(x_data_train))
    train_f1 = f1_score(y_data_train, model.predict(x_data_train))

    test_acc = model.score(x_data_test, y_data_test)
    test_precision = precision_score(y_data_test, model.predict(x_data_test))
    test_recall = recall_score(y_data_test, model.predict(x_data_test))
    test_f1 = f1_score(y_data_test, model.predict(x_data_test))

    evaluation.loc[len(evaluation.index)] = [model_name, variant, train_acc, train_precision, train_recall, train_f1,
                                             test_acc, test_precision, test_recall, test_f1]

# %%
def evaluate_model(model, x_test, y_test, sampling_method):
    pred = model.predict(x_test)
    accscore = metrics.accuracy_score(pred, y_test)

    print(f'{sampling_method} model accuracy for classification is =', str('{:04.2f}'.format(accscore * 100)) + '%')
    print('------------------------------------------------')
    print('Confusion Matrix:')
    print(pd.DataFrame(confusion_matrix(y_test, pred)))
    print('------------------------------------------------')
    print('Classification Report:')
    print(classification_report(y_test, pred))

    probs = model.predict_proba(x_test)
    preds = probs[:, 1]
    fpr, tpr, threshold = metrics.roc_curve(y_test, preds)
    roc_auc = metrics.auc(fpr, tpr)

    plt.title('Receiver Operating Characteristic')
    plt.plot(fpr, tpr, 'b', label='AUC = %0.2f' % roc_auc)
    plt.legend(loc='lower right')
    plt.plot([0, 1], [0, 1], 'r--')
    plt.xlim([0, 1])
    plt.ylim([0, 1])
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    plt.show()

# %% [markdown]
# #### 2.1 Bagging

# %% [markdown]
# ##### 2.1.1 RandomForest

# %% [markdown]
# ###### RandomForest no tuning

# %%
rf = RandomForestClassifier(n_jobs=-1)
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_jobs=-1)

# %%
evaluate_model(rf, X_test, y_test, "none")
add_to_eval_df(rf, "RandomForestClassifier", "clean", X_train, y_train, X_test, y_test)
# Out:
# none model accuracy for classification is = 94.43%
# ------------------------------------------------
# Confusion Matrix:
#       0    1
# 0  7727   27
# 1   435  106
# ------------------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      7754
#            1       0.80      0.20      0.31       541
#
#     accuracy                           0.94      8295
#    macro avg       0.87      0.60      0.64      8295
# weighted avg       0.94      0.94      0.93      8295

# %%
cv = cross_val_score(rf, X_train, y_train, cv=10, scoring='f1', verbose=10)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] START .....................................................................
# [CV] END ................................ score: (test=0.329) total time=  14.1s
# [CV] START .....................................................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   14.1s remaining:    0.0s
# [CV] END ................................ score: (test=0.344) total time=   5.0s
# [CV] START .....................................................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:   19.3s remaining:    0.0s
# [CV] END ................................ score: (test=0.304) total time=   5.3s
# [CV] START .....................................................................
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:   24.7s remaining:    0.0s
# [CV] END ................................ score: (test=0.314) total time=   4.9s
# [CV] START .....................................................................
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:   29.7s remaining:    0.0s
# [CV] END ................................ score: (test=0.331) total time=   4.8s
# [CV] START .....................................................................
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:   34.6s remaining:    0.0s
# [CV] END ................................ score: (test=0.256) total time=   4.7s
# [CV] START .....................................................................
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:   39.4s remaining:    0.0s
# [CV] END ................................ score: (test=0.368) total time=   6.9s
# [CV] START .....................................................................
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:   46.4s remaining:    0.0s
# [CV] END ................................ score: (test=0.291) total time=   6.4s
# [CV] START .....................................................................
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:   52.9s remaining:    0.0s
# [CV] END ................................ score: (test=0.263) total time=  10.6s
# [CV] START .....................................................................
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:  1.1min remaining:    0.0s
# [CV] END ................................ score: (test=0.316) total time=   8.5s
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:  1.2min finished

# %%
np.mean(cv)
# Out:
# 0.31177026207636793

# %% [markdown]
# ###### RandomForest tuning (GridSearchCV)

# %%
# todo

# %% [markdown]
# ###### RandomForest tuning (RandomizedSearchCV)

# %%
param_grid = {
    'n_estimators': [100, 150, 200, 250],
    'max_features': ['sqrt', 'log2', None],
    'max_depth': [3, 6, 9],
    'max_leaf_nodes': [9, 11, 13],
}

# %%
random_search = RandomizedSearchCV(RandomForestClassifier(n_jobs=-1),
                                   param_grid,
                                   scoring='f1',
                                   verbose=10)
random_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5; 1/10] START max_depth=3, max_features=sqrt, max_leaf_nodes=13, n_estimators=100
# [CV 1/5; 1/10] END max_depth=3, max_features=sqrt, max_leaf_nodes=13, n_estimators=100;, score=0.000 total time=   2.3s
# [CV 2/5; 1/10] START max_depth=3, max_features=sqrt, max_leaf_nodes=13, n_estimators=100
# [CV 2/5; 1/10] END max_depth=3, max_features=sqrt, max_leaf_nodes=13, n_estimators=100;, score=0.000 total time=   5.2s
# [CV 3/5; 1/10] START max_depth=3, max_features=sqrt, max_leaf_nodes=13, n_estimators=100
# [CV 3/5; 1/10] END max_depth=3, max_features=sqrt, max_leaf_nodes=13, n_estimators=100;, score=0.000 total time=   4.8s
# [CV 4/5; 1/10] START max_depth=3, max_features=sqrt, max_leaf_nodes=13, n_estimators=100
# [CV 4/5; 1/10] END max_depth=3, max_features=sqrt, max_leaf_nodes=13, n_estimators=100;, score=0.000 total time=   2.9s
# [CV 5/5; 1/10] START max_depth=3, max_features=sqrt, max_leaf_nodes=13, n_estimators=100
# [CV 5/5; 1/10] END max_depth=3, max_features=sqrt, max_leaf_nodes=13, n_estimators=100;, score=0.000 total time=   5.2s
# [CV 1/5; 2/10] START max_depth=6, max_features=None, max_leaf_nodes=11, n_estimators=200
# [CV 1/5; 2/10] END max_depth=6, max_features=None, max_leaf_nodes=11, n_estimators=200;, score=0.279 total time= 1.3min
# [CV 2/5; 2/10] START max_depth=6, max_features=None, max_leaf_nodes=11, n_estimators=200
# [CV 2/5; 2/10] END max_depth=6, max_features=None, max_leaf_nodes=11, n_estimators=200;, score=0.211 total time=  50.9s
# [CV 3/5; 2/10] START max_depth=6, max_features=None, max_leaf_nodes=11, n_estimators=200
# [CV 3/5; 2/10] END max_depth=6, max_features=None, max_leaf_nodes=11, n_estimators=200;, score=0.231 total time=  44.7s
# [CV 4/5; 2/10] START max_depth=6, max_features=None, max_leaf_nodes=11, n_estimators=200
# [CV 4/5; 2/10] END max_depth=6, max_features=None, max_leaf_nodes=11, n_estimators=200;, score=0.254 total time=  44.5s
# [CV 5/5; 2/10] START max_depth=6, max_features=None, max_leaf_nodes=11, n_estimators=200
# [CV 5/5; 2/10] END max_depth=6, max_features=None, max_leaf_nodes=11, n_estimators=200;, score=0.226 total time=  43.6s
# [CV 1/5; 3/10] START max_depth=9, max_features=log2, max_leaf_nodes=9, n_estimators=100
# [CV 1/5; 3/10] END max_depth=9, max_features=log2, max_leaf_nodes=9, n_estimators=100;, score=0.031 total time=   1.2s
# [CV 2/5; 3/10] START max_depth=9, max_features=log2, max_leaf_nodes=9, n_estimators=100
# [CV 2/5; 3/10] END max_depth=9, max_features=log2, max_leaf_nodes=9, n_estimators=100;, score=0.038 total time=   1.2s
# [CV 3/5; 3/10] START max_depth=9, max_features=log2, max_leaf_nodes=9, n_estimators=100
# [CV 3/5; 3/10] END max_depth=9, max_features=log2, max_leaf_nodes=9, n_estimators=100;, score=0.060 total time=   1.3s
# [CV 4/5; 3/10] START max_depth=9, max_features=log2, max_leaf_nodes=9, n_estimators=100
# [CV 4/5; 3/10] END max_depth=9, max_features=log2, max_leaf_nodes=9, n_estimators=100;, score=0.053 total time=   1.0s
# [CV 5/5; 3/10] START max_depth=9, max_features=log2, max_leaf_nodes=9, n_estimators=100
# [CV 5/5; 3/10] END max_depth=9, max_features=log2, max_leaf_nodes=9, n_estimators=100;, score=0.039 total time=   1.4s
# [CV 1/5; 4/10] START max_depth=6, max_features=log2, max_leaf_nodes=11, n_estimators=100
# [CV 1/5; 4/10] END max_depth=6, max_features=log2, max_leaf_nodes=11, n_estimators=100;, score=0.023 total time=   1.2s
# [CV 2/5; 4/10] START max_depth=6, max_features=log2, max_leaf_nodes=11, n_estimators=100
# [CV 2/5; 4/10] END max_depth=6, max_features=log2, max_leaf_nodes=11, n_estimators=100;, score=0.038 total time=   1.1s
# [CV 3/5; 4/10] START max_depth=6, max_features=log2, max_leaf_nodes=11, n_estimators=100
# [CV 3/5; 4/10] END max_depth=6, max_features=log2, max_leaf_nodes=11, n_estimators=100;, score=0.039 total time=   1.3s
# [CV 4/5; 4/10] START max_depth=6, max_features=log2, max_leaf_nodes=11, n_estimators=100
# [CV 4/5; 4/10] END max_depth=6, max_features=log2, max_leaf_nodes=11, n_estimators=100;, score=0.046 total time=   1.0s
# [CV 5/5; 4/10] START max_depth=6, max_features=log2, max_leaf_nodes=11, n_estimators=100
# [CV 5/5; 4/10] END max_depth=6, max_features=log2, max_leaf_nodes=11, n_estimators=100;, score=0.039 total time=   1.0s
# [CV 1/5; 5/10] START max_depth=9, max_features=sqrt, max_leaf_nodes=13, n_estimators=150
# [CV 1/5; 5/10] END max_depth=9, max_features=sqrt, max_leaf_nodes=13, n_estimators=150;, score=0.151 total time=   2.6s
# [CV 2/5; 5/10] START max_depth=9, max_features=sqrt, max_leaf_nodes=13, n_estimators=150
# [CV 2/5; 5/10] END max_depth=9, max_features=sqrt, max_leaf_nodes=13, n_estimators=150;, score=0.094 total time=   3.4s
# [CV 3/5; 5/10] START max_depth=9, max_features=sqrt, max_leaf_nodes=13, n_estimators=150
# [CV 3/5; 5/10] END max_depth=9, max_features=sqrt, max_leaf_nodes=13, n_estimators=150;, score=0.143 total time=   2.8s
# [CV 4/5; 5/10] START max_depth=9, max_features=sqrt, max_leaf_nodes=13, n_estimators=150
# [CV 4/5; 5/10] END max_depth=9, max_features=sqrt, max_leaf_nodes=13, n_estimators=150;, score=0.115 total time=   2.6s
# [CV 5/5; 5/10] START max_depth=9, max_features=sqrt, max_leaf_nodes=13, n_estimators=150
# [CV 5/5; 5/10] END max_depth=9, max_features=sqrt, max_leaf_nodes=13, n_estimators=150;, score=0.082 total time=   2.4s
# [CV 1/5; 6/10] START max_depth=3, max_features=log2, max_leaf_nodes=9, n_estimators=250
# [CV 1/5; 6/10] END max_depth=3, max_features=log2, max_leaf_nodes=9, n_estimators=250;, score=0.000 total time=   2.3s
# [CV 2/5; 6/10] START max_depth=3, max_features=log2, max_leaf_nodes=9, n_estimators=250
# [CV 2/5; 6/10] END max_depth=3, max_features=log2, max_leaf_nodes=9, n_estimators=250;, score=0.000 total time=   2.0s
# [CV 3/5; 6/10] START max_depth=3, max_features=log2, max_leaf_nodes=9, n_estimators=250
# [CV 3/5; 6/10] END max_depth=3, max_features=log2, max_leaf_nodes=9, n_estimators=250;, score=0.000 total time=   2.0s
# [CV 4/5; 6/10] START max_depth=3, max_features=log2, max_leaf_nodes=9, n_estimators=250
# [CV 4/5; 6/10] END max_depth=3, max_features=log2, max_leaf_nodes=9, n_estimators=250;, score=0.000 total time=   2.1s
# [CV 5/5; 6/10] START max_depth=3, max_features=log2, max_leaf_nodes=9, n_estimators=250
# [CV 5/5; 6/10] END max_depth=3, max_features=log2, max_leaf_nodes=9, n_estimators=250;, score=0.000 total time=   2.1s
# [CV 1/5; 7/10] START max_depth=6, max_features=log2, max_leaf_nodes=13, n_estimators=200
# [CV 1/5; 7/10] END max_depth=6, max_features=log2, max_leaf_nodes=13, n_estimators=200;, score=0.046 total time=   1.9s
# [CV 2/5; 7/10] START max_depth=6, max_features=log2, max_leaf_nodes=13, n_estimators=200
# [CV 2/5; 7/10] END max_depth=6, max_features=log2, max_leaf_nodes=13, n_estimators=200;, score=0.038 total time=   1.7s
# [CV 3/5; 7/10] START max_depth=6, max_features=log2, max_leaf_nodes=13, n_estimators=200
# [CV 3/5; 7/10] END max_depth=6, max_features=log2, max_leaf_nodes=13, n_estimators=200;, score=0.053 total time=   1.8s
# [CV 4/5; 7/10] START max_depth=6, max_features=log2, max_leaf_nodes=13, n_estimators=200
# [CV 4/5; 7/10] END max_depth=6, max_features=log2, max_leaf_nodes=13, n_estimators=200;, score=0.053 total time=   1.8s
# [CV 5/5; 7/10] START max_depth=6, max_features=log2, max_leaf_nodes=13, n_estimators=200
# [CV 5/5; 7/10] END max_depth=6, max_features=log2, max_leaf_nodes=13, n_estimators=200;, score=0.039 total time=   1.8s
# [CV 1/5; 8/10] START max_depth=6, max_features=sqrt, max_leaf_nodes=13, n_estimators=100
# [CV 1/5; 8/10] END max_depth=6, max_features=sqrt, max_leaf_nodes=13, n_estimators=100;, score=0.131 total time=   1.7s
# [CV 2/5; 8/10] START max_depth=6, max_features=sqrt, max_leaf_nodes=13, n_estimators=100
# [CV 2/5; 8/10] END max_depth=6, max_features=sqrt, max_leaf_nodes=13, n_estimators=100;, score=0.088 total time=   1.6s
# [CV 3/5; 8/10] START max_depth=6, max_features=sqrt, max_leaf_nodes=13, n_estimators=100
# [CV 3/5; 8/10] END max_depth=6, max_features=sqrt, max_leaf_nodes=13, n_estimators=100;, score=0.124 total time=   1.8s
# [CV 4/5; 8/10] START max_depth=6, max_features=sqrt, max_leaf_nodes=13, n_estimators=100
# [CV 4/5; 8/10] END max_depth=6, max_features=sqrt, max_leaf_nodes=13, n_estimators=100;, score=0.101 total time=   1.6s
# [CV 5/5; 8/10] START max_depth=6, max_features=sqrt, max_leaf_nodes=13, n_estimators=100
# [CV 5/5; 8/10] END max_depth=6, max_features=sqrt, max_leaf_nodes=13, n_estimators=100;, score=0.075 total time=   1.8s
# [CV 1/5; 9/10] START max_depth=6, max_features=None, max_leaf_nodes=13, n_estimators=100
# [CV 1/5; 9/10] END max_depth=6, max_features=None, max_leaf_nodes=13, n_estimators=100;, score=0.302 total time=  24.4s
# [CV 2/5; 9/10] START max_depth=6, max_features=None, max_leaf_nodes=13, n_estimators=100
# [CV 2/5; 9/10] END max_depth=6, max_features=None, max_leaf_nodes=13, n_estimators=100;, score=0.226 total time=  23.1s
# [CV 3/5; 9/10] START max_depth=6, max_features=None, max_leaf_nodes=13, n_estimators=100
# [CV 3/5; 9/10] END max_depth=6, max_features=None, max_leaf_nodes=13, n_estimators=100;, score=0.235 total time=  24.5s
# [CV 4/5; 9/10] START max_depth=6, max_features=None, max_leaf_nodes=13, n_estimators=100
# [CV 4/5; 9/10] END max_depth=6, max_features=None, max_leaf_nodes=13, n_estimators=100;, score=0.275 total time=  24.4s
# [CV 5/5; 9/10] START max_depth=6, max_features=None, max_leaf_nodes=13, n_estimators=100
# [CV 5/5; 9/10] END max_depth=6, max_features=None, max_leaf_nodes=13, n_estimators=100;, score=0.227 total time=  23.8s
# [CV 1/5; 10/10] START max_depth=6, max_features=None, max_leaf_nodes=9, n_estimators=250
# [CV 1/5; 10/10] END max_depth=6, max_features=None, max_leaf_nodes=9, n_estimators=250;, score=0.277 total time=  55.5s
# [CV 2/5; 10/10] START max_depth=6, max_features=None, max_leaf_nodes=9, n_estimators=250
# [CV 2/5; 10/10] END max_depth=6, max_features=None, max_leaf_nodes=9, n_estimators=250;, score=0.208 total time=  51.6s
# [CV 3/5; 10/10] START max_depth=6, max_features=None, max_leaf_nodes=9, n_estimators=250
# [CV 3/5; 10/10] END max_depth=6, max_features=None, max_leaf_nodes=9, n_estimators=250;, score=0.248 total time=  51.7s
# [CV 4/5; 10/10] START max_depth=6, max_features=None, max_leaf_nodes=9, n_estimators=250
# [CV 4/5; 10/10] END max_depth=6, max_features=None, max_leaf_nodes=9, n_estimators=250;, score=0.247 total time=  53.4s
# [CV 5/5; 10/10] START max_depth=6, max_features=None, max_leaf_nodes=9, n_estimators=250
# [CV 5/5; 10/10] END max_depth=6, max_features=None, max_leaf_nodes=9, n_estimators=250;, score=0.190 total time=  52.0s
# RandomizedSearchCV(estimator=RandomForestClassifier(n_jobs=-1),
#                    param_distributions={'max_depth': [3, 6, 9],
#                                         'max_features': ['sqrt', 'log2', None],
#                                         'max_leaf_nodes': [9, 11, 13],
#                                         'n_estimators': [100, 150, 200, 250]},
#                    scoring='f1', verbose=10)

# %%
print(random_search.best_estimator_)
# Out:
# RandomForestClassifier(max_depth=6, max_features=None, max_leaf_nodes=13,
#                        n_jobs=-1)

# %%
rf_tuned = RandomForestClassifier(**random_search.best_params_)
rf_tuned.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=6, max_features=None, max_leaf_nodes=13)

# %%
evaluate_model(rf_tuned, X_test, y_test, "none")
add_to_eval_df(rf_tuned, "RandomForestClassifier-tuned-rand", "clean", X_train, y_train, X_test, y_test)
# Out:
# none model accuracy for classification is = 94.09%
# ------------------------------------------------
# Confusion Matrix:
#       0   1
# 0  7716  38
# 1   452  89
# ------------------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97      7754
#            1       0.70      0.16      0.27       541
#
#     accuracy                           0.94      8295
#    macro avg       0.82      0.58      0.62      8295
# weighted avg       0.93      0.94      0.92      8295

# %% [markdown]
# ###### RandomForest tuning (optuna)
# https://gist.github.com/shamilnabiyev/c1b6e23444a949bc45243eab445a3806

# %%
def objective_rf(trial):
    n_estimators = trial.suggest_int(name="n_estimators", low=100, high=500, step=50)
    max_depth = trial.suggest_int(name="max_depth", low=10, high=150, step=5)
    min_samples_split = trial.suggest_int(name="min_samples_split", low=2, high=10, step=2)
    min_samples_leaf = trial.suggest_int(name="min_samples_leaf", low=1, high=4, step=1)

    params = {
        "n_estimators": n_estimators,
        "max_depth": max_depth,
        "min_samples_split": min_samples_split,
        "min_samples_leaf": min_samples_leaf
    }
    model = RandomForestClassifier(random_state=42, **params)

    cv_score = cross_val_score(model, X_train, y_train, n_jobs=-1, cv=5, scoring='f1')
    mean_cv_accuracy = cv_score.mean()
    return mean_cv_accuracy

# %%
sampler = TPESampler(seed=42)
pruner = optuna.pruners.MedianPruner(n_warmup_steps=10)
study_rf = optuna.create_study(sampler=sampler, pruner=pruner, direction="maximize")
study_rf.optimize(objective_rf, n_trials=50)
# Out:
# [I 2024-11-24 21:22:58,128] A new study created in memory with name: no-name-5f138a9f-7cab-4469-9f2d-205229da02b4
# [I 2024-11-24 21:24:33,590] Trial 0 finished with value: 0.30046149444714315 and parameters: {'n_estimators': 250, 'max_depth': 145, 'min_samples_split': 8, 'min_samples_leaf': 3}. Best is trial 0 with value: 0.30046149444714315.
# [I 2024-11-24 21:25:22,144] Trial 1 finished with value: 0.2874701049490754 and parameters: {'n_estimators': 150, 'max_depth': 30, 'min_samples_split': 2, 'min_samples_leaf': 4}. Best is trial 0 with value: 0.30046149444714315.
# [I 2024-11-24 21:27:10,232] Trial 2 finished with value: 0.2904352832888698 and parameters: {'n_estimators': 350, 'max_depth': 110, 'min_samples_split': 2, 'min_samples_leaf': 4}. Best is trial 0 with value: 0.30046149444714315.
# [I 2024-11-24 21:29:39,989] Trial 3 finished with value: 0.3167948665305661 and parameters: {'n_estimators': 450, 'max_depth': 40, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 3 with value: 0.3167948665305661.
# [I 2024-11-24 21:30:44,162] Trial 4 finished with value: 0.30873901443130775 and parameters: {'n_estimators': 200, 'max_depth': 85, 'min_samples_split': 6, 'min_samples_leaf': 2}. Best is trial 3 with value: 0.3167948665305661.
# [I 2024-11-24 21:32:35,438] Trial 5 finished with value: 0.30918629912896745 and parameters: {'n_estimators': 350, 'max_depth': 30, 'min_samples_split': 4, 'min_samples_leaf': 2}. Best is trial 3 with value: 0.3167948665305661.
# [I 2024-11-24 21:34:09,263] Trial 6 finished with value: 0.30048701589003485 and parameters: {'n_estimators': 300, 'max_depth': 120, 'min_samples_split': 2, 'min_samples_leaf': 3}. Best is trial 3 with value: 0.3167948665305661.
# [I 2024-11-24 21:36:01,963] Trial 7 finished with value: 0.3082828005857184 and parameters: {'n_estimators': 350, 'max_depth': 15, 'min_samples_split': 8, 'min_samples_leaf': 1}. Best is trial 3 with value: 0.3167948665305661.
# [I 2024-11-24 21:36:32,878] Trial 8 finished with value: 0.29454175587164466 and parameters: {'n_estimators': 100, 'max_depth': 145, 'min_samples_split': 10, 'min_samples_leaf': 4}. Best is trial 3 with value: 0.3167948665305661.
# [I 2024-11-24 21:37:36,829] Trial 9 finished with value: 0.3069103263516732 and parameters: {'n_estimators': 200, 'max_depth': 20, 'min_samples_split': 8, 'min_samples_leaf': 2}. Best is trial 3 with value: 0.3167948665305661.
# [I 2024-11-24 21:40:21,750] Trial 10 finished with value: 0.31023780290665776 and parameters: {'n_estimators': 500, 'max_depth': 60, 'min_samples_split': 4, 'min_samples_leaf': 1}. Best is trial 3 with value: 0.3167948665305661.
# [I 2024-11-24 21:43:08,401] Trial 11 finished with value: 0.31023780290665776 and parameters: {'n_estimators': 500, 'max_depth': 60, 'min_samples_split': 4, 'min_samples_leaf': 1}. Best is trial 3 with value: 0.3167948665305661.
# [I 2024-11-24 21:45:55,576] Trial 12 finished with value: 0.31023780290665776 and parameters: {'n_estimators': 500, 'max_depth': 55, 'min_samples_split': 4, 'min_samples_leaf': 1}. Best is trial 3 with value: 0.3167948665305661.
# [I 2024-11-24 21:48:24,626] Trial 13 finished with value: 0.3133164782226262 and parameters: {'n_estimators': 450, 'max_depth': 55, 'min_samples_split': 4, 'min_samples_leaf': 1}. Best is trial 3 with value: 0.3167948665305661.
# [I 2024-11-24 21:50:33,623] Trial 14 finished with value: 0.31392798154077306 and parameters: {'n_estimators': 400, 'max_depth': 45, 'min_samples_split': 6, 'min_samples_leaf': 2}. Best is trial 3 with value: 0.3167948665305661.
# [I 2024-11-24 21:52:57,464] Trial 15 finished with value: 0.31392798154077306 and parameters: {'n_estimators': 400, 'max_depth': 80, 'min_samples_split': 6, 'min_samples_leaf': 2}. Best is trial 3 with value: 0.3167948665305661.
# [I 2024-11-24 21:55:06,563] Trial 16 finished with value: 0.2942448836370131 and parameters: {'n_estimators': 400, 'max_depth': 40, 'min_samples_split': 10, 'min_samples_leaf': 3}. Best is trial 3 with value: 0.3167948665305661.
# [I 2024-11-24 21:57:29,920] Trial 17 finished with value: 0.3148645694714634 and parameters: {'n_estimators': 450, 'max_depth': 80, 'min_samples_split': 6, 'min_samples_leaf': 2}. Best is trial 3 with value: 0.3167948665305661.
# [I 2024-11-24 21:59:57,249] Trial 18 finished with value: 0.3167948665305661 and parameters: {'n_estimators': 450, 'max_depth': 85, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 3 with value: 0.3167948665305661.
# [I 2024-11-24 22:02:23,871] Trial 19 finished with value: 0.3167948665305661 and parameters: {'n_estimators': 450, 'max_depth': 100, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 3 with value: 0.3167948665305661.
# [I 2024-11-24 22:04:01,908] Trial 20 finished with value: 0.32060501824678106 and parameters: {'n_estimators': 300, 'max_depth': 95, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 20 with value: 0.32060501824678106.
# [I 2024-11-24 22:05:41,159] Trial 21 finished with value: 0.32060501824678106 and parameters: {'n_estimators': 300, 'max_depth': 95, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 20 with value: 0.32060501824678106.
# [I 2024-11-24 22:07:19,166] Trial 22 finished with value: 0.32060501824678106 and parameters: {'n_estimators': 300, 'max_depth': 125, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 20 with value: 0.32060501824678106.
# [I 2024-11-24 22:08:43,137] Trial 23 finished with value: 0.3199388226677179 and parameters: {'n_estimators': 250, 'max_depth': 130, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 20 with value: 0.32060501824678106.
# [I 2024-11-24 22:10:25,345] Trial 24 finished with value: 0.3078288728077265 and parameters: {'n_estimators': 300, 'max_depth': 100, 'min_samples_split': 4, 'min_samples_leaf': 1}. Best is trial 20 with value: 0.32060501824678106.
# [I 2024-11-24 22:12:03,352] Trial 25 finished with value: 0.3059823558484314 and parameters: {'n_estimators': 300, 'max_depth': 130, 'min_samples_split': 2, 'min_samples_leaf': 2}. Best is trial 20 with value: 0.32060501824678106.
# [I 2024-11-24 22:13:27,795] Trial 26 finished with value: 0.31747049796304216 and parameters: {'n_estimators': 250, 'max_depth': 100, 'min_samples_split': 4, 'min_samples_leaf': 1}. Best is trial 20 with value: 0.32060501824678106.
# [I 2024-11-24 22:15:06,449] Trial 27 finished with value: 0.3059823558484314 and parameters: {'n_estimators': 300, 'max_depth': 115, 'min_samples_split': 2, 'min_samples_leaf': 2}. Best is trial 20 with value: 0.32060501824678106.
# [I 2024-11-24 22:16:14,788] Trial 28 finished with value: 0.31375137802129355 and parameters: {'n_estimators': 200, 'max_depth': 70, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 20 with value: 0.32060501824678106.
# [I 2024-11-24 22:17:34,583] Trial 29 finished with value: 0.29672726833464314 and parameters: {'n_estimators': 250, 'max_depth': 145, 'min_samples_split': 4, 'min_samples_leaf': 3}. Best is trial 20 with value: 0.32060501824678106.
# [I 2024-11-24 22:19:33,516] Trial 30 finished with value: 0.3203843399905738 and parameters: {'n_estimators': 350, 'max_depth': 130, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 20 with value: 0.32060501824678106.
# [I 2024-11-24 22:21:33,526] Trial 31 finished with value: 0.3203843399905738 and parameters: {'n_estimators': 350, 'max_depth': 130, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 20 with value: 0.32060501824678106.
# [I 2024-11-24 22:23:15,254] Trial 32 finished with value: 0.32060501824678106 and parameters: {'n_estimators': 300, 'max_depth': 150, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 20 with value: 0.32060501824678106.
# [I 2024-11-24 22:24:56,388] Trial 33 finished with value: 0.32060501824678106 and parameters: {'n_estimators': 300, 'max_depth': 150, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 20 with value: 0.32060501824678106.
# [I 2024-11-24 22:26:21,899] Trial 34 finished with value: 0.3199388226677179 and parameters: {'n_estimators': 250, 'max_depth': 140, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 20 with value: 0.32060501824678106.
# [I 2024-11-24 22:28:00,262] Trial 35 finished with value: 0.3059823558484314 and parameters: {'n_estimators': 300, 'max_depth': 110, 'min_samples_split': 2, 'min_samples_leaf': 2}. Best is trial 20 with value: 0.32060501824678106.
# [I 2024-11-24 22:28:47,261] Trial 36 finished with value: 0.2874701049490754 and parameters: {'n_estimators': 150, 'max_depth': 90, 'min_samples_split': 4, 'min_samples_leaf': 4}. Best is trial 20 with value: 0.32060501824678106.
# [I 2024-11-24 22:30:46,104] Trial 37 finished with value: 0.3203843399905738 and parameters: {'n_estimators': 350, 'max_depth': 120, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 20 with value: 0.32060501824678106.
# [I 2024-11-24 22:31:51,896] Trial 38 finished with value: 0.3091989261921144 and parameters: {'n_estimators': 200, 'max_depth': 110, 'min_samples_split': 4, 'min_samples_leaf': 2}. Best is trial 20 with value: 0.32060501824678106.
# [I 2024-11-24 22:33:16,534] Trial 39 finished with value: 0.3199388226677179 and parameters: {'n_estimators': 250, 'max_depth': 95, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 20 with value: 0.32060501824678106.
# [I 2024-11-24 22:35:10,552] Trial 40 finished with value: 0.3080826791725314 and parameters: {'n_estimators': 350, 'max_depth': 140, 'min_samples_split': 2, 'min_samples_leaf': 2}. Best is trial 20 with value: 0.32060501824678106.
# [I 2024-11-24 22:36:52,057] Trial 41 finished with value: 0.32060501824678106 and parameters: {'n_estimators': 300, 'max_depth': 150, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 20 with value: 0.32060501824678106.
# [I 2024-11-24 22:38:33,265] Trial 42 finished with value: 0.32060501824678106 and parameters: {'n_estimators': 300, 'max_depth': 150, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 20 with value: 0.32060501824678106.
# [I 2024-11-24 22:39:57,918] Trial 43 finished with value: 0.3199388226677179 and parameters: {'n_estimators': 250, 'max_depth': 135, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 20 with value: 0.32060501824678106.
# [I 2024-11-24 22:41:39,089] Trial 44 finished with value: 0.3078288728077265 and parameters: {'n_estimators': 300, 'max_depth': 120, 'min_samples_split': 4, 'min_samples_leaf': 1}. Best is trial 20 with value: 0.32060501824678106.
# [I 2024-11-24 22:43:37,369] Trial 45 finished with value: 0.3203843399905738 and parameters: {'n_estimators': 350, 'max_depth': 150, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 20 with value: 0.32060501824678106.
# [I 2024-11-24 22:45:18,702] Trial 46 finished with value: 0.30809760803450137 and parameters: {'n_estimators': 300, 'max_depth': 70, 'min_samples_split': 8, 'min_samples_leaf': 1}. Best is trial 20 with value: 0.32060501824678106.
# [I 2024-11-24 22:46:45,729] Trial 47 finished with value: 0.31747049796304216 and parameters: {'n_estimators': 250, 'max_depth': 140, 'min_samples_split': 4, 'min_samples_leaf': 1}. Best is trial 20 with value: 0.32060501824678106.
# [I 2024-11-24 22:48:50,427] Trial 48 finished with value: 0.31322940937371235 and parameters: {'n_estimators': 400, 'max_depth': 125, 'min_samples_split': 2, 'min_samples_leaf': 2}. Best is trial 20 with value: 0.32060501824678106.
# [I 2024-11-24 22:49:55,391] Trial 49 finished with value: 0.31493902042400357 and parameters: {'n_estimators': 200, 'max_depth': 105, 'min_samples_split': 4, 'min_samples_leaf': 1}. Best is trial 20 with value: 0.32060501824678106.

# %%
print("Number of finished trials: {}".format(len(study_rf.trials)))

print("Best trial:")
trial = study_rf.best_trial

print("  Value: {}".format(trial.value))

print("  Params: ")
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))

plot_optimization_history(study_rf)
plot_param_importances(study_rf)
# Out:
# Number of finished trials: 50
# Best trial:
#   Value: 0.32060501824678106
#   Params:
#     n_estimators: 300
#     max_depth: 95
#     min_samples_split: 2
#     min_samples_leaf: 1
# C:\Users\admin\AppData\Local\Temp\ipykernel_15252\2334329262.py:12: ExperimentalWarning: plot_optimization_history is experimental (supported from v2.2.0). The interface can change in the future.
#   plot_optimization_history(study_rf)
# C:\Users\admin\AppData\Local\Temp\ipykernel_15252\2334329262.py:13: ExperimentalWarning: plot_param_importances is experimental (supported from v2.2.0). The interface can change in the future.
#   plot_param_importances(study_rf)
# <Axes: title={'left': 'Hyperparameter Importances'}, xlabel='Hyperparameter Importance', ylabel='Hyperparameter'>

# %%
rf_tuned_optuna = RandomForestClassifier(**study_rf.best_trial.params)
rf_tuned_optuna.fit(X_train, y_train)
evaluate_model(rf_tuned_optuna, X_test, y_test, "none")
add_to_eval_df(rf_tuned_optuna, "RandomForest-tuned-optuna", "clean", X_train, y_train, X_test, y_test)
# Out:
# none model accuracy for classification is = 94.33%
# ------------------------------------------------
# Confusion Matrix:
#       0   1
# 0  7726  28
# 1   442  99
# ------------------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      7754
#            1       0.78      0.18      0.30       541
#
#     accuracy                           0.94      8295
#    macro avg       0.86      0.59      0.63      8295
# weighted avg       0.94      0.94      0.93      8295

# %% [markdown]
# ##### 2.1.2 BalancedRandomForest untuned

# %% [markdown]
# ###### BalancedRandomForest no tuning

# %%
brf = BalancedRandomForestClassifier(n_jobs=-1)
brf.fit(X_train, y_train)
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# BalancedRandomForestClassifier(n_jobs=-1)

# %%
evaluate_model(brf, X_test, y_test, "none")
add_to_eval_df(brf, "BalancedRandomForestClassifier", "clean", X_train, y_train, X_test, y_test)
# Out:
# none model accuracy for classification is = 83.77%
# ------------------------------------------------
# Confusion Matrix:
#       0     1
# 0  6513  1241
# 1   105   436
# ------------------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.84      0.91      7754
#            1       0.26      0.81      0.39       541
#
#     accuracy                           0.84      8295
#    macro avg       0.62      0.82      0.65      8295
# weighted avg       0.94      0.84      0.87      8295

# %%
cv = cross_val_score(brf, X_train, y_train, cv=10, scoring='f1', verbose=10)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# [CV] START .....................................................................
# [CV] END ................................ score: (test=0.388) total time=   1.5s
# [CV] START .....................................................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.5s remaining:    0.0s
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# [CV] END ................................ score: (test=0.394) total time=   2.7s
# [CV] START .....................................................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    4.3s remaining:    0.0s
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# [CV] END ................................ score: (test=0.365) total time=   2.1s
# [CV] START .....................................................................
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    6.5s remaining:    0.0s
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# [CV] END ................................ score: (test=0.402) total time=   1.2s
# [CV] START .....................................................................
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    7.8s remaining:    0.0s
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# [CV] END ................................ score: (test=0.417) total time=   1.4s
# [CV] START .....................................................................
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    9.3s remaining:    0.0s
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# [CV] END ................................ score: (test=0.400) total time=   2.9s
# [CV] START .....................................................................
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:   12.4s remaining:    0.0s
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# [CV] END ................................ score: (test=0.391) total time=   1.3s
# [CV] START .....................................................................
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:   13.8s remaining:    0.0s
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# [CV] END ................................ score: (test=0.399) total time=   1.1s
# [CV] START .....................................................................
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:   15.0s remaining:    0.0s
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# [CV] END ................................ score: (test=0.366) total time=   1.2s
# [CV] START .....................................................................
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:   16.3s remaining:    0.0s
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# [CV] END ................................ score: (test=0.391) total time=   1.2s
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:   17.6s finished

# %%
np.mean(cv)
# Out:
# 0.3913099996470318

# %% [markdown]
# ###### BalancedRandomForest tuning (RandomizedSearchCV)

# %%
param_grid = {
    'n_estimators': [100, 150, 200, 250],
    'max_features': ['sqrt', 'log2', None],
    'max_depth': [3, 6, 9],
    'max_leaf_nodes': [9, 11, 13],
}

# %%
random_search = RandomizedSearchCV(BalancedRandomForestClassifier(n_jobs=-1),
                                   param_grid,
                                   scoring='f1',
                                   verbose=0)
random_search.fit(X_train, y_train)
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# ...
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# RandomizedSearchCV(estimator=BalancedRandomForestClassifier(n_jobs=-1),
#                    param_distributions={'max_depth': [3, 6, 9],
#                                         'max_features': ['sqrt', 'log2', None],
#                                         'max_leaf_nodes': [9, 11, 13],
#                                         'n_estimators': [100, 150, 200, 250]},
#                    scoring='f1')

# %%
brf_tuned = BalancedRandomForestClassifier(**random_search.best_params_, verbose=0)
brf_tuned.fit(X_train, y_train)
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# ...
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# BalancedRandomForestClassifier(max_depth=9, max_leaf_nodes=9, n_estimators=200)

# %%
evaluate_model(brf_tuned, X_test, y_test, "none")
add_to_eval_df(brf_tuned, "BalancedRandomForestClassifier-tuned", "clean", X_train, y_train, X_test, y_test)
# Out:
# none model accuracy for classification is = 81.70%
# ------------------------------------------------
# Confusion Matrix:
#       0     1
# 0  6354  1400
# 1   118   423
# ------------------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.82      0.89      7754
#            1       0.23      0.78      0.36       541
#
#     accuracy                           0.82      8295
#    macro avg       0.61      0.80      0.63      8295
# weighted avg       0.93      0.82      0.86      8295

# %% [markdown]
# #### 2.2 Boosting

# %% [markdown]
# ##### 2.2.1 XGBClassifier

# %%
xgb = XGBClassifier()
xgb.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
evaluate_model(xgb, X_test, y_test, "none")
add_to_eval_df(xgb, "XGBClassifier", "clean", X_train, y_train, X_test, y_test)
# Out:
# none model accuracy for classification is = 94.68%
# ------------------------------------------------
# Confusion Matrix:
#       0    1
# 0  7676   78
# 1   363  178
# ------------------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97      7754
#            1       0.70      0.33      0.45       541
#
#     accuracy                           0.95      8295
#    macro avg       0.83      0.66      0.71      8295
# weighted avg       0.94      0.95      0.94      8295

# %% [markdown]
# ###### XGBClassifier tuning (GridSearchCV)
# https://www.kaggle.com/code/prashant111/a-guide-on-xgboost-hyperparameters-tuning
# https://www.analyticsvidhya.com/blog/2016/03/complete-guide-parameter-tuning-xgboost-with-codes-python/
#
# Tuning mit GridSearchCV dauert bei großer param-Liste sehr lange, daher einzelne Schritte mit jeweils nur 1 bis max. 2 params
#
# auskommentierte Werte stammen aus TF-IDF GridSearch

# %%
param_test = {
    'learning_rate': [0.1, 0.01, 0.001],
}
gsearch = GridSearchCV(estimator=XGBClassifier(
    seed=42
), param_grid=param_test, scoring='f1', n_jobs=-1, cv=5, verbose=1)

# gsearch.fit(X_train, y_train)
# gsearch.best_score_, gsearch.best_params_

# (0.32039688186494825, {'learning_rate': 0.1})

# %%
xgb_test = XGBClassifier(learning_rate=0.1)
xgb_test.fit(X_train, y_train)
evaluate_model(xgb_test, X_test, y_test, "none")
# Out:
# KeyboardInterrupt

# %%
param_test = {
    'n_estimators': range(100, 250, 50),
}
gsearch = GridSearchCV(estimator=XGBClassifier(
    seed=42,
    learning_rate=0.1,
), param_grid=param_test, scoring='f1', n_jobs=-1, cv=5, verbose=1)

# gsearch.fit(X_train, y_train)
# gsearch.best_score_, gsearch.best_params_

# (0.37817637241282653, {'n_estimators': 200})

# %%
xgb_test = XGBClassifier(learning_rate=0.1, n_estimators=200)
xgb_test.fit(X_train, y_train)
evaluate_model(xgb_test, X_test, y_test, "none")

# %%
param_test = {
    'max_depth': range(5, 13, 2),
}
gsearch = GridSearchCV(estimator=XGBClassifier(
    seed=42,
    learning_rate=0.1,
    n_estimators=200,
), param_grid=param_test, scoring='f1', n_jobs=-1, cv=5, verbose=1)

# gsearch.fit(X_train, y_train)
# gsearch.best_score_, gsearch.best_params_

# (0.4298347587940351, {'max_depth': 11})

# %%
xgb_test = XGBClassifier(learning_rate=0.1, n_estimators=200, max_depth=11)
xgb_test.fit(X_train, y_train)
evaluate_model(xgb_test, X_test, y_test, "none")

# %%
param_test = {
    'subsample': [0.5, 0.7, 1]
}
gsearch = GridSearchCV(estimator=XGBClassifier(
    seed=42,
    learning_rate=0.1,
    n_estimators=200,
    max_depth=11,
), param_grid=param_test, scoring='f1', n_jobs=-1, cv=5, verbose=1)

# gsearch.fit(X_train, y_train)
# gsearch.best_score_, gsearch.best_params_

# (0.4406213750099548, {'subsample': 0.7})

# %%
xgb_test = XGBClassifier(learning_rate=0.1, n_estimators=200, max_depth=11, subsample=0.7)
xgb_test.fit(X_train, y_train)
evaluate_model(xgb_test, X_test, y_test, "none")

# %%
param_test = {
    'min_child_weight': range(1, 6, 2),
}
gsearch = GridSearchCV(estimator=XGBClassifier(
    seed=42,
    learning_rate=0.1,
    n_estimators=200,
    max_depth=11,
    subsample=0.7,
), param_grid=param_test, scoring='f1', n_jobs=-1, cv=5, verbose=1)

# gsearch.fit(X_train, y_train)
# gsearch.best_score_, gsearch.best_params_

# (0.4406213750099548, {'min_child_weight': 1}) <== kein Einfluss auf Modellperformance

# %%
param_test = {
    'gamma': [i / 10.0 for i in range(0, 5)],
}
gsearch = GridSearchCV(estimator=XGBClassifier(
    seed=42,
    learning_rate=0.1,
    n_estimators=200,
    max_depth=11,
    subsample=0.7,
), param_grid=param_test, scoring='f1', n_jobs=-1, cv=5, verbose=1)

# gsearch.fit(X_train, y_train)
# gsearch.best_score_, gsearch.best_params_

# (0.4406213750099548, {'gamma': 0.0}) <== kein Einfluss auf Modellperformance

# %%
param_test = {
    'reg_alpha': [1e-5, 1e-2, 0.1, 1, 100]
}
gsearch = GridSearchCV(estimator=XGBClassifier(
    seed=42,
    learning_rate=0.1,
    n_estimators=200,
    max_depth=11,
    subsample=0.7,
), param_grid=param_test, scoring='f1', n_jobs=-1, cv=5, verbose=1)

gsearch.fit(X_train, y_train)
gsearch.best_score_, gsearch.best_params_

# (0.44114103318625436, {'reg_alpha': 0.01})

# %%
param_test = {
    'reg_alpha': [0.005, 0.01, 0.015, 0.02, 0.025]
}
gsearch = GridSearchCV(estimator=XGBClassifier(
    seed=42,
    learning_rate=0.1,
    n_estimators=200,
    max_depth=11,
    subsample=0.7,
), param_grid=param_test, scoring='f1', n_jobs=-1, cv=5, verbose=1)

gsearch.fit(X_train, y_train)
gsearch.best_score_, gsearch.best_params_

# # (0.44114103318625436, {'reg_alpha': 0.01})

# %%
xgb_tuned_grid = XGBClassifier(learning_rate=0.1, n_estimators=200, max_depth=11, subsample=0.7, reg_alpha=0.01)
xgb_tuned_grid.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=11, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
evaluate_model(xgb_tuned_grid, X_test, y_test, "none")
add_to_eval_df(xgb_tuned_grid, "XGBClassifier-tuned-grid", "clean", X_train, y_train, X_test, y_test)
# Out:
# none model accuracy for classification is = 94.78%
# ------------------------------------------------
# Confusion Matrix:
#       0    1
# 0  7690   64
# 1   369  172
# ------------------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97      7754
#            1       0.73      0.32      0.44       541
#
#     accuracy                           0.95      8295
#    macro avg       0.84      0.65      0.71      8295
# weighted avg       0.94      0.95      0.94      8295

# %% [markdown]
# ###### XGBClassifier tuning (RandomizedSearchCV)
# Vergleich Modellperformance zwischen GridSearchCV <-> RandomizedSearchCV

# %%
param_grid = {
    'learning_rate': [0.1, 0.01, 0.001],
    'n_estimators': range(100, 250, 50),
    'max_depth': range(5, 13, 2),
    'subsample': [0.5, 0.7, 1],
    'min_child_weight': range(1, 6, 2),
    'gamma': [i / 10.0 for i in range(0, 5)],
    'reg_alpha': [1e-5, 1e-2, 0.1, 1, 100],
}

# %%
rsearch = RandomizedSearchCV(XGBClassifier(n_jobs=-1),
                             param_grid,
                             scoring='f1',
                             verbose=1,
                             cv=5,
                             )

# %%
rsearch.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# RandomizedSearchCV(cv=5,
#                    estimator=XGBClassifier(base_score=None, booster=None,
#                                            callbacks=None,
#                                            colsample_bylevel=None,
#                                            colsample_bynode=None,
#                                            colsample_bytree=None, device=None,
#                                            early_stopping_rounds=None,
#                                            enable_categorical=False,
#                                            eval_metric=None, feature_types=None,
#                                            gamma=None, grow_policy=None,
#                                            importance_type=None,
#                                            interaction_constraints=None,
#                                            learning_rate...
#                                            multi_strategy=None,
#                                            n_estimators=None, n_jobs=-1,
#                                            num_parallel_tree=None,
#                                            random_state=None, ...),
#                    param_distributions={'gamma': [0.0, 0.1, 0.2, 0.3, 0.4],
#                                         'learning_rate': [0.1, 0.01, 0.001],
#                                         'max_depth': range(5, 13, 2),
#                                         'min_child_weight': range(1, 6, 2),
#                                         'n_estimators': range(100, 250, 50),
#                                         'reg_alpha': [1e-05, 0.01, 0.1, 1, 100],
#                                         'subsample': [0.5, 0.7, 1]},
#                    scoring='f1', verbose=1)

# %%
rsearch.best_score_, rsearch.best_params_
# Out:
# (0.40697363371850204,
#  {'subsample': 1,
#   'reg_alpha': 1,
#   'n_estimators': 100,
#   'min_child_weight': 5,
#   'max_depth': 9,
#   'learning_rate': 0.1,
#   'gamma': 0.4})

# %%
xgb_tuned_rand = XGBClassifier(**rsearch.best_params_, n_jobs=-1)
xgb_tuned_rand.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=0.4, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=9, max_leaves=None,
#               min_child_weight=5, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=100, n_jobs=-1,
#               num_parallel_tree=None, random_state=None, ...)

# %%
evaluate_model(xgb_tuned_rand, X_test, y_test, "none")
add_to_eval_df(xgb_tuned_rand, "XGBClassifier-tuned-rand", "clean", X_train, y_train, X_test, y_test)
# Out:
# none model accuracy for classification is = 94.90%
# ------------------------------------------------
# Confusion Matrix:
#       0    1
# 0  7695   59
# 1   364  177
# ------------------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97      7754
#            1       0.75      0.33      0.46       541
#
#     accuracy                           0.95      8295
#    macro avg       0.85      0.66      0.71      8295
# weighted avg       0.94      0.95      0.94      8295

# %% [markdown]
# ###### XGBClassifier tuning (optuna)
# https://randomrealizations.com/posts/xgboost-parameter-tuning-with-optuna/
# https://www.kaggle.com/code/rzatemizel/optuna-xgboostcv-integration-with-pruning#Intro

# %%
def balancedlogloss(predt: np.ndarray, dtrain: xgboost.DMatrix) -> Tuple[str, float]:
    ''' balanced log loss metric.'''
    y = dtrain.get_label()
    target_mean = y.mean()
    w0 = 1 / (1 - target_mean)
    w1 = 1 / target_mean
    sample_weight = [w0 if y == 0 else w1 for y in y]
    loss = log_loss(y, predt, eps=1e-15, sample_weight=sample_weight)

    return 'balancedlogloss', loss

def objective(trial):
    dtrain = xgboost.DMatrix(X_train, label=y_train)

    param = {

        "verbosity": 0,
        "objective": "binary:logistic",
        "booster": trial.suggest_categorical("booster", ["gbtree", "gblinear", "dart"]),
        "lambda": trial.suggest_float("lambda", 1e-8, 1.0, log=True),
        "alpha": trial.suggest_float("alpha", 1e-8, 1.0, log=True),
        "subsample": trial.suggest_float("subsample", 0.2, 0.8),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.2, 0.8),
        'scale_pos_weight': 509 / 108,
        'random_state': 42,
    }

    if param["booster"] == "gbtree" or param["booster"] == "dart":
        param["max_depth"] = trial.suggest_int("max_depth", 1, 16)
        param["eta"] = trial.suggest_float("eta", 1e-3, 1.0, log=True)
        param["gamma"] = trial.suggest_float("gamma", 1e-8, 1.0, log=True)
        param["grow_policy"] = trial.suggest_categorical("grow_policy", ["depthwise", "lossguide"])
    if param["booster"] == "dart":
        param["sample_type"] = trial.suggest_categorical("sample_type", ["uniform", "weighted"])
        param["normalize_type"] = trial.suggest_categorical("normalize_type", ["tree", "forest"])
        param["rate_drop"] = trial.suggest_float("rate_drop", 1e-8, 1.0, log=True)
        param["skip_drop"] = trial.suggest_float("skip_drop", 1e-8, 1.0, log=True)

    pruning_callback = optuna.integration.XGBoostPruningCallback(trial, "test-balancedlogloss")
    history = xgboost.cv(param,
                     dtrain,
                     stratified=True,
                     nfold=5,
                     num_boost_round=10000,
                     early_stopping_rounds=50,
                     custom_metric=balancedlogloss,
                     seed=42,
                     callbacks=[pruning_callback])

    mean_balancedlogloss = history["test-balancedlogloss-mean"].values[-1]
    trial.set_user_attr("n_estimators", len(history))
    return mean_balancedlogloss

# %%
sampler = TPESampler(seed=42)
pruner = optuna.pruners.MedianPruner(n_warmup_steps=10)
study = optuna.create_study(sampler=sampler, pruner=pruner, direction="minimize")
study.optimize(objective, n_trials=5)
# Out:
# [I 2024-11-24 19:31:11,635] A new study created in memory with name: no-name-50622107-742c-434e-ac4c-816aa0551dfe
# [I 2024-11-24 19:35:22,472] Trial 0 finished with value: 0.4744846 and parameters: {'booster': 'gblinear', 'lambda': 0.0006155564318973012, 'alpha': 1.77071686435378e-07, 'subsample': 0.2935967122017216, 'colsample_bytree': 0.23485016730091968}. Best is trial 0 with value: 0.4744846.
# [I 2024-11-24 19:49:39,139] Trial 1 finished with value: 0.48108019999999996 and parameters: {'booster': 'gbtree', 'lambda': 1.4610865886287176e-08, 'alpha': 0.574485163632042, 'subsample': 0.6994655844802531, 'colsample_bytree': 0.3274034664069657, 'max_depth': 3, 'eta': 0.0035498788321965025, 'gamma': 2.716051144654844e-06, 'grow_policy': 'depthwise'}. Best is trial 0 with value: 0.4744846.
# [I 2024-11-24 19:50:02,634] Trial 2 finished with value: 0.476497 and parameters: {'booster': 'gblinear', 'lambda': 2.1734877073417355e-06, 'alpha': 8.528933855762793e-06, 'subsample': 0.4736419905302216, 'colsample_bytree': 0.6711055768358083}. Best is trial 0 with value: 0.4744846.
# C:\Users\admin\anaconda3\lib\site-packages\numpy\core\_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# C:\Users\admin\anaconda3\lib\site-packages\numpy\core\_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# C:\Users\admin\anaconda3\lib\site-packages\numpy\core\_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# C:\Users\admin\anaconda3\lib\site-packages\numpy\core\_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# C:\Users\admin\anaconda3\lib\site-packages\numpy\core\_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# C:\Users\admin\anaconda3\lib\site-packages\numpy\core\_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# C:\Users\admin\anaconda3\lib\site-packages\numpy\core\_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# C:\Users\admin\anaconda3\lib\site-packages\numpy\core\_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# C:\Users\admin\anaconda3\lib\site-packages\numpy\core\_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# C:\Users\admin\anaconda3\lib\site-packages\numpy\core\_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# C:\Users\admin\anaconda3\lib\site-packages\numpy\core\_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# C:\Users\admin\anaconda3\lib\site-packages\numpy\core\_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# C:\Users\admin\anaconda3\lib\site-packages\numpy\core\_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# C:\Users\admin\anaconda3\lib\site-packages\numpy\core\_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# C:\Users\admin\anaconda3\lib\site-packages\numpy\core\_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# C:\Users\admin\anaconda3\lib\site-packages\numpy\core\_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# C:\Users\admin\anaconda3\lib\site-packages\numpy\core\_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# C:\Users\admin\anaconda3\lib\site-packages\numpy\core\_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# C:\Users\admin\anaconda3\lib\site-packages\numpy\core\_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# C:\Users\admin\anaconda3\lib\site-packages\numpy\core\_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# C:\Users\admin\anaconda3\lib\site-packages\numpy\core\_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# C:\Users\admin\anaconda3\lib\site-packages\numpy\core\_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# C:\Users\admin\anaconda3\lib\site-packages\numpy\core\_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# C:\Users\admin\anaconda3\lib\site-packages\numpy\core\_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# C:\Users\admin\anaconda3\lib\site-packages\numpy\core\_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# C:\Users\admin\anaconda3\lib\site-packages\numpy\core\_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# C:\Users\admin\anaconda3\lib\site-packages\numpy\core\_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# C:\Users\admin\anaconda3\lib\site-packages\numpy\core\_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# C:\Users\admin\anaconda3\lib\site-packages\numpy\core\_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# C:\Users\admin\anaconda3\lib\site-packages\numpy\core\_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# C:\Users\admin\anaconda3\lib\site-packages\numpy\core\_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# C:\Users\admin\anaconda3\lib\site-packages\numpy\core\_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# C:\Users\admin\anaconda3\lib\site-packages\numpy\core\_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# C:\Users\admin\anaconda3\lib\site-packages\numpy\core\_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# C:\Users\admin\anaconda3\lib\site-packages\numpy\core\_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# C:\Users\admin\anaconda3\lib\site-packages\numpy\core\_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# C:\Users\admin\anaconda3\lib\site-packages\numpy\core\_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# C:\Users\admin\anaconda3\lib\site-packages\numpy\core\_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# C:\Users\admin\anaconda3\lib\site-packages\numpy\core\_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# C:\Users\admin\anaconda3\lib\site-packages\numpy\core\_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# C:\Users\admin\anaconda3\lib\site-packages\numpy\core\_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# C:\Users\admin\anaconda3\lib\site-packages\numpy\core\_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# C:\Users\admin\anaconda3\lib\site-packages\numpy\core\_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# C:\Users\admin\anaconda3\lib\site-packages\numpy\core\_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# C:\Users\admin\anaconda3\lib\site-packages\numpy\core\_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# C:\Users\admin\anaconda3\lib\site-packages\numpy\core\_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# C:\Users\admin\anaconda3\lib\site-packages\numpy\core\_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# C:\Users\admin\anaconda3\lib\site-packages\numpy\core\_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# C:\Users\admin\anaconda3\lib\site-packages\numpy\core\_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# [I 2024-11-24 19:52:12,452] Trial 3 finished with value: 0.8261904 and parameters: {'booster': 'dart', 'lambda': 2.3528990899815284e-08, 'alpha': 0.0007250347382396634, 'subsample': 0.30231447421237495, 'colsample_bytree': 0.23903095579116773, 'max_depth': 16, 'eta': 0.7886714129990487, 'gamma': 0.02932100047183291, 'grow_policy': 'depthwise', 'sample_type': 'uniform', 'normalize_type': 'forest', 'rate_drop': 1.8841183049085085e-08, 'skip_drop': 0.1881755597772026}. Best is trial 0 with value: 0.4744846.
# [I 2024-11-24 19:56:41,577] Trial 4 finished with value: 0.47754719999999995 and parameters: {'booster': 'gblinear', 'lambda': 0.00014472520367197597, 'alpha': 0.00023641892308789696, 'subsample': 0.31091267331531625, 'colsample_bytree': 0.7817507766587353}. Best is trial 0 with value: 0.4744846.

# %%
print("Number of finished trials: {}".format(len(study.trials)))

print("Best trial:")
trial = study.best_trial

print("  Value: {}".format(trial.value))

print("  Params: ")
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))
# print("  Number of estimators: {}".format(trial.user_attrs["n_estimators"]))

plot_optimization_history(study)
plot_param_importances(study)
# Out:
# Number of finished trials: 5
# Best trial:
#   Value: 0.4744846
#   Params:
#     booster: gblinear
#     lambda: 0.0006155564318973012
#     alpha: 1.77071686435378e-07
#     subsample: 0.2935967122017216
#     colsample_bytree: 0.23485016730091968
# C:\Users\admin\AppData\Local\Temp\ipykernel_15252\993762437.py:13: ExperimentalWarning: plot_optimization_history is experimental (supported from v2.2.0). The interface can change in the future.
#   plot_optimization_history(study)
# C:\Users\admin\AppData\Local\Temp\ipykernel_15252\993762437.py:14: ExperimentalWarning: plot_param_importances is experimental (supported from v2.2.0). The interface can change in the future.
#   plot_param_importances(study)
# <Axes: title={'left': 'Hyperparameter Importances'}, xlabel='Hyperparameter Importance', ylabel='Hyperparameter'>

# %%
xgb_tuned_optuna = XGBClassifier(**study.best_trial.params)
xgb_tuned_optuna.fit(X_train, y_train)
evaluate_model(xgb_tuned_optuna, X_test, y_test, "none")
add_to_eval_df(xgb_tuned_optuna, "XGBClassifier-tuned-optuna", "clean", X_train, y_train, X_test, y_test)
# Out:
# none model accuracy for classification is = 93.91%
# ------------------------------------------------
# Confusion Matrix:
#       0   1
# 0  7693  61
# 1   444  97
# ------------------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97      7754
#            1       0.61      0.18      0.28       541
#
#     accuracy                           0.94      8295
#    macro avg       0.78      0.59      0.62      8295
# weighted avg       0.92      0.94      0.92      8295

# %% [markdown]
# ##### 2.2.1 CatBoostClassifier

# %%
cat = CatBoostClassifier(iterations=100,
                         depth=5,
                         learning_rate=0.1,
                         loss_function='Logloss',
                         verbose=True)
cat.fit(X_train, y_train)
# Out:
# 0:	learn: 0.5564558	total: 178ms	remaining: 17.6s
# 1:	learn: 0.4592830	total: 202ms	remaining: 9.87s
# 2:	learn: 0.3861263	total: 226ms	remaining: 7.3s
# 3:	learn: 0.3332650	total: 251ms	remaining: 6.04s
# 4:	learn: 0.2969638	total: 277ms	remaining: 5.27s
# 5:	learn: 0.2684588	total: 301ms	remaining: 4.72s
# 6:	learn: 0.2456776	total: 328ms	remaining: 4.36s
# 7:	learn: 0.2295749	total: 353ms	remaining: 4.06s
# 8:	learn: 0.2155045	total: 378ms	remaining: 3.82s
# 9:	learn: 0.2074765	total: 404ms	remaining: 3.64s
# 10:	learn: 0.2001826	total: 430ms	remaining: 3.48s
# 11:	learn: 0.1933055	total: 455ms	remaining: 3.33s
# 12:	learn: 0.1876212	total: 481ms	remaining: 3.22s
# 13:	learn: 0.1838539	total: 505ms	remaining: 3.1s
# 14:	learn: 0.1802649	total: 530ms	remaining: 3s
# 15:	learn: 0.1773749	total: 554ms	remaining: 2.91s
# 16:	learn: 0.1751286	total: 579ms	remaining: 2.82s
# 17:	learn: 0.1726874	total: 603ms	remaining: 2.75s
# 18:	learn: 0.1705187	total: 627ms	remaining: 2.67s
# 19:	learn: 0.1687924	total: 652ms	remaining: 2.61s
# 20:	learn: 0.1671469	total: 679ms	remaining: 2.55s
# 21:	learn: 0.1655379	total: 703ms	remaining: 2.49s
# 22:	learn: 0.1642666	total: 730ms	remaining: 2.44s
# 23:	learn: 0.1631780	total: 756ms	remaining: 2.39s
# 24:	learn: 0.1623074	total: 779ms	remaining: 2.34s
# 25:	learn: 0.1613551	total: 803ms	remaining: 2.29s
# 26:	learn: 0.1600172	total: 829ms	remaining: 2.24s
# 27:	learn: 0.1589137	total: 855ms	remaining: 2.2s
# 28:	learn: 0.1584539	total: 880ms	remaining: 2.15s
# 29:	learn: 0.1576501	total: 906ms	remaining: 2.11s
# 30:	learn: 0.1568963	total: 932ms	remaining: 2.07s
# 31:	learn: 0.1559450	total: 958ms	remaining: 2.04s
# 32:	learn: 0.1549666	total: 985ms	remaining: 2s
# 33:	learn: 0.1544982	total: 1.01s	remaining: 1.96s
# 34:	learn: 0.1538507	total: 1.04s	remaining: 1.93s
# 35:	learn: 0.1533517	total: 1.06s	remaining: 1.89s
# 36:	learn: 0.1528277	total: 1.09s	remaining: 1.85s
# 37:	learn: 0.1522675	total: 1.11s	remaining: 1.81s
# 38:	learn: 0.1516732	total: 1.14s	remaining: 1.78s
# 39:	learn: 0.1511817	total: 1.16s	remaining: 1.74s
# 40:	learn: 0.1506758	total: 1.19s	remaining: 1.71s
# 41:	learn: 0.1500940	total: 1.21s	remaining: 1.67s
# 42:	learn: 0.1497009	total: 1.23s	remaining: 1.63s
# 43:	learn: 0.1491297	total: 1.26s	remaining: 1.6s
# 44:	learn: 0.1488265	total: 1.28s	remaining: 1.57s
# 45:	learn: 0.1484113	total: 1.31s	remaining: 1.54s
# 46:	learn: 0.1479407	total: 1.33s	remaining: 1.5s
# 47:	learn: 0.1473808	total: 1.36s	remaining: 1.47s
# 48:	learn: 0.1469787	total: 1.39s	remaining: 1.44s
# 49:	learn: 0.1465453	total: 1.41s	remaining: 1.41s
# 50:	learn: 0.1460989	total: 1.44s	remaining: 1.38s
# 51:	learn: 0.1456821	total: 1.47s	remaining: 1.36s
# 52:	learn: 0.1453054	total: 1.49s	remaining: 1.32s
# 53:	learn: 0.1450340	total: 1.52s	remaining: 1.29s
# 54:	learn: 0.1446143	total: 1.54s	remaining: 1.26s
# 55:	learn: 0.1442875	total: 1.57s	remaining: 1.23s
# 56:	learn: 0.1439190	total: 1.59s	remaining: 1.2s
# 57:	learn: 0.1436035	total: 1.62s	remaining: 1.17s
# 58:	learn: 0.1431685	total: 1.64s	remaining: 1.14s
# 59:	learn: 0.1428518	total: 1.67s	remaining: 1.11s
# 60:	learn: 0.1424797	total: 1.69s	remaining: 1.08s
# 61:	learn: 0.1421224	total: 1.71s	remaining: 1.05s
# 62:	learn: 0.1418228	total: 1.73s	remaining: 1.02s
# 63:	learn: 0.1415526	total: 1.75s	remaining: 987ms
# 64:	learn: 0.1413286	total: 1.78s	remaining: 957ms
# 65:	learn: 0.1409934	total: 1.8s	remaining: 928ms
# 66:	learn: 0.1406727	total: 1.82s	remaining: 899ms
# 67:	learn: 0.1403987	total: 1.85s	remaining: 869ms
# 68:	learn: 0.1401496	total: 1.87s	remaining: 840ms
# 69:	learn: 0.1398364	total: 1.89s	remaining: 810ms
# 70:	learn: 0.1394858	total: 1.91s	remaining: 781ms
# 71:	learn: 0.1389279	total: 1.94s	remaining: 753ms
# 72:	learn: 0.1386409	total: 1.96s	remaining: 724ms
# 73:	learn: 0.1383049	total: 1.98s	remaining: 697ms
# 74:	learn: 0.1378613	total: 2.01s	remaining: 670ms
# 75:	learn: 0.1375404	total: 2.04s	remaining: 643ms
# 76:	learn: 0.1372728	total: 2.06s	remaining: 615ms
# 77:	learn: 0.1370230	total: 2.08s	remaining: 587ms
# 78:	learn: 0.1366120	total: 2.1s	remaining: 559ms
# 79:	learn: 0.1361951	total: 2.13s	remaining: 531ms
# 80:	learn: 0.1360082	total: 2.15s	remaining: 504ms
# 81:	learn: 0.1356308	total: 2.17s	remaining: 476ms
# 82:	learn: 0.1352708	total: 2.19s	remaining: 449ms
# 83:	learn: 0.1350319	total: 2.21s	remaining: 422ms
# 84:	learn: 0.1346124	total: 2.24s	remaining: 395ms
# 85:	learn: 0.1342291	total: 2.26s	remaining: 368ms
# 86:	learn: 0.1339369	total: 2.28s	remaining: 341ms
# 87:	learn: 0.1336706	total: 2.31s	remaining: 314ms
# 88:	learn: 0.1332908	total: 2.33s	remaining: 288ms
# 89:	learn: 0.1329654	total: 2.35s	remaining: 261ms
# 90:	learn: 0.1327469	total: 2.37s	remaining: 235ms
# 91:	learn: 0.1322879	total: 2.4s	remaining: 208ms
# 92:	learn: 0.1318768	total: 2.42s	remaining: 182ms
# 93:	learn: 0.1315850	total: 2.44s	remaining: 156ms
# 94:	learn: 0.1311587	total: 2.46s	remaining: 130ms
# 95:	learn: 0.1309050	total: 2.49s	remaining: 104ms
# 96:	learn: 0.1306014	total: 2.51s	remaining: 77.7ms
# 97:	learn: 0.1304292	total: 2.54s	remaining: 51.7ms
# 98:	learn: 0.1302505	total: 2.56s	remaining: 25.8ms
# 99:	learn: 0.1299313	total: 2.58s	remaining: 0us

# %%
evaluate_model(cat, X_test, y_test, "none")
add_to_eval_df(cat, "CatBoostClassifier", "clean", X_train, y_train, X_test, y_test)
# Out:
# none model accuracy for classification is = 94.32%
# ------------------------------------------------
# Confusion Matrix:
#       0    1
# 0  7686   68
# 1   403  138
# ------------------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97      7754
#            1       0.67      0.26      0.37       541
#
#     accuracy                           0.94      8295
#    macro avg       0.81      0.62      0.67      8295
# weighted avg       0.93      0.94      0.93      8295

# %% [markdown]
# ##### 2.2.1 LGBMClassifier

# %%
light = LGBMClassifier()
light.fit(X_train, y_train)
# Out:
# [LightGBM] [Info] Number of positive: 1270, number of negative: 18084
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.022668 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 76500
# [LightGBM] [Info] Number of data points in the train set: 19354, number of used features: 300
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.065620 -> initscore=-2.656011
# [LightGBM] [Info] Start training from score -2.656011
# LGBMClassifier()

# %%
evaluate_model(light, X_test, y_test, "none")
add_to_eval_df(light, "LGBMClassifier", "clean", X_train, y_train, X_test, y_test)
# Out:
# none model accuracy for classification is = 94.61%
# ------------------------------------------------
# Confusion Matrix:
#       0    1
# 0  7677   77
# 1   370  171
# ------------------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97      7754
#            1       0.69      0.32      0.43       541
#
#     accuracy                           0.95      8295
#    macro avg       0.82      0.65      0.70      8295
# weighted avg       0.94      0.95      0.94      8295

# %% [markdown]
# #### 2.3 Stacking

# %% [markdown]
# ##### 2.3.1 Stacking: RandomForest + LinearSVC

# %%
base_models = [
    ('rf', RandomForestClassifier(random_state=42)),
    ('svc', LinearSVC(random_state=42))
]
stack = StackingClassifier(estimators=base_models, n_jobs=-1)

# %%
stack.fit(X_train, y_train)
# Out:
# StackingClassifier(estimators=[('rf', RandomForestClassifier(random_state=42)),
#                                ('svc', LinearSVC(random_state=42))],
#                    n_jobs=-1)

# %%
evaluate_model(stack, X_test, y_test, "none")
add_to_eval_df(stack, "StackingClassifier", "clean", X_train, y_train, X_test, y_test)
# Out:
# none model accuracy for classification is = 94.60%
# ------------------------------------------------
# Confusion Matrix:
#       0    1
# 0  7688   66
# 1   382  159
# ------------------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97      7754
#            1       0.71      0.29      0.42       541
#
#     accuracy                           0.95      8295
#    macro avg       0.83      0.64      0.69      8295
# weighted avg       0.94      0.95      0.94      8295

# %% [markdown]
# Vergleich: SVC

# %%
svc = LinearSVC()
svc.fit(X_train, y_train)
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# LinearSVC()

# %%
evaluate_model(svc, X_test, y_test, "none")
add_to_eval_df(svc, "LinearSVC", "clean", X_train, y_train, X_test, y_test)
# Out:
# none model accuracy for classification is = 94.32%
# ------------------------------------------------
# Confusion Matrix:
#       0    1
# 0  7720   34
# 1   437  104
# ------------------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      7754
#            1       0.75      0.19      0.31       541
#
#     accuracy                           0.94      8295
#    macro avg       0.85      0.59      0.64      8295
# weighted avg       0.93      0.94      0.93      8295
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 evaluate_model(svc, X_test, y_test, "none")
#       2 add_to_eval_df(svc, "LinearSVC", "clean", X_train, y_train, X_test, y_test)
#
# Cell In[8], line 13, in evaluate_model(model, x_test, y_test, sampling_method)
#      10 print('Classification Report:')
#      11 print(classification_report(y_test, pred))
# ---> 13 probs = model.predict_proba(x_test)
#      14 preds = probs[:, 1]
#      15 fpr, tpr, threshold = metrics.roc_curve(y_test, preds)
#
# AttributeError: 'LinearSVC' object has no attribute 'predict_proba'

# %% [markdown]
# #### Model comparision

# %%
evaluation.sort_values(by=["test_prec"], ascending=False)
# Out:
#                                    model variant  train_acc  train_prec  \
# 0                 RandomForestClassifier   clean   0.999948    0.999213
# 11             RandomForest-tuned-optuna   clean   0.999948    1.000000
# 6               XGBClassifier-tuned-rand   clean   0.998192    1.000000
# 5               XGBClassifier-tuned-grid   clean   0.999948    1.000000
# 10                    StackingClassifier   clean   0.971065    0.914720
# 1      RandomForestClassifier-tuned-rand   clean   0.943526    0.784566
# 4                          XGBClassifier   clean   0.999948    1.000000
# 9                         LGBMClassifier   clean   0.995298    0.993305
# 8                     CatBoostClassifier   clean   0.952361    0.828302
# 7             XGBClassifier-tuned-optuna   clean   0.939651    0.618605
# 2         BalancedRandomForestClassifier   clean   0.860184    0.319416
# 3   BalancedRandomForestClassifier-tuned   clean   0.817195    0.240741
#
#     train_rec  train_f1  test_acc  test_prec  test_rec   test_f1
# 0    1.000000  0.999606  0.944304   0.796992  0.195933  0.314540
# 11   0.999213  0.999606  0.943339   0.779528  0.182994  0.296407
# 6    0.972441  0.986028  0.949005   0.750000  0.327172  0.455598
# 5    0.999213  0.999606  0.947800   0.728814  0.317930  0.442728
# 10   0.616535  0.736595  0.945992   0.706667  0.293900  0.415144
# 1    0.192126  0.308665  0.940928   0.700787  0.164510  0.266467
# 4    0.999213  0.999606  0.946835   0.695312  0.329020  0.446675
# 9    0.934646  0.963083  0.946112   0.689516  0.316081  0.433460
# 8    0.345669  0.487778  0.943219   0.669903  0.255083  0.369478
# 7    0.209449  0.312941  0.939120   0.613924  0.179298  0.277539
# 2    1.000000  0.484178  0.837734   0.259988  0.805915  0.393147
# 3    0.829134  0.373140  0.816998   0.232035  0.781885  0.357868

# %%
evaluation.sort_values(by=["test_rec"], ascending=False)
# Out:
#                                    model variant  train_acc  train_prec  \
# 2         BalancedRandomForestClassifier   clean   0.860184    0.319416
# 3   BalancedRandomForestClassifier-tuned   clean   0.817195    0.240741
# 4                          XGBClassifier   clean   0.999948    1.000000
# 6               XGBClassifier-tuned-rand   clean   0.998192    1.000000
# 5               XGBClassifier-tuned-grid   clean   0.999948    1.000000
# 9                         LGBMClassifier   clean   0.995298    0.993305
# 10                    StackingClassifier   clean   0.971065    0.914720
# 8                     CatBoostClassifier   clean   0.952361    0.828302
# 0                 RandomForestClassifier   clean   0.999948    0.999213
# 11             RandomForest-tuned-optuna   clean   0.999948    1.000000
# 7             XGBClassifier-tuned-optuna   clean   0.939651    0.618605
# 1      RandomForestClassifier-tuned-rand   clean   0.943526    0.784566
#
#     train_rec  train_f1  test_acc  test_prec  test_rec   test_f1
# 2    1.000000  0.484178  0.837734   0.259988  0.805915  0.393147
# 3    0.829134  0.373140  0.816998   0.232035  0.781885  0.357868
# 4    0.999213  0.999606  0.946835   0.695312  0.329020  0.446675
# 6    0.972441  0.986028  0.949005   0.750000  0.327172  0.455598
# 5    0.999213  0.999606  0.947800   0.728814  0.317930  0.442728
# 9    0.934646  0.963083  0.946112   0.689516  0.316081  0.433460
# 10   0.616535  0.736595  0.945992   0.706667  0.293900  0.415144
# 8    0.345669  0.487778  0.943219   0.669903  0.255083  0.369478
# 0    1.000000  0.999606  0.944304   0.796992  0.195933  0.314540
# 11   0.999213  0.999606  0.943339   0.779528  0.182994  0.296407
# 7    0.209449  0.312941  0.939120   0.613924  0.179298  0.277539
# 1    0.192126  0.308665  0.940928   0.700787  0.164510  0.266467

# %%
evaluation.sort_values(by=["test_f1"], ascending=False)
# Out:
#                                    model variant  train_acc  train_prec  \
# 6               XGBClassifier-tuned-rand   clean   0.998192    1.000000
# 4                          XGBClassifier   clean   0.999948    1.000000
# 5               XGBClassifier-tuned-grid   clean   0.999948    1.000000
# 9                         LGBMClassifier   clean   0.995298    0.993305
# 10                    StackingClassifier   clean   0.971065    0.914720
# 2         BalancedRandomForestClassifier   clean   0.860184    0.319416
# 8                     CatBoostClassifier   clean   0.952361    0.828302
# 3   BalancedRandomForestClassifier-tuned   clean   0.817195    0.240741
# 0                 RandomForestClassifier   clean   0.999948    0.999213
# 11             RandomForest-tuned-optuna   clean   0.999948    1.000000
# 7             XGBClassifier-tuned-optuna   clean   0.939651    0.618605
# 1      RandomForestClassifier-tuned-rand   clean   0.943526    0.784566
#
#     train_rec  train_f1  test_acc  test_prec  test_rec   test_f1
# 6    0.972441  0.986028  0.949005   0.750000  0.327172  0.455598
# 4    0.999213  0.999606  0.946835   0.695312  0.329020  0.446675
# 5    0.999213  0.999606  0.947800   0.728814  0.317930  0.442728
# 9    0.934646  0.963083  0.946112   0.689516  0.316081  0.433460
# 10   0.616535  0.736595  0.945992   0.706667  0.293900  0.415144
# 2    1.000000  0.484178  0.837734   0.259988  0.805915  0.393147
# 8    0.345669  0.487778  0.943219   0.669903  0.255083  0.369478
# 3    0.829134  0.373140  0.816998   0.232035  0.781885  0.357868
# 0    1.000000  0.999606  0.944304   0.796992  0.195933  0.314540
# 11   0.999213  0.999606  0.943339   0.779528  0.182994  0.296407
# 7    0.209449  0.312941  0.939120   0.613924  0.179298  0.277539
# 1    0.192126  0.308665  0.940928   0.700787  0.164510  0.266467

# %%
evaluation['vectorize_variant'] = "ft"
evaluation = evaluation[['model',
 'variant',
 'vectorize_variant',
 'train_acc',
 'train_prec',
 'train_rec',
 'train_f1',
 'test_acc',
 'test_prec',
 'test_rec',
 'test_f1']]

outname = 'evaluation_ft.csv'

outdir = './eval_data'
if not os.path.exists(outdir):
    os.mkdir(outdir)

fullname = os.path.join(outdir, outname)

evaluation.to_csv(fullname)
