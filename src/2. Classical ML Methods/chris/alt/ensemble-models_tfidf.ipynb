# %% [markdown]
# #### Imports & Downloads

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix, classification_report
from sklearn import metrics

from sklearn.ensemble import RandomForestClassifier, StackingClassifier
from imblearn.ensemble import BalancedRandomForestClassifier
from xgboost import XGBClassifier
import xgboost as xgboost
from sklearn.svm import LinearSVC

from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier

from sklearn.model_selection import cross_val_score
import vectorize_functions

from sklearn.metrics import mean_squared_error
import time
import optuna

from optuna.visualization.matplotlib import plot_optimization_history
from optuna.visualization.matplotlib import plot_param_importances
from typing import Tuple
from sklearn.metrics import log_loss
from optuna.samplers import TPESampler

# %% [markdown]
# ### Einladen der vektorisierten Daten - TFIDF

# %%
X_train, X_test, y_train, y_test = vectorize_functions.vectorize_tfidf()

# %%
positive = np.count_nonzero(y_train == 1)
negative = np.count_nonzero(y_train == 0)
print("Train")
print("- Positive:", positive)
print("- Negative:", negative)
print("- Verhältnis:", negative / positive)

positive = np.count_nonzero(y_test == 1)
negative = np.count_nonzero(y_test == 0)
print("Test")
print("- Positive:", positive)
print("- Negative:", negative)
print("- Verhältnis:", negative / positive)
# Out:
# Train
# - Positive: 1270
# - Negative: 18084
# - Verhältnis: 14.239370078740157
# Test
# - Positive: 541
# - Negative: 7754
# - Verhältnis: 14.33271719038817

# %%
print("X_train shape", X_train.shape)
print("y_train shape", y_train.shape)

print("X_test shape", X_test.shape)
print("y_test shape", y_test.shape)
# Out:
# X_train shape (19354, 6293)
# y_train shape (19354,)
# X_test shape (8295, 6293)
# y_test shape (8295,)

# %% [markdown]
# ### 2. Ensemble Models

# %%
evaluation = pd.DataFrame(
    columns=["model", "variant", "train_acc", "train_prec", "train_rec", "train_f1", "test_acc", "test_prec",
             "test_rec", "test_f1"])

# %%
def add_to_eval_df(model, model_name, variant, x_data_train, y_data_train, x_data_test, y_data_test):
    train_acc = model.score(x_data_train, y_data_train)
    train_precision = precision_score(y_data_train, model.predict(x_data_train))
    train_recall = recall_score(y_data_train, model.predict(x_data_train))
    train_f1 = f1_score(y_data_train, model.predict(x_data_train))

    test_acc = model.score(x_data_test, y_data_test)
    test_precision = precision_score(y_data_test, model.predict(x_data_test))
    test_recall = recall_score(y_data_test, model.predict(x_data_test))
    test_f1 = f1_score(y_data_test, model.predict(x_data_test))

    evaluation.loc[len(evaluation.index)] = [model_name, variant, train_acc, train_precision, train_recall, train_f1,
                                             test_acc, test_precision, test_recall, test_f1]

# %%
def evaluate_model(model, x_test, y_test, sampling_method):
    pred = model.predict(x_test)
    accscore = metrics.accuracy_score(pred, y_test)

    print(f'{sampling_method} model accuracy for classification is =', str('{:04.2f}'.format(accscore * 100)) + '%')
    print('------------------------------------------------')
    print('Confusion Matrix:')
    print(pd.DataFrame(confusion_matrix(y_test, pred)))
    print('------------------------------------------------')
    print('Classification Report:')
    print(classification_report(y_test, pred))

    probs = model.predict_proba(x_test)
    preds = probs[:, 1]
    fpr, tpr, threshold = metrics.roc_curve(y_test, preds)
    roc_auc = metrics.auc(fpr, tpr)

    plt.title('Receiver Operating Characteristic')
    plt.plot(fpr, tpr, 'b', label='AUC = %0.2f' % roc_auc)
    plt.legend(loc='lower right')
    plt.plot([0, 1], [0, 1], 'r--')
    plt.xlim([0, 1])
    plt.ylim([0, 1])
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    plt.show()

# %% [markdown]
# #### 2.1 Bagging

# %% [markdown]
# ##### 2.1.1 RandomForest

# %% [markdown]
# ###### RandomForest no tuning

# %%
rf = RandomForestClassifier(n_jobs=-1)
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_jobs=-1)

# %%
evaluate_model(rf, X_test, y_test, "none")
add_to_eval_df(rf, "RandomForestClassifier", "clean", X_train, y_train, X_test, y_test)
# Out:
# none model accuracy for classification is = 95.78%
# ------------------------------------------------
# Confusion Matrix:
#       0    1
# 0  7706   48
# 1   302  239
# ------------------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98      7754
#            1       0.83      0.44      0.58       541
#
#     accuracy                           0.96      8295
#    macro avg       0.90      0.72      0.78      8295
# weighted avg       0.95      0.96      0.95      8295

# %%
cv = cross_val_score(rf, X_train, y_train, cv=10, scoring='f1', verbose=10)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] START .....................................................................
# [CV] END ................................ score: (test=0.511) total time=  21.4s
# [CV] START .....................................................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   21.4s remaining:    0.0s
# [CV] END ................................ score: (test=0.510) total time=   3.7s
# [CV] START .....................................................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:   25.2s remaining:    0.0s
# [CV] END ................................ score: (test=0.533) total time=   2.8s
# [CV] START .....................................................................
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:   28.0s remaining:    0.0s
# [CV] END ................................ score: (test=0.526) total time=   3.3s
# [CV] START .....................................................................
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:   31.4s remaining:    0.0s
# [CV] END ................................ score: (test=0.551) total time=   3.2s
# [CV] START .....................................................................
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:   34.7s remaining:    0.0s
# [CV] END ................................ score: (test=0.480) total time=   3.6s
# [CV] START .....................................................................
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:   38.4s remaining:    0.0s
# [CV] END ................................ score: (test=0.544) total time=   3.4s
# [CV] START .....................................................................
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:   41.8s remaining:    0.0s
# [CV] END ................................ score: (test=0.546) total time=   3.1s
# [CV] START .....................................................................
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:   45.0s remaining:    0.0s
# [CV] END ................................ score: (test=0.569) total time=   2.6s
# [CV] START .....................................................................
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:   47.7s remaining:    0.0s
# [CV] END ................................ score: (test=0.538) total time=   2.6s
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:   50.4s finished

# %%
np.mean(cv)
# Out:
# 0.53078702366625

# %% [markdown]
# ###### RandomForest tuning (GridSearchCV)

# %%
# todo

# %% [markdown]
# ###### RandomForest tuning (RandomizedSearchCV)

# %%
param_grid = {
    'n_estimators': [100, 150, 200, 250],
    'max_features': ['sqrt', 'log2', None],
    'max_depth': [3, 6, 9],
    'max_leaf_nodes': [9, 11, 13],
}

# %%
random_search = RandomizedSearchCV(RandomForestClassifier(n_jobs=-1),
                                   param_grid,
                                   scoring='f1',
                                   verbose=10)
random_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5; 1/10] START max_depth=3, max_features=None, max_leaf_nodes=9, n_estimators=200
# [CV 1/5; 1/10] END max_depth=3, max_features=None, max_leaf_nodes=9, n_estimators=200;, score=0.213 total time=   2.4s
# [CV 2/5; 1/10] START max_depth=3, max_features=None, max_leaf_nodes=9, n_estimators=200
# [CV 2/5; 1/10] END max_depth=3, max_features=None, max_leaf_nodes=9, n_estimators=200;, score=0.177 total time=   2.5s
# [CV 3/5; 1/10] START max_depth=3, max_features=None, max_leaf_nodes=9, n_estimators=200
# [CV 3/5; 1/10] END max_depth=3, max_features=None, max_leaf_nodes=9, n_estimators=200;, score=0.147 total time=   2.4s
# [CV 4/5; 1/10] START max_depth=3, max_features=None, max_leaf_nodes=9, n_estimators=200
# [CV 4/5; 1/10] END max_depth=3, max_features=None, max_leaf_nodes=9, n_estimators=200;, score=0.236 total time=   2.5s
# [CV 5/5; 1/10] START max_depth=3, max_features=None, max_leaf_nodes=9, n_estimators=200
# [CV 5/5; 1/10] END max_depth=3, max_features=None, max_leaf_nodes=9, n_estimators=200;, score=0.224 total time=   2.3s
# [CV 1/5; 2/10] START max_depth=3, max_features=sqrt, max_leaf_nodes=9, n_estimators=100
# [CV 1/5; 2/10] END max_depth=3, max_features=sqrt, max_leaf_nodes=9, n_estimators=100;, score=0.000 total time=   0.2s
# [CV 2/5; 2/10] START max_depth=3, max_features=sqrt, max_leaf_nodes=9, n_estimators=100
# [CV 2/5; 2/10] END max_depth=3, max_features=sqrt, max_leaf_nodes=9, n_estimators=100;, score=0.000 total time=   0.2s
# [CV 3/5; 2/10] START max_depth=3, max_features=sqrt, max_leaf_nodes=9, n_estimators=100
# [CV 3/5; 2/10] END max_depth=3, max_features=sqrt, max_leaf_nodes=9, n_estimators=100;, score=0.000 total time=   0.2s
# [CV 4/5; 2/10] START max_depth=3, max_features=sqrt, max_leaf_nodes=9, n_estimators=100
# [CV 4/5; 2/10] END max_depth=3, max_features=sqrt, max_leaf_nodes=9, n_estimators=100;, score=0.000 total time=   0.2s
# [CV 5/5; 2/10] START max_depth=3, max_features=sqrt, max_leaf_nodes=9, n_estimators=100
# [CV 5/5; 2/10] END max_depth=3, max_features=sqrt, max_leaf_nodes=9, n_estimators=100;, score=0.000 total time=   0.2s
# [CV 1/5; 3/10] START max_depth=9, max_features=log2, max_leaf_nodes=13, n_estimators=250
# [CV 1/5; 3/10] END max_depth=9, max_features=log2, max_leaf_nodes=13, n_estimators=250;, score=0.000 total time=   0.6s
# [CV 2/5; 3/10] START max_depth=9, max_features=log2, max_leaf_nodes=13, n_estimators=250
# [CV 2/5; 3/10] END max_depth=9, max_features=log2, max_leaf_nodes=13, n_estimators=250;, score=0.000 total time=   0.6s
# [CV 3/5; 3/10] START max_depth=9, max_features=log2, max_leaf_nodes=13, n_estimators=250
# [CV 3/5; 3/10] END max_depth=9, max_features=log2, max_leaf_nodes=13, n_estimators=250;, score=0.000 total time=   0.6s
# [CV 4/5; 3/10] START max_depth=9, max_features=log2, max_leaf_nodes=13, n_estimators=250
# [CV 4/5; 3/10] END max_depth=9, max_features=log2, max_leaf_nodes=13, n_estimators=250;, score=0.000 total time=   0.6s
# [CV 5/5; 3/10] START max_depth=9, max_features=log2, max_leaf_nodes=13, n_estimators=250
# [CV 5/5; 3/10] END max_depth=9, max_features=log2, max_leaf_nodes=13, n_estimators=250;, score=0.000 total time=   0.6s
# [CV 1/5; 4/10] START max_depth=6, max_features=None, max_leaf_nodes=9, n_estimators=250
# [CV 1/5; 4/10] END max_depth=6, max_features=None, max_leaf_nodes=9, n_estimators=250;, score=0.313 total time=   5.9s
# [CV 2/5; 4/10] START max_depth=6, max_features=None, max_leaf_nodes=9, n_estimators=250
# [CV 2/5; 4/10] END max_depth=6, max_features=None, max_leaf_nodes=9, n_estimators=250;, score=0.280 total time=   6.5s
# [CV 3/5; 4/10] START max_depth=6, max_features=None, max_leaf_nodes=9, n_estimators=250
# [CV 3/5; 4/10] END max_depth=6, max_features=None, max_leaf_nodes=9, n_estimators=250;, score=0.224 total time=   6.0s
# [CV 4/5; 4/10] START max_depth=6, max_features=None, max_leaf_nodes=9, n_estimators=250
# [CV 4/5; 4/10] END max_depth=6, max_features=None, max_leaf_nodes=9, n_estimators=250;, score=0.307 total time=   6.5s
# [CV 5/5; 4/10] START max_depth=6, max_features=None, max_leaf_nodes=9, n_estimators=250
# [CV 5/5; 4/10] END max_depth=6, max_features=None, max_leaf_nodes=9, n_estimators=250;, score=0.340 total time=   6.7s
# [CV 1/5; 5/10] START max_depth=9, max_features=log2, max_leaf_nodes=11, n_estimators=250
# [CV 1/5; 5/10] END max_depth=9, max_features=log2, max_leaf_nodes=11, n_estimators=250;, score=0.000 total time=   0.7s
# [CV 2/5; 5/10] START max_depth=9, max_features=log2, max_leaf_nodes=11, n_estimators=250
# [CV 2/5; 5/10] END max_depth=9, max_features=log2, max_leaf_nodes=11, n_estimators=250;, score=0.000 total time=   0.7s
# [CV 3/5; 5/10] START max_depth=9, max_features=log2, max_leaf_nodes=11, n_estimators=250
# [CV 3/5; 5/10] END max_depth=9, max_features=log2, max_leaf_nodes=11, n_estimators=250;, score=0.000 total time=   0.7s
# [CV 4/5; 5/10] START max_depth=9, max_features=log2, max_leaf_nodes=11, n_estimators=250
# [CV 4/5; 5/10] END max_depth=9, max_features=log2, max_leaf_nodes=11, n_estimators=250;, score=0.000 total time=   0.7s
# [CV 5/5; 5/10] START max_depth=9, max_features=log2, max_leaf_nodes=11, n_estimators=250
# [CV 5/5; 5/10] END max_depth=9, max_features=log2, max_leaf_nodes=11, n_estimators=250;, score=0.000 total time=   0.8s
# [CV 1/5; 6/10] START max_depth=3, max_features=log2, max_leaf_nodes=13, n_estimators=100
# [CV 1/5; 6/10] END max_depth=3, max_features=log2, max_leaf_nodes=13, n_estimators=100;, score=0.000 total time=   0.3s
# [CV 2/5; 6/10] START max_depth=3, max_features=log2, max_leaf_nodes=13, n_estimators=100
# [CV 2/5; 6/10] END max_depth=3, max_features=log2, max_leaf_nodes=13, n_estimators=100;, score=0.000 total time=   0.2s
# [CV 3/5; 6/10] START max_depth=3, max_features=log2, max_leaf_nodes=13, n_estimators=100
# [CV 3/5; 6/10] END max_depth=3, max_features=log2, max_leaf_nodes=13, n_estimators=100;, score=0.000 total time=   0.3s
# [CV 4/5; 6/10] START max_depth=3, max_features=log2, max_leaf_nodes=13, n_estimators=100
# [CV 4/5; 6/10] END max_depth=3, max_features=log2, max_leaf_nodes=13, n_estimators=100;, score=0.000 total time=   0.3s
# [CV 5/5; 6/10] START max_depth=3, max_features=log2, max_leaf_nodes=13, n_estimators=100
# [CV 5/5; 6/10] END max_depth=3, max_features=log2, max_leaf_nodes=13, n_estimators=100;, score=0.000 total time=   0.2s
# [CV 1/5; 7/10] START max_depth=6, max_features=sqrt, max_leaf_nodes=11, n_estimators=150
# [CV 1/5; 7/10] END max_depth=6, max_features=sqrt, max_leaf_nodes=11, n_estimators=150;, score=0.000 total time=   0.4s
# [CV 2/5; 7/10] START max_depth=6, max_features=sqrt, max_leaf_nodes=11, n_estimators=150
# [CV 2/5; 7/10] END max_depth=6, max_features=sqrt, max_leaf_nodes=11, n_estimators=150;, score=0.000 total time=   0.4s
# [CV 3/5; 7/10] START max_depth=6, max_features=sqrt, max_leaf_nodes=11, n_estimators=150
# [CV 3/5; 7/10] END max_depth=6, max_features=sqrt, max_leaf_nodes=11, n_estimators=150;, score=0.000 total time=   0.3s
# [CV 4/5; 7/10] START max_depth=6, max_features=sqrt, max_leaf_nodes=11, n_estimators=150
# [CV 4/5; 7/10] END max_depth=6, max_features=sqrt, max_leaf_nodes=11, n_estimators=150;, score=0.000 total time=   0.4s
# [CV 5/5; 7/10] START max_depth=6, max_features=sqrt, max_leaf_nodes=11, n_estimators=150
# [CV 5/5; 7/10] END max_depth=6, max_features=sqrt, max_leaf_nodes=11, n_estimators=150;, score=0.000 total time=   0.4s
# [CV 1/5; 8/10] START max_depth=3, max_features=None, max_leaf_nodes=13, n_estimators=200
# [CV 1/5; 8/10] END max_depth=3, max_features=None, max_leaf_nodes=13, n_estimators=200;, score=0.208 total time=   2.4s
# [CV 2/5; 8/10] START max_depth=3, max_features=None, max_leaf_nodes=13, n_estimators=200
# [CV 2/5; 8/10] END max_depth=3, max_features=None, max_leaf_nodes=13, n_estimators=200;, score=0.177 total time=   3.2s
# [CV 3/5; 8/10] START max_depth=3, max_features=None, max_leaf_nodes=13, n_estimators=200
# [CV 3/5; 8/10] END max_depth=3, max_features=None, max_leaf_nodes=13, n_estimators=200;, score=0.147 total time=   2.5s
# [CV 4/5; 8/10] START max_depth=3, max_features=None, max_leaf_nodes=13, n_estimators=200
# [CV 4/5; 8/10] END max_depth=3, max_features=None, max_leaf_nodes=13, n_estimators=200;, score=0.236 total time=   2.8s
# [CV 5/5; 8/10] START max_depth=3, max_features=None, max_leaf_nodes=13, n_estimators=200
# [CV 5/5; 8/10] END max_depth=3, max_features=None, max_leaf_nodes=13, n_estimators=200;, score=0.224 total time=   2.4s
# [CV 1/5; 9/10] START max_depth=6, max_features=sqrt, max_leaf_nodes=9, n_estimators=200
# [CV 1/5; 9/10] END max_depth=6, max_features=sqrt, max_leaf_nodes=9, n_estimators=200;, score=0.000 total time=   0.5s
# [CV 2/5; 9/10] START max_depth=6, max_features=sqrt, max_leaf_nodes=9, n_estimators=200
# [CV 2/5; 9/10] END max_depth=6, max_features=sqrt, max_leaf_nodes=9, n_estimators=200;, score=0.000 total time=   0.5s
# [CV 3/5; 9/10] START max_depth=6, max_features=sqrt, max_leaf_nodes=9, n_estimators=200
# [CV 3/5; 9/10] END max_depth=6, max_features=sqrt, max_leaf_nodes=9, n_estimators=200;, score=0.000 total time=   0.5s
# [CV 4/5; 9/10] START max_depth=6, max_features=sqrt, max_leaf_nodes=9, n_estimators=200
# [CV 4/5; 9/10] END max_depth=6, max_features=sqrt, max_leaf_nodes=9, n_estimators=200;, score=0.000 total time=   0.5s
# [CV 5/5; 9/10] START max_depth=6, max_features=sqrt, max_leaf_nodes=9, n_estimators=200
# [CV 5/5; 9/10] END max_depth=6, max_features=sqrt, max_leaf_nodes=9, n_estimators=200;, score=0.000 total time=   0.5s
# [CV 1/5; 10/10] START max_depth=3, max_features=log2, max_leaf_nodes=9, n_estimators=150
# [CV 1/5; 10/10] END max_depth=3, max_features=log2, max_leaf_nodes=9, n_estimators=150;, score=0.000 total time=   0.4s
# [CV 2/5; 10/10] START max_depth=3, max_features=log2, max_leaf_nodes=9, n_estimators=150
# [CV 2/5; 10/10] END max_depth=3, max_features=log2, max_leaf_nodes=9, n_estimators=150;, score=0.000 total time=   0.3s
# [CV 3/5; 10/10] START max_depth=3, max_features=log2, max_leaf_nodes=9, n_estimators=150
# [CV 3/5; 10/10] END max_depth=3, max_features=log2, max_leaf_nodes=9, n_estimators=150;, score=0.000 total time=   0.3s
# [CV 4/5; 10/10] START max_depth=3, max_features=log2, max_leaf_nodes=9, n_estimators=150
# [CV 4/5; 10/10] END max_depth=3, max_features=log2, max_leaf_nodes=9, n_estimators=150;, score=0.000 total time=   0.3s
# [CV 5/5; 10/10] START max_depth=3, max_features=log2, max_leaf_nodes=9, n_estimators=150
# [CV 5/5; 10/10] END max_depth=3, max_features=log2, max_leaf_nodes=9, n_estimators=150;, score=0.000 total time=   0.3s
# RandomizedSearchCV(estimator=RandomForestClassifier(n_jobs=-1),
#                    param_distributions={'max_depth': [3, 6, 9],
#                                         'max_features': ['sqrt', 'log2', None],
#                                         'max_leaf_nodes': [9, 11, 13],
#                                         'n_estimators': [100, 150, 200, 250]},
#                    scoring='f1', verbose=10)

# %%
print(random_search.best_estimator_)
# Out:
# RandomForestClassifier(max_depth=6, max_features=None, max_leaf_nodes=9,
#                        n_estimators=250, n_jobs=-1)

# %%
rf_tuned = RandomForestClassifier(**random_search.best_params_)
rf_tuned.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=6, max_features=None, max_leaf_nodes=9,
#                        n_estimators=250)

# %%
evaluate_model(rf_tuned, X_test, y_test, "none")
add_to_eval_df(rf_tuned, "RandomForestClassifier-tuned-rand", "clean", X_train, y_train, X_test, y_test)
# Out:
# none model accuracy for classification is = 94.51%
# ------------------------------------------------
# Confusion Matrix:
#       0    1
# 0  7724   30
# 1   425  116
# ------------------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      7754
#            1       0.79      0.21      0.34       541
#
#     accuracy                           0.95      8295
#    macro avg       0.87      0.61      0.65      8295
# weighted avg       0.94      0.95      0.93      8295

# %% [markdown]
# ###### RandomForest tuning (optuna)
# https://gist.github.com/shamilnabiyev/c1b6e23444a949bc45243eab445a3806

# %%
def objective_rf(trial):
    n_estimators = trial.suggest_int(name="n_estimators", low=100, high=500, step=50)
    max_depth = trial.suggest_int(name="max_depth", low=10, high=150, step=5)
    min_samples_split = trial.suggest_int(name="min_samples_split", low=2, high=10, step=2)
    min_samples_leaf = trial.suggest_int(name="min_samples_leaf", low=1, high=4, step=1)

    params = {
        "n_estimators": n_estimators,
        "max_depth": max_depth,
        "min_samples_split": min_samples_split,
        "min_samples_leaf": min_samples_leaf
    }
    model = RandomForestClassifier(random_state=42, **params)

    cv_score = cross_val_score(model, X_train, y_train, n_jobs=-1, cv=5, scoring='f1')
    mean_cv_accuracy = cv_score.mean()
    return mean_cv_accuracy

# %%
sampler = TPESampler(seed=42)
pruner = optuna.pruners.MedianPruner(n_warmup_steps=10)
study_rf = optuna.create_study(sampler=sampler, pruner=pruner, direction="maximize")
study_rf.optimize(objective_rf, n_trials=50)
# Out:
# [I 2024-11-24 11:20:37,208] A new study created in memory with name: no-name-4fc1acca-bdec-433a-920a-626dbb2498b1
# [I 2024-11-24 11:21:39,744] Trial 0 finished with value: 0.31835293192531455 and parameters: {'n_estimators': 250, 'max_depth': 145, 'min_samples_split': 8, 'min_samples_leaf': 3}. Best is trial 0 with value: 0.31835293192531455.
# [I 2024-11-24 11:21:47,458] Trial 1 finished with value: 0.05354801346215332 and parameters: {'n_estimators': 150, 'max_depth': 30, 'min_samples_split': 2, 'min_samples_leaf': 4}. Best is trial 0 with value: 0.31835293192531455.
# [I 2024-11-24 11:22:32,341] Trial 2 finished with value: 0.2616067272986254 and parameters: {'n_estimators': 350, 'max_depth': 110, 'min_samples_split': 2, 'min_samples_leaf': 4}. Best is trial 0 with value: 0.31835293192531455.
# [I 2024-11-24 11:23:19,544] Trial 3 finished with value: 0.13848324246725674 and parameters: {'n_estimators': 450, 'max_depth': 40, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 0 with value: 0.31835293192531455.
# [I 2024-11-24 11:23:51,113] Trial 4 finished with value: 0.290804509388422 and parameters: {'n_estimators': 200, 'max_depth': 85, 'min_samples_split': 6, 'min_samples_leaf': 2}. Best is trial 0 with value: 0.31835293192531455.
# [I 2024-11-24 11:24:10,413] Trial 5 finished with value: 0.05802897313821241 and parameters: {'n_estimators': 350, 'max_depth': 30, 'min_samples_split': 4, 'min_samples_leaf': 2}. Best is trial 0 with value: 0.31835293192531455.
# [I 2024-11-24 11:24:58,188] Trial 6 finished with value: 0.3086932457611077 and parameters: {'n_estimators': 300, 'max_depth': 120, 'min_samples_split': 2, 'min_samples_leaf': 3}. Best is trial 0 with value: 0.31835293192531455.
# [I 2024-11-24 11:25:09,899] Trial 7 finished with value: 0.0 and parameters: {'n_estimators': 350, 'max_depth': 15, 'min_samples_split': 8, 'min_samples_leaf': 1}. Best is trial 0 with value: 0.31835293192531455.
# [I 2024-11-24 11:25:28,464] Trial 8 finished with value: 0.2839890985116241 and parameters: {'n_estimators': 100, 'max_depth': 145, 'min_samples_split': 10, 'min_samples_leaf': 4}. Best is trial 0 with value: 0.31835293192531455.
# [I 2024-11-24 11:25:35,948] Trial 9 finished with value: 0.003125 and parameters: {'n_estimators': 200, 'max_depth': 20, 'min_samples_split': 8, 'min_samples_leaf': 2}. Best is trial 0 with value: 0.31835293192531455.
# [I 2024-11-24 11:26:56,041] Trial 10 finished with value: 0.3197969827169171 and parameters: {'n_estimators': 500, 'max_depth': 145, 'min_samples_split': 10, 'min_samples_leaf': 3}. Best is trial 10 with value: 0.3197969827169171.
# [I 2024-11-24 11:28:12,906] Trial 11 finished with value: 0.31882426590922136 and parameters: {'n_estimators': 500, 'max_depth': 140, 'min_samples_split': 10, 'min_samples_leaf': 3}. Best is trial 10 with value: 0.3197969827169171.
# [I 2024-11-24 11:29:21,305] Trial 12 finished with value: 0.299192583879908 and parameters: {'n_estimators': 500, 'max_depth': 115, 'min_samples_split': 10, 'min_samples_leaf': 3}. Best is trial 10 with value: 0.3197969827169171.
# [I 2024-11-24 11:30:41,505] Trial 13 finished with value: 0.3205822988016317 and parameters: {'n_estimators': 500, 'max_depth': 150, 'min_samples_split': 10, 'min_samples_leaf': 3}. Best is trial 13 with value: 0.3205822988016317.
# [I 2024-11-24 11:31:26,558] Trial 14 finished with value: 0.19556722376341448 and parameters: {'n_estimators': 450, 'max_depth': 65, 'min_samples_split': 6, 'min_samples_leaf': 3}. Best is trial 13 with value: 0.3205822988016317.
# [I 2024-11-24 11:32:22,999] Trial 15 finished with value: 0.3099456610408227 and parameters: {'n_estimators': 450, 'max_depth': 95, 'min_samples_split': 10, 'min_samples_leaf': 2}. Best is trial 13 with value: 0.3205822988016317.
# [I 2024-11-24 11:32:59,443] Trial 16 finished with value: 0.18298212597752855 and parameters: {'n_estimators': 400, 'max_depth': 65, 'min_samples_split': 8, 'min_samples_leaf': 4}. Best is trial 13 with value: 0.3205822988016317.
# [I 2024-11-24 11:34:12,985] Trial 17 finished with value: 0.30682064281576216 and parameters: {'n_estimators': 500, 'max_depth': 125, 'min_samples_split': 10, 'min_samples_leaf': 3}. Best is trial 13 with value: 0.3205822988016317.
# [I 2024-11-24 11:35:15,970] Trial 18 finished with value: 0.36046966571510425 and parameters: {'n_estimators': 400, 'max_depth': 130, 'min_samples_split': 4, 'min_samples_leaf': 2}. Best is trial 18 with value: 0.36046966571510425.
# [I 2024-11-24 11:36:34,911] Trial 19 finished with value: 0.43554748079315386 and parameters: {'n_estimators': 400, 'max_depth': 130, 'min_samples_split': 6, 'min_samples_leaf': 1}. Best is trial 19 with value: 0.43554748079315386.
# [I 2024-11-24 11:37:47,804] Trial 20 finished with value: 0.3997727633878913 and parameters: {'n_estimators': 400, 'max_depth': 100, 'min_samples_split': 4, 'min_samples_leaf': 1}. Best is trial 19 with value: 0.43554748079315386.
# [I 2024-11-24 11:38:57,554] Trial 21 finished with value: 0.4053171764890823 and parameters: {'n_estimators': 400, 'max_depth': 105, 'min_samples_split': 4, 'min_samples_leaf': 1}. Best is trial 19 with value: 0.43554748079315386.
# [I 2024-11-24 11:40:07,626] Trial 22 finished with value: 0.3997727633878913 and parameters: {'n_estimators': 400, 'max_depth': 100, 'min_samples_split': 4, 'min_samples_leaf': 1}. Best is trial 19 with value: 0.43554748079315386.
# [I 2024-11-24 11:40:50,416] Trial 23 finished with value: 0.3302824167847104 and parameters: {'n_estimators': 300, 'max_depth': 75, 'min_samples_split': 4, 'min_samples_leaf': 1}. Best is trial 19 with value: 0.43554748079315386.
# [I 2024-11-24 11:41:57,291] Trial 24 finished with value: 0.40479541500650623 and parameters: {'n_estimators': 400, 'max_depth': 105, 'min_samples_split': 6, 'min_samples_leaf': 1}. Best is trial 19 with value: 0.43554748079315386.
# [I 2024-11-24 11:42:56,671] Trial 25 finished with value: 0.4328284246439627 and parameters: {'n_estimators': 300, 'max_depth': 130, 'min_samples_split': 6, 'min_samples_leaf': 1}. Best is trial 19 with value: 0.43554748079315386.
# [I 2024-11-24 11:43:56,136] Trial 26 finished with value: 0.4328284246439627 and parameters: {'n_estimators': 300, 'max_depth': 130, 'min_samples_split': 6, 'min_samples_leaf': 1}. Best is trial 19 with value: 0.43554748079315386.
# [I 2024-11-24 11:44:53,434] Trial 27 finished with value: 0.4328284246439627 and parameters: {'n_estimators': 300, 'max_depth': 130, 'min_samples_split': 6, 'min_samples_leaf': 1}. Best is trial 19 with value: 0.43554748079315386.
# [I 2024-11-24 11:45:32,227] Trial 28 finished with value: 0.3536814961771698 and parameters: {'n_estimators': 250, 'max_depth': 125, 'min_samples_split': 6, 'min_samples_leaf': 2}. Best is trial 19 with value: 0.43554748079315386.
# [I 2024-11-24 11:46:20,405] Trial 29 finished with value: 0.4337666294597747 and parameters: {'n_estimators': 250, 'max_depth': 135, 'min_samples_split': 8, 'min_samples_leaf': 1}. Best is trial 19 with value: 0.43554748079315386.
# [I 2024-11-24 11:47:10,997] Trial 30 finished with value: 0.4395752227852542 and parameters: {'n_estimators': 250, 'max_depth': 140, 'min_samples_split': 8, 'min_samples_leaf': 1}. Best is trial 30 with value: 0.4395752227852542.
# [I 2024-11-24 11:47:58,342] Trial 31 finished with value: 0.4395752227852542 and parameters: {'n_estimators': 250, 'max_depth': 140, 'min_samples_split': 8, 'min_samples_leaf': 1}. Best is trial 30 with value: 0.4395752227852542.
# [I 2024-11-24 11:48:48,678] Trial 32 finished with value: 0.4395752227852542 and parameters: {'n_estimators': 250, 'max_depth': 140, 'min_samples_split': 8, 'min_samples_leaf': 1}. Best is trial 30 with value: 0.4395752227852542.
# [I 2024-11-24 11:49:29,649] Trial 33 finished with value: 0.4436954450583882 and parameters: {'n_estimators': 200, 'max_depth': 150, 'min_samples_split': 8, 'min_samples_leaf': 1}. Best is trial 33 with value: 0.4436954450583882.
# [I 2024-11-24 11:50:03,159] Trial 34 finished with value: 0.38788920303234453 and parameters: {'n_estimators': 200, 'max_depth': 150, 'min_samples_split': 8, 'min_samples_leaf': 2}. Best is trial 33 with value: 0.4436954450583882.
# [I 2024-11-24 11:50:30,591] Trial 35 finished with value: 0.43776107469495396 and parameters: {'n_estimators': 150, 'max_depth': 140, 'min_samples_split': 8, 'min_samples_leaf': 1}. Best is trial 33 with value: 0.4436954450583882.
# [I 2024-11-24 11:51:10,579] Trial 36 finished with value: 0.4070198768415052 and parameters: {'n_estimators': 200, 'max_depth': 115, 'min_samples_split': 8, 'min_samples_leaf': 1}. Best is trial 33 with value: 0.4436954450583882.
# [I 2024-11-24 11:51:37,178] Trial 37 finished with value: 0.3859319384092207 and parameters: {'n_estimators': 150, 'max_depth': 150, 'min_samples_split': 8, 'min_samples_leaf': 2}. Best is trial 33 with value: 0.4436954450583882.
# [I 2024-11-24 11:52:23,749] Trial 38 finished with value: 0.4395752227852542 and parameters: {'n_estimators': 250, 'max_depth': 140, 'min_samples_split': 8, 'min_samples_leaf': 1}. Best is trial 33 with value: 0.4436954450583882.
# [I 2024-11-24 11:52:38,802] Trial 39 finished with value: 0.16939352298676488 and parameters: {'n_estimators': 200, 'max_depth': 50, 'min_samples_split': 8, 'min_samples_leaf': 2}. Best is trial 33 with value: 0.4436954450583882.
# [I 2024-11-24 11:52:55,429] Trial 40 finished with value: 0.41905394518047967 and parameters: {'n_estimators': 100, 'max_depth': 120, 'min_samples_split': 8, 'min_samples_leaf': 1}. Best is trial 33 with value: 0.4436954450583882.
# [I 2024-11-24 11:53:42,344] Trial 41 finished with value: 0.4395752227852542 and parameters: {'n_estimators': 250, 'max_depth': 140, 'min_samples_split': 8, 'min_samples_leaf': 1}. Best is trial 33 with value: 0.4436954450583882.
# [I 2024-11-24 11:54:28,874] Trial 42 finished with value: 0.4395752227852542 and parameters: {'n_estimators': 250, 'max_depth': 140, 'min_samples_split': 8, 'min_samples_leaf': 1}. Best is trial 33 with value: 0.4436954450583882.
# [I 2024-11-24 11:55:24,655] Trial 43 finished with value: 0.4469881015036633 and parameters: {'n_estimators': 250, 'max_depth': 150, 'min_samples_split': 8, 'min_samples_leaf': 1}. Best is trial 43 with value: 0.4469881015036633.
# [I 2024-11-24 11:56:07,132] Trial 44 finished with value: 0.4436954450583882 and parameters: {'n_estimators': 200, 'max_depth': 150, 'min_samples_split': 8, 'min_samples_leaf': 1}. Best is trial 43 with value: 0.4469881015036633.
# [I 2024-11-24 11:56:43,354] Trial 45 finished with value: 0.3883750802421419 and parameters: {'n_estimators': 200, 'max_depth': 150, 'min_samples_split': 10, 'min_samples_leaf': 2}. Best is trial 43 with value: 0.4469881015036633.
# [I 2024-11-24 11:57:21,385] Trial 46 finished with value: 0.4436954450583882 and parameters: {'n_estimators': 200, 'max_depth': 150, 'min_samples_split': 8, 'min_samples_leaf': 1}. Best is trial 43 with value: 0.4469881015036633.
# [I 2024-11-24 11:57:50,259] Trial 47 finished with value: 0.4438595358314819 and parameters: {'n_estimators': 150, 'max_depth': 150, 'min_samples_split': 8, 'min_samples_leaf': 1}. Best is trial 43 with value: 0.4469881015036633.
# [I 2024-11-24 11:58:14,324] Trial 48 finished with value: 0.38679304985240515 and parameters: {'n_estimators': 150, 'max_depth': 150, 'min_samples_split': 10, 'min_samples_leaf': 2}. Best is trial 43 with value: 0.4469881015036633.
# [I 2024-11-24 11:58:37,355] Trial 49 finished with value: 0.2887346766473567 and parameters: {'n_estimators': 150, 'max_depth': 145, 'min_samples_split': 8, 'min_samples_leaf': 4}. Best is trial 43 with value: 0.4469881015036633.

# %%
print("Number of finished trials: {}".format(len(study_rf.trials)))

print("Best trial:")
trial = study_rf.best_trial

print("  Value: {}".format(trial.value))

print("  Params: ")
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))

plot_optimization_history(study_rf)
plot_param_importances(study_rf)
# Out:
# Number of finished trials: 50
# Best trial:
#   Value: 0.4469881015036633
#   Params:
#     n_estimators: 250
#     max_depth: 150
#     min_samples_split: 8
#     min_samples_leaf: 1
# C:\Users\admin\AppData\Local\Temp\ipykernel_20112\2334329262.py:12: ExperimentalWarning: plot_optimization_history is experimental (supported from v2.2.0). The interface can change in the future.
#   plot_optimization_history(study_rf)
# C:\Users\admin\AppData\Local\Temp\ipykernel_20112\2334329262.py:13: ExperimentalWarning: plot_param_importances is experimental (supported from v2.2.0). The interface can change in the future.
#   plot_param_importances(study_rf)
# <Axes: title={'left': 'Hyperparameter Importances'}, xlabel='Hyperparameter Importance', ylabel='Hyperparameter'>

# %%
rf_tuned_optuna = RandomForestClassifier(**study_rf.best_trial.params)
rf_tuned_optuna.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[215], line 1
# ----> 1 rf_tuned_optuna = RandomForestClassifier(**study_rf.best_trial.params)
#       2 rf_tuned_optuna.fit(X_train, y_train)
#       3 evaluate_model(rf_tuned_optuna, X_test, y_test, "none")
#
# File ~\anaconda3\lib\site-packages\optuna\study\study.py:162, in Study.best_trial(self)
#     156 if self._is_multi_objective():
#     157     raise RuntimeError(
#     158         "A single best trial cannot be retrieved from a multi-objective study. Consider "
#     159         "using Study.best_trials to retrieve a list containing the best trials."
#     160     )
# --> 162 best_trial = self._storage.get_best_trial(self._study_id)
#     164 # If the trial with the best value is infeasible, select the best trial from all feasible
#     165 # trials. Note that the behavior is undefined when constrained optimization without the
#     166 # violation value in the best-valued trial.
#     167 constraints = best_trial.system_attrs.get(_CONSTRAINTS_KEY)
#
# File ~\anaconda3\lib\site-packages\optuna\storages\_in_memory.py:249, in InMemoryStorage.get_best_trial(self, study_id)
#     246 best_trial_id = self._studies[study_id].best_trial_id
#     248 if best_trial_id is None:
# --> 249     raise ValueError("No trials are completed yet.")
#     250 elif len(self._studies[study_id].directions) > 1:
#     251     raise RuntimeError(
#     252         "Best trial can be obtained only for single-objective optimization."
#     253     )
#
# ValueError: No trials are completed yet.

# %%
evaluate_model(rf_tuned_optuna, X_test, y_test, "none")
add_to_eval_df(rf_tuned_optuna, "RandomForest-tuned-optuna", "clean", X_train, y_train, X_test, y_test)
# Out:
# none model accuracy for classification is = 95.44%
# ------------------------------------------------
# Confusion Matrix:
#       0    1
# 0  7724   30
# 1   348  193
# ------------------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      7754
#            1       0.87      0.36      0.51       541
#
#     accuracy                           0.95      8295
#    macro avg       0.91      0.68      0.74      8295
# weighted avg       0.95      0.95      0.95      8295

# %% [markdown]
# ##### 2.1.2 BalancedRandomForest untuned

# %% [markdown]
# ###### BalancedRandomForest no tuning

# %%
brf = BalancedRandomForestClassifier(n_jobs=-1)
brf.fit(X_train, y_train)
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# BalancedRandomForestClassifier(n_jobs=-1)

# %%
evaluate_model(brf, X_test, y_test, "none")
add_to_eval_df(brf, "BalancedRandomForestClassifier", "clean", X_train, y_train, X_test, y_test)
# Out:
# none model accuracy for classification is = 88.38%
# ------------------------------------------------
# Confusion Matrix:
#       0    1
# 0  6946  808
# 1   156  385
# ------------------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.90      0.94      7754
#            1       0.32      0.71      0.44       541
#
#     accuracy                           0.88      8295
#    macro avg       0.65      0.80      0.69      8295
# weighted avg       0.94      0.88      0.90      8295

# %%
cv = cross_val_score(brf, X_train, y_train, cv=10, scoring='f1', verbose=10)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# [CV] START .....................................................................
# [CV] END ................................ score: (test=0.430) total time=   1.1s
# [CV] START .....................................................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.1s remaining:    0.0s
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# [CV] END ................................ score: (test=0.464) total time=   0.8s
# [CV] START .....................................................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    2.0s remaining:    0.0s
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# [CV] END ................................ score: (test=0.396) total time=   0.8s
# [CV] START .....................................................................
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    2.9s remaining:    0.0s
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# [CV] END ................................ score: (test=0.450) total time=   0.8s
# [CV] START .....................................................................
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    3.9s remaining:    0.0s
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# [CV] END ................................ score: (test=0.429) total time=   0.8s
# [CV] START .....................................................................
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    4.8s remaining:    0.0s
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# [CV] END ................................ score: (test=0.449) total time=   0.8s
# [CV] START .....................................................................
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    5.7s remaining:    0.0s
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# [CV] END ................................ score: (test=0.425) total time=   0.8s
# [CV] START .....................................................................
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    6.7s remaining:    0.0s
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# [CV] END ................................ score: (test=0.443) total time=   0.8s
# [CV] START .....................................................................
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    7.6s remaining:    0.0s
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# [CV] END ................................ score: (test=0.426) total time=   0.8s
# [CV] START .....................................................................
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:    8.5s remaining:    0.0s
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# [CV] END ................................ score: (test=0.435) total time=   0.8s
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:    9.5s finished

# %%
np.mean(cv)
# Out:
# 0.43476764184134975

# %% [markdown]
# ###### BalancedRandomForest tuning (RandomizedSearchCV)

# %%
param_grid = {
    'n_estimators': [100, 150, 200, 250],
    'max_features': ['sqrt', 'log2', None],
    'max_depth': [3, 6, 9],
    'max_leaf_nodes': [9, 11, 13],
}

# %%
random_search = RandomizedSearchCV(BalancedRandomForestClassifier(n_jobs=-1),
                                   param_grid,
                                   scoring='f1',
                                   verbose=0)
random_search.fit(X_train, y_train)
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# ...
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# RandomizedSearchCV(estimator=BalancedRandomForestClassifier(n_jobs=-1),
#                    param_distributions={'max_depth': [3, 6, 9],
#                                         'max_features': ['sqrt', 'log2', None],
#                                         'max_leaf_nodes': [9, 11, 13],
#                                         'n_estimators': [100, 150, 200, 250]},
#                    scoring='f1')

# %%
brf_tuned = BalancedRandomForestClassifier(**random_search.best_params_, verbose=0)
brf_tuned.fit(X_train, y_train)
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# ...
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function delayed is deprecated; The function `delayed` has been moved from `sklearn.utils.fixes` to `sklearn.utils.parallel`. This import path will be removed in 1.5.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\utils\parallel.py:114: UserWarning: `sklearn.utils.parallel.delayed` should be used with `sklearn.utils.parallel.Parallel` to make it possible to propagate the scikit-learn configuration of the current thread to the joblib workers.
#   warnings.warn(
# BalancedRandomForestClassifier(max_depth=9, max_leaf_nodes=13, n_estimators=200)

# %%
evaluate_model(brf_tuned, X_test, y_test, "none")
add_to_eval_df(brf_tuned, "BalancedRandomForestClassifier-tuned", "clean", X_train, y_train, X_test, y_test)
# Out:
# none model accuracy for classification is = 88.55%
# ------------------------------------------------
# Confusion Matrix:
#       0    1
# 0  6974  780
# 1   170  371
# ------------------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.90      0.94      7754
#            1       0.32      0.69      0.44       541
#
#     accuracy                           0.89      8295
#    macro avg       0.65      0.79      0.69      8295
# weighted avg       0.93      0.89      0.90      8295

# %% [markdown]
# #### 2.2 Boosting

# %% [markdown]
# ##### 2.2.1 XGBClassifier

# %%
xgb = XGBClassifier()
xgb.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
evaluate_model(xgb, X_test, y_test, "none")
add_to_eval_df(xgb, "XGBClassifier", "clean", X_train, y_train, X_test, y_test)
# Out:
# none model accuracy for classification is = 95.03%
# ------------------------------------------------
# Confusion Matrix:
#       0    1
# 0  7714   40
# 1   372  169
# ------------------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97      7754
#            1       0.81      0.31      0.45       541
#
#     accuracy                           0.95      8295
#    macro avg       0.88      0.65      0.71      8295
# weighted avg       0.94      0.95      0.94      8295

# %% [markdown]
# ###### XGBClassifier tuning (GridSearchCV)
# https://www.kaggle.com/code/prashant111/a-guide-on-xgboost-hyperparameters-tuning
# https://www.analyticsvidhya.com/blog/2016/03/complete-guide-parameter-tuning-xgboost-with-codes-python/
#
# Tuning mit GridSearchCV dauert bei großer param-Liste sehr lange, daher einzelne Schritte mit jeweils nur 1 bis max. 2 params

# %%
param_test = {
    'learning_rate': [0.1, 0.01, 0.001],
}
gsearch = GridSearchCV(estimator=XGBClassifier(
    seed=42
), param_grid=param_test, scoring='f1', n_jobs=-1, cv=5, verbose=1)

# gsearch.fit(X_train, y_train)
# gsearch.best_score_, gsearch.best_params_

# (0.32039688186494825, {'learning_rate': 0.1})

# %%
xgb_test = XGBClassifier(learning_rate=0.1)
xgb_test.fit(X_train, y_train)
evaluate_model(xgb_test, X_test, y_test, "none")
# Out:
# none model accuracy for classification is = 94.85%
# ------------------------------------------------
# Confusion Matrix:
#       0    1
# 0  7732   22
# 1   405  136
# ------------------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      7754
#            1       0.86      0.25      0.39       541
#
#     accuracy                           0.95      8295
#    macro avg       0.91      0.62      0.68      8295
# weighted avg       0.94      0.95      0.94      8295

# %%
param_test = {
    'n_estimators': range(100, 250, 50),
}
gsearch = GridSearchCV(estimator=XGBClassifier(
    seed=42,
    learning_rate=0.1,
), param_grid=param_test, scoring='f1', n_jobs=-1, cv=5, verbose=1)

# gsearch.fit(X_train, y_train)
# gsearch.best_score_, gsearch.best_params_

# (0.37817637241282653, {'n_estimators': 200})

# %%
xgb_test = XGBClassifier(learning_rate=0.1, n_estimators=200)
xgb_test.fit(X_train, y_train)
evaluate_model(xgb_test, X_test, y_test, "none")
# Out:
# none model accuracy for classification is = 95.01%
# ------------------------------------------------
# Confusion Matrix:
#       0    1
# 0  7722   32
# 1   382  159
# ------------------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      7754
#            1       0.83      0.29      0.43       541
#
#     accuracy                           0.95      8295
#    macro avg       0.89      0.64      0.70      8295
# weighted avg       0.95      0.95      0.94      8295

# %%
param_test = {
    'max_depth': range(5, 13, 2),
}
gsearch = GridSearchCV(estimator=XGBClassifier(
    seed=42,
    learning_rate=0.1,
    n_estimators=200,
), param_grid=param_test, scoring='f1', n_jobs=-1, cv=5, verbose=1)

# gsearch.fit(X_train, y_train)
# gsearch.best_score_, gsearch.best_params_

# (0.4298347587940351, {'max_depth': 11})

# %%
xgb_test = XGBClassifier(learning_rate=0.1, n_estimators=200, max_depth=11)
xgb_test.fit(X_train, y_train)
evaluate_model(xgb_test, X_test, y_test, "none")
# Out:
# none model accuracy for classification is = 95.09%
# ------------------------------------------------
# Confusion Matrix:
#       0    1
# 0  7708   46
# 1   361  180
# ------------------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97      7754
#            1       0.80      0.33      0.47       541
#
#     accuracy                           0.95      8295
#    macro avg       0.88      0.66      0.72      8295
# weighted avg       0.94      0.95      0.94      8295

# %%
param_test = {
    'subsample': [0.5, 0.7, 1]
}
gsearch = GridSearchCV(estimator=XGBClassifier(
    seed=42,
    learning_rate=0.1,
    n_estimators=200,
    max_depth=11,
), param_grid=param_test, scoring='f1', n_jobs=-1, cv=5, verbose=1)

# gsearch.fit(X_train, y_train)
# gsearch.best_score_, gsearch.best_params_

# (0.4406213750099548, {'subsample': 0.7})

# %%
xgb_test = XGBClassifier(learning_rate=0.1, n_estimators=200, max_depth=11, subsample=0.7)
xgb_test.fit(X_train, y_train)
evaluate_model(xgb_test, X_test, y_test, "none")
# Out:
# none model accuracy for classification is = 95.11%
# ------------------------------------------------
# Confusion Matrix:
#       0    1
# 0  7701   53
# 1   353  188
# ------------------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97      7754
#            1       0.78      0.35      0.48       541
#
#     accuracy                           0.95      8295
#    macro avg       0.87      0.67      0.73      8295
# weighted avg       0.94      0.95      0.94      8295

# %%
param_test = {
    'min_child_weight': range(1, 6, 2),
}
gsearch = GridSearchCV(estimator=XGBClassifier(
    seed=42,
    learning_rate=0.1,
    n_estimators=200,
    max_depth=11,
    subsample=0.7,
), param_grid=param_test, scoring='f1', n_jobs=-1, cv=5, verbose=1)

# gsearch.fit(X_train, y_train)
# gsearch.best_score_, gsearch.best_params_

# (0.4406213750099548, {'min_child_weight': 1}) <== kein Einfluss auf Modellperformance

# %%
param_test = {
    'gamma': [i / 10.0 for i in range(0, 5)],
}
gsearch = GridSearchCV(estimator=XGBClassifier(
    seed=42,
    learning_rate=0.1,
    n_estimators=200,
    max_depth=11,
    subsample=0.7,
), param_grid=param_test, scoring='f1', n_jobs=-1, cv=5, verbose=1)

# gsearch.fit(X_train, y_train)
# gsearch.best_score_, gsearch.best_params_

# (0.4406213750099548, {'gamma': 0.0}) <== kein Einfluss auf Modellperformance

# %%
param_test = {
    'reg_alpha': [1e-5, 1e-2, 0.1, 1, 100]
}
gsearch = GridSearchCV(estimator=XGBClassifier(
    seed=42,
    learning_rate=0.1,
    n_estimators=200,
    max_depth=11,
    subsample=0.7,
), param_grid=param_test, scoring='f1', n_jobs=-1, cv=5, verbose=1)

gsearch.fit(X_train, y_train)
gsearch.best_score_, gsearch.best_params_

# (0.44114103318625436, {'reg_alpha': 0.01})
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# (0.44114103318625436, {'reg_alpha': 0.01})

# %%
param_test = {
    'reg_alpha': [0.005, 0.01, 0.015, 0.02, 0.025]
}
gsearch = GridSearchCV(estimator=XGBClassifier(
    seed=42,
    learning_rate=0.1,
    n_estimators=200,
    max_depth=11,
    subsample=0.7,
), param_grid=param_test, scoring='f1', n_jobs=-1, cv=5, verbose=1)

gsearch.fit(X_train, y_train)
gsearch.best_score_, gsearch.best_params_

# # (0.44114103318625436, {'reg_alpha': 0.01})
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# (0.44114103318625436, {'reg_alpha': 0.01})

# %%
xgb_tuned_grid = XGBClassifier(learning_rate=0.1, n_estimators=200, max_depth=11, subsample=0.7, reg_alpha=0.01)
xgb_tuned_grid.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=11, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
evaluate_model(xgb_tuned_grid, X_test, y_test, "none")
add_to_eval_df(xgb_tuned_grid, "XGBClassifier-tuned-grid", "clean", X_train, y_train, X_test, y_test)
# Out:
# none model accuracy for classification is = 95.07%
# ------------------------------------------------
# Confusion Matrix:
#       0    1
# 0  7700   54
# 1   355  186
# ------------------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97      7754
#            1       0.78      0.34      0.48       541
#
#     accuracy                           0.95      8295
#    macro avg       0.87      0.67      0.73      8295
# weighted avg       0.94      0.95      0.94      8295

# %% [markdown]
# ###### XGBClassifier tuning (RandomizedSearchCV)
# Vergleich Modellperformance zwischen GridSearchCV <-> RandomizedSearchCV

# %%
param_grid = {
    'learning_rate': [0.1, 0.01, 0.001],
    'n_estimators': range(100, 250, 50),
    'max_depth': range(5, 13, 2),
    'subsample': [0.5, 0.7, 1],
    'min_child_weight': range(1, 6, 2),
    'gamma': [i / 10.0 for i in range(0, 5)],
    'reg_alpha': [1e-5, 1e-2, 0.1, 1, 100],
}

# %%
rsearch = RandomizedSearchCV(XGBClassifier(n_jobs=-1),
                             param_grid,
                             scoring='f1',
                             verbose=1,
                             cv=5,
                             )

# %%
rsearch.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# RandomizedSearchCV(cv=5,
#                    estimator=XGBClassifier(base_score=None, booster=None,
#                                            callbacks=None,
#                                            colsample_bylevel=None,
#                                            colsample_bynode=None,
#                                            colsample_bytree=None, device=None,
#                                            early_stopping_rounds=None,
#                                            enable_categorical=False,
#                                            eval_metric=None, feature_types=None,
#                                            gamma=None, grow_policy=None,
#                                            importance_type=None,
#                                            interaction_constraints=None,
#                                            learning_rate...
#                                            multi_strategy=None,
#                                            n_estimators=None, n_jobs=-1,
#                                            num_parallel_tree=None,
#                                            random_state=None, ...),
#                    param_distributions={'gamma': [0.0, 0.1, 0.2, 0.3, 0.4],
#                                         'learning_rate': [0.1, 0.01, 0.001],
#                                         'max_depth': range(5, 13, 2),
#                                         'min_child_weight': range(1, 6, 2),
#                                         'n_estimators': range(100, 250, 50),
#                                         'reg_alpha': [1e-05, 0.01, 0.1, 1, 100],
#                                         'subsample': [0.5, 0.7, 1]},
#                    scoring='f1', verbose=1)

# %%
rsearch.best_score_, rsearch.best_params_
# Out:
# (0.3395061099097244,
#  {'subsample': 1,
#   'reg_alpha': 1e-05,
#   'n_estimators': 100,
#   'min_child_weight': 1,
#   'max_depth': 7,
#   'learning_rate': 0.1,
#   'gamma': 0.0})

# %%
xgb_tuned_rand = XGBClassifier(**rsearch.best_params_, n_jobs=-1)
xgb_tuned_rand.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=0.0, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=7, max_leaves=None,
#               min_child_weight=1, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=100, n_jobs=-1,
#               num_parallel_tree=None, random_state=None, ...)

# %%
evaluate_model(xgb_tuned_rand, X_test, y_test, "none")
add_to_eval_df(xgb_tuned_rand, "XGBClassifier-tuned-rand", "clean", X_train, y_train, X_test, y_test)
# Out:
# none model accuracy for classification is = 94.82%
# ------------------------------------------------
# Confusion Matrix:
#       0    1
# 0  7729   25
# 1   405  136
# ------------------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      7754
#            1       0.84      0.25      0.39       541
#
#     accuracy                           0.95      8295
#    macro avg       0.90      0.62      0.68      8295
# weighted avg       0.94      0.95      0.93      8295

# %% [markdown]
# ###### XGBClassifier tuning (optuna)
# https://randomrealizations.com/posts/xgboost-parameter-tuning-with-optuna/
# https://www.kaggle.com/code/rzatemizel/optuna-xgboostcv-integration-with-pruning#Intro

# %%
def balancedlogloss(predt: np.ndarray, dtrain: xgboost.DMatrix) -> Tuple[str, float]:
    ''' balanced log loss metric.'''
    y = dtrain.get_label()
    target_mean = y.mean()
    w0 = 1 / (1 - target_mean)
    w1 = 1 / target_mean
    sample_weight = [w0 if y == 0 else w1 for y in y]
    loss = log_loss(y, predt, eps=1e-15, sample_weight=sample_weight)

    return 'balancedlogloss', loss

def objective(trial):
    dtrain = xgboost.DMatrix(X_train, label=y_train)

    param = {

        "verbosity": 0,
        "objective": "binary:logistic",
        "booster": trial.suggest_categorical("booster", ["gbtree", "gblinear", "dart"]),
        "lambda": trial.suggest_float("lambda", 1e-8, 1.0, log=True),
        "alpha": trial.suggest_float("alpha", 1e-8, 1.0, log=True),
        "subsample": trial.suggest_float("subsample", 0.2, 0.8),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.2, 0.8),
        'scale_pos_weight': 509 / 108,
        'random_state': 42,
    }

    if param["booster"] == "gbtree" or param["booster"] == "dart":
        param["max_depth"] = trial.suggest_int("max_depth", 1, 16)
        param["eta"] = trial.suggest_float("eta", 1e-3, 1.0, log=True)
        param["gamma"] = trial.suggest_float("gamma", 1e-8, 1.0, log=True)
        param["grow_policy"] = trial.suggest_categorical("grow_policy", ["depthwise", "lossguide"])
    if param["booster"] == "dart":
        param["sample_type"] = trial.suggest_categorical("sample_type", ["uniform", "weighted"])
        param["normalize_type"] = trial.suggest_categorical("normalize_type", ["tree", "forest"])
        param["rate_drop"] = trial.suggest_float("rate_drop", 1e-8, 1.0, log=True)
        param["skip_drop"] = trial.suggest_float("skip_drop", 1e-8, 1.0, log=True)

    pruning_callback = optuna.integration.XGBoostPruningCallback(trial, "test-balancedlogloss")
    history = xgboost.cv(param,
                     dtrain,
                     stratified=True,
                     nfold=5,
                     num_boost_round=10000,
                     early_stopping_rounds=50,
                     custom_metric=balancedlogloss,
                     seed=42,
                     callbacks=[pruning_callback])

    mean_balancedlogloss = history["test-balancedlogloss-mean"].values[-1]
    trial.set_user_attr("n_estimators", len(history))
    return mean_balancedlogloss
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[152], line 1
# ----> 1 def balancedlogloss(predt: np.ndarray, dtrain: xgb.DMatrix) -> Tuple[str, float]:
#       2     ''' balanced log loss metric.'''
#       3     y = dtrain.get_label()
#
# AttributeError: 'XGBClassifier' object has no attribute 'DMatrix'

# %%
sampler = TPESampler(seed=42)
pruner = optuna.pruners.MedianPruner(n_warmup_steps=10)
study = optuna.create_study(sampler=sampler, pruner=pruner, direction="minimize")
study.optimize(objective, n_trials=5)
# Out:
# [I 2024-11-24 10:55:05,762] A new study created in memory with name: no-name-64164aee-f9ac-4192-b0e6-e126636d0e82
# [I 2024-11-24 10:55:45,300] Trial 0 finished with value: 0.31662025610271566 and parameters: {'n_estimators': 200, 'max_features': 'auto', 'max_depth': 70, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 0 with value: 0.31662025610271566.
# [I 2024-11-24 10:55:56,703] Trial 1 finished with value: 0.2374879956461494 and parameters: {'n_estimators': 100, 'max_features': 'auto', 'max_depth': 90, 'min_samples_split': 2, 'min_samples_leaf': 4}. Best is trial 1 with value: 0.2374879956461494.
# [I 2024-11-24 10:56:21,914] Trial 2 finished with value: 0.05956033390149031 and parameters: {'n_estimators': 500, 'max_features': 'auto', 'max_depth': 30, 'min_samples_split': 4, 'min_samples_leaf': 3}. Best is trial 2 with value: 0.05956033390149031.
# [I 2024-11-24 10:56:28,154] Trial 3 finished with value: 0.0 and parameters: {'n_estimators': 300, 'max_features': 'sqrt', 'max_depth': 10, 'min_samples_split': 4, 'min_samples_leaf': 2}. Best is trial 3 with value: 0.0.
# [I 2024-11-24 10:57:09,691] Trial 4 finished with value: 0.2910508929849558 and parameters: {'n_estimators': 300, 'max_features': 'auto', 'max_depth': 70, 'min_samples_split': 6, 'min_samples_leaf': 1}. Best is trial 3 with value: 0.0.

# %%
print("Number of finished trials: {}".format(len(study.trials)))

print("Best trial:")
trial = study.best_trial

print("  Value: {}".format(trial.value))

print("  Params: ")
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))
# print("  Number of estimators: {}".format(trial.user_attrs["n_estimators"]))

plot_optimization_history(study)
plot_param_importances(study)
# Out:
# Number of finished trials: 5
# Best trial:
#   Value: 0.0
#   Params:
#     n_estimators: 300
#     max_features: sqrt
#     max_depth: 10
#     min_samples_split: 4
#     min_samples_leaf: 2
# C:\Users\admin\AppData\Local\Temp\ipykernel_20112\993762437.py:13: ExperimentalWarning: plot_optimization_history is experimental (supported from v2.2.0). The interface can change in the future.
#   plot_optimization_history(study)
# C:\Users\admin\AppData\Local\Temp\ipykernel_20112\993762437.py:14: ExperimentalWarning: plot_param_importances is experimental (supported from v2.2.0). The interface can change in the future.
#   plot_param_importances(study)
# <Axes: title={'left': 'Hyperparameter Importances'}, xlabel='Hyperparameter Importance', ylabel='Hyperparameter'>

# %%
xgb_tuned_optuna = XGBClassifier(**study.best_trial.params)
xgb_tuned_optuna.fit(X_train, y_train)
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\xgboost\core.py:158: UserWarning: [11:08:11] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "max_features", "min_samples_leaf", "min_samples_split" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# none model accuracy for classification is = 95.37%
# ------------------------------------------------
# Confusion Matrix:
#       0    1
# 0  7694   60
# 1   324  217
# ------------------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98      7754
#            1       0.78      0.40      0.53       541
#
#     accuracy                           0.95      8295
#    macro avg       0.87      0.70      0.75      8295
# weighted avg       0.95      0.95      0.95      8295

# %%
evaluate_model(xgb_tuned_optuna, X_test, y_test, "none")
add_to_eval_df(xgb_tuned_optuna, "XGBClassifier-tuned-optuna", "clean", X_train, y_train, X_test, y_test)
# Out:
# none model accuracy for classification is = 95.37%
# ------------------------------------------------
# Confusion Matrix:
#       0    1
# 0  7694   60
# 1   324  217
# ------------------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98      7754
#            1       0.78      0.40      0.53       541
#
#     accuracy                           0.95      8295
#    macro avg       0.87      0.70      0.75      8295
# weighted avg       0.95      0.95      0.95      8295

# %% [markdown]
# ##### 2.2.1 CatBoostClassifier

# %%
cat = CatBoostClassifier(iterations=100,
                         depth=5,
                         learning_rate=0.1,
                         loss_function='Logloss',
                         verbose=True)
cat.fit(X_train, y_train)
# Out:
# 0:	learn: 0.6816596	total: 1.36s	remaining: 11m 19s
# 1:	learn: 0.6702015	total: 5.18s	remaining: 21m 29s
# 2:	learn: 0.6586307	total: 9.2s	remaining: 25m 23s
# 3:	learn: 0.6478688	total: 13.4s	remaining: 27m 40s
# 4:	learn: 0.6374998	total: 14.9s	remaining: 24m 39s
# 5:	learn: 0.6272634	total: 16s	remaining: 21m 56s
# 6:	learn: 0.6169796	total: 16.9s	remaining: 19m 51s
# 7:	learn: 0.6069776	total: 17.9s	remaining: 18m 17s
# 8:	learn: 0.5975432	total: 18.8s	remaining: 17m 2s
# 9:	learn: 0.5882883	total: 19.7s	remaining: 16m 3s
# 10:	learn: 0.5789863	total: 20.6s	remaining: 15m 16s
# 11:	learn: 0.5703713	total: 21.5s	remaining: 14m 35s
# 12:	learn: 0.5619140	total: 22.5s	remaining: 14m 2s
# 13:	learn: 0.5532308	total: 23.4s	remaining: 13m 32s
# 14:	learn: 0.5450940	total: 24.4s	remaining: 13m 7s
# 15:	learn: 0.5368353	total: 25.3s	remaining: 12m 45s
# 16:	learn: 0.5290384	total: 26.2s	remaining: 12m 24s
# 17:	learn: 0.5216955	total: 27.1s	remaining: 12m 5s
# 18:	learn: 0.5140508	total: 28s	remaining: 11m 49s
# 19:	learn: 0.5062437	total: 28.9s	remaining: 11m 34s
# 20:	learn: 0.4993875	total: 29.9s	remaining: 11m 21s
# 21:	learn: 0.4928292	total: 30.8s	remaining: 11m 8s
# 22:	learn: 0.4863292	total: 31.7s	remaining: 10m 57s
# 23:	learn: 0.4795692	total: 32.6s	remaining: 10m 47s
# 24:	learn: 0.4727703	total: 33.6s	remaining: 10m 37s
# 25:	learn: 0.4662129	total: 34.5s	remaining: 10m 28s
# 26:	learn: 0.4597015	total: 35.4s	remaining: 10m 20s
# 27:	learn: 0.4540711	total: 36.3s	remaining: 10m 12s
# 28:	learn: 0.4482831	total: 37.2s	remaining: 10m 4s
# 29:	learn: 0.4426880	total: 38.2s	remaining: 9m 57s
# 30:	learn: 0.4374655	total: 39.1s	remaining: 9m 51s
# 31:	learn: 0.4322081	total: 40s	remaining: 9m 45s
# 32:	learn: 0.4266552	total: 41s	remaining: 9m 39s
# 33:	learn: 0.4217246	total: 41.9s	remaining: 9m 34s
# 34:	learn: 0.4167749	total: 42.8s	remaining: 9m 28s
# 35:	learn: 0.4117967	total: 43.7s	remaining: 9m 23s
# 36:	learn: 0.4071648	total: 44.6s	remaining: 9m 18s
# 37:	learn: 0.4025945	total: 45.5s	remaining: 9m 13s
# 38:	learn: 0.3982460	total: 46.5s	remaining: 9m 9s
# 39:	learn: 0.3937054	total: 47.3s	remaining: 9m 4s
# 40:	learn: 0.3896217	total: 48.2s	remaining: 8m 59s
# 41:	learn: 0.3854350	total: 49.1s	remaining: 8m 55s
# 42:	learn: 0.3813797	total: 50s	remaining: 8m 51s
# 43:	learn: 0.3773476	total: 51s	remaining: 8m 48s
# 44:	learn: 0.3734360	total: 51.9s	remaining: 8m 44s
# 45:	learn: 0.3695449	total: 52.8s	remaining: 8m 41s
# 46:	learn: 0.3658578	total: 53.7s	remaining: 8m 37s
# 47:	learn: 0.3618995	total: 54.7s	remaining: 8m 34s
# 48:	learn: 0.3582329	total: 55.6s	remaining: 8m 31s
# 49:	learn: 0.3546942	total: 56.5s	remaining: 8m 28s
# 50:	learn: 0.3512605	total: 57.5s	remaining: 8m 25s
# 51:	learn: 0.3479794	total: 58.4s	remaining: 8m 23s
# 52:	learn: 0.3448260	total: 59.3s	remaining: 8m 20s
# 53:	learn: 0.3418801	total: 1m	remaining: 8m 17s
# 54:	learn: 0.3388059	total: 1m 1s	remaining: 8m 14s
# 55:	learn: 0.3358594	total: 1m 2s	remaining: 8m 12s
# 56:	learn: 0.3330287	total: 1m 3s	remaining: 8m 9s
# 57:	learn: 0.3301014	total: 1m 3s	remaining: 8m 7s
# 58:	learn: 0.3272390	total: 1m 4s	remaining: 8m 4s
# 59:	learn: 0.3243335	total: 1m 5s	remaining: 8m 2s
# 60:	learn: 0.3217300	total: 1m 6s	remaining: 8m
# 61:	learn: 0.3192149	total: 1m 7s	remaining: 7m 57s
# 62:	learn: 0.3165256	total: 1m 8s	remaining: 7m 55s
# 63:	learn: 0.3139020	total: 1m 9s	remaining: 7m 52s
# 64:	learn: 0.3115075	total: 1m 10s	remaining: 7m 50s
# 65:	learn: 0.3090207	total: 1m 11s	remaining: 7m 48s
# 66:	learn: 0.3067974	total: 1m 12s	remaining: 7m 46s
# 67:	learn: 0.3046025	total: 1m 13s	remaining: 7m 44s
# 68:	learn: 0.3024267	total: 1m 14s	remaining: 7m 42s
# 69:	learn: 0.3002699	total: 1m 15s	remaining: 7m 40s
# 70:	learn: 0.2981754	total: 1m 16s	remaining: 7m 39s
# 71:	learn: 0.2959135	total: 1m 17s	remaining: 7m 37s
# 72:	learn: 0.2939416	total: 1m 17s	remaining: 7m 36s
# 73:	learn: 0.2919113	total: 1m 18s	remaining: 7m 34s
# 74:	learn: 0.2899838	total: 1m 19s	remaining: 7m 33s
# 75:	learn: 0.2881360	total: 1m 21s	remaining: 7m 32s
# 76:	learn: 0.2863812	total: 1m 22s	remaining: 7m 31s
# 77:	learn: 0.2844844	total: 1m 23s	remaining: 7m 29s
# 78:	learn: 0.2827241	total: 1m 24s	remaining: 7m 29s
# 79:	learn: 0.2808877	total: 1m 25s	remaining: 7m 27s
# 80:	learn: 0.2791681	total: 1m 26s	remaining: 7m 26s
# 81:	learn: 0.2774623	total: 1m 27s	remaining: 7m 25s
# 82:	learn: 0.2758056	total: 1m 28s	remaining: 7m 24s
# 83:	learn: 0.2742549	total: 1m 29s	remaining: 7m 23s
# 84:	learn: 0.2726442	total: 1m 30s	remaining: 7m 23s
# 85:	learn: 0.2711123	total: 1m 31s	remaining: 7m 22s
# 86:	learn: 0.2697346	total: 1m 32s	remaining: 7m 21s
# 87:	learn: 0.2683138	total: 1m 34s	remaining: 7m 20s
# 88:	learn: 0.2670427	total: 1m 35s	remaining: 7m 19s
# 89:	learn: 0.2656960	total: 1m 36s	remaining: 7m 17s
# 90:	learn: 0.2643476	total: 1m 36s	remaining: 7m 15s
# 91:	learn: 0.2629761	total: 1m 37s	remaining: 7m 14s
# 92:	learn: 0.2616313	total: 1m 38s	remaining: 7m 12s
# 93:	learn: 0.2603895	total: 1m 39s	remaining: 7m 10s
# 94:	learn: 0.2590915	total: 1m 40s	remaining: 7m 9s
# 95:	learn: 0.2577754	total: 1m 41s	remaining: 7m 7s
# 96:	learn: 0.2566347	total: 1m 42s	remaining: 7m 5s
# 97:	learn: 0.2555245	total: 1m 43s	remaining: 7m 4s
# 98:	learn: 0.2543258	total: 1m 44s	remaining: 7m 2s
# 99:	learn: 0.2531822	total: 1m 45s	remaining: 7m 1s
# 100:	learn: 0.2521659	total: 1m 46s	remaining: 6m 59s
# 101:	learn: 0.2510264	total: 1m 47s	remaining: 6m 58s
# 102:	learn: 0.2500319	total: 1m 48s	remaining: 6m 56s
# 103:	learn: 0.2488783	total: 1m 49s	remaining: 6m 55s
# 104:	learn: 0.2478087	total: 1m 49s	remaining: 6m 53s
# 105:	learn: 0.2467548	total: 1m 50s	remaining: 6m 52s
# 106:	learn: 0.2458346	total: 1m 51s	remaining: 6m 50s
# 107:	learn: 0.2448672	total: 1m 52s	remaining: 6m 49s
# 108:	learn: 0.2439835	total: 1m 53s	remaining: 6m 47s
# 109:	learn: 0.2430680	total: 1m 54s	remaining: 6m 46s
# 110:	learn: 0.2421399	total: 1m 55s	remaining: 6m 44s
# 111:	learn: 0.2412731	total: 1m 56s	remaining: 6m 43s
# 112:	learn: 0.2404128	total: 1m 57s	remaining: 6m 42s
# 113:	learn: 0.2396364	total: 1m 58s	remaining: 6m 40s
# 114:	learn: 0.2387152	total: 1m 59s	remaining: 6m 39s
# 115:	learn: 0.2379387	total: 2m	remaining: 6m 37s
# 116:	learn: 0.2371619	total: 2m 1s	remaining: 6m 36s
# 117:	learn: 0.2363699	total: 2m 1s	remaining: 6m 34s
# 118:	learn: 0.2356511	total: 2m 2s	remaining: 6m 33s
# 119:	learn: 0.2349461	total: 2m 3s	remaining: 6m 32s
# 120:	learn: 0.2342500	total: 2m 4s	remaining: 6m 30s
# 121:	learn: 0.2334210	total: 2m 5s	remaining: 6m 29s
# 122:	learn: 0.2327317	total: 2m 6s	remaining: 6m 27s
# 123:	learn: 0.2320445	total: 2m 7s	remaining: 6m 26s
# 124:	learn: 0.2313837	total: 2m 8s	remaining: 6m 25s
# 125:	learn: 0.2306945	total: 2m 9s	remaining: 6m 23s
# 126:	learn: 0.2300124	total: 2m 10s	remaining: 6m 22s
# 127:	learn: 0.2293391	total: 2m 11s	remaining: 6m 21s
# 128:	learn: 0.2286963	total: 2m 12s	remaining: 6m 19s
# 129:	learn: 0.2280810	total: 2m 12s	remaining: 6m 18s
# 130:	learn: 0.2274671	total: 2m 13s	remaining: 6m 17s
# 131:	learn: 0.2268129	total: 2m 14s	remaining: 6m 15s
# 132:	learn: 0.2261763	total: 2m 15s	remaining: 6m 14s
# 133:	learn: 0.2256069	total: 2m 16s	remaining: 6m 13s
# 134:	learn: 0.2250312	total: 2m 17s	remaining: 6m 11s
# 135:	learn: 0.2244665	total: 2m 18s	remaining: 6m 10s
# 136:	learn: 0.2239023	total: 2m 19s	remaining: 6m 9s
# 137:	learn: 0.2233412	total: 2m 20s	remaining: 6m 8s
# 138:	learn: 0.2227986	total: 2m 21s	remaining: 6m 6s
# 139:	learn: 0.2222328	total: 2m 22s	remaining: 6m 5s
# 140:	learn: 0.2217355	total: 2m 23s	remaining: 6m 4s
# 141:	learn: 0.2212006	total: 2m 24s	remaining: 6m 3s
# 142:	learn: 0.2206847	total: 2m 25s	remaining: 6m 2s
# 143:	learn: 0.2202347	total: 2m 25s	remaining: 6m
# 144:	learn: 0.2197422	total: 2m 26s	remaining: 5m 59s
# 145:	learn: 0.2192876	total: 2m 27s	remaining: 5m 58s
# 146:	learn: 0.2187833	total: 2m 28s	remaining: 5m 56s
# 147:	learn: 0.2183341	total: 2m 29s	remaining: 5m 55s
# 148:	learn: 0.2178616	total: 2m 30s	remaining: 5m 54s
# 149:	learn: 0.2173953	total: 2m 31s	remaining: 5m 53s
# 150:	learn: 0.2169404	total: 2m 32s	remaining: 5m 52s
# 151:	learn: 0.2164384	total: 2m 33s	remaining: 5m 50s
# 152:	learn: 0.2159603	total: 2m 34s	remaining: 5m 49s
# 153:	learn: 0.2155007	total: 2m 35s	remaining: 5m 48s
# 154:	learn: 0.2150951	total: 2m 35s	remaining: 5m 47s
# 155:	learn: 0.2146743	total: 2m 36s	remaining: 5m 45s
# 156:	learn: 0.2142910	total: 2m 37s	remaining: 5m 44s
# 157:	learn: 0.2139030	total: 2m 38s	remaining: 5m 43s
# 158:	learn: 0.2134801	total: 2m 39s	remaining: 5m 42s
# 159:	learn: 0.2130926	total: 2m 40s	remaining: 5m 41s
# 160:	learn: 0.2127013	total: 2m 41s	remaining: 5m 39s
# 161:	learn: 0.2123719	total: 2m 42s	remaining: 5m 38s
# 162:	learn: 0.2119715	total: 2m 43s	remaining: 5m 37s
# 163:	learn: 0.2115701	total: 2m 44s	remaining: 5m 36s
# 164:	learn: 0.2112508	total: 2m 45s	remaining: 5m 35s
# 165:	learn: 0.2109063	total: 2m 45s	remaining: 5m 33s
# 166:	learn: 0.2105971	total: 2m 46s	remaining: 5m 32s
# 167:	learn: 0.2102223	total: 2m 47s	remaining: 5m 31s
# 168:	learn: 0.2098420	total: 2m 48s	remaining: 5m 30s
# 169:	learn: 0.2094797	total: 2m 49s	remaining: 5m 29s
# 170:	learn: 0.2091442	total: 2m 50s	remaining: 5m 27s
# 171:	learn: 0.2088543	total: 2m 51s	remaining: 5m 26s
# 172:	learn: 0.2085157	total: 2m 52s	remaining: 5m 25s
# 173:	learn: 0.2081746	total: 2m 53s	remaining: 5m 24s
# 174:	learn: 0.2078352	total: 2m 54s	remaining: 5m 23s
# 175:	learn: 0.2075583	total: 2m 55s	remaining: 5m 22s
# 176:	learn: 0.2072593	total: 2m 55s	remaining: 5m 21s
# 177:	learn: 0.2069442	total: 2m 56s	remaining: 5m 19s
# 178:	learn: 0.2066844	total: 2m 57s	remaining: 5m 18s
# 179:	learn: 0.2063925	total: 2m 58s	remaining: 5m 17s
# 180:	learn: 0.2061143	total: 2m 59s	remaining: 5m 16s
# 181:	learn: 0.2058483	total: 3m	remaining: 5m 15s
# 182:	learn: 0.2055308	total: 3m 1s	remaining: 5m 14s
# 183:	learn: 0.2052511	total: 3m 2s	remaining: 5m 12s
# 184:	learn: 0.2050124	total: 3m 3s	remaining: 5m 11s
# 185:	learn: 0.2047547	total: 3m 3s	remaining: 5m 10s
# 186:	learn: 0.2044855	total: 3m 4s	remaining: 5m 9s
# 187:	learn: 0.2042383	total: 3m 5s	remaining: 5m 8s
# 188:	learn: 0.2039682	total: 3m 6s	remaining: 5m 7s
# 189:	learn: 0.2036660	total: 3m 7s	remaining: 5m 6s
# 190:	learn: 0.2034245	total: 3m 8s	remaining: 5m 4s
# 191:	learn: 0.2031482	total: 3m 9s	remaining: 5m 3s
# 192:	learn: 0.2028975	total: 3m 10s	remaining: 5m 2s
# 193:	learn: 0.2026751	total: 3m 11s	remaining: 5m 1s
# 194:	learn: 0.2024645	total: 3m 12s	remaining: 5m
# 195:	learn: 0.2022000	total: 3m 13s	remaining: 4m 59s
# 196:	learn: 0.2019375	total: 3m 13s	remaining: 4m 58s
# 197:	learn: 0.2017176	total: 3m 14s	remaining: 4m 57s
# 198:	learn: 0.2015212	total: 3m 15s	remaining: 4m 56s
# 199:	learn: 0.2013166	total: 3m 16s	remaining: 4m 54s
# 200:	learn: 0.2010837	total: 3m 17s	remaining: 4m 53s
# 201:	learn: 0.2008657	total: 3m 18s	remaining: 4m 53s
# 202:	learn: 0.2006274	total: 3m 23s	remaining: 4m 57s
# 203:	learn: 0.2003976	total: 3m 27s	remaining: 5m 1s
# 204:	learn: 0.2001924	total: 3m 30s	remaining: 5m 3s
# 205:	learn: 0.1999224	total: 3m 32s	remaining: 5m 3s
# 206:	learn: 0.1997090	total: 3m 33s	remaining: 5m 2s
# 207:	learn: 0.1994729	total: 3m 34s	remaining: 5m 1s
# 208:	learn: 0.1992454	total: 3m 35s	remaining: 5m
# 209:	learn: 0.1990436	total: 3m 36s	remaining: 4m 59s
# 210:	learn: 0.1988411	total: 3m 37s	remaining: 4m 58s
# 211:	learn: 0.1986437	total: 3m 38s	remaining: 4m 57s
# 212:	learn: 0.1984568	total: 3m 39s	remaining: 4m 55s
# 213:	learn: 0.1982538	total: 3m 40s	remaining: 4m 54s
# 214:	learn: 0.1980474	total: 3m 41s	remaining: 4m 53s
# 215:	learn: 0.1978515	total: 3m 42s	remaining: 4m 52s
# 216:	learn: 0.1976375	total: 3m 43s	remaining: 4m 51s
# 217:	learn: 0.1974540	total: 3m 44s	remaining: 4m 50s
# 218:	learn: 0.1972473	total: 3m 45s	remaining: 4m 49s
# 219:	learn: 0.1970449	total: 3m 46s	remaining: 4m 47s
# 220:	learn: 0.1968492	total: 3m 47s	remaining: 4m 46s
# 221:	learn: 0.1966711	total: 3m 48s	remaining: 4m 45s
# 222:	learn: 0.1964611	total: 3m 49s	remaining: 4m 44s
# 223:	learn: 0.1962521	total: 3m 50s	remaining: 4m 43s
# 224:	learn: 0.1960442	total: 3m 51s	remaining: 4m 42s
# 225:	learn: 0.1958599	total: 3m 52s	remaining: 4m 41s
# 226:	learn: 0.1956629	total: 3m 53s	remaining: 4m 40s
# 227:	learn: 0.1954879	total: 3m 54s	remaining: 4m 39s
# 228:	learn: 0.1953260	total: 3m 55s	remaining: 4m 38s
# 229:	learn: 0.1951088	total: 3m 55s	remaining: 4m 36s
# 230:	learn: 0.1949233	total: 3m 56s	remaining: 4m 35s
# 231:	learn: 0.1947539	total: 3m 57s	remaining: 4m 34s
# 232:	learn: 0.1945636	total: 3m 58s	remaining: 4m 33s
# 233:	learn: 0.1944102	total: 3m 59s	remaining: 4m 32s
# 234:	learn: 0.1942413	total: 4m	remaining: 4m 31s
# 235:	learn: 0.1940690	total: 4m 1s	remaining: 4m 30s
# 236:	learn: 0.1938873	total: 4m 2s	remaining: 4m 29s
# 237:	learn: 0.1936966	total: 4m 3s	remaining: 4m 28s
# 238:	learn: 0.1935319	total: 4m 4s	remaining: 4m 26s
# 239:	learn: 0.1933701	total: 4m 5s	remaining: 4m 25s
# 240:	learn: 0.1931915	total: 4m 6s	remaining: 4m 24s
# 241:	learn: 0.1930385	total: 4m 7s	remaining: 4m 23s
# 242:	learn: 0.1928754	total: 4m 8s	remaining: 4m 22s
# 243:	learn: 0.1927032	total: 4m 9s	remaining: 4m 21s
# 244:	learn: 0.1925314	total: 4m 10s	remaining: 4m 20s
# 245:	learn: 0.1923951	total: 4m 11s	remaining: 4m 19s
# 246:	learn: 0.1922216	total: 4m 12s	remaining: 4m 18s
# 247:	learn: 0.1920670	total: 4m 13s	remaining: 4m 17s
# 248:	learn: 0.1919349	total: 4m 14s	remaining: 4m 16s
# 249:	learn: 0.1918113	total: 4m 14s	remaining: 4m 14s
# 250:	learn: 0.1916663	total: 4m 15s	remaining: 4m 13s
# 251:	learn: 0.1915373	total: 4m 16s	remaining: 4m 12s
# 252:	learn: 0.1913623	total: 4m 17s	remaining: 4m 11s
# 253:	learn: 0.1911959	total: 4m 18s	remaining: 4m 10s
# 254:	learn: 0.1910758	total: 4m 19s	remaining: 4m 9s
# 255:	learn: 0.1909341	total: 4m 20s	remaining: 4m 8s
# 256:	learn: 0.1907948	total: 4m 21s	remaining: 4m 7s
# 257:	learn: 0.1906564	total: 4m 22s	remaining: 4m 6s
# 258:	learn: 0.1905205	total: 4m 23s	remaining: 4m 5s
# 259:	learn: 0.1903773	total: 4m 24s	remaining: 4m 3s
# 260:	learn: 0.1902294	total: 4m 25s	remaining: 4m 2s
# 261:	learn: 0.1900870	total: 4m 26s	remaining: 4m 1s
# 262:	learn: 0.1899439	total: 4m 27s	remaining: 4m
# 263:	learn: 0.1897832	total: 4m 27s	remaining: 3m 59s
# 264:	learn: 0.1896488	total: 4m 28s	remaining: 3m 58s
# 265:	learn: 0.1895373	total: 4m 29s	remaining: 3m 57s
# 266:	learn: 0.1894106	total: 4m 30s	remaining: 3m 56s
# 267:	learn: 0.1892821	total: 4m 31s	remaining: 3m 55s
# 268:	learn: 0.1891501	total: 4m 32s	remaining: 3m 54s
# 269:	learn: 0.1890056	total: 4m 33s	remaining: 3m 52s
# 270:	learn: 0.1888636	total: 4m 34s	remaining: 3m 51s
# 271:	learn: 0.1887457	total: 4m 35s	remaining: 3m 50s
# 272:	learn: 0.1886110	total: 4m 36s	remaining: 3m 49s
# 273:	learn: 0.1884921	total: 4m 37s	remaining: 3m 48s
# 274:	learn: 0.1883404	total: 4m 38s	remaining: 3m 47s
# 275:	learn: 0.1882261	total: 4m 39s	remaining: 3m 46s
# 276:	learn: 0.1881189	total: 4m 47s	remaining: 3m 51s
# 277:	learn: 0.1879925	total: 4m 48s	remaining: 3m 50s
# 278:	learn: 0.1878843	total: 4m 49s	remaining: 3m 49s
# 279:	learn: 0.1877728	total: 4m 50s	remaining: 3m 47s
# 280:	learn: 0.1876597	total: 4m 51s	remaining: 3m 46s
# 281:	learn: 0.1875437	total: 4m 52s	remaining: 3m 45s
# 282:	learn: 0.1874228	total: 4m 52s	remaining: 3m 44s
# 283:	learn: 0.1873235	total: 4m 53s	remaining: 3m 43s
# 284:	learn: 0.1872195	total: 4m 54s	remaining: 3m 42s
# 285:	learn: 0.1870943	total: 4m 55s	remaining: 3m 41s
# 286:	learn: 0.1869740	total: 4m 56s	remaining: 3m 40s
# 287:	learn: 0.1868499	total: 4m 57s	remaining: 3m 38s
# 288:	learn: 0.1867443	total: 4m 58s	remaining: 3m 37s
# 289:	learn: 0.1866403	total: 4m 59s	remaining: 3m 36s
# 290:	learn: 0.1864854	total: 5m	remaining: 3m 35s
# 291:	learn: 0.1863791	total: 5m 1s	remaining: 3m 34s
# 292:	learn: 0.1862666	total: 5m 2s	remaining: 3m 33s
# 293:	learn: 0.1861696	total: 5m 2s	remaining: 3m 32s
# 294:	learn: 0.1860818	total: 5m 3s	remaining: 3m 31s
# 295:	learn: 0.1859745	total: 5m 4s	remaining: 3m 30s
# 296:	learn: 0.1858658	total: 5m 5s	remaining: 3m 28s
# 297:	learn: 0.1857534	total: 5m 6s	remaining: 3m 27s
# 298:	learn: 0.1856499	total: 5m 7s	remaining: 3m 26s
# 299:	learn: 0.1855421	total: 5m 8s	remaining: 3m 25s
# 300:	learn: 0.1854333	total: 5m 9s	remaining: 3m 24s
# 301:	learn: 0.1853155	total: 5m 10s	remaining: 3m 23s
# 302:	learn: 0.1852144	total: 5m 11s	remaining: 3m 22s
# 303:	learn: 0.1850980	total: 5m 12s	remaining: 3m 21s
# 304:	learn: 0.1849984	total: 5m 13s	remaining: 3m 20s
# 305:	learn: 0.1848790	total: 5m 14s	remaining: 3m 19s
# 306:	learn: 0.1847752	total: 5m 15s	remaining: 3m 18s
# 307:	learn: 0.1846675	total: 5m 16s	remaining: 3m 17s
# 308:	learn: 0.1845622	total: 5m 17s	remaining: 3m 15s
# 309:	learn: 0.1844521	total: 5m 17s	remaining: 3m 14s
# 310:	learn: 0.1843571	total: 5m 18s	remaining: 3m 13s
# 311:	learn: 0.1842459	total: 5m 19s	remaining: 3m 12s
# 312:	learn: 0.1841376	total: 5m 20s	remaining: 3m 11s
# 313:	learn: 0.1840159	total: 5m 21s	remaining: 3m 10s
# 314:	learn: 0.1839211	total: 5m 22s	remaining: 3m 9s
# 315:	learn: 0.1837900	total: 5m 23s	remaining: 3m 8s
# 316:	learn: 0.1836878	total: 5m 24s	remaining: 3m 7s
# 317:	learn: 0.1835952	total: 5m 25s	remaining: 3m 6s
# 318:	learn: 0.1834903	total: 5m 26s	remaining: 3m 5s
# 319:	learn: 0.1833999	total: 5m 27s	remaining: 3m 4s
# 320:	learn: 0.1833039	total: 5m 28s	remaining: 3m 2s
# 321:	learn: 0.1831925	total: 5m 29s	remaining: 3m 1s
# 322:	learn: 0.1831016	total: 5m 29s	remaining: 3m
# 323:	learn: 0.1830053	total: 5m 30s	remaining: 2m 59s
# 324:	learn: 0.1829087	total: 5m 31s	remaining: 2m 58s
# 325:	learn: 0.1828243	total: 5m 32s	remaining: 2m 57s
# 326:	learn: 0.1827147	total: 5m 33s	remaining: 2m 56s
# 327:	learn: 0.1826357	total: 5m 34s	remaining: 2m 55s
# 328:	learn: 0.1825542	total: 5m 35s	remaining: 2m 54s
# 329:	learn: 0.1824400	total: 5m 36s	remaining: 2m 53s
# 330:	learn: 0.1823413	total: 5m 37s	remaining: 2m 52s
# 331:	learn: 0.1822395	total: 5m 38s	remaining: 2m 51s
# 332:	learn: 0.1821516	total: 5m 39s	remaining: 2m 50s
# 333:	learn: 0.1820436	total: 5m 40s	remaining: 2m 49s
# 334:	learn: 0.1819303	total: 5m 40s	remaining: 2m 47s
# 335:	learn: 0.1818363	total: 5m 41s	remaining: 2m 46s
# 336:	learn: 0.1817407	total: 5m 42s	remaining: 2m 45s
# 337:	learn: 0.1816533	total: 5m 43s	remaining: 2m 44s
# 338:	learn: 0.1815537	total: 5m 44s	remaining: 2m 43s
# 339:	learn: 0.1814382	total: 5m 45s	remaining: 2m 42s
# 340:	learn: 0.1813478	total: 5m 46s	remaining: 2m 41s
# 341:	learn: 0.1812334	total: 5m 47s	remaining: 2m 40s
# 342:	learn: 0.1811146	total: 5m 48s	remaining: 2m 39s
# 343:	learn: 0.1810203	total: 5m 49s	remaining: 2m 38s
# 344:	learn: 0.1809290	total: 5m 50s	remaining: 2m 37s
# 345:	learn: 0.1808587	total: 5m 51s	remaining: 2m 36s
# 346:	learn: 0.1807685	total: 5m 51s	remaining: 2m 35s
# 347:	learn: 0.1806841	total: 5m 52s	remaining: 2m 34s
# 348:	learn: 0.1805929	total: 5m 53s	remaining: 2m 33s
# 349:	learn: 0.1804979	total: 5m 54s	remaining: 2m 31s
# 350:	learn: 0.1804231	total: 5m 55s	remaining: 2m 30s
# 351:	learn: 0.1803522	total: 5m 56s	remaining: 2m 29s
# 352:	learn: 0.1802648	total: 5m 57s	remaining: 2m 28s
# 353:	learn: 0.1801639	total: 5m 58s	remaining: 2m 27s
# 354:	learn: 0.1800918	total: 5m 59s	remaining: 2m 26s
# 355:	learn: 0.1799939	total: 6m	remaining: 2m 25s
# 356:	learn: 0.1798781	total: 6m 1s	remaining: 2m 24s
# 357:	learn: 0.1797875	total: 6m 2s	remaining: 2m 23s
# 358:	learn: 0.1797044	total: 6m 2s	remaining: 2m 22s
# 359:	learn: 0.1795969	total: 6m 3s	remaining: 2m 21s
# 360:	learn: 0.1795150	total: 6m 4s	remaining: 2m 20s
# 361:	learn: 0.1793946	total: 6m 5s	remaining: 2m 19s
# 362:	learn: 0.1793073	total: 6m 6s	remaining: 2m 18s
# 363:	learn: 0.1792178	total: 6m 7s	remaining: 2m 17s
# 364:	learn: 0.1791274	total: 6m 8s	remaining: 2m 16s
# 365:	learn: 0.1790386	total: 6m 9s	remaining: 2m 15s
# 366:	learn: 0.1789231	total: 6m 10s	remaining: 2m 14s
# 367:	learn: 0.1788390	total: 6m 11s	remaining: 2m 13s
# 368:	learn: 0.1787321	total: 6m 12s	remaining: 2m 12s
# 369:	learn: 0.1786675	total: 6m 13s	remaining: 2m 11s
# 370:	learn: 0.1785961	total: 6m 14s	remaining: 2m 10s
# 371:	learn: 0.1785416	total: 6m 15s	remaining: 2m 9s
# 372:	learn: 0.1784488	total: 6m 16s	remaining: 2m 8s
# 373:	learn: 0.1783573	total: 6m 17s	remaining: 2m 7s
# 374:	learn: 0.1782920	total: 6m 18s	remaining: 2m 6s
# 375:	learn: 0.1782082	total: 6m 19s	remaining: 2m 5s
# 376:	learn: 0.1781306	total: 6m 20s	remaining: 2m 4s
# 377:	learn: 0.1780406	total: 6m 20s	remaining: 2m 2s
# 378:	learn: 0.1779633	total: 6m 21s	remaining: 2m 1s
# 379:	learn: 0.1778842	total: 6m 22s	remaining: 2m
# 380:	learn: 0.1777979	total: 6m 23s	remaining: 1m 59s
# 381:	learn: 0.1777152	total: 6m 24s	remaining: 1m 58s
# 382:	learn: 0.1776401	total: 6m 25s	remaining: 1m 57s
# 383:	learn: 0.1775520	total: 6m 26s	remaining: 1m 56s
# 384:	learn: 0.1774579	total: 6m 27s	remaining: 1m 55s
# 385:	learn: 0.1773733	total: 6m 28s	remaining: 1m 54s
# 386:	learn: 0.1772994	total: 6m 29s	remaining: 1m 53s
# 387:	learn: 0.1772189	total: 6m 30s	remaining: 1m 52s
# 388:	learn: 0.1771395	total: 6m 31s	remaining: 1m 51s
# 389:	learn: 0.1770769	total: 6m 32s	remaining: 1m 50s
# 390:	learn: 0.1769838	total: 6m 33s	remaining: 1m 49s
# 391:	learn: 0.1768964	total: 6m 34s	remaining: 1m 48s
# 392:	learn: 0.1768257	total: 6m 35s	remaining: 1m 47s
# 393:	learn: 0.1767553	total: 6m 36s	remaining: 1m 46s
# 394:	learn: 0.1766717	total: 6m 37s	remaining: 1m 45s
# 395:	learn: 0.1766057	total: 6m 38s	remaining: 1m 44s
# 396:	learn: 0.1765261	total: 6m 39s	remaining: 1m 43s
# 397:	learn: 0.1764414	total: 6m 40s	remaining: 1m 42s
# 398:	learn: 0.1763613	total: 6m 41s	remaining: 1m 41s
# 399:	learn: 0.1762908	total: 6m 42s	remaining: 1m 40s
# 400:	learn: 0.1762129	total: 6m 43s	remaining: 1m 39s
# 401:	learn: 0.1761384	total: 6m 44s	remaining: 1m 38s
# 402:	learn: 0.1760421	total: 6m 45s	remaining: 1m 37s
# 403:	learn: 0.1759515	total: 6m 46s	remaining: 1m 36s
# 404:	learn: 0.1758706	total: 6m 47s	remaining: 1m 35s
# 405:	learn: 0.1757863	total: 6m 47s	remaining: 1m 34s
# 406:	learn: 0.1757156	total: 6m 48s	remaining: 1m 33s
# 407:	learn: 0.1756019	total: 6m 49s	remaining: 1m 32s
# 408:	learn: 0.1755230	total: 6m 50s	remaining: 1m 31s
# 409:	learn: 0.1754420	total: 6m 51s	remaining: 1m 30s
# 410:	learn: 0.1753716	total: 6m 52s	remaining: 1m 29s
# 411:	learn: 0.1753048	total: 6m 53s	remaining: 1m 28s
# 412:	learn: 0.1752383	total: 6m 54s	remaining: 1m 27s
# 413:	learn: 0.1751519	total: 6m 55s	remaining: 1m 26s
# 414:	learn: 0.1750851	total: 6m 56s	remaining: 1m 25s
# 415:	learn: 0.1750123	total: 6m 57s	remaining: 1m 24s
# 416:	learn: 0.1749485	total: 6m 57s	remaining: 1m 23s
# 417:	learn: 0.1748710	total: 6m 58s	remaining: 1m 22s
# 418:	learn: 0.1747918	total: 6m 59s	remaining: 1m 21s
# 419:	learn: 0.1747264	total: 7m	remaining: 1m 20s
# 420:	learn: 0.1746548	total: 7m 1s	remaining: 1m 19s
# 421:	learn: 0.1746094	total: 7m 2s	remaining: 1m 18s
# 422:	learn: 0.1745396	total: 7m 3s	remaining: 1m 17s
# 423:	learn: 0.1744456	total: 7m 4s	remaining: 1m 16s
# 424:	learn: 0.1743708	total: 7m 5s	remaining: 1m 15s
# 425:	learn: 0.1742690	total: 7m 5s	remaining: 1m 13s
# 426:	learn: 0.1741950	total: 7m 6s	remaining: 1m 12s
# 427:	learn: 0.1741272	total: 7m 7s	remaining: 1m 11s
# 428:	learn: 0.1740553	total: 7m 8s	remaining: 1m 10s
# 429:	learn: 0.1740008	total: 7m 9s	remaining: 1m 9s
# 430:	learn: 0.1739397	total: 7m 10s	remaining: 1m 8s
# 431:	learn: 0.1738621	total: 7m 11s	remaining: 1m 7s
# 432:	learn: 0.1737978	total: 7m 12s	remaining: 1m 6s
# 433:	learn: 0.1737158	total: 7m 13s	remaining: 1m 5s
# 434:	learn: 0.1736495	total: 7m 14s	remaining: 1m 4s
# 435:	learn: 0.1735687	total: 7m 15s	remaining: 1m 3s
# 436:	learn: 0.1734935	total: 7m 15s	remaining: 1m 2s
# 437:	learn: 0.1734329	total: 7m 16s	remaining: 1m 1s
# 438:	learn: 0.1733488	total: 7m 17s	remaining: 1m
# 439:	learn: 0.1732885	total: 7m 18s	remaining: 59.8s
# 440:	learn: 0.1732295	total: 7m 19s	remaining: 58.8s
# 441:	learn: 0.1731735	total: 7m 20s	remaining: 57.8s
# 442:	learn: 0.1731006	total: 7m 21s	remaining: 56.8s
# 443:	learn: 0.1730195	total: 7m 22s	remaining: 55.8s
# 444:	learn: 0.1729724	total: 7m 23s	remaining: 54.8s
# 445:	learn: 0.1728783	total: 7m 24s	remaining: 53.8s
# 446:	learn: 0.1728186	total: 7m 24s	remaining: 52.8s
# 447:	learn: 0.1727521	total: 7m 25s	remaining: 51.7s
# 448:	learn: 0.1726880	total: 7m 26s	remaining: 50.7s
# 449:	learn: 0.1726231	total: 7m 27s	remaining: 49.7s
# 450:	learn: 0.1725393	total: 7m 28s	remaining: 48.7s
# 451:	learn: 0.1724721	total: 7m 29s	remaining: 47.7s
# 452:	learn: 0.1724184	total: 7m 30s	remaining: 46.7s
# 453:	learn: 0.1723701	total: 7m 31s	remaining: 45.7s
# 454:	learn: 0.1723136	total: 7m 32s	remaining: 44.7s
# 455:	learn: 0.1722502	total: 7m 32s	remaining: 43.7s
# 456:	learn: 0.1721715	total: 7m 33s	remaining: 42.7s
# 457:	learn: 0.1720956	total: 7m 34s	remaining: 41.7s
# 458:	learn: 0.1720128	total: 7m 35s	remaining: 40.7s
# 459:	learn: 0.1719527	total: 7m 36s	remaining: 39.7s
# 460:	learn: 0.1718831	total: 7m 37s	remaining: 38.7s
# 461:	learn: 0.1718254	total: 7m 38s	remaining: 37.7s
# 462:	learn: 0.1717597	total: 7m 39s	remaining: 36.7s
# 463:	learn: 0.1716989	total: 7m 39s	remaining: 35.7s
# 464:	learn: 0.1716269	total: 7m 40s	remaining: 34.7s
# 465:	learn: 0.1715402	total: 7m 41s	remaining: 33.7s
# 466:	learn: 0.1714839	total: 7m 42s	remaining: 32.7s
# 467:	learn: 0.1714191	total: 7m 43s	remaining: 31.7s
# 468:	learn: 0.1713466	total: 7m 44s	remaining: 30.7s
# 469:	learn: 0.1712838	total: 7m 45s	remaining: 29.7s
# 470:	learn: 0.1712244	total: 7m 46s	remaining: 28.7s
# 471:	learn: 0.1711562	total: 7m 47s	remaining: 27.7s
# 472:	learn: 0.1710857	total: 7m 47s	remaining: 26.7s
# 473:	learn: 0.1710172	total: 7m 48s	remaining: 25.7s
# 474:	learn: 0.1709562	total: 7m 49s	remaining: 24.7s
# 475:	learn: 0.1708869	total: 7m 50s	remaining: 23.7s
# 476:	learn: 0.1708240	total: 7m 51s	remaining: 22.7s
# 477:	learn: 0.1707658	total: 7m 52s	remaining: 21.7s
# 478:	learn: 0.1707003	total: 7m 53s	remaining: 20.7s
# 479:	learn: 0.1706275	total: 7m 54s	remaining: 19.8s
# 480:	learn: 0.1705575	total: 7m 55s	remaining: 18.8s
# 481:	learn: 0.1705016	total: 7m 56s	remaining: 17.8s
# 482:	learn: 0.1704538	total: 7m 57s	remaining: 16.8s
# 483:	learn: 0.1703998	total: 7m 58s	remaining: 15.8s
# 484:	learn: 0.1703471	total: 8m 4s	remaining: 15s
# 485:	learn: 0.1702919	total: 8m 5s	remaining: 14s
# 486:	learn: 0.1702384	total: 8m 6s	remaining: 13s
# 487:	learn: 0.1701695	total: 8m 7s	remaining: 12s
# 488:	learn: 0.1701153	total: 8m 8s	remaining: 11s
# 489:	learn: 0.1700545	total: 8m 9s	remaining: 9.99s
# 490:	learn: 0.1699725	total: 8m 10s	remaining: 8.99s
# 491:	learn: 0.1698941	total: 8m 11s	remaining: 7.99s
# 492:	learn: 0.1698467	total: 8m 12s	remaining: 6.99s
# 493:	learn: 0.1697975	total: 8m 13s	remaining: 5.99s
# 494:	learn: 0.1697357	total: 8m 14s	remaining: 4.99s
# 495:	learn: 0.1696827	total: 8m 14s	remaining: 3.99s
# 496:	learn: 0.1696078	total: 8m 15s	remaining: 2.99s
# 497:	learn: 0.1695279	total: 8m 16s	remaining: 2s
# 498:	learn: 0.1694601	total: 8m 17s	remaining: 997ms
# 499:	learn: 0.1694135	total: 8m 18s	remaining: 0us

# %%
evaluate_model(cat, X_test, y_test, "none")
add_to_eval_df(cat, "CatBoostClassifier", "clean", X_train, y_train, X_test, y_test)
# Out:
# none model accuracy for classification is = 94.58%
# ------------------------------------------------
# Confusion Matrix:
#       0    1
# 0  7743   11
# 1   439  102
# ------------------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      7754
#            1       0.90      0.19      0.31       541
#
#     accuracy                           0.95      8295
#    macro avg       0.92      0.59      0.64      8295
# weighted avg       0.94      0.95      0.93      8295

# %% [markdown]
# ##### 2.2.1 LGBMClassifier

# %%
light = LGBMClassifier()
light.fit(X_train, y_train)
# Out:
# [LightGBM] [Info] Number of positive: 1270, number of negative: 18084
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.032977 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 33541
# [LightGBM] [Info] Number of data points in the train set: 19354, number of used features: 1210
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.065620 -> initscore=-2.656011
# [LightGBM] [Info] Start training from score -2.656011
# LGBMClassifier()

# %%
evaluate_model(light, X_test, y_test, "none")
add_to_eval_df(light, "LGBMClassifier", "clean", X_train, y_train, X_test, y_test)
# Out:
# none model accuracy for classification is = 94.82%
# ------------------------------------------------
# Confusion Matrix:
#       0    1
# 0  7700   54
# 1   376  165
# ------------------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97      7754
#            1       0.75      0.30      0.43       541
#
#     accuracy                           0.95      8295
#    macro avg       0.85      0.65      0.70      8295
# weighted avg       0.94      0.95      0.94      8295

# %% [markdown]
# #### 2.3 Stacking

# %% [markdown]
# ##### 2.3.1 Stacking: RandomForest + LinearSVC

# %%
base_models = [
    ('rf', RandomForestClassifier(random_state=42)),
    ('svc', LinearSVC(random_state=42))
]
stack = StackingClassifier(estimators=base_models, n_jobs=-1)

# %%
stack.fit(X_train, y_train)
# Out:
# StackingClassifier(estimators=[('rf', RandomForestClassifier(random_state=42)),
#                                ('svc', LinearSVC(random_state=42))],
#                    n_jobs=-1)

# %%
evaluate_model(stack, X_test, y_test, "none")
add_to_eval_df(stack, "StackingClassifier", "clean", X_train, y_train, X_test, y_test)
# Out:
# none model accuracy for classification is = 96.07%
# ------------------------------------------------
# Confusion Matrix:
#       0    1
# 0  7682   72
# 1   254  287
# ------------------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      7754
#            1       0.80      0.53      0.64       541
#
#     accuracy                           0.96      8295
#    macro avg       0.88      0.76      0.81      8295
# weighted avg       0.96      0.96      0.96      8295

# %% [markdown]
# Vergleich: SVC

# %%
svc = LinearSVC()
svc.fit(X_train, y_train)
# Out:
# LinearSVC()

# %%
evaluate_model(svc, X_test, y_test, "none")
add_to_eval_df(svc, "LinearSVC", "clean", X_train, y_train, X_test, y_test)
# Out:
# none model accuracy for classification is = 95.84%
# ------------------------------------------------
# Confusion Matrix:
#       0    1
# 0  7684   70
# 1   275  266
# ------------------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      7754
#            1       0.79      0.49      0.61       541
#
#     accuracy                           0.96      8295
#    macro avg       0.88      0.74      0.79      8295
# weighted avg       0.95      0.96      0.95      8295
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[163], line 1
# ----> 1 evaluate_model(svc, X_test, y_test, "none")
#       2 add_to_eval_df(svc, "LinearSVC", "clean", X_train, y_train, X_test, y_test)
#
# Cell In[109], line 13, in evaluate_model(model, x_test, y_test, sampling_method)
#      10 print('Classification Report:')
#      11 print(classification_report(y_test, pred))
# ---> 13 probs = model.predict_proba(x_test)
#      14 preds = probs[:, 1]
#      15 fpr, tpr, threshold = metrics.roc_curve(y_test, preds)
#
# AttributeError: 'LinearSVC' object has no attribute 'predict_proba'

# %% [markdown]
# #### Model comparision

# %%
evaluation.sort_values(by=["test_prec"], ascending=False)
# Out:
#                                    model variant  train_acc  train_prec  \
# 9                     CatBoostClassifier   clean   0.946058    0.915441
# 2              RandomForest-tuned-optuna   clean   0.972305    0.990642
# 7               XGBClassifier-tuned-rand   clean   0.951276    0.931398
# 1                 RandomForestClassifier   clean   0.999897    1.000000
# 5                          XGBClassifier   clean   0.959750    0.922547
# 0                     StackingClassifier   clean   0.995040    0.988353
# 8             XGBClassifier-tuned-optuna   clean   0.978919    0.985360
# 6               XGBClassifier-tuned-grid   clean   0.962333    0.921997
# 10                        LGBMClassifier   clean   0.961713    0.927302
# 3         BalancedRandomForestClassifier   clean   0.905549    0.409942
# 4   BalancedRandomForestClassifier-tuned   clean   0.885398    0.334266
#
#     train_rec  train_f1  test_acc  test_prec  test_rec   test_f1
# 9    0.196063  0.322957  0.945750   0.902655  0.188540  0.311927
# 2    0.583465  0.734390  0.954430   0.865471  0.356747  0.505236
# 7    0.277953  0.428138  0.948162   0.844720  0.251386  0.387464
# 1    0.998425  0.999212  0.957806   0.832753  0.441774  0.577295
# 5    0.422047  0.579146  0.950332   0.808612  0.312384  0.450667
# 0    0.935433  0.961165  0.960699   0.799443  0.530499  0.637778
# 8    0.688976  0.810936  0.953707   0.783394  0.401109  0.530562
# 6    0.465354  0.618524  0.950693   0.775000  0.343808  0.476312
# 10   0.451969  0.607729  0.948162   0.753425  0.304991  0.434211
# 3    1.000000  0.581502  0.883785   0.322716  0.711645  0.444060
# 4    0.752756  0.462954  0.885473   0.322328  0.685767  0.438534

# %%
evaluation.sort_values(by=["test_rec"], ascending=False)
# Out:
#                                    model variant  train_acc  train_prec  \
# 3         BalancedRandomForestClassifier   clean   0.905549    0.409942
# 4   BalancedRandomForestClassifier-tuned   clean   0.885398    0.334266
# 0                     StackingClassifier   clean   0.995040    0.988353
# 1                 RandomForestClassifier   clean   0.999897    1.000000
# 8             XGBClassifier-tuned-optuna   clean   0.978919    0.985360
# 2              RandomForest-tuned-optuna   clean   0.972305    0.990642
# 6               XGBClassifier-tuned-grid   clean   0.962333    0.921997
# 5                          XGBClassifier   clean   0.959750    0.922547
# 10                        LGBMClassifier   clean   0.961713    0.927302
# 7               XGBClassifier-tuned-rand   clean   0.951276    0.931398
# 9                     CatBoostClassifier   clean   0.946058    0.915441
#
#     train_rec  train_f1  test_acc  test_prec  test_rec   test_f1
# 3    1.000000  0.581502  0.883785   0.322716  0.711645  0.444060
# 4    0.752756  0.462954  0.885473   0.322328  0.685767  0.438534
# 0    0.935433  0.961165  0.960699   0.799443  0.530499  0.637778
# 1    0.998425  0.999212  0.957806   0.832753  0.441774  0.577295
# 8    0.688976  0.810936  0.953707   0.783394  0.401109  0.530562
# 2    0.583465  0.734390  0.954430   0.865471  0.356747  0.505236
# 6    0.465354  0.618524  0.950693   0.775000  0.343808  0.476312
# 5    0.422047  0.579146  0.950332   0.808612  0.312384  0.450667
# 10   0.451969  0.607729  0.948162   0.753425  0.304991  0.434211
# 7    0.277953  0.428138  0.948162   0.844720  0.251386  0.387464
# 9    0.196063  0.322957  0.945750   0.902655  0.188540  0.311927

# %%
evaluation.sort_values(by=["test_f1"], ascending=False)
# Out:
#                                    model variant  train_acc  train_prec  \
# 0                     StackingClassifier   clean   0.995040    0.988353
# 1                 RandomForestClassifier   clean   0.999897    1.000000
# 8             XGBClassifier-tuned-optuna   clean   0.978919    0.985360
# 2              RandomForest-tuned-optuna   clean   0.972305    0.990642
# 6               XGBClassifier-tuned-grid   clean   0.962333    0.921997
# 5                          XGBClassifier   clean   0.959750    0.922547
# 3         BalancedRandomForestClassifier   clean   0.905549    0.409942
# 4   BalancedRandomForestClassifier-tuned   clean   0.885398    0.334266
# 10                        LGBMClassifier   clean   0.961713    0.927302
# 7               XGBClassifier-tuned-rand   clean   0.951276    0.931398
# 9                     CatBoostClassifier   clean   0.946058    0.915441
#
#     train_rec  train_f1  test_acc  test_prec  test_rec   test_f1
# 0    0.935433  0.961165  0.960699   0.799443  0.530499  0.637778
# 1    0.998425  0.999212  0.957806   0.832753  0.441774  0.577295
# 8    0.688976  0.810936  0.953707   0.783394  0.401109  0.530562
# 2    0.583465  0.734390  0.954430   0.865471  0.356747  0.505236
# 6    0.465354  0.618524  0.950693   0.775000  0.343808  0.476312
# 5    0.422047  0.579146  0.950332   0.808612  0.312384  0.450667
# 3    1.000000  0.581502  0.883785   0.322716  0.711645  0.444060
# 4    0.752756  0.462954  0.885473   0.322328  0.685767  0.438534
# 10   0.451969  0.607729  0.948162   0.753425  0.304991  0.434211
# 7    0.277953  0.428138  0.948162   0.844720  0.251386  0.387464
# 9    0.196063  0.322957  0.945750   0.902655  0.188540  0.311927

# %%
evaluation['vectorize_variant'] = "tfidf"
evaluation = evaluation[['model',
 'variant',
 'vectorize_variant',
 'train_acc',
 'train_prec',
 'train_rec',
 'train_f1',
 'test_acc',
 'test_prec',
 'test_rec',
 'test_f1']]

outname = 'evaluation_tfidf.csv'

outdir = './eval_data'
if not os.path.exists(outdir):
    os.mkdir(outdir)

fullname = os.path.join(outdir, outname)

evaluation.to_csv(fullname)
