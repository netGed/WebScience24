# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
tfidf = pd.read_csv('./eval_data/nb_grid_tfidf_mixed_dataset.csv')#, index_col=0)
tfidf_cnb = pd.read_csv('./eval_data/cnb_grid_tfidf_mixed_dataset.csv')#, index_col=0)
w2v = pd.read_csv('./eval_data/nb_grid_w2v_mixed_dataset.csv')#, index_col=0)
w2v_param = pd.read_csv('./eval_data/nb_grid_w2v_parameters_mixed_dataset.csv')#, index_col=0)
glv = pd.read_csv('./eval_data/nb_grid_glv_mixed_dataset.csv')#, index_col=0)

# %%
evaluation = pd.concat([tfidf,
                        tfidf_cnb,
                        w2v,
                        w2v_param,
                        glv,
                        ])

# %%
evaluation
# Out:
#              model         alpha fit_prior   class_prior  train_accuracy  \
# 0   TF-IDF (Multi)  1.000000e-10      True           NaN        0.867526
# 1   TF-IDF (Multi)  1.000000e-10     False           NaN        0.783629
# 2   TF-IDF (Multi)  1.000000e-10      True  [0.25, 0.75]        0.593787
# 3   TF-IDF (Multi)  1.000000e-10     False  [0.25, 0.75]        0.593787
# 4   TF-IDF (Multi)  1.000000e-10      True    [0.5, 0.5]        0.783629
# ..             ...           ...       ...           ...             ...
# 19           Glove           NaN       NaN           NaN        0.502791
# 20           Glove           NaN       NaN           NaN        0.457406
# 21           Glove           NaN       NaN           NaN        0.433911
# 22           Glove           NaN       NaN           NaN        0.424772
# 23           Glove           NaN       NaN           NaN        0.420114
#
#     train_recall  train_precision  train_f1  test_accuracy  test_recall  \
# 0       0.331526         0.832078  0.474140       0.832574     0.203532
# 1       0.886909         0.449086  0.596257       0.725094     0.673308
# 2       0.991673         0.306234  0.467960       0.545051     0.786280
# 3       0.991673         0.306234  0.467960       0.545051     0.786280
# 4       0.886909         0.449086  0.596257       0.725094     0.673308
# ..           ...              ...       ...            ...          ...
# 19      0.896204         0.252276  0.393722       0.498128     0.893140
# 20      0.929415         0.240107  0.381624       0.451205     0.925289
# 21      0.940744         0.233788  0.374506       0.428170     0.937288
# 22      0.944423         0.231362  0.371673       0.418729     0.942495
# 23      0.946553         0.230186  0.370317       0.413438     0.944306
#
#     test_precision   test_f1 norm      priors  var_smoothing  vector_size  \
# 0         0.601338  0.304127  NaN         NaN            NaN          NaN
# 1         0.358919  0.468236  NaN         NaN            NaN          NaN
# 2         0.253356  0.383228  NaN         NaN            NaN          NaN
# 3         0.253356  0.383228  NaN         NaN            NaN          NaN
# 4         0.358919  0.468236  NaN         NaN            NaN          NaN
# ..             ...       ...  ...         ...            ...          ...
# 19        0.249605  0.390169  NaN  [0.5, 0.5]           0.10          NaN
# 20        0.237037  0.377395  NaN  [0.5, 0.5]           0.25          NaN
# 21        0.231104  0.370785  NaN  [0.5, 0.5]           0.50          NaN
# 22        0.228837  0.368260  NaN  [0.5, 0.5]           0.75          NaN
# 23        0.227451  0.366601  NaN  [0.5, 0.5]           1.00          NaN
#
#     window  min_count
# 0      NaN        NaN
# 1      NaN        NaN
# 2      NaN        NaN
# 3      NaN        NaN
# 4      NaN        NaN
# ..     ...        ...
# 19     NaN        NaN
# 20     NaN        NaN
# 21     NaN        NaN
# 22     NaN        NaN
# 23     NaN        NaN
#
# [204 rows x 18 columns]

# %%
evaluation.sort_values(by=["test_recall"], ascending=False)
# Out:
#              model  alpha fit_prior   class_prior  train_accuracy  \
# 15           Glove    NaN       NaN           NaN        0.195371
# 14           Glove    NaN       NaN           NaN        0.217906
# 13           Glove    NaN       NaN           NaN        0.262070
# 12           Glove    NaN       NaN           NaN        0.336496
# 26  TF-IDF (Multi)   0.50      True  [0.25, 0.75]        0.450359
# ..             ...    ...       ...           ...             ...
# 9        W2V Param    NaN       NaN           NaN        0.817484
# 17       W2V Param    NaN       NaN           NaN        0.816891
# 30  TF-IDF (Multi)   0.75      True           NaN        0.848322
# 36  TF-IDF (Multi)   1.00      True           NaN        0.843961
# 7            Glove    NaN       NaN           NaN        0.818566
#
#     train_recall  train_precision  train_f1  test_accuracy  test_recall  \
# 15      0.999032         0.182817  0.309075       0.193635     0.998642
# 14      0.997870         0.186964  0.314923       0.215448     0.997736
# 13      0.994481         0.195560  0.326847       0.260500     0.994114
# 12      0.981313         0.211225  0.347625       0.333469     0.980756
# 26      0.987994         0.245336  0.393066       0.424792     0.977360
# ..           ...              ...       ...            ...          ...
# 9       0.147463         0.478630  0.225463       0.816905     0.146027
# 17      0.141266         0.472474  0.217501       0.816905     0.141952
# 30      0.186774         0.866577  0.307312       0.833103     0.124293
# 36      0.155403         0.878009  0.264067       0.831719     0.101426
# 7       0.102827         0.483167  0.169567       0.817679     0.098936
#
#     test_precision   test_f1 norm        priors  var_smoothing  vector_size  \
# 15        0.182130  0.308074  NaN  [0.25, 0.75]           1.00          NaN
# 14        0.186146  0.313755  NaN  [0.25, 0.75]           0.75          NaN
# 13        0.194844  0.325826  NaN  [0.25, 0.75]           0.50          NaN
# 12        0.210036  0.345979  NaN  [0.25, 0.75]           0.25          NaN
# 26        0.235246  0.379216  NaN           NaN            NaN          NaN
# ..             ...       ...  ...           ...            ...          ...
# 9         0.470117  0.222836  NaN           NaN            NaN         10.0
# 17        0.469311  0.217973  NaN           NaN            NaN         10.0
# 30        0.702046  0.211194  NaN           NaN            NaN          NaN
# 36        0.729642  0.178096  NaN           NaN            NaN          NaN
# 7         0.466382  0.163242  NaN           NaN           1.00          NaN
#
#     window  min_count
# 15     NaN        NaN
# 14     NaN        NaN
# 13     NaN        NaN
# 12     NaN        NaN
# 26     NaN        NaN
# ..     ...        ...
# 9     10.0        3.0
# 17    35.0        3.0
# 30     NaN        NaN
# 36     NaN        NaN
# 7      NaN        NaN
#
# [204 rows x 18 columns]

# %%
evaluation.sort_values(by=["test_precision"], ascending=False)
# Out:
#              model         alpha fit_prior class_prior  train_accuracy  \
# 36  TF-IDF (Multi)  1.000000e+00      True         NaN        0.843961
# 30  TF-IDF (Multi)  7.500000e-01      True         NaN        0.848322
# 24  TF-IDF (Multi)  5.000000e-01      True         NaN        0.853328
# 18  TF-IDF (Multi)  2.500000e-01      True         NaN        0.859921
# 12  TF-IDF (Multi)  1.000000e-01      True         NaN        0.863706
# ..             ...           ...       ...         ...             ...
# 12           Glove           NaN       NaN         NaN        0.336496
# 0    TF-IDF (Comp)  1.000000e-10       NaN         NaN        0.305693
# 13           Glove           NaN       NaN         NaN        0.262070
# 14           Glove           NaN       NaN         NaN        0.217906
# 15           Glove           NaN       NaN         NaN        0.195371
#
#     train_recall  train_precision  train_f1  test_accuracy  test_recall  \
# 36      0.155403         0.878009  0.264067       0.831719     0.101426
# 30      0.186774         0.866577  0.307312       0.833103     0.124293
# 24      0.224923         0.851852  0.355879       0.834527     0.149649
# 18      0.274787         0.839893  0.414095       0.836196     0.182024
# 12      0.306061         0.830095  0.447227       0.835382     0.196513
# ..           ...              ...       ...            ...          ...
# 12      0.981313         0.211225  0.347625       0.333469     0.980756
# 0       1.000000         0.206008  0.341636       0.296435     0.966493
# 13      0.994481         0.195560  0.326847       0.260500     0.994114
# 14      0.997870         0.186964  0.314923       0.215448     0.997736
# 15      0.999032         0.182817  0.309075       0.193635     0.998642
#
#     test_precision   test_f1  norm        priors  var_smoothing  vector_size  \
# 36        0.729642  0.178096   NaN           NaN            NaN          NaN
# 30        0.702046  0.211194   NaN           NaN            NaN          NaN
# 24        0.680742  0.245360   NaN           NaN            NaN          NaN
# 18        0.661184  0.285461   NaN           NaN            NaN          NaN
# 12        0.636364  0.300294   NaN           NaN            NaN          NaN
# ..             ...       ...   ...           ...            ...          ...
# 12        0.210036  0.345979   NaN  [0.25, 0.75]           0.25          NaN
# 0         0.199402  0.330597  True           NaN            NaN          NaN
# 13        0.194844  0.325826   NaN  [0.25, 0.75]           0.50          NaN
# 14        0.186146  0.313755   NaN  [0.25, 0.75]           0.75          NaN
# 15        0.182130  0.308074   NaN  [0.25, 0.75]           1.00          NaN
#
#     window  min_count
# 36     NaN        NaN
# 30     NaN        NaN
# 24     NaN        NaN
# 18     NaN        NaN
# 12     NaN        NaN
# ..     ...        ...
# 12     NaN        NaN
# 0      NaN        NaN
# 13     NaN        NaN
# 14     NaN        NaN
# 15     NaN        NaN
#
# [204 rows x 18 columns]

# %%
evaluation.sort_values(by=["test_f1"], ascending=False)
# Out:
#              model  alpha fit_prior class_prior  train_accuracy  train_recall  \
# 8    TF-IDF (Comp)   0.50       NaN         NaN        0.842095      0.684353
# 9    TF-IDF (Comp)   0.50       NaN         NaN        0.778396      0.834334
# 29  TF-IDF (Multi)   0.50     False  [0.5, 0.5]        0.778396      0.834334
# 28  TF-IDF (Multi)   0.50      True  [0.5, 0.5]        0.778396      0.834334
# 25  TF-IDF (Multi)   0.50     False         NaN        0.778396      0.834334
# ..             ...    ...       ...         ...             ...           ...
# 9        W2V Param    NaN       NaN         NaN        0.817484      0.147463
# 17       W2V Param    NaN       NaN         NaN        0.816891      0.141266
# 30  TF-IDF (Multi)   0.75      True         NaN        0.848322      0.186774
# 36  TF-IDF (Multi)   1.00      True         NaN        0.843961      0.155403
# 7            Glove    NaN       NaN         NaN        0.818566      0.102827
#
#     train_precision  train_f1  test_accuracy  test_recall  test_precision  \
# 8          0.549568  0.609599       0.796191     0.575957        0.447966
# 9          0.439396  0.575637       0.728309     0.747113        0.372503
# 29         0.439396  0.575637       0.728309     0.747113        0.372503
# 28         0.439396  0.575637       0.728309     0.747113        0.372503
# 25         0.439396  0.575637       0.728309     0.747113        0.372503
# ..              ...       ...            ...          ...             ...
# 9          0.478630  0.225463       0.816905     0.146027        0.470117
# 17         0.472474  0.217501       0.816905     0.141952        0.469311
# 30         0.866577  0.307312       0.833103     0.124293        0.702046
# 36         0.878009  0.264067       0.831719     0.101426        0.729642
# 7          0.483167  0.169567       0.817679     0.098936        0.466382
#
#      test_f1   norm priors  var_smoothing  vector_size  window  min_count
# 8   0.503962   True    NaN            NaN          NaN     NaN        NaN
# 9   0.497138  False    NaN            NaN          NaN     NaN        NaN
# 29  0.497138    NaN    NaN            NaN          NaN     NaN        NaN
# 28  0.497138    NaN    NaN            NaN          NaN     NaN        NaN
# 25  0.497138    NaN    NaN            NaN          NaN     NaN        NaN
# ..       ...    ...    ...            ...          ...     ...        ...
# 9   0.222836    NaN    NaN            NaN         10.0    10.0        3.0
# 17  0.217973    NaN    NaN            NaN         10.0    35.0        3.0
# 30  0.211194    NaN    NaN            NaN          NaN     NaN        NaN
# 36  0.178096    NaN    NaN            NaN          NaN     NaN        NaN
# 7   0.163242    NaN    NaN            1.0          NaN     NaN        NaN
#
# [204 rows x 18 columns]

# %% [markdown]
# ### Visualisierung F1-Score

# %%
fig, ax = plt.subplots(figsize=(20, 7))
plt.xticks(rotation=30)
sns.barplot(data=evaluation, y=evaluation.test_f1, x=evaluation.model, label="Test F1-Score")
# Out:
# <Axes: xlabel='model', ylabel='test_f1'>

# %% [markdown]
# Topwerte ähnlich zu erstem Datensatz, W2V und Glove deutlich besser

# %% [markdown]
# ### Unterschiede/Schwankungen zw. Train <-> Test F1-Scores

# %%
fig, ax = plt.subplots(figsize=(20, 7))
plt.xticks(rotation=30)

diff = evaluation['train_f1'] - evaluation['test_f1']
sns.scatterplot(data=evaluation, y=evaluation['train_f1'], x=evaluation.model, ax=ax, label="Train F1-Score")
sns.scatterplot(data=evaluation, y=evaluation['test_f1'], x=evaluation.model, ax=ax, label="Test F1-Score")
sns.lineplot(data=evaluation, y=diff, x=evaluation.model, label="Differenz Train-Test")

plt.show()

# %% [markdown]
# ### Vergleich Accuracy - F1-Score

# %%
fig, ax = plt.subplots(figsize=(20, 7))
plt.xticks(rotation=30)
sns.barplot(data=evaluation, y=evaluation.test_f1, x=evaluation.model, label="F1-Score")
sns.lineplot(data=evaluation, y=evaluation.test_accuracy, x=evaluation.model, label="Accuracy")
# Out:
# <Axes: xlabel='model', ylabel='test_f1'>

# %% [markdown]
# Accuracy schlechter als im ersten Datensatz

# %% [markdown]
# ### Vergleich Precision - Recall

# %%
fig, ax = plt.subplots(figsize=(20, 7))
plt.xticks(rotation=30)
a = sns.lineplot(data=evaluation, y=evaluation.test_precision, x=evaluation.model, label="Precision")
b = sns.lineplot(data=evaluation, y=evaluation.test_recall, x=evaluation.model, label="Recall")

# %% [markdown]
# Recall hier stärker Modell abhängig, bei W2V ähnlich bei W2V Param deutlich schlechter

# %% [markdown]
# #### Auswertung

# %% [markdown]
# ### Analyse W2V Parameter

# %%
w2v_param.sort_values(by=["test_recall"], ascending=False)
# Out:
#         model  vector_size  window  min_count  train_accuracy  train_recall  \
# 85  W2V Param          300       5          3        0.645922      0.748451
# 83  W2V Param          300       3         10        0.627363      0.758617
# 86  W2V Param          300       5          5        0.638579      0.747676
# 87  W2V Param          300       5         10        0.630259      0.753195
# 84  W2V Param          300       5          1        0.647509      0.750000
# ..        ...          ...     ...        ...             ...           ...
# 19  W2V Param           10      35         10        0.816455      0.175542
# 1   W2V Param           10       3          3        0.813176      0.158404
# 13  W2V Param           10      20          3        0.812583      0.161406
# 9   W2V Param           10      10          3        0.817484      0.147463
# 17  W2V Param           10      35          3        0.816891      0.141266
#
#     train_precision  train_f1  test_accuracy  test_recall  test_precision  \
# 85         0.303948  0.432327       0.635398     0.756849        0.297738
# 83         0.293380  0.423125       0.615782     0.756849        0.285482
# 86         0.298874  0.427043       0.626974     0.752094        0.291583
# 87         0.294347  0.423278       0.618509     0.750962        0.286170
# 84         0.305285  0.433937       0.634950     0.750509        0.296432
# ..              ...       ...            ...          ...             ...
# 19         0.474483  0.256273       0.816539     0.174100        0.472069
# 1          0.447606  0.233998       0.814708     0.163007        0.456853
# 13         0.444415  0.236807       0.809946     0.155535        0.422250
# 9          0.478630  0.225463       0.816905     0.146027        0.470117
# 17         0.472474  0.217501       0.816905     0.141952        0.469311
#
#      test_f1
# 85  0.427357
# 83  0.414584
# 86  0.420240
# 87  0.414418
# 84  0.425000
# ..       ...
# 19  0.254383
# 1   0.240280
# 13  0.227333
# 9   0.222836
# 17  0.217973
#
# [100 rows x 12 columns]

# %%
w2v_param.sort_values(by=["test_f1"], ascending=False)
# Out:
#         model  vector_size  window  min_count  train_accuracy  train_recall  \
# 96  W2V Param          300      35          1        0.701319      0.686193
# 76  W2V Param          200      35          1        0.715900      0.655306
# 57  W2V Param          100      35          3        0.737407      0.584527
# 77  W2V Param          200      35          3        0.708871      0.662277
# 92  W2V Param          300      20          1        0.687888      0.704396
# ..        ...          ...     ...        ...             ...           ...
# 19  W2V Param           10      35         10        0.816455      0.175542
# 1   W2V Param           10       3          3        0.813176      0.158404
# 13  W2V Param           10      20          3        0.812583      0.161406
# 9   W2V Param           10      10          3        0.817484      0.147463
# 17  W2V Param           10      35          3        0.816891      0.141266
#
#     train_precision  train_f1  test_accuracy  test_recall  test_precision  \
# 96         0.337959  0.452872       0.693961     0.691872        0.331633
# 76         0.347148  0.453863       0.709629     0.655875        0.340343
# 57         0.359324  0.445059       0.735227     0.593842        0.357601
# 77         0.341266  0.450430       0.702263     0.665384        0.334852
# 92         0.328947  0.448465       0.678577     0.717682        0.322778
# ..              ...       ...            ...          ...             ...
# 19         0.474483  0.256273       0.816539     0.174100        0.472069
# 1          0.447606  0.233998       0.814708     0.163007        0.456853
# 13         0.444415  0.236807       0.809946     0.155535        0.422250
# 9          0.478630  0.225463       0.816905     0.146027        0.470117
# 17         0.472474  0.217501       0.816905     0.141952        0.469311
#
#      test_f1
# 96  0.448357
# 76  0.448140
# 57  0.446392
# 77  0.445506
# 92  0.445287
# ..       ...
# 19  0.254383
# 1   0.240280
# 13  0.227333
# 9   0.222836
# 17  0.217973
#
# [100 rows x 12 columns]

# %%
w2v_param.sort_values(by=["test_precision"], ascending=False)
# Out:
#         model  vector_size  window  min_count  train_accuracy  train_recall  \
# 11  W2V Param           10      10         10        0.817868      0.175833
# 10  W2V Param           10      10          5        0.814362      0.211658
# 7   W2V Param           10       5         10        0.818147      0.188710
# 2   W2V Param           10       3          5        0.813263      0.225988
# 19  W2V Param           10      35         10        0.816455      0.175542
# ..        ...          ...     ...        ...             ...           ...
# 82  W2V Param          300       3          5        0.635840      0.745740
# 67  W2V Param          200       5         10        0.637724      0.737510
# 63  W2V Param          200       3         10        0.635649      0.743610
# 87  W2V Param          300       5         10        0.630259      0.753195
# 83  W2V Param          300       3         10        0.627363      0.758617
#
#     train_precision  train_f1  test_accuracy  test_recall  test_precision  \
# 11         0.484784  0.258065       0.817557     0.175685        0.479604
# 10         0.466396  0.291175       0.816621     0.214625        0.477582
# 7          0.487738  0.272131       0.817068     0.184514        0.477166
# 2          0.462545  0.303630       0.815807     0.231605        0.474710
# 19         0.474483  0.256273       0.816539     0.174100        0.472069
# ..              ...       ...            ...          ...             ...
# 82         0.296756  0.424563       0.625549     0.745302        0.289585
# 67         0.296658  0.423120       0.625265     0.736020        0.287877
# 63         0.296285  0.423736       0.622701     0.738963        0.286769
# 87         0.294347  0.423278       0.618509     0.750962        0.286170
# 83         0.293380  0.423125       0.615782     0.756849        0.285482
#
#      test_f1
# 11  0.257167
# 10  0.296157
# 7   0.266122
# 2   0.311321
# 19  0.254383
# ..       ...
# 82  0.417105
# 67  0.413877
# 63  0.413191
# 87  0.414418
# 83  0.414584
#
# [100 rows x 12 columns]

# %% [markdown]
# #### Auswertung

# %% [markdown]
# Bezogen auf NB(!):
# - Precision besser
# - F1 ähnlich
# - Recall schlechter
# (Vergleich ersten Datensatz)
