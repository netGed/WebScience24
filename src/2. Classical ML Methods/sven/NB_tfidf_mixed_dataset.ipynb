# %%
from sklearn.naive_bayes import MultinomialNB # ideal für counting features wie bow oder tfidf https://towardsdatascience.com/why-how-to-use-the-naive-bayes-algorithms-in-a-regulated-industry-with-sklearn-python-code-dbd8304ab2cf
from sklearn.naive_bayes import GaussianNB # für Features in Decimal Form geeignet
from sklearn.naive_bayes import ComplementNB # ähnlich wie Multinomial, soll sich aber besser für imbalanced data eignen
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    ConfusionMatrixDisplay,
    f1_score,
    recall_score,
    precision_score,
    classification_report,
)
import pandas as pd
from sklearn.model_selection import GridSearchCV, train_test_split, cross_val_score
import pickle
import joblib

# %%
def evaluate(y_test,y_pred):
    accuracy = accuracy_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    print("Accuracy:", accuracy)
    print("F1 Score:", f1)
    print("Recall:", recall)
    print("Precision:", precision)
    print("\n")
    print("Confusion Matrix")
    print(pd.DataFrame(confusion_matrix(y_test, y_pred)))
    print("\n")
    print("Classification Report")
    print(classification_report(y_test, y_pred))

# %% [markdown]
# ## Daten Einladen und TFIDF Vektorisierung

# %%
# %run ../../functions/vectorize_functions.py

# %%
filepath_name = (('../../../data/mixed_dataset/train_cleaned.csv'))
df_cleaned = pd.read_csv(filepath_name, encoding='utf-8')

# %%
X_train_tfidf, X_test_tfidf, y_train_tfidf, y_test_tfidf, vectorizer_tfidf = vectorize_tfidf(df=df_cleaned, text_column='tweet_cleaned', 
                                                                                 label_column="label")

# %%
print(X_train_tfidf.shape)
print(X_test_tfidf.shape)
print(y_train_tfidf.shape)
print(y_test_tfidf.shape)
print(type(X_train_tfidf))
# Out:
# (57332, 13198)
# (24572, 13198)
# (57332,)
# (24572,)
# <class 'scipy.sparse._csr.csr_matrix'>

# %%
# save vectorizer

#with open('saved_models/vectorizer/vectorizer_nb_tfidf.pkl','wb') as f:
 #   pickle.dump(vectorizer_tfidf, f)

joblib.dump(vectorizer_tfidf, 'saved_models/vectorizer/vectorizer_tfidf.joblib')
# Out:
# ['saved_models/vectorizer/vectorizer_tfidf.joblib']

# %% [markdown]
# ## Multinomial NB

# %%
clf_tfidf = MultinomialNB()
clf_tfidf.fit(X_train_tfidf,y_train_tfidf)
y_pred_tfidf = clf_tfidf.predict(X_test_tfidf)

# %%
evaluate(y_test_tfidf, y_pred_tfidf)
# Out:
# Accuracy: 0.8317190297900049
# F1 Score: 0.17809580600278274
# Recall: 0.10142630744849446
# Precision: 0.7296416938110749
#
#
# Confusion Matrix
#        0    1
# 0  19989  166
# 1   3969  448
#
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.83      0.99      0.91     20155
#            1       0.73      0.10      0.18      4417
#
#     accuracy                           0.83     24572
#    macro avg       0.78      0.55      0.54     24572
# weighted avg       0.82      0.83      0.78     24572

# %%
# Model speichern
#with open('saved_models/model_nb_tfidf_mn.pkl','wb') as f:
 #   pickle.dump(clf_tfidf,f)
joblib.dump(clf_tfidf, 'saved_models/tfidf_mn/model_tfidf_nm.joblib')
# Out:
# ['saved_models/tfidf_mn/model_tfidf_nmjoblib']

# %%
results_list = []

param_grid = {
    'alpha' : [1.0e-10, 0.01, 0.1, 0.25, 0.5, 0.75, 1],
    'fit_prior' : [True, False],
    'class_prior' : [None, [.25,.75], [.5,.5]]
}

nb = MultinomialNB()

grid_search = GridSearchCV(estimator=nb, param_grid=param_grid, scoring='f1', cv=3, verbose=2, n_jobs=-1)

grid_search.fit(X_train_tfidf, y_train_tfidf)

for idx, params in enumerate(grid_search.cv_results_['params']):
    model = MultinomialNB(**params)  
    model.fit(X_train_tfidf, y_train_tfidf)  

    y_train_pred_tfidf = model.predict(X_train_tfidf)

    y_test_pred_tfidf = model.predict(X_test_tfidf)

    train_accuracy = accuracy_score(y_train_tfidf, y_train_pred_tfidf)
    train_recall = recall_score(y_train_tfidf, y_train_pred_tfidf)
    train_precision = precision_score(y_train_tfidf, y_train_pred_tfidf)
    train_f1 = f1_score(y_train_tfidf, y_train_pred_tfidf)

    test_accuracy = accuracy_score(y_test_tfidf, y_test_pred_tfidf)
    test_recall = recall_score(y_test_tfidf, y_test_pred_tfidf)
    test_precision = precision_score(y_test_tfidf, y_test_pred_tfidf)
    test_f1 = f1_score(y_test_tfidf, y_test_pred_tfidf)

    test_report = classification_report(y_test_tfidf, y_test_pred_tfidf, output_dict=True)

    result_dict = {
        'model': 'TF-IDF (Multi)',
        'alpha': params['alpha'],
        'fit_prior': params['fit_prior'],
        'class_prior': params['class_prior'],
        'train_accuracy': train_accuracy,
        'train_recall': train_recall,
        'train_precision': train_precision,
        'train_f1': train_f1,
        'test_accuracy': test_accuracy,
        'test_recall': test_recall,
        'test_precision': test_precision,
        'test_f1': test_f1,
        'test_recall_1': test_report['1']['recall'],
    }

    results_list.append(result_dict)

    filename = f'saved_models/tfidf_mn/model_tfidf_comp_{idx}.joblib'
    #with open(filename,'wb') as file:
     #   pickle.dump(model,file)
    joblib.dump(model, filename)



results_df = pd.DataFrame(results_list)

results_df.to_csv('eval_data/nb_grid_tfidf_mixed_dataset.csv', index=False)

print(results_df)
# Out:
# Fitting 3 folds for each of 42 candidates, totalling 126 fits
#              model         alpha  fit_prior   class_prior  train_accuracy  \
# 0   TF-IDF (Multi)  1.000000e-10       True          None        0.867526
# 1   TF-IDF (Multi)  1.000000e-10      False          None        0.783629
# 2   TF-IDF (Multi)  1.000000e-10       True  [0.25, 0.75]        0.593787
# 3   TF-IDF (Multi)  1.000000e-10      False  [0.25, 0.75]        0.593787
# 4   TF-IDF (Multi)  1.000000e-10       True    [0.5, 0.5]        0.783629
# 5   TF-IDF (Multi)  1.000000e-10      False    [0.5, 0.5]        0.783629
# 6   TF-IDF (Multi)  1.000000e-02       True          None        0.866846
# 7   TF-IDF (Multi)  1.000000e-02      False          None        0.780594
# 8   TF-IDF (Multi)  1.000000e-02       True  [0.25, 0.75]        0.571688
# 9   TF-IDF (Multi)  1.000000e-02      False  [0.25, 0.75]        0.571688
# 10  TF-IDF (Multi)  1.000000e-02       True    [0.5, 0.5]        0.780594
# 11  TF-IDF (Multi)  1.000000e-02      False    [0.5, 0.5]        0.780594
# 12  TF-IDF (Multi)  1.000000e-01       True          None        0.863706
# 13  TF-IDF (Multi)  1.000000e-01      False          None        0.774454
# 14  TF-IDF (Multi)  1.000000e-01       True  [0.25, 0.75]        0.516919
# 15  TF-IDF (Multi)  1.000000e-01      False  [0.25, 0.75]        0.516919
# 16  TF-IDF (Multi)  1.000000e-01       True    [0.5, 0.5]        0.774454
# 17  TF-IDF (Multi)  1.000000e-01      False    [0.5, 0.5]        0.774454
# 18  TF-IDF (Multi)  2.500000e-01       True          None        0.859921
# 19  TF-IDF (Multi)  2.500000e-01      False          None        0.773512
# 20  TF-IDF (Multi)  2.500000e-01       True  [0.25, 0.75]        0.477970
# 21  TF-IDF (Multi)  2.500000e-01      False  [0.25, 0.75]        0.477970
# 22  TF-IDF (Multi)  2.500000e-01       True    [0.5, 0.5]        0.773512
# 23  TF-IDF (Multi)  2.500000e-01      False    [0.5, 0.5]        0.773512
# 24  TF-IDF (Multi)  5.000000e-01       True          None        0.853328
# 25  TF-IDF (Multi)  5.000000e-01      False          None        0.778396
# 26  TF-IDF (Multi)  5.000000e-01       True  [0.25, 0.75]        0.450359
# 27  TF-IDF (Multi)  5.000000e-01      False  [0.25, 0.75]        0.450359
# 28  TF-IDF (Multi)  5.000000e-01       True    [0.5, 0.5]        0.778396
# 29  TF-IDF (Multi)  5.000000e-01      False    [0.5, 0.5]        0.778396
# 30  TF-IDF (Multi)  7.500000e-01       True          None        0.848322
# 31  TF-IDF (Multi)  7.500000e-01      False          None        0.785164
# 32  TF-IDF (Multi)  7.500000e-01       True  [0.25, 0.75]        0.444098
# 33  TF-IDF (Multi)  7.500000e-01      False  [0.25, 0.75]        0.444098
# 34  TF-IDF (Multi)  7.500000e-01       True    [0.5, 0.5]        0.785164
# 35  TF-IDF (Multi)  7.500000e-01      False    [0.5, 0.5]        0.785164
# 36  TF-IDF (Multi)  1.000000e+00       True          None        0.843961
# 37  TF-IDF (Multi)  1.000000e+00      False          None        0.791914
# 38  TF-IDF (Multi)  1.000000e+00       True  [0.25, 0.75]        0.445284
# 39  TF-IDF (Multi)  1.000000e+00      False  [0.25, 0.75]        0.445284
# 40  TF-IDF (Multi)  1.000000e+00       True    [0.5, 0.5]        0.791914
# 41  TF-IDF (Multi)  1.000000e+00      False    [0.5, 0.5]        0.791914
#
#     train_recall  train_precision  train_f1  test_accuracy  test_recall  \
# 0       0.331526         0.832078  0.474140       0.832574     0.203532
# 1       0.886909         0.449086  0.596257       0.725094     0.673308
# 2       0.991673         0.306234  0.467960       0.545051     0.786280
# 3       0.991673         0.306234  0.467960       0.545051     0.786280
# 4       0.886909         0.449086  0.596257       0.725094     0.673308
# 5       0.886909         0.449086  0.596257       0.725094     0.673308
# 6       0.327653         0.830633  0.469935       0.833469     0.202626
# 7       0.886232         0.445250  0.592715       0.726884     0.700249
# 8       0.992060         0.295104  0.454893       0.533371     0.877066
# 9       0.992060         0.295104  0.454893       0.533371     0.877066
# 10      0.886232         0.445250  0.592715       0.726884     0.700249
# 11      0.886232         0.445250  0.592715       0.726884     0.700249
# 12      0.306061         0.830095  0.447227       0.835382     0.196513
# 13      0.879454         0.437334  0.584172       0.725623     0.750509
# 14      0.991867         0.270604  0.425203       0.481564     0.947023
# 15      0.991867         0.270604  0.425203       0.481564     0.947023
# 16      0.879454         0.437334  0.584172       0.725623     0.750509
# 17      0.879454         0.437334  0.584172       0.725623     0.750509
# 18      0.274787         0.839893  0.414095       0.836196     0.182024
# 19      0.865511         0.435306  0.579270       0.722692     0.759565
# 20      0.990608         0.255373  0.406065       0.447949     0.970342
# 21      0.990608         0.255373  0.406065       0.447949     0.970342
# 22      0.865511         0.435306  0.579270       0.722692     0.759565
# 23      0.865511         0.435306  0.579270       0.722692     0.759565
# 24      0.224923         0.851852  0.355879       0.834527     0.149649
# 25      0.834334         0.439396  0.575637       0.728309     0.747113
# 26      0.987994         0.245336  0.393066       0.424792     0.977360
# 27      0.987994         0.245336  0.393066       0.424792     0.977360
# 28      0.834334         0.439396  0.575637       0.728309     0.747113
# 29      0.834334         0.439396  0.575637       0.728309     0.747113
# 30      0.186774         0.866577  0.307312       0.833103     0.124293
# 31      0.801123         0.446351  0.573289       0.735878     0.717908
# 32      0.983830         0.242709  0.389363       0.418566     0.975549
# 33      0.983830         0.242709  0.389363       0.418566     0.975549
# 34      0.801123         0.446351  0.573289       0.735878     0.717908
# 35      0.801123         0.446351  0.573289       0.735878     0.717908
# 36      0.155403         0.878009  0.264067       0.831719     0.101426
# 37      0.762006         0.453812  0.568847       0.745116     0.683496
# 38      0.980345         0.242660  0.389027       0.419624     0.969210
# 39      0.980345         0.242660  0.389027       0.419624     0.969210
# 40      0.762006         0.453812  0.568847       0.745116     0.683496
# 41      0.762006         0.453812  0.568847       0.745116     0.683496
#
#     test_precision   test_f1  test_recall_1
# 0         0.601338  0.304127       0.203532
# 1         0.358919  0.468236       0.673308
# 2         0.253356  0.383228       0.786280
# 3         0.253356  0.383228       0.786280
# 4         0.358919  0.468236       0.673308
# 5         0.358919  0.468236       0.673308
# 6         0.610922  0.304318       0.202626
# 7         0.364741  0.479646       0.700249
# 8         0.261810  0.403248       0.877066
# 9         0.261810  0.403248       0.877066
# 10        0.364741  0.479646       0.700249
# 11        0.364741  0.479646       0.700249
# 12        0.636364  0.300294       0.196513
# 13        0.370184  0.495812       0.750509
# 14        0.250659  0.396399       0.947023
# 15        0.250659  0.396399       0.947023
# 16        0.370184  0.495812       0.750509
# 17        0.370184  0.495812       0.750509
# 18        0.661184  0.285461       0.182024
# 19        0.368398  0.496155       0.759565
# 20        0.241874  0.387225       0.970342
# 21        0.241874  0.387225       0.970342
# 22        0.368398  0.496155       0.759565
# 23        0.368398  0.496155       0.759565
# 24        0.680742  0.245360       0.149649
# 25        0.372503  0.497138       0.747113
# 26        0.235246  0.379216       0.977360
# 27        0.235246  0.379216       0.977360
# 28        0.372503  0.497138       0.747113
# 29        0.372503  0.497138       0.747113
# 30        0.702046  0.211194       0.124293
# 31        0.376827  0.494233       0.717908
# 32        0.233070  0.376250       0.975549
# 33        0.233070  0.376250       0.975549
# 34        0.376827  0.494233       0.717908
# 35        0.376827  0.494233       0.717908
# 36        0.729642  0.178096       0.101426
# 37        0.382927  0.490854       0.683496
# 38        0.232587  0.375148       0.969210
# 39        0.232587  0.375148       0.969210
# 40        0.382927  0.490854       0.683496
# 41        0.382927  0.490854       0.683496

# %%
results_df.sort_values(by=['test_f1'],ascending=False)
# Out:
#              model         alpha  fit_prior   class_prior  train_accuracy  \
# 28  TF-IDF (Multi)  5.000000e-01       True    [0.5, 0.5]        0.778396
# 25  TF-IDF (Multi)  5.000000e-01      False          None        0.778396
# 29  TF-IDF (Multi)  5.000000e-01      False    [0.5, 0.5]        0.778396
# 23  TF-IDF (Multi)  2.500000e-01      False    [0.5, 0.5]        0.773512
# 22  TF-IDF (Multi)  2.500000e-01       True    [0.5, 0.5]        0.773512
# 19  TF-IDF (Multi)  2.500000e-01      False          None        0.773512
# 17  TF-IDF (Multi)  1.000000e-01      False    [0.5, 0.5]        0.774454
# 16  TF-IDF (Multi)  1.000000e-01       True    [0.5, 0.5]        0.774454
# 13  TF-IDF (Multi)  1.000000e-01      False          None        0.774454
# 31  TF-IDF (Multi)  7.500000e-01      False          None        0.785164
# 34  TF-IDF (Multi)  7.500000e-01       True    [0.5, 0.5]        0.785164
# 35  TF-IDF (Multi)  7.500000e-01      False    [0.5, 0.5]        0.785164
# 37  TF-IDF (Multi)  1.000000e+00      False          None        0.791914
# 40  TF-IDF (Multi)  1.000000e+00       True    [0.5, 0.5]        0.791914
# 41  TF-IDF (Multi)  1.000000e+00      False    [0.5, 0.5]        0.791914
# 11  TF-IDF (Multi)  1.000000e-02      False    [0.5, 0.5]        0.780594
# 10  TF-IDF (Multi)  1.000000e-02       True    [0.5, 0.5]        0.780594
# 7   TF-IDF (Multi)  1.000000e-02      False          None        0.780594
# 5   TF-IDF (Multi)  1.000000e-10      False    [0.5, 0.5]        0.783629
# 4   TF-IDF (Multi)  1.000000e-10       True    [0.5, 0.5]        0.783629
# 1   TF-IDF (Multi)  1.000000e-10      False          None        0.783629
# 9   TF-IDF (Multi)  1.000000e-02      False  [0.25, 0.75]        0.571688
# 8   TF-IDF (Multi)  1.000000e-02       True  [0.25, 0.75]        0.571688
# 14  TF-IDF (Multi)  1.000000e-01       True  [0.25, 0.75]        0.516919
# 15  TF-IDF (Multi)  1.000000e-01      False  [0.25, 0.75]        0.516919
# 21  TF-IDF (Multi)  2.500000e-01      False  [0.25, 0.75]        0.477970
# 20  TF-IDF (Multi)  2.500000e-01       True  [0.25, 0.75]        0.477970
# 3   TF-IDF (Multi)  1.000000e-10      False  [0.25, 0.75]        0.593787
# 2   TF-IDF (Multi)  1.000000e-10       True  [0.25, 0.75]        0.593787
# 26  TF-IDF (Multi)  5.000000e-01       True  [0.25, 0.75]        0.450359
# 27  TF-IDF (Multi)  5.000000e-01      False  [0.25, 0.75]        0.450359
# 32  TF-IDF (Multi)  7.500000e-01       True  [0.25, 0.75]        0.444098
# 33  TF-IDF (Multi)  7.500000e-01      False  [0.25, 0.75]        0.444098
# 38  TF-IDF (Multi)  1.000000e+00       True  [0.25, 0.75]        0.445284
# 39  TF-IDF (Multi)  1.000000e+00      False  [0.25, 0.75]        0.445284
# 6   TF-IDF (Multi)  1.000000e-02       True          None        0.866846
# 0   TF-IDF (Multi)  1.000000e-10       True          None        0.867526
# 12  TF-IDF (Multi)  1.000000e-01       True          None        0.863706
# 18  TF-IDF (Multi)  2.500000e-01       True          None        0.859921
# 24  TF-IDF (Multi)  5.000000e-01       True          None        0.853328
# 30  TF-IDF (Multi)  7.500000e-01       True          None        0.848322
# 36  TF-IDF (Multi)  1.000000e+00       True          None        0.843961
#
#     train_recall  train_precision  train_f1  test_accuracy  test_recall  \
# 28      0.834334         0.439396  0.575637       0.728309     0.747113
# 25      0.834334         0.439396  0.575637       0.728309     0.747113
# 29      0.834334         0.439396  0.575637       0.728309     0.747113
# 23      0.865511         0.435306  0.579270       0.722692     0.759565
# 22      0.865511         0.435306  0.579270       0.722692     0.759565
# 19      0.865511         0.435306  0.579270       0.722692     0.759565
# 17      0.879454         0.437334  0.584172       0.725623     0.750509
# 16      0.879454         0.437334  0.584172       0.725623     0.750509
# 13      0.879454         0.437334  0.584172       0.725623     0.750509
# 31      0.801123         0.446351  0.573289       0.735878     0.717908
# 34      0.801123         0.446351  0.573289       0.735878     0.717908
# 35      0.801123         0.446351  0.573289       0.735878     0.717908
# 37      0.762006         0.453812  0.568847       0.745116     0.683496
# 40      0.762006         0.453812  0.568847       0.745116     0.683496
# 41      0.762006         0.453812  0.568847       0.745116     0.683496
# 11      0.886232         0.445250  0.592715       0.726884     0.700249
# 10      0.886232         0.445250  0.592715       0.726884     0.700249
# 7       0.886232         0.445250  0.592715       0.726884     0.700249
# 5       0.886909         0.449086  0.596257       0.725094     0.673308
# 4       0.886909         0.449086  0.596257       0.725094     0.673308
# 1       0.886909         0.449086  0.596257       0.725094     0.673308
# 9       0.992060         0.295104  0.454893       0.533371     0.877066
# 8       0.992060         0.295104  0.454893       0.533371     0.877066
# 14      0.991867         0.270604  0.425203       0.481564     0.947023
# 15      0.991867         0.270604  0.425203       0.481564     0.947023
# 21      0.990608         0.255373  0.406065       0.447949     0.970342
# 20      0.990608         0.255373  0.406065       0.447949     0.970342
# 3       0.991673         0.306234  0.467960       0.545051     0.786280
# 2       0.991673         0.306234  0.467960       0.545051     0.786280
# 26      0.987994         0.245336  0.393066       0.424792     0.977360
# 27      0.987994         0.245336  0.393066       0.424792     0.977360
# 32      0.983830         0.242709  0.389363       0.418566     0.975549
# 33      0.983830         0.242709  0.389363       0.418566     0.975549
# 38      0.980345         0.242660  0.389027       0.419624     0.969210
# 39      0.980345         0.242660  0.389027       0.419624     0.969210
# 6       0.327653         0.830633  0.469935       0.833469     0.202626
# 0       0.331526         0.832078  0.474140       0.832574     0.203532
# 12      0.306061         0.830095  0.447227       0.835382     0.196513
# 18      0.274787         0.839893  0.414095       0.836196     0.182024
# 24      0.224923         0.851852  0.355879       0.834527     0.149649
# 30      0.186774         0.866577  0.307312       0.833103     0.124293
# 36      0.155403         0.878009  0.264067       0.831719     0.101426
#
#     test_precision   test_f1  test_recall_1
# 28        0.372503  0.497138       0.747113
# 25        0.372503  0.497138       0.747113
# 29        0.372503  0.497138       0.747113
# 23        0.368398  0.496155       0.759565
# 22        0.368398  0.496155       0.759565
# 19        0.368398  0.496155       0.759565
# 17        0.370184  0.495812       0.750509
# 16        0.370184  0.495812       0.750509
# 13        0.370184  0.495812       0.750509
# 31        0.376827  0.494233       0.717908
# 34        0.376827  0.494233       0.717908
# 35        0.376827  0.494233       0.717908
# 37        0.382927  0.490854       0.683496
# 40        0.382927  0.490854       0.683496
# 41        0.382927  0.490854       0.683496
# 11        0.364741  0.479646       0.700249
# 10        0.364741  0.479646       0.700249
# 7         0.364741  0.479646       0.700249
# 5         0.358919  0.468236       0.673308
# 4         0.358919  0.468236       0.673308
# 1         0.358919  0.468236       0.673308
# 9         0.261810  0.403248       0.877066
# 8         0.261810  0.403248       0.877066
# 14        0.250659  0.396399       0.947023
# 15        0.250659  0.396399       0.947023
# 21        0.241874  0.387225       0.970342
# 20        0.241874  0.387225       0.970342
# 3         0.253356  0.383228       0.786280
# 2         0.253356  0.383228       0.786280
# 26        0.235246  0.379216       0.977360
# 27        0.235246  0.379216       0.977360
# 32        0.233070  0.376250       0.975549
# 33        0.233070  0.376250       0.975549
# 38        0.232587  0.375148       0.969210
# 39        0.232587  0.375148       0.969210
# 6         0.610922  0.304318       0.202626
# 0         0.601338  0.304127       0.203532
# 12        0.636364  0.300294       0.196513
# 18        0.661184  0.285461       0.182024
# 24        0.680742  0.245360       0.149649
# 30        0.702046  0.211194       0.124293
# 36        0.729642  0.178096       0.101426

# %%
results_df.sort_values(by=['test_recall_1'],ascending=False)
# Out:
#              model         alpha  fit_prior   class_prior  train_accuracy  \
# 27  TF-IDF (Multi)  5.000000e-01      False  [0.25, 0.75]        0.450359
# 26  TF-IDF (Multi)  5.000000e-01       True  [0.25, 0.75]        0.450359
# 32  TF-IDF (Multi)  7.500000e-01       True  [0.25, 0.75]        0.444098
# 33  TF-IDF (Multi)  7.500000e-01      False  [0.25, 0.75]        0.444098
# 20  TF-IDF (Multi)  2.500000e-01       True  [0.25, 0.75]        0.477970
# 21  TF-IDF (Multi)  2.500000e-01      False  [0.25, 0.75]        0.477970
# 38  TF-IDF (Multi)  1.000000e+00       True  [0.25, 0.75]        0.445284
# 39  TF-IDF (Multi)  1.000000e+00      False  [0.25, 0.75]        0.445284
# 14  TF-IDF (Multi)  1.000000e-01       True  [0.25, 0.75]        0.516919
# 15  TF-IDF (Multi)  1.000000e-01      False  [0.25, 0.75]        0.516919
# 8   TF-IDF (Multi)  1.000000e-02       True  [0.25, 0.75]        0.571688
# 9   TF-IDF (Multi)  1.000000e-02      False  [0.25, 0.75]        0.571688
# 2   TF-IDF (Multi)  1.000000e-10       True  [0.25, 0.75]        0.593787
# 3   TF-IDF (Multi)  1.000000e-10      False  [0.25, 0.75]        0.593787
# 23  TF-IDF (Multi)  2.500000e-01      False    [0.5, 0.5]        0.773512
# 19  TF-IDF (Multi)  2.500000e-01      False          None        0.773512
# 22  TF-IDF (Multi)  2.500000e-01       True    [0.5, 0.5]        0.773512
# 13  TF-IDF (Multi)  1.000000e-01      False          None        0.774454
# 16  TF-IDF (Multi)  1.000000e-01       True    [0.5, 0.5]        0.774454
# 17  TF-IDF (Multi)  1.000000e-01      False    [0.5, 0.5]        0.774454
# 29  TF-IDF (Multi)  5.000000e-01      False    [0.5, 0.5]        0.778396
# 28  TF-IDF (Multi)  5.000000e-01       True    [0.5, 0.5]        0.778396
# 25  TF-IDF (Multi)  5.000000e-01      False          None        0.778396
# 35  TF-IDF (Multi)  7.500000e-01      False    [0.5, 0.5]        0.785164
# 34  TF-IDF (Multi)  7.500000e-01       True    [0.5, 0.5]        0.785164
# 31  TF-IDF (Multi)  7.500000e-01      False          None        0.785164
# 11  TF-IDF (Multi)  1.000000e-02      False    [0.5, 0.5]        0.780594
# 7   TF-IDF (Multi)  1.000000e-02      False          None        0.780594
# 10  TF-IDF (Multi)  1.000000e-02       True    [0.5, 0.5]        0.780594
# 40  TF-IDF (Multi)  1.000000e+00       True    [0.5, 0.5]        0.791914
# 37  TF-IDF (Multi)  1.000000e+00      False          None        0.791914
# 41  TF-IDF (Multi)  1.000000e+00      False    [0.5, 0.5]        0.791914
# 1   TF-IDF (Multi)  1.000000e-10      False          None        0.783629
# 5   TF-IDF (Multi)  1.000000e-10      False    [0.5, 0.5]        0.783629
# 4   TF-IDF (Multi)  1.000000e-10       True    [0.5, 0.5]        0.783629
# 0   TF-IDF (Multi)  1.000000e-10       True          None        0.867526
# 6   TF-IDF (Multi)  1.000000e-02       True          None        0.866846
# 12  TF-IDF (Multi)  1.000000e-01       True          None        0.863706
# 18  TF-IDF (Multi)  2.500000e-01       True          None        0.859921
# 24  TF-IDF (Multi)  5.000000e-01       True          None        0.853328
# 30  TF-IDF (Multi)  7.500000e-01       True          None        0.848322
# 36  TF-IDF (Multi)  1.000000e+00       True          None        0.843961
#
#     train_recall  train_precision  train_f1  test_accuracy  test_recall  \
# 27      0.987994         0.245336  0.393066       0.424792     0.977360
# 26      0.987994         0.245336  0.393066       0.424792     0.977360
# 32      0.983830         0.242709  0.389363       0.418566     0.975549
# 33      0.983830         0.242709  0.389363       0.418566     0.975549
# 20      0.990608         0.255373  0.406065       0.447949     0.970342
# 21      0.990608         0.255373  0.406065       0.447949     0.970342
# 38      0.980345         0.242660  0.389027       0.419624     0.969210
# 39      0.980345         0.242660  0.389027       0.419624     0.969210
# 14      0.991867         0.270604  0.425203       0.481564     0.947023
# 15      0.991867         0.270604  0.425203       0.481564     0.947023
# 8       0.992060         0.295104  0.454893       0.533371     0.877066
# 9       0.992060         0.295104  0.454893       0.533371     0.877066
# 2       0.991673         0.306234  0.467960       0.545051     0.786280
# 3       0.991673         0.306234  0.467960       0.545051     0.786280
# 23      0.865511         0.435306  0.579270       0.722692     0.759565
# 19      0.865511         0.435306  0.579270       0.722692     0.759565
# 22      0.865511         0.435306  0.579270       0.722692     0.759565
# 13      0.879454         0.437334  0.584172       0.725623     0.750509
# 16      0.879454         0.437334  0.584172       0.725623     0.750509
# 17      0.879454         0.437334  0.584172       0.725623     0.750509
# 29      0.834334         0.439396  0.575637       0.728309     0.747113
# 28      0.834334         0.439396  0.575637       0.728309     0.747113
# 25      0.834334         0.439396  0.575637       0.728309     0.747113
# 35      0.801123         0.446351  0.573289       0.735878     0.717908
# 34      0.801123         0.446351  0.573289       0.735878     0.717908
# 31      0.801123         0.446351  0.573289       0.735878     0.717908
# 11      0.886232         0.445250  0.592715       0.726884     0.700249
# 7       0.886232         0.445250  0.592715       0.726884     0.700249
# 10      0.886232         0.445250  0.592715       0.726884     0.700249
# 40      0.762006         0.453812  0.568847       0.745116     0.683496
# 37      0.762006         0.453812  0.568847       0.745116     0.683496
# 41      0.762006         0.453812  0.568847       0.745116     0.683496
# 1       0.886909         0.449086  0.596257       0.725094     0.673308
# 5       0.886909         0.449086  0.596257       0.725094     0.673308
# 4       0.886909         0.449086  0.596257       0.725094     0.673308
# 0       0.331526         0.832078  0.474140       0.832574     0.203532
# 6       0.327653         0.830633  0.469935       0.833469     0.202626
# 12      0.306061         0.830095  0.447227       0.835382     0.196513
# 18      0.274787         0.839893  0.414095       0.836196     0.182024
# 24      0.224923         0.851852  0.355879       0.834527     0.149649
# 30      0.186774         0.866577  0.307312       0.833103     0.124293
# 36      0.155403         0.878009  0.264067       0.831719     0.101426
#
#     test_precision   test_f1  test_recall_1
# 27        0.235246  0.379216       0.977360
# 26        0.235246  0.379216       0.977360
# 32        0.233070  0.376250       0.975549
# 33        0.233070  0.376250       0.975549
# 20        0.241874  0.387225       0.970342
# 21        0.241874  0.387225       0.970342
# 38        0.232587  0.375148       0.969210
# 39        0.232587  0.375148       0.969210
# 14        0.250659  0.396399       0.947023
# 15        0.250659  0.396399       0.947023
# 8         0.261810  0.403248       0.877066
# 9         0.261810  0.403248       0.877066
# 2         0.253356  0.383228       0.786280
# 3         0.253356  0.383228       0.786280
# 23        0.368398  0.496155       0.759565
# 19        0.368398  0.496155       0.759565
# 22        0.368398  0.496155       0.759565
# 13        0.370184  0.495812       0.750509
# 16        0.370184  0.495812       0.750509
# 17        0.370184  0.495812       0.750509
# 29        0.372503  0.497138       0.747113
# 28        0.372503  0.497138       0.747113
# 25        0.372503  0.497138       0.747113
# 35        0.376827  0.494233       0.717908
# 34        0.376827  0.494233       0.717908
# 31        0.376827  0.494233       0.717908
# 11        0.364741  0.479646       0.700249
# 7         0.364741  0.479646       0.700249
# 10        0.364741  0.479646       0.700249
# 40        0.382927  0.490854       0.683496
# 37        0.382927  0.490854       0.683496
# 41        0.382927  0.490854       0.683496
# 1         0.358919  0.468236       0.673308
# 5         0.358919  0.468236       0.673308
# 4         0.358919  0.468236       0.673308
# 0         0.601338  0.304127       0.203532
# 6         0.610922  0.304318       0.202626
# 12        0.636364  0.300294       0.196513
# 18        0.661184  0.285461       0.182024
# 24        0.680742  0.245360       0.149649
# 30        0.702046  0.211194       0.124293
# 36        0.729642  0.178096       0.101426

# %% [markdown]
# ## Complement NB

# %%
clf_tfidf_comp = ComplementNB()
clf_tfidf_comp.fit(X_train_tfidf,y_train_tfidf)
y_pred_tfidf_comp = clf_tfidf_comp.predict(X_test_tfidf)

# %%
evaluate(y_test_tfidf, y_pred_tfidf_comp)
# Out:
# Accuracy: 0.7451163926420316
# F1 Score: 0.4908544020811316
# Recall: 0.6834955852388499
# Precision: 0.38292744799594114
#
#
# Confusion Matrix
#        0     1
# 0  15290  4865
# 1   1398  3019
#
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.92      0.76      0.83     20155
#            1       0.38      0.68      0.49      4417
#
#     accuracy                           0.75     24572
#    macro avg       0.65      0.72      0.66     24572
# weighted avg       0.82      0.75      0.77     24572

# %%
# Model speichern
#with open('saved_models/tfidf_comp/model_nb_tfidf_comp.pkl','wb') as f:
 #   pickle.dump(clf_tfidf_comp,f)
joblib.dump(clf_tfidf, 'saved_models/tfidf_comp/model_tfidf_comp.joblib')
# Out:
# ['saved_models/tfidf_comp/model_tfidf_comp.joblib']

# %%
results_list = []

param_grid = {
    'alpha' : [1.0e-10, 0.01, 0.1, 0.25, 0.5, 0.75, 1],
    'norm' : [True, False]
}

cnb = ComplementNB()

grid_search = GridSearchCV(estimator=cnb, param_grid=param_grid, scoring='f1', cv=3, verbose=2, n_jobs=-1)

grid_search.fit(X_train_tfidf, y_train_tfidf)

for idx, params in enumerate(grid_search.cv_results_['params']):
    model = ComplementNB(**params)  
    model.fit(X_train_tfidf, y_train_tfidf)  

    y_train_pred_tfidf = model.predict(X_train_tfidf)

    y_test_pred_tfidf = model.predict(X_test_tfidf)

    train_accuracy = accuracy_score(y_train_tfidf, y_train_pred_tfidf)
    train_recall = recall_score(y_train_tfidf, y_train_pred_tfidf)
    train_precision = precision_score(y_train_tfidf, y_train_pred_tfidf)
    train_f1 = f1_score(y_train_tfidf, y_train_pred_tfidf)

    test_accuracy = accuracy_score(y_test_tfidf, y_test_pred_tfidf)
    test_recall = recall_score(y_test_tfidf, y_test_pred_tfidf)
    test_precision = precision_score(y_test_tfidf, y_test_pred_tfidf)
    test_f1 = f1_score(y_test_tfidf, y_test_pred_tfidf)

    test_report = classification_report(y_test_tfidf, y_test_pred_tfidf, output_dict=True)

    result_dict = {
        'model': 'TF-IDF (Comp)',
        'alpha': params['alpha'],
        'norm': params['norm'],
        'train_accuracy': train_accuracy,
        'train_recall': train_recall,
        'train_precision': train_precision,
        'train_f1': train_f1,
        'test_accuracy': test_accuracy,
        'test_recall': test_recall,
        'test_precision': test_precision,
        'test_f1': test_f1,
        'test_recall_1': test_report['1']['recall'],
    }

    results_list.append(result_dict)

    filename = f'saved_models/tfidf_comp/model_nb_tfidf_comp_{idx}.joblib'
    #with open(filename,'wb') as file:
     #   pickle.dump(model,file)
    joblib.dump(model, filename)

results_df_comp = pd.DataFrame(results_list)

results_df_comp.to_csv('eval_data/cnb_grid_tfidf_mixed_dataset.csv', index=False)

print(results_df_comp)
# Out:
# Fitting 3 folds for each of 14 candidates, totalling 42 fits
#             model         alpha   norm  train_accuracy  train_recall  \
# 0   TF-IDF (Comp)  1.000000e-10   True        0.305693      1.000000
# 1   TF-IDF (Comp)  1.000000e-10  False        0.783629      0.886909
# 2   TF-IDF (Comp)  1.000000e-02   True        0.440173      0.998354
# 3   TF-IDF (Comp)  1.000000e-02  False        0.780594      0.886232
# 4   TF-IDF (Comp)  1.000000e-01   True        0.645434      0.963981
# 5   TF-IDF (Comp)  1.000000e-01  False        0.774454      0.879454
# 6   TF-IDF (Comp)  2.500000e-01   True        0.775082      0.864349
# 7   TF-IDF (Comp)  2.500000e-01  False        0.773512      0.865511
# 8   TF-IDF (Comp)  5.000000e-01   True        0.842095      0.684353
# 9   TF-IDF (Comp)  5.000000e-01  False        0.778396      0.834334
# 10  TF-IDF (Comp)  7.500000e-01   True        0.855909      0.545217
# 11  TF-IDF (Comp)  7.500000e-01  False        0.785164      0.801123
# 12  TF-IDF (Comp)  1.000000e+00   True        0.859189      0.457397
# 13  TF-IDF (Comp)  1.000000e+00  False        0.791914      0.762006
#
#     train_precision  train_f1  test_accuracy  test_recall  test_precision  \
# 0          0.206008  0.341636       0.296435     0.966493        0.199402
# 1          0.449086  0.596257       0.725094     0.673308        0.358919
# 2          0.243241  0.391176       0.415717     0.957211        0.229833
# 3          0.445250  0.592715       0.726884     0.700249        0.364741
# 4          0.332843  0.494831       0.597143     0.887254        0.294219
# 5          0.437334  0.584172       0.725623     0.750509        0.370184
# 6          0.437148  0.580637       0.724483     0.757528        0.369928
# 7          0.435306  0.579270       0.722692     0.759565        0.368398
# 8          0.549568  0.609599       0.796191     0.575957        0.447966
# 9          0.439396  0.575637       0.728309     0.747113        0.372503
# 10         0.612398  0.576858       0.818452     0.457550        0.494616
# 11         0.446351  0.573289       0.735878     0.717908        0.376827
# 12         0.656750  0.539239       0.826428     0.376726        0.523929
# 13         0.453812  0.568847       0.745116     0.683496        0.382927
#
#      test_f1  test_recall_1
# 0   0.330597       0.966493
# 1   0.468236       0.673308
# 2   0.370666       0.957211
# 3   0.479646       0.700249
# 4   0.441901       0.887254
# 5   0.495812       0.750509
# 6   0.497103       0.757528
# 7   0.496155       0.759565
# 8   0.503962       0.575957
# 9   0.497138       0.747113
# 10  0.475362       0.457550
# 11  0.494233       0.717908
# 12  0.438298       0.376726
# 13  0.490854       0.683496

# %%
results_df_comp.sort_values(by=['test_f1'],ascending=False)
# Out:
#             model         alpha   norm  train_accuracy  train_recall  \
# 8   TF-IDF (Comp)  5.000000e-01   True        0.842095      0.684353
# 9   TF-IDF (Comp)  5.000000e-01  False        0.778396      0.834334
# 6   TF-IDF (Comp)  2.500000e-01   True        0.775082      0.864349
# 7   TF-IDF (Comp)  2.500000e-01  False        0.773512      0.865511
# 5   TF-IDF (Comp)  1.000000e-01  False        0.774454      0.879454
# 11  TF-IDF (Comp)  7.500000e-01  False        0.785164      0.801123
# 13  TF-IDF (Comp)  1.000000e+00  False        0.791914      0.762006
# 3   TF-IDF (Comp)  1.000000e-02  False        0.780594      0.886232
# 10  TF-IDF (Comp)  7.500000e-01   True        0.855909      0.545217
# 1   TF-IDF (Comp)  1.000000e-10  False        0.783629      0.886909
# 4   TF-IDF (Comp)  1.000000e-01   True        0.645434      0.963981
# 12  TF-IDF (Comp)  1.000000e+00   True        0.859189      0.457397
# 2   TF-IDF (Comp)  1.000000e-02   True        0.440173      0.998354
# 0   TF-IDF (Comp)  1.000000e-10   True        0.305693      1.000000
#
#     train_precision  train_f1  test_accuracy  test_recall  test_precision  \
# 8          0.549568  0.609599       0.796191     0.575957        0.447966
# 9          0.439396  0.575637       0.728309     0.747113        0.372503
# 6          0.437148  0.580637       0.724483     0.757528        0.369928
# 7          0.435306  0.579270       0.722692     0.759565        0.368398
# 5          0.437334  0.584172       0.725623     0.750509        0.370184
# 11         0.446351  0.573289       0.735878     0.717908        0.376827
# 13         0.453812  0.568847       0.745116     0.683496        0.382927
# 3          0.445250  0.592715       0.726884     0.700249        0.364741
# 10         0.612398  0.576858       0.818452     0.457550        0.494616
# 1          0.449086  0.596257       0.725094     0.673308        0.358919
# 4          0.332843  0.494831       0.597143     0.887254        0.294219
# 12         0.656750  0.539239       0.826428     0.376726        0.523929
# 2          0.243241  0.391176       0.415717     0.957211        0.229833
# 0          0.206008  0.341636       0.296435     0.966493        0.199402
#
#      test_f1  test_recall_1
# 8   0.503962       0.575957
# 9   0.497138       0.747113
# 6   0.497103       0.757528
# 7   0.496155       0.759565
# 5   0.495812       0.750509
# 11  0.494233       0.717908
# 13  0.490854       0.683496
# 3   0.479646       0.700249
# 10  0.475362       0.457550
# 1   0.468236       0.673308
# 4   0.441901       0.887254
# 12  0.438298       0.376726
# 2   0.370666       0.957211
# 0   0.330597       0.966493

# %%
results_df_comp.sort_values(by=['test_recall_1'],ascending=False)
# Out:
#             model         alpha   norm  train_accuracy  train_recall  \
# 0   TF-IDF (Comp)  1.000000e-10   True        0.305693      1.000000
# 2   TF-IDF (Comp)  1.000000e-02   True        0.440173      0.998354
# 4   TF-IDF (Comp)  1.000000e-01   True        0.645434      0.963981
# 7   TF-IDF (Comp)  2.500000e-01  False        0.773512      0.865511
# 6   TF-IDF (Comp)  2.500000e-01   True        0.775082      0.864349
# 5   TF-IDF (Comp)  1.000000e-01  False        0.774454      0.879454
# 9   TF-IDF (Comp)  5.000000e-01  False        0.778396      0.834334
# 11  TF-IDF (Comp)  7.500000e-01  False        0.785164      0.801123
# 3   TF-IDF (Comp)  1.000000e-02  False        0.780594      0.886232
# 13  TF-IDF (Comp)  1.000000e+00  False        0.791914      0.762006
# 1   TF-IDF (Comp)  1.000000e-10  False        0.783629      0.886909
# 8   TF-IDF (Comp)  5.000000e-01   True        0.842095      0.684353
# 10  TF-IDF (Comp)  7.500000e-01   True        0.855909      0.545217
# 12  TF-IDF (Comp)  1.000000e+00   True        0.859189      0.457397
#
#     train_precision  train_f1  test_accuracy  test_recall  test_precision  \
# 0          0.206008  0.341636       0.296435     0.966493        0.199402
# 2          0.243241  0.391176       0.415717     0.957211        0.229833
# 4          0.332843  0.494831       0.597143     0.887254        0.294219
# 7          0.435306  0.579270       0.722692     0.759565        0.368398
# 6          0.437148  0.580637       0.724483     0.757528        0.369928
# 5          0.437334  0.584172       0.725623     0.750509        0.370184
# 9          0.439396  0.575637       0.728309     0.747113        0.372503
# 11         0.446351  0.573289       0.735878     0.717908        0.376827
# 3          0.445250  0.592715       0.726884     0.700249        0.364741
# 13         0.453812  0.568847       0.745116     0.683496        0.382927
# 1          0.449086  0.596257       0.725094     0.673308        0.358919
# 8          0.549568  0.609599       0.796191     0.575957        0.447966
# 10         0.612398  0.576858       0.818452     0.457550        0.494616
# 12         0.656750  0.539239       0.826428     0.376726        0.523929
#
#      test_f1  test_recall_1
# 0   0.330597       0.966493
# 2   0.370666       0.957211
# 4   0.441901       0.887254
# 7   0.496155       0.759565
# 6   0.497103       0.757528
# 5   0.495812       0.750509
# 9   0.497138       0.747113
# 11  0.494233       0.717908
# 3   0.479646       0.700249
# 13  0.490854       0.683496
# 1   0.468236       0.673308
# 8   0.503962       0.575957
# 10  0.475362       0.457550
# 12  0.438298       0.376726

# %% [markdown]
# ## Test Dataset

# %%
filepath_name_test = (('../../../data/mixed_dataset/test_cleaned.csv'))
df_test = pd.read_csv(filepath_name_test, encoding ='utf-8')

# %%
df_test = df_test[df_test['tweet_cleaned'].notna()]

# %%
#with open('saved_models/vectorizer/vectorizer_nb_tfidf.pkl','rb') as f:
 #   vectorizer_tfidf_saved = pickle.load(f)
vec_tfidf_save = joblib.load('saved_models/vectorizer/vectorizer_tfidf.joblib')

# %%
x_test = vec_tfidf_save.transform(df_test['tweet_cleaned'])

# %%
print(x_test.shape)
# Out:
# (32466, 13198)

# %%
y_test = df_test['label']

# %%
y_test
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 32577    0
# 32578    0
# 32579    0
# 32580    0
# 32581    1
# Name: label, Length: 32466, dtype: int64

# %% [markdown]
# # Test bestes F1-Model

# %%
# import Comp Model 8 
#with open('saved_models/tfidf_comp/model_nb_tfidf_comp_8.pkl','rb') as f:
 #   clf_comp_8 = pickle.load(f)
clf_comp_8 = joblib.load('saved_models/tfidf_comp/model_nb_tfidf_comp_8.joblib')

# %%
y_pred = clf_comp_8.predict(x_test)

# %%
evaluate(y_test, y_pred)
# Out:
# Accuracy: 0.7743793507053532
# F1 Score: 0.514932785908218
# Recall: 0.5685041672759176
# Precision: 0.47058823529411764
#
#
# Confusion Matrix
#        0     1
# 0  21253  4374
# 1   2951  3888
#
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.88      0.83      0.85     25627
#            1       0.47      0.57      0.51      6839
#
#     accuracy                           0.77     32466
#    macro avg       0.67      0.70      0.68     32466
# weighted avg       0.79      0.77      0.78     32466

# %%
# Save Confusionmatrix
confusion_matrix_df = pd.DataFrame(confusion_matrix(y_test, y_pred))

# %%
confusion_matrix_df
# Out:
#        0     1
# 0  21253  4374
# 1   2951  3888

# %%
confusion_matrix_df.to_csv("eval_data/nb_comp_tfidf_confusion_matrix.csv", index=True)

# %%
# Save Classificationreport
classification_report_df = pd.DataFrame(classification_report(y_test, y_pred, output_dict=True)).transpose()

# %%
classification_report_df
# Out:
#               precision    recall  f1-score       support
# 0              0.878078  0.829321  0.853003  25627.000000
# 1              0.470588  0.568504  0.514933   6839.000000
# accuracy       0.774379  0.774379  0.774379      0.774379
# macro avg      0.674333  0.698912  0.683968  32466.000000
# weighted avg   0.792240  0.774379  0.781788  32466.000000

# %%
classification_report_df.to_csv("eval_data/nb_comp_tfidf_classification_report.csv", index=True)

# %% [markdown]
# # Test bestes Recall(1)-Model

# %%
clf_comp_0 = joblib.load('saved_models/tfidf_comp/model_nb_tfidf_comp_0.joblib')

# %%
y_pred_rec = clf_comp_0.predict(x_test)

# %%
evaluate(y_test, y_pred_rec)
# Out:
# Accuracy: 0.2587630136142426
# F1 Score: 0.35920649713753156
# Recall: 0.9862553004825266
# Precision: 0.21959239484307852
#
#
# Confusion Matrix
#       0      1
# 0  1656  23971
# 1    94   6745
#
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.95      0.06      0.12     25627
#            1       0.22      0.99      0.36      6839
#
#     accuracy                           0.26     32466
#    macro avg       0.58      0.53      0.24     32466
# weighted avg       0.79      0.26      0.17     32466

# %%
# Save Confusionmatrix
confusion_matrix_df_rec = pd.DataFrame(confusion_matrix(y_test, y_pred))

# %%
confusion_matrix_df_rec
# Out:
#        0     1
# 0  21253  4374
# 1   2951  3888

# %%
confusion_matrix_df_rec.to_csv("eval_data/nb_comp_tfidf_rec_confusion_matrix.csv", index=True)

# %%
# Save Classificationreport
classification_report_df_rec = pd.DataFrame(classification_report(y_test, y_pred_rec, output_dict=True)).transpose()

# %%
classification_report_df_rec
# Out:
#               precision    recall  f1-score       support
# 0              0.946286  0.064619  0.120977  25627.000000
# 1              0.219592  0.986255  0.359206   6839.000000
# accuracy       0.258763  0.258763  0.258763      0.258763
# macro avg      0.582939  0.525437  0.240092  32466.000000
# weighted avg   0.793207  0.258763  0.171161  32466.000000

# %%
classification_report_df_rec.to_csv("eval_data/nb_comp_tfidf_rec_classification_report.csv", index=True)
