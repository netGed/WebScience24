# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
tfidf = pd.read_csv('./eval_data/nb_mn_tfidf_mixed_dataset.csv')#, index_col=0)
tfidf_cnb = pd.read_csv('./eval_data/nb_comp_tfidf_mixed_dataset.csv')#, index_col=0)
w2v = pd.read_csv('./eval_data/nb_w2v_mixed_dataset.csv')#, index_col=0)
w2v_param = pd.read_csv('./eval_data/nb_w2v_param_mixed_dataset.csv')#, index_col=0)
glv = pd.read_csv('./eval_data/nb_glv_mixed_dataset.csv')#, index_col=0)

# %%
evaluation = pd.concat([tfidf,
                        tfidf_cnb,
                        w2v,
                        w2v_param,
                        glv,
                        ])

# %%
evaluation
# Out:
#              model         alpha fit_prior   class_prior  train_f1  \
# 0   TF-IDF (Multi)  1.000000e-10      True           NaN  0.474140
# 1   TF-IDF (Multi)  1.000000e-10     False           NaN  0.596257
# 2   TF-IDF (Multi)  1.000000e-10      True    [0.1, 0.9]  0.424579
# 3   TF-IDF (Multi)  1.000000e-10     False    [0.1, 0.9]  0.424579
# 4   TF-IDF (Multi)  1.000000e-10      True  [0.25, 0.75]  0.467960
# ..             ...           ...       ...           ...       ...
# 61           Glove           NaN       NaN           NaN  0.329260
# 62           Glove           NaN       NaN           NaN  0.257854
# 63           Glove           NaN       NaN           NaN  0.188518
# 64           Glove           NaN       NaN           NaN  0.090829
# 65           Glove           NaN       NaN           NaN  0.038346
#
#     train_recall  train_precision  train_accuracy  train_mcc   test_f1  ...  \
# 0       0.331526         0.832078        0.867526   0.471721  0.304127  ...
# 1       0.886909         0.449086        0.783629   0.520049  0.468236  ...
# 2       0.999516         0.269537        0.511948   0.329964  0.353547  ...
# 3       0.999516         0.269537        0.511948   0.329964  0.353547  ...
# 4       0.991673         0.306234        0.593787   0.388229  0.383228  ...
# ..           ...              ...             ...        ...       ...  ...
# 61      0.267428         0.428283        0.803722   0.229868  0.322912  ...
# 62      0.179609         0.456897        0.813751   0.198805  0.250000  ...
# 63      0.117157         0.482264        0.818304   0.168178  0.180197  ...
# 64      0.049768         0.519192        0.820519   0.116946  0.093369  ...
# 65      0.019849         0.563187        0.820659   0.079672  0.038033  ...
#
#     test_precision  test_accuracy  test_mcc  norm      priors var_smoothing  \
# 0         0.601338       0.832574  0.279445   NaN         NaN           NaN
# 1         0.358919       0.725094  0.332809   NaN         NaN           NaN
# 2         0.226925       0.474198  0.161536   NaN         NaN           NaN
# 3         0.226925       0.474198  0.161536   NaN         NaN           NaN
# 4         0.253356       0.545051  0.215301   NaN         NaN           NaN
# ..             ...            ...       ...   ...         ...           ...
# 61        0.417986       0.801685  0.221591   NaN  [0.9, 0.1]           0.4
# 62        0.443228       0.812225  0.189124   NaN  [0.9, 0.1]           0.5
# 63        0.459610       0.816702  0.156040   NaN  [0.9, 0.1]           0.6
# 64        0.533019       0.821382  0.121906   NaN  [0.9, 0.1]           0.8
# 65        0.550633       0.820894  0.077700   NaN  [0.9, 0.1]           1.0
#
#     vectorizer  model_nr  vector_size  window
# 0          NaN       NaN          NaN     NaN
# 1          NaN       NaN          NaN     NaN
# 2          NaN       NaN          NaN     NaN
# 3          NaN       NaN          NaN     NaN
# 4          NaN       NaN          NaN     NaN
# ..         ...       ...          ...     ...
# 61         NaN       NaN          NaN     NaN
# 62         NaN       NaN          NaN     NaN
# 63         NaN       NaN          NaN     NaN
# 64         NaN       NaN          NaN     NaN
# 65         NaN       NaN          NaN     NaN
#
# [2186 rows x 21 columns]

# %%
evaluation.sort_values(by=["test_recall"], ascending=False)
# Out:
#          model  alpha fit_prior class_prior  train_f1  train_recall  \
# 548  W2V Param    NaN       NaN         NaN  0.305969      1.000000
# 417  W2V Param    NaN       NaN         NaN  0.306460      1.000000
# 219  W2V Param    NaN       NaN         NaN  0.306555      1.000000
# 218  W2V Param    NaN       NaN         NaN  0.308303      1.000000
# 153  W2V Param    NaN       NaN         NaN  0.307358      1.000000
# ..         ...    ...       ...         ...       ...           ...
# 193  W2V Param    NaN       NaN         NaN  0.000967      0.000484
# 262  W2V Param    NaN       NaN         NaN  0.000580      0.000290
# 10   W2V Param    NaN       NaN         NaN  0.000000      0.000000
# 329  W2V Param    NaN       NaN         NaN  0.000000      0.000000
# 263  W2V Param    NaN       NaN         NaN  0.000194      0.000097
#
#      train_precision  train_accuracy  train_mcc   test_f1  ...  \
# 548         0.180616        0.182760   0.024008  0.305326  ...
# 417         0.180958        0.184644   0.031516  0.305855  ...
# 219         0.181025        0.185010   0.032780  0.306130  ...
# 218         0.182245        0.191673   0.050625  0.307848  ...
# 153         0.181585        0.188080   0.041925  0.306843  ...
# ..               ...             ...        ...       ...  ...
# 193         0.625000        0.819891   0.013675  0.000000  ...
# 262         0.230769        0.819734   0.001984  0.000000  ...
# 10          0.000000        0.819856   0.000000  0.000000  ...
# 329         0.000000        0.819839  -0.001958  0.000000  ...
# 263         0.166667        0.819787  -0.000359  0.000000  ...
#
#      test_precision  test_accuracy  test_mcc  norm      priors var_smoothing  \
# 548        0.180168       0.182036  0.022374   NaN  [0.1, 0.9]           0.8
# 417        0.180536       0.184071  0.030814   NaN  [0.1, 0.9]           1.0
# 219        0.180728       0.185129  0.034404   NaN  [0.1, 0.9]           1.0
# 218        0.181927       0.191682  0.051427   NaN  [0.1, 0.9]           0.8
# 153        0.181225       0.187856  0.042300   NaN  [0.1, 0.9]           1.0
# ..              ...            ...       ...   ...         ...           ...
# 193        0.000000       0.820202 -0.002986   NaN  [0.9, 0.1]           0.4
# 262        0.000000       0.819917 -0.008448   NaN  [0.9, 0.1]           0.8
# 10         0.000000       0.820202 -0.002986   NaN         NaN           1.0
# 329        0.000000       0.820202 -0.002986   NaN  [0.9, 0.1]           1.0
# 263        0.000000       0.820120 -0.005173   NaN  [0.9, 0.1]           1.0
#
#      vectorizer  model_nr  vector_size  window
# 548         8.0      20.0         10.0    30.0
# 417         6.0      21.0         10.0     5.0
# 219         3.0      21.0          5.0    30.0
# 218         3.0      20.0          5.0    30.0
# 153         2.0      21.0          5.0    10.0
# ..          ...       ...          ...     ...
# 193         2.0      61.0          5.0    10.0
# 262         3.0      64.0          5.0    30.0
# 10          0.0      10.0          5.0     3.0
# 329         4.0      65.0         10.0     1.0
# 263         3.0      65.0          5.0    30.0
#
# [2186 rows x 21 columns]

# %%
evaluation.sort_values(by=["test_precision"], ascending=False)
# Out:
#               model  alpha fit_prior class_prior  train_f1  train_recall  \
# 592       W2V Param    NaN       NaN         NaN  0.000194      0.000097
# 119  TF-IDF (Multi)    1.0     False  [0.9, 0.1]  0.089803      0.047153
# 118  TF-IDF (Multi)    1.0      True  [0.9, 0.1]  0.089803      0.047153
# 107  TF-IDF (Multi)    0.8     False  [0.9, 0.1]  0.109754      0.058288
# 106  TF-IDF (Multi)    0.8      True  [0.9, 0.1]  0.109754      0.058288
# ..              ...    ...       ...         ...       ...           ...
# 131       W2V Param    NaN       NaN         NaN  0.000000      0.000000
# 130       W2V Param    NaN       NaN         NaN  0.000000      0.000000
# 129       W2V Param    NaN       NaN         NaN  0.000000      0.000000
# 61        W2V Param    NaN       NaN         NaN  0.000194      0.000097
# 193       W2V Param    NaN       NaN         NaN  0.000967      0.000484
#
#      train_precision  train_accuracy  train_mcc   test_f1  ...  \
# 592         0.333333        0.819839   0.002884  0.000905  ...
# 119         0.940154        0.827810   0.188833  0.055629  ...
# 118         0.940154        0.827810   0.188833  0.055629  ...
# 107         0.937695        0.829659   0.209772  0.070716  ...
# 106         0.937695        0.829659   0.209772  0.070716  ...
# ..               ...             ...        ...       ...  ...
# 131         0.000000        0.819856   0.000000  0.000000  ...
# 130         0.000000        0.819856   0.000000  0.000000  ...
# 129         0.000000        0.819856   0.000000  0.000000  ...
# 61          0.333333        0.819839   0.002884  0.000000  ...
# 193         0.625000        0.819891   0.013675  0.000000  ...
#
#      test_precision  test_accuracy  test_mcc  norm      priors var_smoothing  \
# 592        1.000000       0.820324  0.019273   NaN  [0.9, 0.1]           0.8
# 119        0.852349       0.824516  0.136814   NaN         NaN           NaN
# 118        0.852349       0.824516  0.136814   NaN         NaN           NaN
# 107        0.844560       0.825655  0.154045   NaN         NaN           NaN
# 106        0.844560       0.825655  0.154045   NaN         NaN           NaN
# ..              ...            ...       ...   ...         ...           ...
# 131        0.000000       0.820243  0.000000   NaN  [0.9, 0.1]           1.0
# 130        0.000000       0.820243  0.000000   NaN  [0.9, 0.1]           0.8
# 129        0.000000       0.820243  0.000000   NaN  [0.9, 0.1]           0.6
# 61         0.000000       0.820120 -0.005173   NaN  [0.9, 0.1]           0.4
# 193        0.000000       0.820202 -0.002986   NaN  [0.9, 0.1]           0.4
#
#      vectorizer  model_nr  vector_size  window
# 592         8.0      64.0         10.0    30.0
# 119         NaN       NaN          NaN     NaN
# 118         NaN       NaN          NaN     NaN
# 107         NaN       NaN          NaN     NaN
# 106         NaN       NaN          NaN     NaN
# ..          ...       ...          ...     ...
# 131         1.0      65.0          5.0     5.0
# 130         1.0      64.0          5.0     5.0
# 129         1.0      63.0          5.0     5.0
# 61          0.0      61.0          5.0     3.0
# 193         2.0      61.0          5.0    10.0
#
# [2186 rows x 21 columns]

# %%
evaluation.sort_values(by=["test_f1"], ascending=False)
# Out:
#               model  alpha fit_prior class_prior  train_f1  train_recall  \
# 10    TF-IDF (Comp)    0.4       NaN         NaN  0.610112      0.754163
# 12    TF-IDF (Comp)    0.5       NaN         NaN  0.609599      0.684353
# 61   TF-IDF (Multi)    0.4     False         NaN  0.577609      0.849245
# 66   TF-IDF (Multi)    0.4      True  [0.5, 0.5]  0.577609      0.849245
# 67   TF-IDF (Multi)    0.4     False  [0.5, 0.5]  0.577609      0.849245
# ..              ...    ...       ...         ...       ...           ...
# 395       W2V Param    NaN       NaN         NaN  0.000000      0.000000
# 394       W2V Param    NaN       NaN         NaN  0.000000      0.000000
# 263       W2V Param    NaN       NaN         NaN  0.000194      0.000097
# 10        W2V Param    NaN       NaN         NaN  0.000000      0.000000
# 262       W2V Param    NaN       NaN         NaN  0.000580      0.000290
#
#      train_precision  train_accuracy  train_mcc   test_f1  ...  \
# 10          0.512266        0.826362   0.519197  0.507594  ...
# 12          0.549568        0.842095   0.516948  0.503962  ...
# 61          0.437631        0.776251   0.491192  0.498135  ...
# 66          0.437631        0.776251   0.491192  0.498135  ...
# 67          0.437631        0.776251   0.491192  0.498135  ...
# ..               ...             ...        ...       ...  ...
# 395         0.000000        0.819856   0.000000  0.000000  ...
# 394         0.000000        0.819856   0.000000  0.000000  ...
# 263         0.166667        0.819787  -0.000359  0.000000  ...
# 10          0.000000        0.819856   0.000000  0.000000  ...
# 262         0.230769        0.819734   0.001984  0.000000  ...
#
#      test_precision  test_accuracy  test_mcc  norm      priors var_smoothing  \
# 10         0.420864       0.777023  0.384850  True         NaN           NaN
# 12         0.447966       0.796191  0.382952  True         NaN           NaN
# 61         0.371454       0.726192  0.379166   NaN         NaN           NaN
# 66         0.371454       0.726192  0.379166   NaN         NaN           NaN
# 67         0.371454       0.726192  0.379166   NaN         NaN           NaN
# ..              ...            ...       ...   ...         ...           ...
# 395        0.000000       0.820243  0.000000   NaN  [0.9, 0.1]           1.0
# 394        0.000000       0.820243  0.000000   NaN  [0.9, 0.1]           0.8
# 263        0.000000       0.820120 -0.005173   NaN  [0.9, 0.1]           1.0
# 10         0.000000       0.820202 -0.002986   NaN         NaN           1.0
# 262        0.000000       0.819917 -0.008448   NaN  [0.9, 0.1]           0.8
#
#      vectorizer  model_nr  vector_size  window
# 10          NaN       NaN          NaN     NaN
# 12          NaN       NaN          NaN     NaN
# 61          NaN       NaN          NaN     NaN
# 66          NaN       NaN          NaN     NaN
# 67          NaN       NaN          NaN     NaN
# ..          ...       ...          ...     ...
# 395         5.0      65.0         10.0     3.0
# 394         5.0      64.0         10.0     3.0
# 263         3.0      65.0          5.0    30.0
# 10          0.0      10.0          5.0     3.0
# 262         3.0      64.0          5.0    30.0
#
# [2186 rows x 21 columns]

# %% [markdown]
# ### Visualisierung F1-Score

# %%
fig, ax = plt.subplots(figsize=(20, 7))
plt.xticks(rotation=30)
sns.barplot(data=evaluation, y=evaluation.test_f1, x=evaluation.model, label="Test F1-Score")
# Out:
# <Axes: xlabel='model', ylabel='test_f1'>

# %% [markdown]
# Topwerte ähnlich zu erstem Datensatz, W2V und Glove deutlich besser

# %% [markdown]
# ### Unterschiede/Schwankungen zw. Train <-> Test F1-Scores

# %%
fig, ax = plt.subplots(figsize=(20, 7))
plt.xticks(rotation=30)

diff = evaluation['train_f1'] - evaluation['test_f1']
sns.scatterplot(data=evaluation, y=evaluation['train_f1'], x=evaluation.model, ax=ax, label="Train F1-Score")
sns.scatterplot(data=evaluation, y=evaluation['test_f1'], x=evaluation.model, ax=ax, label="Test F1-Score")
sns.lineplot(data=evaluation, y=diff, x=evaluation.model, label="Differenz Train-Test")

plt.show()

# %% [markdown]
# ### Vergleich Accuracy - F1-Score

# %%
fig, ax = plt.subplots(figsize=(20, 7))
plt.xticks(rotation=30)
sns.barplot(data=evaluation, y=evaluation.test_f1, x=evaluation.model, label="F1-Score")
sns.lineplot(data=evaluation, y=evaluation.test_accuracy, x=evaluation.model, label="Accuracy")
# Out:
# <Axes: xlabel='model', ylabel='test_f1'>

# %% [markdown]
# Accuracy schlechter als im ersten Datensatz

# %% [markdown]
# ### Vergleich Precision - Recall

# %%
fig, ax = plt.subplots(figsize=(20, 7))
plt.xticks(rotation=30)
a = sns.lineplot(data=evaluation, y=evaluation.test_precision, x=evaluation.model, label="Precision")
b = sns.lineplot(data=evaluation, y=evaluation.test_recall, x=evaluation.model, label="Recall")

# %% [markdown]
# Recall hier stärker Modell abhängig, bei W2V ähnlich bei W2V Param deutlich schlechter

# %% [markdown]
# #### Auswertung

# %% [markdown]
# ### Analyse W2V Parameter

# %%
w2v_param.sort_values(by=["test_recall"], ascending=False)
# Out:
#          model  vectorizer  model_nr  vector_size  window      priors  \
# 482  W2V Param           7        20           10      10  [0.1, 0.9]
# 351  W2V Param           5        21           10       3  [0.1, 0.9]
# 219  W2V Param           3        21            5      30  [0.1, 0.9]
# 548  W2V Param           8        20           10      30  [0.1, 0.9]
# 549  W2V Param           8        21           10      30  [0.1, 0.9]
# ..         ...         ...       ...          ...     ...         ...
# 394  W2V Param           5        64           10       3  [0.9, 0.1]
# 65   W2V Param           0        65            5       3  [0.9, 0.1]
# 64   W2V Param           0        64            5       3  [0.9, 0.1]
# 63   W2V Param           0        63            5       3  [0.9, 0.1]
# 263  W2V Param           3        65            5      30  [0.9, 0.1]
#
#      var_smoothing  train_f1  train_recall  train_precision  train_accuracy  \
# 482            0.8  0.308868      0.999903         0.182643        0.193888
# 351            1.0  0.306142      1.000000         0.180736        0.183423
# 219            1.0  0.306555      1.000000         0.181025        0.185010
# 548            0.8  0.305969      1.000000         0.180616        0.182760
# 549            1.0  0.305512      1.000000         0.180298        0.180998
# ..             ...       ...           ...              ...             ...
# 394            0.8  0.000000      0.000000         0.000000        0.819856
# 65             1.0  0.000000      0.000000         0.000000        0.819856
# 64             0.8  0.000000      0.000000         0.000000        0.819856
# 63             0.6  0.000000      0.000000         0.000000        0.819856
# 263            1.0  0.000194      0.000097         0.166667        0.819787
#
#      train_mcc   test_f1  test_recall  test_precision  test_accuracy  test_mcc
# 482   0.055018  0.308159          1.0        0.182144       0.192862  0.053944
# 351   0.026887  0.305580          1.0        0.180345       0.183013  0.026755
# 219   0.032780  0.306130          1.0        0.180728       0.185129  0.034404
# 548   0.024008  0.305326          1.0        0.180168       0.182036  0.022374
# 549   0.013710  0.304905          1.0        0.179875       0.180409  0.011950
# ..         ...       ...          ...             ...            ...       ...
# 394   0.000000  0.000000          0.0        0.000000       0.820243  0.000000
# 65    0.000000  0.000000          0.0        0.000000       0.820243  0.000000
# 64    0.000000  0.000000          0.0        0.000000       0.820243  0.000000
# 63    0.000000  0.000000          0.0        0.000000       0.820243  0.000000
# 263  -0.000359  0.000000          0.0        0.000000       0.820120 -0.005173
#
# [1914 rows x 17 columns]

# %%
w2v_param.sort_values(by=["test_f1"], ascending=False)
# Out:
#           model  vectorizer  model_nr  vector_size  window      priors  \
# 1520  W2V Param          23         2          200      30         NaN
# 1519  W2V Param          23         1          200      30         NaN
# 1518  W2V Param          23         0          200      30         NaN
# 1575  W2V Param          23        57          200      30  [0.9, 0.1]
# 1521  W2V Param          23         3          200      30         NaN
# ...         ...         ...       ...          ...     ...         ...
# 61    W2V Param           0        61            5       3  [0.9, 0.1]
# 262   W2V Param           3        64            5      30  [0.9, 0.1]
# 263   W2V Param           3        65            5      30  [0.9, 0.1]
# 394   W2V Param           5        64           10       3  [0.9, 0.1]
# 129   W2V Param           1        63            5       5  [0.9, 0.1]
#
#       var_smoothing  train_f1  train_recall  train_precision  train_accuracy  \
# 1520   1.000000e-02  0.452793      0.666344         0.342900        0.709865
# 1519   1.000000e-09  0.452799      0.662955         0.343811        0.711348
# 1518   1.000000e-10  0.452799      0.662955         0.343811        0.711348
# 1575   1.000000e-02  0.453875      0.619771         0.358038        0.731319
# 1521   5.000000e-02  0.451293      0.674187         0.339162        0.704668
# ...             ...       ...           ...              ...             ...
# 61     4.000000e-01  0.000194      0.000097         0.333333        0.819839
# 262    8.000000e-01  0.000580      0.000290         0.230769        0.819734
# 263    1.000000e+00  0.000194      0.000097         0.166667        0.819787
# 394    8.000000e-01  0.000000      0.000000         0.000000        0.819856
# 129    6.000000e-01  0.000000      0.000000         0.000000        0.819856
#
#       train_mcc   test_f1  test_recall  test_precision  test_accuracy  \
# 1520   0.310813  0.449742     0.670591        0.338321       0.705030
# 1519   0.310699  0.449527     0.667421        0.338890       0.706170
# 1518   0.310699  0.449527     0.667421        0.338890       0.706170
# 1575   0.311600  0.449123     0.620557        0.351907       0.726355
# 1521   0.309049  0.448472     0.677836        0.335087       0.700309
# ...         ...       ...          ...             ...            ...
# 61     0.002884  0.000000     0.000000        0.000000       0.820120
# 262    0.001984  0.000000     0.000000        0.000000       0.819917
# 263   -0.000359  0.000000     0.000000        0.000000       0.820120
# 394    0.000000  0.000000     0.000000        0.000000       0.820243
# 129    0.000000  0.000000     0.000000        0.000000       0.820243
#
#       test_mcc
# 1520  0.307224
# 1519  0.306795
# 1518  0.306795
# 1575  0.305419
# 1521  0.305780
# ...        ...
# 61   -0.005173
# 262  -0.008448
# 263  -0.005173
# 394   0.000000
# 129   0.000000
#
# [1914 rows x 17 columns]

# %%
w2v_param.sort_values(by=["test_precision"], ascending=False)
# Out:
#          model  vectorizer  model_nr  vector_size  window      priors  \
# 592  W2V Param           8        64           10      30  [0.9, 0.1]
# 523  W2V Param           7        61           10      10  [0.9, 0.1]
# 388  W2V Param           5        58           10       3  [0.9, 0.1]
# 389  W2V Param           5        59           10       3  [0.9, 0.1]
# 387  W2V Param           5        57           10       3  [0.9, 0.1]
# ..         ...         ...       ...          ...     ...         ...
# 197  W2V Param           2        65            5      10  [0.9, 0.1]
# 196  W2V Param           2        64            5      10  [0.9, 0.1]
# 195  W2V Param           2        63            5      10  [0.9, 0.1]
# 194  W2V Param           2        62            5      10  [0.9, 0.1]
# 10   W2V Param           0        10            5       3         NaN
#
#      var_smoothing  train_f1  train_recall  train_precision  train_accuracy  \
# 592           0.80  0.000194      0.000097         0.333333        0.819839
# 523           0.40  0.016795      0.008521         0.582781        0.820292
# 388           0.05  0.075812      0.040666         0.558511        0.821391
# 389           0.10  0.057011      0.030015         0.566728        0.821130
# 387           0.01  0.092545      0.050542         0.547744        0.821444
# ..             ...       ...           ...              ...             ...
# 197           1.00  0.000000      0.000000         0.000000        0.819856
# 196           0.80  0.000000      0.000000         0.000000        0.819856
# 195           0.60  0.000194      0.000097         0.500000        0.819856
# 194           0.50  0.000194      0.000097         0.333333        0.819839
# 10            1.00  0.000000      0.000000         0.000000        0.819856
#
#      train_mcc   test_f1  test_recall  test_precision  test_accuracy  test_mcc
# 592   0.002884  0.000905     0.000453        1.000000       0.820324  0.019273
# 523   0.053839  0.016529     0.008377        0.616667       0.820812  0.056294
# 388   0.113504  0.075143     0.040072        0.602041       0.822684  0.121020
# 389   0.098728  0.057352     0.030111        0.601810       0.822074  0.104710
# 387   0.124361  0.095833     0.052072        0.600522       0.823376  0.137884
# ..         ...       ...          ...             ...            ...       ...
# 197   0.000000  0.000000     0.000000        0.000000       0.820243  0.000000
# 196   0.000000  0.000000     0.000000        0.000000       0.820243  0.000000
# 195   0.004916  0.000000     0.000000        0.000000       0.820243  0.000000
# 194   0.002884  0.000000     0.000000        0.000000       0.820243  0.000000
# 10    0.000000  0.000000     0.000000        0.000000       0.820202 -0.002986
#
# [1914 rows x 17 columns]

# %% [markdown]
# #### Auswertung

# %% [markdown]
# Bezogen auf NB(!):
# - Precision besser
# - F1 ähnlich
# - Recall schlechter
# (Vergleich ersten Datensatz)
