# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
tfidf = pd.read_csv('./eval_data/nb_grid_tfidf_new_dataset.csv')#, index_col=0)
tfidf_cnb = pd.read_csv('./eval_data/cnb_grid_tfidf_new_dataset.csv')#, index_col=0)
w2v = pd.read_csv('./eval_data/nb_grid_w2v_new_dataset.csv')#, index_col=0)
w2v_param = pd.read_csv('./eval_data/nb_grid_w2v_parameters_new_dataset.csv')#, index_col=0)
glv = pd.read_csv('./eval_data/nb_grid_glv_new_dataset.csv')#, index_col=0)

# %%
evaluation = pd.concat([tfidf,
                        tfidf_cnb,
                        w2v,
                        w2v_param,
                        glv,
                        ], ignore_index=True)

# %%
evaluation
# Out:
#               model         alpha fit_prior   class_prior  train_accuracy  \
# 0    TF-IDF (Multi)  1.000000e-10      True           NaN        0.842044
# 1    TF-IDF (Multi)  1.000000e-10     False           NaN        0.788824
# 2    TF-IDF (Multi)  1.000000e-10      True  [0.25, 0.75]        0.551902
# 3    TF-IDF (Multi)  1.000000e-10     False  [0.25, 0.75]        0.551902
# 4    TF-IDF (Multi)  1.000000e-10      True    [0.5, 0.5]        0.788824
# ..              ...           ...       ...           ...             ...
# 198           Glove           NaN       NaN           NaN        0.490403
# 199           Glove           NaN       NaN           NaN        0.425150
# 200           Glove           NaN       NaN           NaN        0.391171
# 201           Glove           NaN       NaN           NaN        0.379067
# 202           Glove           NaN       NaN           NaN        0.372583
#
#      train_recall  train_precision  train_f1  test_accuracy  test_recall  \
# 0        0.317944         0.851560  0.463014       0.804984     0.203623
# 1        0.852896         0.504151  0.633712       0.710306     0.620056
# 2        0.991398         0.322415  0.486586       0.488573     0.780301
# 3        0.991398         0.322415  0.486586       0.488573     0.780301
# 4        0.852896         0.504151  0.633712       0.710306     0.620056
# ..            ...              ...       ...            ...          ...
# 198      0.866616         0.278433  0.421457       0.487159     0.871651
# 199      0.910279         0.259748  0.404167       0.423931     0.915540
# 200      0.929551         0.251118  0.395415       0.391174     0.932636
# 201      0.934778         0.248043  0.392054       0.378768     0.938505
# 202      0.937500         0.246429  0.390273       0.372511     0.942332
#
#      test_precision   test_f1 norm      priors  var_smoothing  vector_size  \
# 0          0.632831  0.308108  NaN         NaN            NaN          NaN
# 1          0.387869  0.477219  NaN         NaN            NaN          NaN
# 2          0.263712  0.394199  NaN         NaN            NaN          NaN
# 3          0.263712  0.394199  NaN         NaN            NaN          NaN
# 4          0.387869  0.477219  NaN         NaN            NaN          NaN
# ..              ...       ...  ...         ...            ...          ...
# 198        0.276868  0.420250  NaN  [0.5, 0.5]           0.10          NaN
# 199        0.259174  0.403986  NaN  [0.5, 0.5]           0.25          NaN
# 200        0.250686  0.395156  NaN  [0.5, 0.5]           0.50          NaN
# 201        0.247610  0.391839  NaN  [0.5, 0.5]           0.75          NaN
# 202        0.246216  0.390422  NaN  [0.5, 0.5]           1.00          NaN
#
#      window  min_count
# 0       NaN        NaN
# 1       NaN        NaN
# 2       NaN        NaN
# 3       NaN        NaN
# 4       NaN        NaN
# ..      ...        ...
# 198     NaN        NaN
# 199     NaN        NaN
# 200     NaN        NaN
# 201     NaN        NaN
# 202     NaN        NaN
#
# [203 rows x 18 columns]

# %%
evaluation.sort_values(by=["test_recall"], ascending=False)
# Out:
#               model  alpha fit_prior   class_prior  train_accuracy  \
# 194           Glove    NaN       NaN           NaN        0.215327
# 193           Glove    NaN       NaN           NaN        0.217332
# 192           Glove    NaN       NaN           NaN        0.225588
# 191           Glove    NaN       NaN           NaN        0.262693
# 33   TF-IDF (Multi)   0.75     False  [0.25, 0.75]        0.391590
# ..              ...    ...       ...           ...             ...
# 85        W2V Param    NaN       NaN           NaN        0.787518
# 82        W2V Param    NaN       NaN           NaN        0.786562
# 86        W2V Param    NaN       NaN           NaN        0.786072
# 81        W2V Param    NaN       NaN           NaN        0.788125
# 186           Glove    NaN       NaN           NaN        0.787915
#
#      train_recall  train_precision  train_f1  test_accuracy  test_recall  \
# 194      0.999456         0.214362  0.353011       0.214115     1.000000
# 193      0.999020         0.214740  0.353496       0.216400     0.999490
# 192      0.997387         0.216334  0.355549       0.224943     0.998469
# 191      0.986389         0.223409  0.364305       0.262325     0.990814
# 33       0.989220         0.259024  0.410547       0.363750     0.975504
# ..            ...              ...       ...            ...          ...
# 85       0.108014         0.519100  0.178819       0.789585     0.111763
# 82       0.098323         0.509019  0.164811       0.788007     0.106660
# 86       0.098541         0.503057  0.164800       0.787137     0.100791
# 81       0.080793         0.535740  0.140411       0.788824     0.081909
# 186      0.079377         0.532895  0.138173       0.787899     0.076550
#
#      test_precision   test_f1 norm        priors  var_smoothing  vector_size  \
# 194        0.213430  0.351780  NaN  [0.25, 0.75]           1.00          NaN
# 193        0.213857  0.352327  NaN  [0.25, 0.75]           0.75          NaN
# 192        0.215580  0.354599  NaN  [0.25, 0.75]           0.50          NaN
# 191        0.223110  0.364208  NaN  [0.25, 0.75]           0.25          NaN
# 33         0.247925  0.395367  NaN           NaN            NaN          NaN
# ..              ...       ...  ...           ...            ...          ...
# 85         0.531553  0.184693  NaN           NaN            NaN         10.0
# 82         0.514145  0.176669  NaN           NaN            NaN         10.0
# 86         0.504470  0.168014  NaN           NaN            NaN         10.0
# 81         0.531457  0.141941  NaN           NaN            NaN         10.0
# 186        0.518135  0.133393  NaN           NaN           1.00          NaN
#
#      window  min_count
# 194     NaN        NaN
# 193     NaN        NaN
# 192     NaN        NaN
# 191     NaN        NaN
# 33      NaN        NaN
# ..      ...        ...
# 85      5.0        5.0
# 82      3.0       10.0
# 86      5.0       10.0
# 81      3.0        5.0
# 186     NaN        NaN
#
# [203 rows x 18 columns]

# %%
evaluation.sort_values(by=["test_precision"], ascending=False)
# Out:
#               model         alpha fit_prior class_prior  train_accuracy  \
# 36   TF-IDF (Multi)  1.000000e+00      True         NaN        0.813079
# 30   TF-IDF (Multi)  7.500000e-01      True         NaN        0.818303
# 24   TF-IDF (Multi)  5.000000e-01      True         NaN        0.824460
# 18   TF-IDF (Multi)  2.500000e-01      True         NaN        0.832785
# 12   TF-IDF (Multi)  1.000000e-01      True         NaN        0.837963
# ..              ...           ...       ...         ...             ...
# 42    TF-IDF (Comp)  1.000000e-10       NaN         NaN        0.320507
# 191           Glove           NaN       NaN         NaN        0.262693
# 192           Glove           NaN       NaN         NaN        0.225588
# 193           Glove           NaN       NaN         NaN        0.217332
# 194           Glove           NaN       NaN         NaN        0.215327
#
#      train_recall  train_precision  train_f1  test_accuracy  test_recall  \
# 36       0.145797         0.887343  0.250444       0.803896     0.113549
# 30       0.176503         0.876690  0.293846       0.805420     0.131156
# 24       0.212979         0.867406  0.341988       0.807759     0.156928
# 18       0.261760         0.860415  0.401403       0.809120     0.182955
# 12       0.292683         0.856051  0.436222       0.808031     0.196734
# ..            ...              ...       ...            ...          ...
# 42       0.999891         0.239652  0.386636       0.298781     0.948201
# 191      0.986389         0.223409  0.364305       0.262325     0.990814
# 192      0.997387         0.216334  0.355549       0.224943     0.998469
# 193      0.999020         0.214740  0.353496       0.216400     0.999490
# 194      0.999456         0.214362  0.353011       0.214115     1.000000
#
#      test_precision   test_f1  norm        priors  var_smoothing  vector_size  \
# 36         0.773913  0.198042   NaN           NaN            NaN          NaN
# 30         0.750365  0.223284   NaN           NaN            NaN          NaN
# 24         0.728673  0.258241   NaN           NaN            NaN          NaN
# 18         0.700880  0.290166   NaN           NaN            NaN          NaN
# 12         0.669852  0.304142   NaN           NaN            NaN          NaN
# ..              ...       ...   ...           ...            ...          ...
# 42         0.226585  0.365766  True           NaN            NaN          NaN
# 191        0.223110  0.364208   NaN  [0.25, 0.75]           0.25          NaN
# 192        0.215580  0.354599   NaN  [0.25, 0.75]           0.50          NaN
# 193        0.213857  0.352327   NaN  [0.25, 0.75]           0.75          NaN
# 194        0.213430  0.351780   NaN  [0.25, 0.75]           1.00          NaN
#
#      window  min_count
# 36      NaN        NaN
# 30      NaN        NaN
# 24      NaN        NaN
# 18      NaN        NaN
# 12      NaN        NaN
# ..      ...        ...
# 42      NaN        NaN
# 191     NaN        NaN
# 192     NaN        NaN
# 193     NaN        NaN
# 194     NaN        NaN
#
# [203 rows x 18 columns]

# %%
evaluation.sort_values(by=["test_f1"], ascending=False)
# Out:
#               model  alpha fit_prior class_prior  train_accuracy  \
# 22   TF-IDF (Multi)   0.25      True  [0.5, 0.5]        0.785256
# 23   TF-IDF (Multi)   0.25     False  [0.5, 0.5]        0.785256
# 49    TF-IDF (Comp)   0.25       NaN         NaN        0.785256
# 19   TF-IDF (Multi)   0.25     False         NaN        0.785256
# 48    TF-IDF (Comp)   0.25       NaN         NaN        0.778213
# ..              ...    ...       ...         ...             ...
# 85        W2V Param    NaN       NaN         NaN        0.787518
# 82        W2V Param    NaN       NaN         NaN        0.786562
# 86        W2V Param    NaN       NaN         NaN        0.786072
# 81        W2V Param    NaN       NaN         NaN        0.788125
# 186           Glove    NaN       NaN         NaN        0.787915
#
#      train_recall  train_precision  train_f1  test_accuracy  test_recall  \
# 22       0.826546         0.499211  0.622468       0.716400     0.687675
# 23       0.826546         0.499211  0.622468       0.716400     0.687675
# 49       0.826546         0.499211  0.622468       0.716400     0.687675
# 19       0.826546         0.499211  0.622468       0.716400     0.687675
# 48       0.840592         0.489661  0.618838       0.708891     0.703241
# ..            ...              ...       ...            ...          ...
# 85       0.108014         0.519100  0.178819       0.789585     0.111763
# 82       0.098323         0.509019  0.164811       0.788007     0.106660
# 86       0.098541         0.503057  0.164800       0.787137     0.100791
# 81       0.080793         0.535740  0.140411       0.788824     0.081909
# 186      0.079377         0.532895  0.138173       0.787899     0.076550
#
#      test_precision   test_f1   norm priors  var_smoothing  vector_size  \
# 22         0.403262  0.508395    NaN    NaN            NaN          NaN
# 23         0.403262  0.508395    NaN    NaN            NaN          NaN
# 49         0.403262  0.508395  False    NaN            NaN          NaN
# 19         0.403262  0.508395    NaN    NaN            NaN          NaN
# 48         0.396947  0.507457   True    NaN            NaN          NaN
# ..              ...       ...    ...    ...            ...          ...
# 85         0.531553  0.184693    NaN    NaN            NaN         10.0
# 82         0.514145  0.176669    NaN    NaN            NaN         10.0
# 86         0.504470  0.168014    NaN    NaN            NaN         10.0
# 81         0.531457  0.141941    NaN    NaN            NaN         10.0
# 186        0.518135  0.133393    NaN    NaN            1.0          NaN
#
#      window  min_count
# 22      NaN        NaN
# 23      NaN        NaN
# 49      NaN        NaN
# 19      NaN        NaN
# 48      NaN        NaN
# ..      ...        ...
# 85      5.0        5.0
# 82      3.0       10.0
# 86      5.0       10.0
# 81      3.0        5.0
# 186     NaN        NaN
#
# [203 rows x 18 columns]

# %% [markdown]
# ### Visualisierung F1-Score

# %%
fig, ax = plt.subplots(figsize=(20, 7))
plt.xticks(rotation=30)
sns.barplot(data=evaluation, y=evaluation.test_f1, x=evaluation.model, label="Test F1-Score")
# Out:
# <Axes: xlabel='model', ylabel='test_f1'>

# %% [markdown]
# F1 besser als beim ersten Datensatz. Speziell bei W2V. TF-IDF aber immer noch am besten

# %% [markdown]
# ### Unterschiede/Schwankungen zw. Train <-> Test F1-Scores

# %%
fig, ax = plt.subplots(figsize=(20, 7))
plt.xticks(rotation=30)

diff = evaluation['train_f1'] - evaluation['test_f1']
sns.scatterplot(data=evaluation, y=evaluation['train_f1'], x=evaluation.model, ax=ax, label="Train F1-Score")
sns.scatterplot(data=evaluation, y=evaluation['test_f1'], x=evaluation.model, ax=ax, label="Test F1-Score")
sns.lineplot(data=evaluation, y=diff, x=evaluation.model, label="Differenz Train-Test")

plt.show()

# %% [markdown]
# ### Vergleich Accuracy - F1-Score

# %%
fig, ax = plt.subplots(figsize=(20, 7))
plt.xticks(rotation=30)
sns.barplot(data=evaluation, y=evaluation.test_f1, x=evaluation.model, label="F1-Score")
sns.lineplot(data=evaluation, y=evaluation.test_accuracy, x=evaluation.model, label="Accuracy")
# Out:
# <Axes: xlabel='model', ylabel='test_f1'>

# %% [markdown]
# Accuracy schlechter als beim ersten Datensatz

# %% [markdown]
# ### Vergleich Precision - Recall

# %%
fig, ax = plt.subplots(figsize=(20, 7))
plt.xticks(rotation=30)
a = sns.lineplot(data=evaluation, y=evaluation.test_precision, x=evaluation.model, label="Precision")
b = sns.lineplot(data=evaluation, y=evaluation.test_recall, x=evaluation.model, label="Recall")

# %% [markdown]
# Precision ähnlich wie beim ersten Datensatz um 0,4. Recall allerdings deutlich schlechter (z.T. 0,9 vs 0,65)

# %% [markdown]
# #### Auswertung

# %% [markdown]
# ### Analyse W2V Parameter

# %%
w2v_param.sort_values(by=["test_recall"], ascending=False)
# Out:
#         model  vector_size  window  min_count  train_accuracy  train_recall  \
# 82  W2V Param          300       3         10        0.720423      0.618467
# 86  W2V Param          300       5         10        0.719956      0.621516
# 90  W2V Param          300      10         10        0.714289      0.607252
# 81  W2V Param          300       3          5        0.726836      0.602352
# 98  W2V Param          300      35         10        0.702139      0.591355
# ..        ...          ...     ...        ...             ...           ...
# 18  W2V Param           10      35         10        0.785373      0.117160
# 5   W2V Param           10       5          5        0.787518      0.108014
# 2   W2V Param           10       3         10        0.786562      0.098323
# 6   W2V Param           10       5         10        0.786072      0.098541
# 1   W2V Param           10       3          5        0.788125      0.080793
#
#     train_precision  train_f1  test_accuracy  test_recall  test_precision  \
# 82         0.401017  0.486551       0.713897     0.617760        0.391684
# 86         0.400843  0.487363       0.713026     0.613422        0.390070
# 90         0.392167  0.476565       0.706170     0.596836        0.379769
# 81         0.406974  0.485753       0.721134     0.594539        0.397204
# 98         0.375848  0.459592       0.696866     0.592243        0.368764
# ..              ...       ...            ...          ...             ...
# 18         0.495624  0.189520       0.785069     0.121460        0.484232
# 5          0.519100  0.178819       0.789585     0.111763        0.531553
# 2          0.509019  0.164811       0.788007     0.106660        0.514145
# 6          0.503057  0.164800       0.787137     0.100791        0.504470
# 1          0.535740  0.140411       0.788824     0.081909        0.531457
#
#      test_f1
# 82  0.479406
# 86  0.476890
# 90  0.464179
# 81  0.476239
# 98  0.454519
# ..       ...
# 18  0.194206
# 5   0.184693
# 2   0.176669
# 6   0.168014
# 1   0.141941
#
# [99 rows x 12 columns]

# %%
w2v_param.sort_values(by=["test_f1"], ascending=False)
# Out:
#         model  vector_size  window  min_count  train_accuracy  train_recall  \
# 82  W2V Param          300       3         10        0.720423      0.618467
# 86  W2V Param          300       5         10        0.719956      0.621516
# 81  W2V Param          300       3          5        0.726836      0.602352
# 85  W2V Param          300       5          5        0.727652      0.605727
# 80  W2V Param          300       3          3        0.729728      0.592334
# ..        ...          ...     ...        ...             ...           ...
# 18  W2V Param           10      35         10        0.785373      0.117160
# 5   W2V Param           10       5          5        0.787518      0.108014
# 2   W2V Param           10       3         10        0.786562      0.098323
# 6   W2V Param           10       5         10        0.786072      0.098541
# 1   W2V Param           10       3          5        0.788125      0.080793
#
#     train_precision  train_f1  test_accuracy  test_recall  test_precision  \
# 82         0.401017  0.486551       0.713897     0.617760        0.391684
# 86         0.400843  0.487363       0.713026     0.613422        0.390070
# 81         0.406974  0.485753       0.721134     0.594539        0.397204
# 85         0.408443  0.487897       0.723365     0.588926        0.399239
# 80         0.409484  0.484223       0.726140     0.579995        0.401590
# ..              ...       ...            ...          ...             ...
# 18         0.495624  0.189520       0.785069     0.121460        0.484232
# 5          0.519100  0.178819       0.789585     0.111763        0.531553
# 2          0.509019  0.164811       0.788007     0.106660        0.514145
# 6          0.503057  0.164800       0.787137     0.100791        0.504470
# 1          0.535740  0.140411       0.788824     0.081909        0.531457
#
#      test_f1
# 82  0.479406
# 86  0.476890
# 81  0.476239
# 85  0.475876
# 80  0.474580
# ..       ...
# 18  0.194206
# 5   0.184693
# 2   0.176669
# 6   0.168014
# 1   0.141941
#
# [99 rows x 12 columns]

# %%
w2v_param.sort_values(by=["test_precision"], ascending=False)
# Out:
#         model  vector_size  window  min_count  train_accuracy  train_recall  \
# 5   W2V Param           10       5          5        0.787518      0.108014
# 1   W2V Param           10       3          5        0.788125      0.080793
# 2   W2V Param           10       3         10        0.786562      0.098323
# 14  W2V Param           10      20         10        0.783834      0.116616
# 6   W2V Param           10       5         10        0.786072      0.098541
# ..        ...          ...     ...        ...             ...           ...
# 74  W2V Param          200      20         10        0.718230      0.567182
# 90  W2V Param          300      10         10        0.714289      0.607252
# 78  W2V Param          200      35         10        0.712913      0.564242
# 94  W2V Param          300      20         10        0.705520      0.596472
# 98  W2V Param          300      35         10        0.702139      0.591355
#
#     train_precision  train_f1  test_accuracy  test_recall  test_precision  \
# 5          0.519100  0.178819       0.789585     0.111763        0.531553
# 1          0.535740  0.140411       0.788824     0.081909        0.531457
# 2          0.509019  0.164811       0.788007     0.106660        0.514145
# 14         0.480916  0.187714       0.787409     0.123246        0.506289
# 6          0.503057  0.164800       0.787137     0.100791        0.504470
# ..              ...       ...            ...          ...             ...
# 74         0.391184  0.463022       0.713788     0.565450        0.383856
# 90         0.392167  0.476565       0.706170     0.596836        0.379769
# 78         0.384136  0.457087       0.709163     0.565450        0.378286
# 94         0.380443  0.464572       0.699532     0.590712        0.371410
# 98         0.375848  0.459592       0.696866     0.592243        0.368764
#
#      test_f1
# 5   0.184693
# 1   0.141941
# 2   0.176669
# 14  0.198235
# 6   0.168014
# ..       ...
# 74  0.457284
# 90  0.464179
# 78  0.453309
# 94  0.456068
# 98  0.454519
#
# [99 rows x 12 columns]

# %% [markdown]
# #### Auswertung

# %% [markdown]
# Bezogen auf NB(!):
# - Recall schlechter als beim ersten Datensatz
# - F1 ähnlich
# - Precision besser
